# %% [markdown]
# # Convert DICOM to NIFTI

# %%
# import everything you need
from nipype.interfaces.dcm2nii import Dcm2niix
from nipype import Node, Workflow
import os, re

# %%
# define useful functions

# get subject directories from parent directory
def get_subdirs(dir):
    subdirs=[]
    for i in os.listdir(dir):
        # verify subject number in directory and exclude other dirs
        match=re.match(r'(.*\d{3}$)', i)
        if os.path.isdir(os.path.join(dir, i)) and match:
            subdirs.append(os.path.join(dir, match.group(0)))
    return sorted(subdirs)

# %%
# get subject dir-list
subdirs=get_subdirs("/VBM/")
print(subdirs)
# Out:
# ['/VBM/FED006', '/VBM/FED007', '/VBM/FED008', '/VBM/FED009', '/VBM/FED010', '/VBM/FED011', '/VBM/FED012', '/VBM/FED013', '/VBM/FED014', '/VBM/FED015', '/VBM/FED016', '/VBM/FED017', '/VBM/FED018', '/VBM/FED019', '/VBM/FED020', '/VBM/FED021', '/VBM/FED022', '/VBM/FED023', '/VBM/FED024', '/VBM/FED025', '/VBM/FED026', '/VBM/FED027', '/VBM/FED028', '/VBM/FED029', '/VBM/FED030', '/VBM/FED031', '/VBM/FED032', '/VBM/FED033', '/VBM/FED034', '/VBM/FED035', '/VBM/FED036', '/VBM/FED037', '/VBM/FED038', '/VBM/FED039', '/VBM/FED040', '/VBM/FED041', '/VBM/FED042', '/VBM/FED043', '/VBM/FED044', '/VBM/FED045', '/VBM/FED046', '/VBM/FED047', '/VBM/FED048', '/VBM/FED049', '/VBM/FED050', '/VBM/FED051', '/VBM/FED052', '/VBM/FED053', '/VBM/FED054', '/VBM/FED055', '/VBM/FED056', '/VBM/FED057', '/VBM/FED058', '/VBM/FED059', '/VBM/FED060', '/VBM/FED061', '/VBM/FED062', '/VBM/FED063', '/VBM/FED064', '/VBM/FED065', '/VBM/FED066', '/VBM/FED067', '/VBM/FED068']

# %%
# get T1-MPRAGE source list via subject lists
sequencedirs=[]
for i in subdirs:
    for j in os.listdir(i):
        if os.path.isdir(os.path.join(i, j)) and j.endswith("05") or j.endswith("09"):
            sequencedirs.append(os.path.join(i, j))
            
# sort the list entries
sequencedirs=sorted(sequencedirs)

# %%
print(sequencedirs)
# Out:
# ['/VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED009/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED010/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED011/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED012/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED013/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED014/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED015/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED016/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED017/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED018/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED019/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED020/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED021/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED022/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED023/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED024/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED025/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED026/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED027/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED028/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED029/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED030/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED031/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED032/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED033/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED034/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED035/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED036/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED037/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED038/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED039/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED040/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED041/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED042/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED043/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED044/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED045/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED046/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED047/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED048/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009', '/VBM/FED050/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED051/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED052/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED053/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED054/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED055/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED056/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED057/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED058/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED059/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED060/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED061/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED062/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED063/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED064/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED065/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED066/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED067/T1_MPRAGE_SAG_ISO_0_9_0005', '/VBM/FED068/T1_MPRAGE_SAG_ISO_0_9_0005']

# %%
# use sequence-list as source_dir and save output of converter in parent dir

# iterate over sequence and subject dirs, create nodes and run them to create NIFTI files
for i,j in zip(sequencedirs, subdirs):
    print(i,j)
    # create DICOM-to-NIFTI converter node
    converter=Node(Dcm2niix(), name='converter')
    converter.inputs.compress='n' # do not compress -> SPM options etc.
    converter.inputs.source_dir=i
    converter.inputs.output_dir=j
    converter.run()
# Out:
# /VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED006
# 200124-14:57:22,611 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpftq714kb/converter".
# 200124-14:57:22,616 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED006 -s n -v n /VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:23,107 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.107671:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:23,108 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.107671:Found 192 DICOM file(s)
# 200124-14:57:23,109 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.107671:Convert 192 DICOM as /VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141106153429_5 (256x256x192x1)
# 200124-14:57:23,180 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.180411:Conversion required 0.472853 seconds (0.302472 for core code).
# 200124-14:57:23,208 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED007
# 200124-14:57:23,210 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpiuprkruj/converter".
# 200124-14:57:23,215 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED007 -s n -v n /VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:23,683 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.683214:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:23,684 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.683214:Found 192 DICOM file(s)
# 200124-14:57:23,685 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.683214:Convert 192 DICOM as /VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141107104226_5 (256x256x192x1)
# 200124-14:57:23,753 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:23.753810:Conversion required 0.513388 seconds (0.339800 for core code).
# 200124-14:57:23,781 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED008
# 200124-14:57:23,784 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpez25ft48/converter".
# 200124-14:57:23,788 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED008 -s n -v n /VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:24,249 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.249577:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:24,250 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.249577:Found 192 DICOM file(s)
# 200124-14:57:24,251 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.249577:Convert 192 DICOM as /VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141112155009_5 (256x256x192x1)
# 200124-14:57:24,321 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.321055:Conversion required 0.515969 seconds (0.342452 for core code).
# 200124-14:57:24,348 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED009/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED009
# 200124-14:57:24,351 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8l2muki6/converter".
# 200124-14:57:24,355 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED009 -s n -v n /VBM/FED009/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:24,828 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.827975:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:24,829 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.827975:Found 192 DICOM file(s)
# 200124-14:57:24,829 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:24.827975:Convert 192 DICOM as /VBM/FED009/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5 (256x256x192x1)
# 200124-14:57:25,74 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:25.074837:Conversion required 0.700106 seconds (0.521786 for core code).
# 200124-14:57:25,109 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED010/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED010
# 200124-14:57:25,111 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpe14tdmlm/converter".
# 200124-14:57:25,116 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED010 -s n -v n /VBM/FED010/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:25,546 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:25.546357:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:25,547 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:25.546357:Found 192 DICOM file(s)
# 200124-14:57:25,548 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:25.546357:Convert 192 DICOM as /VBM/FED010/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5 (256x256x192x1)
# 200124-14:57:25,616 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:25.616415:Conversion required 0.479746 seconds (0.321672 for core code).
# 200124-14:57:25,644 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED011/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED011
# 200124-14:57:25,645 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpimgrl9e7/converter".
# 200124-14:57:25,650 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED011 -s n -v n /VBM/FED011/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:26,110 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.110428:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:26,111 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.110428:Found 192 DICOM file(s)
# 200124-14:57:26,112 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.110428:Convert 192 DICOM as /VBM/FED011/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5 (256x256x192x1)
# 200124-14:57:26,183 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.183395:Conversion required 0.512772 seconds (0.339087 for core code).
# 200124-14:57:26,211 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED012/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED012
# 200124-14:57:26,212 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpkuh1enzw/converter".
# 200124-14:57:26,217 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED012 -s n -v n /VBM/FED012/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:26,682 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.682244:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:26,683 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.682244:Found 192 DICOM file(s)
# 200124-14:57:26,684 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.682244:Convert 192 DICOM as /VBM/FED012/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5 (256x256x192x1)
# 200124-14:57:26,932 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:26.932435:Conversion required 0.694916 seconds (0.520518 for core code).
# 200124-14:57:26,967 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED013/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED013
# 200124-14:57:26,969 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpe6xtqqds/converter".
# 200124-14:57:26,973 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED013 -s n -v n /VBM/FED013/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:27,473 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.473677:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:27,474 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.473677:Found 192 DICOM file(s)
# 200124-14:57:27,475 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.473677:Convert 192 DICOM as /VBM/FED013/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5 (256x256x192x1)
# 200124-14:57:27,543 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.543341:Conversion required 0.547565 seconds (0.355732 for core code).
# 200124-14:57:27,572 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED014/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED014
# 200124-14:57:27,574 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpvehe_oku/converter".
# 200124-14:57:27,578 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED014 -s n -v n /VBM/FED014/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:27,999 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.999233:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:28,0 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.999233:Found 192 DICOM file(s)
# 200124-14:57:28,1 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:27.999233:Convert 192 DICOM as /VBM/FED014/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5 (256x256x192x1)
# 200124-14:57:28,244 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:28.244308:Conversion required 0.639368 seconds (0.471833 for core code).
# 200124-14:57:28,275 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED015/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED015
# 200124-14:57:28,277 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpdaqms5gz/converter".
# 200124-14:57:28,282 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED015 -s n -v n /VBM/FED015/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:28,959 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:28.959431:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:28,960 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:28.959431:Found 192 DICOM file(s)
# 200124-14:57:28,961 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:28.959431:Convert 192 DICOM as /VBM/FED015/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5 (256x256x192x1)
# 200124-14:57:29,29 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:29.029473:Conversion required 0.723902 seconds (0.320765 for core code).
# 200124-14:57:29,53 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED016/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED016
# 200124-14:57:29,55 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpt_2bkayr/converter".
# 200124-14:57:29,58 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED016 -s n -v n /VBM/FED016/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:29,466 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:29.465936:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:29,467 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:29.465936:Found 192 DICOM file(s)
# 200124-14:57:29,467 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:29.465936:Convert 192 DICOM as /VBM/FED016/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5 (256x256x192x1)
# 200124-14:57:29,713 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:29.713279:Conversion required 0.641776 seconds (0.467790 for core code).
# 200124-14:57:29,744 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED017/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED017
# 200124-14:57:29,747 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpnxbkrbz8/converter".
# 200124-14:57:29,752 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED017 -s n -v n /VBM/FED017/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:30,210 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.210597:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:30,211 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.210597:Found 192 DICOM file(s)
# 200124-14:57:30,212 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.210597:Convert 192 DICOM as /VBM/FED017/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5 (256x256x192x1)
# 200124-14:57:30,280 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.280673:Conversion required 0.510730 seconds (0.331001 for core code).
# 200124-14:57:30,307 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED018/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED018
# 200124-14:57:30,309 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp006ggtg_/converter".
# 200124-14:57:30,312 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED018 -s n -v n /VBM/FED018/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:30,789 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.789825:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:30,791 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.789825:Found 192 DICOM file(s)
# 200124-14:57:30,791 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:30.789825:Convert 192 DICOM as /VBM/FED018/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5 (256x256x192x1)
# 200124-14:57:31,41 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:31.041508:Conversion required 0.701065 seconds (0.513915 for core code).
# 200124-14:57:31,75 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED019/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED019
# 200124-14:57:31,77 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpfsfma6yk/converter".
# 200124-14:57:31,82 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED019 -s n -v n /VBM/FED019/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:31,562 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:31.562146:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:31,566 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:31.562146:Found 192 DICOM file(s)
# 200124-14:57:31,567 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:31.562146:Convert 192 DICOM as /VBM/FED019/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5 (256x256x192x1)
# 200124-14:57:31,838 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:31.838583:Conversion required 0.737329 seconds (0.567022 for core code).
# 200124-14:57:31,875 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED020/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED020
# 200124-14:57:31,877 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpglxm005p/converter".
# 200124-14:57:31,882 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED020 -s n -v n /VBM/FED020/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:32,344 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:32.344056:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:32,345 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:32.344056:Found 192 DICOM file(s)
# 200124-14:57:32,346 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:32.344056:Convert 192 DICOM as /VBM/FED020/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5 (256x256x192x1)
# 200124-14:57:32,594 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:32.594243:Conversion required 0.687458 seconds (0.513953 for core code).
# 200124-14:57:32,632 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED021/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED021
# 200124-14:57:32,635 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp2uiwg7ai/converter".
# 200124-14:57:32,640 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED021 -s n -v n /VBM/FED021/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:33,127 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:33.127507:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:33,129 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:33.127507:Found 192 DICOM file(s)
# 200124-14:57:33,129 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:33.127507:Convert 192 DICOM as /VBM/FED021/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5 (256x256x192x1)
# 200124-14:57:33,220 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:33.220169:Conversion required 0.559488 seconds (0.385312 for core code).
# 200124-14:57:33,250 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED022/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED022
# 200124-14:57:33,252 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpj130z231/converter".
# 200124-14:57:33,255 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED022 -s n -v n /VBM/FED022/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:34,37 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.036986:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:34,38 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.036986:Found 384 DICOM file(s)
# 200124-14:57:34,38 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.036986:192 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 200124-14:57:34,39 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.036986:Convert 192 DICOM as /VBM/FED022/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5 (256x256x192x1)
# 200124-14:57:34,107 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.107315:Conversion required 0.833229 seconds (0.506117 for core code).
# 200124-14:57:34,135 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED023/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED023
# 200124-14:57:34,137 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmps0si0_kw/converter".
# 200124-14:57:34,141 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED023 -s n -v n /VBM/FED023/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:34,687 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.687738:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:34,689 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.687738:Found 192 DICOM file(s)
# 200124-14:57:34,689 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.687738:Convert 192 DICOM as /VBM/FED023/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5 (256x256x192x1)
# 200124-14:57:34,776 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:34.776308:Conversion required 0.617709 seconds (0.438817 for core code).
# 200124-14:57:34,811 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED024/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED024
# 200124-14:57:34,813 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8kasrihw/converter".
# 200124-14:57:34,819 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED024 -s n -v n /VBM/FED024/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:35,367 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.367766:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:35,368 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.367766:Found 192 DICOM file(s)
# 200124-14:57:35,369 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.367766:Convert 192 DICOM as /VBM/FED024/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5 (256x256x192x1)
# 200124-14:57:35,440 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.440831:Conversion required 0.594687 seconds (0.404214 for core code).
# 200124-14:57:35,476 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED025/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED025
# 200124-14:57:35,478 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp2djmji69/converter".
# 200124-14:57:35,483 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED025 -s n -v n /VBM/FED025/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:35,952 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.952580:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:35,954 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.952580:Found 192 DICOM file(s)
# 200124-14:57:35,956 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:35.952580:Convert 192 DICOM as /VBM/FED025/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5 (256x256x192x1)
# 200124-14:57:36,45 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:36.045540:Conversion required 0.540672 seconds (0.379774 for core code).
# 200124-14:57:36,82 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED026/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED026
# 200124-14:57:36,89 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpmuvc83rg/converter".
# 200124-14:57:36,94 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED026 -s n -v n /VBM/FED026/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:36,579 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:36.579124:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:36,580 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:36.579124:Found 192 DICOM file(s)
# 200124-14:57:36,582 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:36.579124:Convert 192 DICOM as /VBM/FED026/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5 (256x256x192x1)
# 200124-14:57:36,674 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:36.674276:Conversion required 0.552916 seconds (0.372370 for core code).
# 200124-14:57:36,711 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED027/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED027
# 200124-14:57:36,714 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpfl11c7lm/converter".
# 200124-14:57:36,719 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED027 -s n -v n /VBM/FED027/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:37,181 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.181494:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:37,183 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.181494:Found 192 DICOM file(s)
# 200124-14:57:37,185 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.181494:Convert 192 DICOM as /VBM/FED027/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150218162601_5 (256x256x192x1)
# 200124-14:57:37,276 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.276194:Conversion required 0.532160 seconds (0.357098 for core code).
# 200124-14:57:37,310 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED028/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED028
# 200124-14:57:37,313 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmprjzeronf/converter".
# 200124-14:57:37,317 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED028 -s n -v n /VBM/FED028/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:37,855 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.855550:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:37,856 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.855550:Found 192 DICOM file(s)
# 200124-14:57:37,857 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.855550:Convert 192 DICOM as /VBM/FED028/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150219142148_5 (256x256x192x1)
# 200124-14:57:37,927 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:37.927225:Conversion required 0.571978 seconds (0.380887 for core code).
# 200124-14:57:37,956 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED029/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED029
# 200124-14:57:37,958 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpdnl0zgdp/converter".
# 200124-14:57:37,961 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED029 -s n -v n /VBM/FED029/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:38,441 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:38.441025:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:38,442 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:38.441025:Found 192 DICOM file(s)
# 200124-14:57:38,443 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:38.441025:Convert 192 DICOM as /VBM/FED029/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150226091949_5 (256x256x192x1)
# 200124-14:57:38,515 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:38.515569:Conversion required 0.536284 seconds (0.338267 for core code).
# 200124-14:57:38,543 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED030/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED030
# 200124-14:57:38,545 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpzfwwjpk_/converter".
# 200124-14:57:38,549 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED030 -s n -v n /VBM/FED030/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:39,40 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.040776:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:39,41 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.040776:Found 192 DICOM file(s)
# 200124-14:57:39,42 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.040776:Convert 192 DICOM as /VBM/FED030/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150226154844_5 (256x256x192x1)
# 200124-14:57:39,112 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.112249:Conversion required 0.541244 seconds (0.359090 for core code).
# 200124-14:57:39,139 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED031/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED031
# 200124-14:57:39,141 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp0m33or0p/converter".
# 200124-14:57:39,145 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED031 -s n -v n /VBM/FED031/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:39,602 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.602872:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:39,604 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.602872:Found 192 DICOM file(s)
# 200124-14:57:39,604 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.602872:Convert 192 DICOM as /VBM/FED031/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150310152650_5 (256x256x192x1)
# 200124-14:57:39,674 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:39.674286:Conversion required 0.504845 seconds (0.329902 for core code).
# 200124-14:57:39,701 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED032/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED032
# 200124-14:57:39,703 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8dht970w/converter".
# 200124-14:57:39,706 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED032 -s n -v n /VBM/FED032/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:40,140 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.140158:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:40,141 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.140158:Found 192 DICOM file(s)
# 200124-14:57:40,142 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.140158:Convert 192 DICOM as /VBM/FED032/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150313125246_5 (256x256x192x1)
# 200124-14:57:40,210 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.210575:Conversion required 0.487371 seconds (0.301975 for core code).
# 200124-14:57:40,238 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED033/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED033
# 200124-14:57:40,240 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpiobdl97c/converter".
# 200124-14:57:40,244 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED033 -s n -v n /VBM/FED033/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:40,695 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.695530:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:40,696 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.695530:Found 192 DICOM file(s)
# 200124-14:57:40,697 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.695530:Convert 192 DICOM as /VBM/FED033/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150326151309_5 (256x256x192x1)
# 200124-14:57:40,767 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:40.767104:Conversion required 0.503393 seconds (0.325072 for core code).
# 200124-14:57:40,793 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED034/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED034
# 200124-14:57:40,795 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmppn_mkjgj/converter".
# 200124-14:57:40,800 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED034 -s n -v n /VBM/FED034/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:41,304 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.304050:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:41,305 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.304050:Found 192 DICOM file(s)
# 200124-14:57:41,306 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.304050:Convert 192 DICOM as /VBM/FED034/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150909125805_5 (256x256x192x1)
# 200124-14:57:41,376 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.376884:Conversion required 0.551008 seconds (0.372198 for core code).
# 200124-14:57:41,404 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED035/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED035
# 200124-14:57:41,405 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpzq6cr7jc/converter".
# 200124-14:57:41,409 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED035 -s n -v n /VBM/FED035/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:41,901 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.901510:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:41,902 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.901510:Found 192 DICOM file(s)
# 200124-14:57:41,903 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.901510:Convert 192 DICOM as /VBM/FED035/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150917120306_5 (256x256x192x1)
# 200124-14:57:41,972 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:41.972376:Conversion required 0.546288 seconds (0.371467 for core code).
# 200124-14:57:41,998 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED036/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED036
# 200124-14:57:42,0 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmphj50twib/converter".
# 200124-14:57:42,4 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED036 -s n -v n /VBM/FED036/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:42,473 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:42.473108:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:42,474 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:42.473108:Found 192 DICOM file(s)
# 200124-14:57:42,475 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:42.473108:Convert 192 DICOM as /VBM/FED036/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150924172133_5 (256x256x192x1)
# 200124-14:57:42,543 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:42.543880:Conversion required 0.521265 seconds (0.345063 for core code).
# 200124-14:57:42,571 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED037/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED037
# 200124-14:57:42,572 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp2on27wva/converter".
# 200124-14:57:42,576 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED037 -s n -v n /VBM/FED037/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:43,57 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.057466:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:43,58 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.057466:Found 192 DICOM file(s)
# 200124-14:57:43,59 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.057466:Convert 192 DICOM as /VBM/FED037/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150929162030_5 (256x256x192x1)
# 200124-14:57:43,135 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.134962:Conversion required 0.539488 seconds (0.355591 for core code).
# 200124-14:57:43,161 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED038/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED038
# 200124-14:57:43,163 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp2c119d_n/converter".
# 200124-14:57:43,168 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED038 -s n -v n /VBM/FED038/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:43,653 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.653035:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:43,654 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.653035:Found 192 DICOM file(s)
# 200124-14:57:43,654 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.653035:Convert 192 DICOM as /VBM/FED038/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151001125857_5 (256x256x192x1)
# 200124-14:57:43,724 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:43.724284:Conversion required 0.534429 seconds (0.348366 for core code).
# 200124-14:57:43,751 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED039/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED039
# 200124-14:57:43,753 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpn0b5rb5g/converter".
# 200124-14:57:43,756 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED039 -s n -v n /VBM/FED039/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:44,250 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.250232:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:44,251 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.250232:Found 192 DICOM file(s)
# 200124-14:57:44,252 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.250232:Convert 192 DICOM as /VBM/FED039/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151001173950_5 (256x256x192x1)
# 200124-14:57:44,447 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.447547:Conversion required 0.671285 seconds (0.478364 for core code).
# 200124-14:57:44,478 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED040/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED040
# 200124-14:57:44,480 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpn3v7a2jz/converter".
# 200124-14:57:44,484 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED040 -s n -v n /VBM/FED040/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:44,981 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.981291:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:44,982 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.981291:Found 192 DICOM file(s)
# 200124-14:57:44,983 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:44.981291:Convert 192 DICOM as /VBM/FED040/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151009111760_5 (256x256x192x1)
# 200124-14:57:45,53 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:45.053419:Conversion required 0.547553 seconds (0.369722 for core code).
# 200124-14:57:45,78 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED041/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED041
# 200124-14:57:45,80 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpr0djh38w/converter".
# 200124-14:57:45,84 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED041 -s n -v n /VBM/FED041/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:45,542 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:45.542448:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:45,543 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:45.542448:Found 192 DICOM file(s)
# 200124-14:57:45,544 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:45.542448:Convert 192 DICOM as /VBM/FED041/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151009164129_5 (256x256x192x1)
# 200124-14:57:45,622 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:45.622942:Conversion required 0.523387 seconds (0.342353 for core code).
# 200124-14:57:45,654 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED042/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED042
# 200124-14:57:45,656 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp1d7myzl_/converter".
# 200124-14:57:45,660 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED042 -s n -v n /VBM/FED042/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:46,154 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.154435:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:46,155 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.154435:Found 192 DICOM file(s)
# 200124-14:57:46,156 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.154435:Convert 192 DICOM as /VBM/FED042/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151013110112_5 (256x256x192x1)
# 200124-14:57:46,225 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.225275:Conversion required 0.542910 seconds (0.364651 for core code).
# 200124-14:57:46,251 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED043/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED043
# 200124-14:57:46,253 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpahjd0mk1/converter".
# 200124-14:57:46,257 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED043 -s n -v n /VBM/FED043/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:46,764 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.764222:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:46,766 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.764222:Found 192 DICOM file(s)
# 200124-14:57:46,767 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.764222:Convert 192 DICOM as /VBM/FED043/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151015122011_5 (256x256x192x1)
# 200124-14:57:46,841 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:46.841871:Conversion required 0.567626 seconds (0.377232 for core code).
# 200124-14:57:46,869 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED044/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED044
# 200124-14:57:46,871 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp_zy_y7xd/converter".
# 200124-14:57:46,874 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED044 -s n -v n /VBM/FED044/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:47,348 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.348759:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:47,350 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.348759:Found 192 DICOM file(s)
# 200124-14:57:47,351 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.348759:Convert 192 DICOM as /VBM/FED044/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151029121235_5 (256x256x192x1)
# 200124-14:57:47,420 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.420717:Conversion required 0.527952 seconds (0.356737 for core code).
# 200124-14:57:47,446 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED045/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED045
# 200124-14:57:47,449 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp9dmukk55/converter".
# 200124-14:57:47,453 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED045 -s n -v n /VBM/FED045/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:47,917 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.917150:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:47,918 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.917150:Found 192 DICOM file(s)
# 200124-14:57:47,919 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.917150:Convert 192 DICOM as /VBM/FED045/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151105173027_5 (256x256x192x1)
# 200124-14:57:47,989 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:47.989271:Conversion required 0.520287 seconds (0.345181 for core code).
# 200124-14:57:48,15 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED046/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED046
# 200124-14:57:48,17 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpl04vijrc/converter".
# 200124-14:57:48,21 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED046 -s n -v n /VBM/FED046/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:48,934 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:48.934601:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:48,935 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:48.934601:Found 384 DICOM file(s)
# 200124-14:57:48,936 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:48.934601:192 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 200124-14:57:48,937 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:48.934601:Convert 192 DICOM as /VBM/FED046/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151106125904_5 (256x256x192x1)
# 200124-14:57:49,7 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:49.007299:Conversion required 0.969885 seconds (0.606015 for core code).
# 200124-14:57:49,34 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED047/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED047
# 200124-14:57:49,36 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpcw7149py/converter".
# 200124-14:57:49,40 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED047 -s n -v n /VBM/FED047/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:49,491 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:49.491591:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:49,493 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:49.491591:Found 192 DICOM file(s)
# 200124-14:57:49,494 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:49.491591:Convert 192 DICOM as /VBM/FED047/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151116144126_5 (256x256x192x1)
# 200124-14:57:49,568 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:49.568306:Conversion required 0.505689 seconds (0.327709 for core code).
# 200124-14:57:49,594 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED048/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED048
# 200124-14:57:49,596 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpb7w7uw7s/converter".
# 200124-14:57:49,600 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED048 -s n -v n /VBM/FED048/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:50,27 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.027603:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:50,29 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.027603:Found 192 DICOM file(s)
# 200124-14:57:50,30 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.027603:Convert 192 DICOM as /VBM/FED048/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151118152060_5 (256x256x192x1)
# 200124-14:57:50,105 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.105303:Conversion required 0.487673 seconds (0.318560 for core code).
# 200124-14:57:50,131 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED050/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED050
# 200124-14:57:50,134 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpc_9mv5yc/converter".
# 200124-14:57:50,137 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED050 -s n -v n /VBM/FED050/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:50,632 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.632733:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:50,634 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.632733:Found 192 DICOM file(s)
# 200124-14:57:50,635 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.632733:Convert 192 DICOM as /VBM/FED050/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151201165820_5 (256x256x192x1)
# 200124-14:57:50,706 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:50.706218:Conversion required 0.552835 seconds (0.363364 for core code).
# 200124-14:57:50,732 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED051/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED051
# 200124-14:57:50,734 nipype.workflow INFO:
# ...
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED054 -s n -v n /VBM/FED054/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:52,883 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:52.883356:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:52,884 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:52.883356:Found 192 DICOM file(s)
# 200124-14:57:52,885 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:52.883356:Convert 192 DICOM as /VBM/FED054/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151208140706_5 (256x256x192x1)
# 200124-14:57:53,92 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:53.092082:Conversion required 0.634002 seconds (0.460944 for core code).
# 200124-14:57:53,122 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED055/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED055
# 200124-14:57:53,125 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpseaklvvk/converter".
# 200124-14:57:53,130 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED055 -s n -v n /VBM/FED055/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:53,606 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:53.606300:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:53,609 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:53.606300:Found 192 DICOM file(s)
# 200124-14:57:53,610 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:53.606300:Convert 192 DICOM as /VBM/FED055/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151214092109_5 (256x256x192x1)
# 200124-14:57:53,678 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:53.678642:Conversion required 0.529034 seconds (0.342731 for core code).
# 200124-14:57:53,705 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED056/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED056
# 200124-14:57:53,709 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpah5y52ep/converter".
# 200124-14:57:53,713 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED056 -s n -v n /VBM/FED056/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:54,174 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.174428:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:54,176 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.174428:Found 192 DICOM file(s)
# 200124-14:57:54,177 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.174428:Convert 192 DICOM as /VBM/FED056/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151215155556_5 (256x256x192x1)
# 200124-14:57:54,253 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.253526:Conversion required 0.523083 seconds (0.327313 for core code).
# 200124-14:57:54,279 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED057/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED057
# 200124-14:57:54,281 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmph93ko6r8/converter".
# 200124-14:57:54,285 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED057 -s n -v n /VBM/FED057/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:54,750 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.750733:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:54,752 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.750733:Found 192 DICOM file(s)
# 200124-14:57:54,753 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.750733:Convert 192 DICOM as /VBM/FED057/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151216154455_5 (256x256x192x1)
# 200124-14:57:54,825 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:54.825872:Conversion required 0.523218 seconds (0.353293 for core code).
# 200124-14:57:54,853 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED058/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED058
# 200124-14:57:54,856 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpmkvw4uai/converter".
# 200124-14:57:54,860 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED058 -s n -v n /VBM/FED058/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:55,340 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.339893:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:55,341 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.339893:Found 192 DICOM file(s)
# 200124-14:57:55,342 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.339893:Convert 192 DICOM as /VBM/FED058/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160217151251_5 (256x256x192x1)
# 200124-14:57:55,417 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.417853:Conversion required 0.542058 seconds (0.363762 for core code).
# 200124-14:57:55,444 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED059/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED059
# 200124-14:57:55,445 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpyhg7qbch/converter".
# 200124-14:57:55,450 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED059 -s n -v n /VBM/FED059/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:55,933 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.933081:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:55,934 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.933081:Found 192 DICOM file(s)
# 200124-14:57:55,935 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:55.933081:Convert 192 DICOM as /VBM/FED059/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160218100702_5 (256x256x192x1)
# 200124-14:57:56,175 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:56.175703:Conversion required 0.706602 seconds (0.519430 for core code).
# 200124-14:57:56,206 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED060/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED060
# 200124-14:57:56,208 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpghb5x8gu/converter".
# 200124-14:57:56,212 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED060 -s n -v n /VBM/FED060/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:56,750 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:56.750695:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:56,751 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:56.750695:Found 192 DICOM file(s)
# 200124-14:57:56,752 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:56.750695:Convert 192 DICOM as /VBM/FED060/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160224151260_5 (256x256x192x1)
# 200124-14:57:56,821 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:56.821361:Conversion required 0.586465 seconds (0.400691 for core code).
# 200124-14:57:56,846 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED061/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED061
# 200124-14:57:56,849 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpnk0w8_09/converter".
# 200124-14:57:56,854 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED061 -s n -v n /VBM/FED061/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:57,311 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.311570:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:57,312 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.311570:Found 192 DICOM file(s)
# 200124-14:57:57,313 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.311570:Convert 192 DICOM as /VBM/FED061/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160301111011_5 (256x256x192x1)
# 200124-14:57:57,382 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.382493:Conversion required 0.510912 seconds (0.335799 for core code).
# 200124-14:57:57,408 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED062/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED062
# 200124-14:57:57,410 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpcwke5iuh/converter".
# 200124-14:57:57,414 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED062 -s n -v n /VBM/FED062/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:57,905 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.905024:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:57,906 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.905024:Found 192 DICOM file(s)
# 200124-14:57:57,906 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.905024:Convert 192 DICOM as /VBM/FED062/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160301164049_5 (256x256x192x1)
# 200124-14:57:57,977 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:57.977917:Conversion required 0.547161 seconds (0.368403 for core code).
# 200124-14:57:58,3 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED063/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED063
# 200124-14:57:58,4 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpid2g7fbx/converter".
# 200124-14:57:58,8 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED063 -s n -v n /VBM/FED063/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:58,416 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:58.416260:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:58,417 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:58.416260:Found 192 DICOM file(s)
# 200124-14:57:58,418 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:58.416260:Convert 192 DICOM as /VBM/FED063/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5 (256x256x192x1)
# 200124-14:57:58,487 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:58.487767:Conversion required 0.463067 seconds (0.313061 for core code).
# 200124-14:57:58,514 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED064/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED064
# 200124-14:57:58,516 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpchrwmihv/converter".
# 200124-14:57:58,521 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED064 -s n -v n /VBM/FED064/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:59,57 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.057534:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:59,58 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.057534:Found 192 DICOM file(s)
# 200124-14:57:59,59 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.057534:Convert 192 DICOM as /VBM/FED064/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5 (256x256x192x1)
# 200124-14:57:59,135 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.135653:Conversion required 0.592116 seconds (0.316822 for core code).
# 200124-14:57:59,162 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED065/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED065
# 200124-14:57:59,164 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4wfhqu8p/converter".
# 200124-14:57:59,168 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED065 -s n -v n /VBM/FED065/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:57:59,663 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.663572:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:57:59,664 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.663572:Found 192 DICOM file(s)
# 200124-14:57:59,665 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.663572:Convert 192 DICOM as /VBM/FED065/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5 (256x256x192x1)
# 200124-14:57:59,736 nipype.interface INFO:
# 	 stdout 2020-01-24T14:57:59.736207:Conversion required 0.551175 seconds (0.334566 for core code).
# 200124-14:57:59,761 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED066/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED066
# 200124-14:57:59,762 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpimmxxaim/converter".
# 200124-14:57:59,766 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED066 -s n -v n /VBM/FED066/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:58:00,206 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.205889:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:58:00,207 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.205889:Found 192 DICOM file(s)
# 200124-14:58:00,208 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.205889:Convert 192 DICOM as /VBM/FED066/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5 (256x256x192x1)
# 200124-14:58:00,276 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.276758:Conversion required 0.491422 seconds (0.339444 for core code).
# 200124-14:58:00,301 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED067/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED067
# 200124-14:58:00,303 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmphqd42nbm/converter".
# 200124-14:58:00,307 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED067 -s n -v n /VBM/FED067/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:58:00,730 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.730231:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:58:00,731 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.730231:Found 192 DICOM file(s)
# 200124-14:58:00,732 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.730231:Convert 192 DICOM as /VBM/FED067/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5 (256x256x192x1)
# 200124-14:58:00,800 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:00.800927:Conversion required 0.477860 seconds (0.327974 for core code).
# 200124-14:58:00,826 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /VBM/FED068/T1_MPRAGE_SAG_ISO_0_9_0005 /VBM/FED068
# 200124-14:58:00,828 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpi_obfac2/converter".
# 200124-14:58:00,832 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED068 -s n -v n /VBM/FED068/T1_MPRAGE_SAG_ISO_0_9_0005
# 200124-14:58:01,239 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:01.239532:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-14:58:01,240 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:01.239532:Found 192 DICOM file(s)
# 200124-14:58:01,241 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:01.239532:Convert 192 DICOM as /VBM/FED068/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5 (256x256x192x1)
# 200124-14:58:01,315 nipype.interface INFO:
# 	 stdout 2020-01-24T14:58:01.315038:Conversion required 0.462628 seconds (0.298819 for core code).
# 200124-14:58:01,342 nipype.workflow INFO:
# 	 [Node] Finished "converter".

# %% [markdown]
# For testing or re-doing single subjects:

# %%
# print sequencedirs + subdirs and crop, if testing
sequencedir=sequencedirs[43]
subdir=subdirs[43]

print(sequencedir, subdir)
# Out:
# /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009 /VBM/FED049

# %%
# use sequence-list as source_dir and save output of converter in parent dir

# insert the two variable values directly, create nodes and run them to create NIFTI files

# create DICOM-to-NIFTI converter node
converter=Node(Dcm2niix(), name='converter')
converter.inputs.compress='n' # do not compress -> SPM options etc.
converter.inputs.source_dir=sequencedir
converter.inputs.output_dir=subdir
converter.run()
# Out:
# 200124-15:38:14,358 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpjnxkds55/converter".
# 200124-15:38:14,362 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED049 -s n -v n /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009
# 200124-15:38:14,833 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-15:38:14,835 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Found 192 DICOM file(s)
# 200124-15:38:14,836 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Convert 192 DICOM as /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009_t1_mprage_sag_iso_0.9_20151123115353_9 (256x256x192x1)
# 200124-15:38:15,102 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:15.102243:Conversion required 0.712450 seconds (0.546249 for core code).
# 200124-15:38:15,135 nipype.workflow INFO:
# 	 [Node] Finished "converter".
