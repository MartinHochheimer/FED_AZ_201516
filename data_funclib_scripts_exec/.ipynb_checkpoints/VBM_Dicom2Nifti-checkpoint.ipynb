# %% [markdown]
# # Convert DICOM to NIFTI

# %% [markdown]
# Gather necessary pre-requisites:

# %%
# import everything you need
from nipype.interfaces.dcm2nii import Dcm2niix
from nipype import Node, Workflow
import os, re
# Out:
# 200211-06:16:59,453 nipype.utils INFO:
# 	 Running nipype version 1.4.0-dev (latest: 1.4.1)

# %%
# define useful functions

# get subject directories from parent directory
def get_subdirs(dir):
    subdirs=[]
    for i in os.listdir(dir):
        # verify subject number in directory and exclude other dirs
        match=re.match(r'(.*\d{3}$)', i)
        if os.path.isdir(os.path.join(dir, i)) and match:
            subdirs.append(os.path.join(dir, match.group(0)))
    return sorted(subdirs)

# %% [markdown]
# Get files

# %%
# get subject dir-list
subdirs=get_subdirs("/VBM/")
print(subdirs)
print(len(subdirs))
# Out:
# ['/fMRI/FED006', '/fMRI/FED007', '/fMRI/FED008', '/fMRI/FED009', '/fMRI/FED010', '/fMRI/FED011', '/fMRI/FED012', '/fMRI/FED013', '/fMRI/FED014', '/fMRI/FED015', '/fMRI/FED016', '/fMRI/FED017', '/fMRI/FED018', '/fMRI/FED019', '/fMRI/FED020', '/fMRI/FED021', '/fMRI/FED022', '/fMRI/FED023', '/fMRI/FED024', '/fMRI/FED025', '/fMRI/FED026', '/fMRI/FED027', '/fMRI/FED028', '/fMRI/FED029', '/fMRI/FED030', '/fMRI/FED031', '/fMRI/FED032', '/fMRI/FED033', '/fMRI/FED034', '/fMRI/FED035', '/fMRI/FED036', '/fMRI/FED037', '/fMRI/FED038', '/fMRI/FED039', '/fMRI/FED040', '/fMRI/FED041', '/fMRI/FED042', '/fMRI/FED043', '/fMRI/FED044', '/fMRI/FED045', '/fMRI/FED046', '/fMRI/FED047', '/fMRI/FED048', '/fMRI/FED049', '/fMRI/FED050', '/fMRI/FED051', '/fMRI/FED052', '/fMRI/FED053', '/fMRI/FED054', '/fMRI/FED055', '/fMRI/FED056', '/fMRI/FED057', '/fMRI/FED058', '/fMRI/FED059', '/fMRI/FED060', '/fMRI/FED061', '/fMRI/FED062', '/fMRI/FED063', '/fMRI/FED064', '/fMRI/FED065', '/fMRI/FED066', '/fMRI/FED067', '/fMRI/FED068']
# 63

# %%
# get T1-MPRAGE source list via subject lists
sequencedirs=[]
for i in subdirs:
    for j in os.listdir(i):
        if os.path.isdir(os.path.join(i, j)) and j.endswith("ISO_0_9_0005") or j.endswith("ISO_0_9_0009"):
            sequencedirs.append(os.path.join(i, j))
            
# sort the list entries
sequencedirs=sorted(sequencedirs)

# %%
print(sequencedirs)
print(len(sequencedirs))
# Out:
# ['/fMRI/FED006/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED007/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED008/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED009/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED010/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED011/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED012/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED013/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED014/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED015/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED016/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED017/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED018/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED019/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED020/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED021/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED022/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED023/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED024/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED025/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED026/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED027/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED028/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED029/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED030/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED031/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED032/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED033/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED034/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED035/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED036/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED037/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED038/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED039/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED040/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED041/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED042/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED043/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED044/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED045/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED046/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED047/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED048/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED049/T1_MPRAGE_SAG_ISO_0_9_0009', '/fMRI/FED050/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED051/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED052/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED053/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED054/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED055/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED056/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED057/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED058/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED059/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED060/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED061/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED062/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED063/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED064/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED065/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED066/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED067/T1_MPRAGE_SAG_ISO_0_9_0005', '/fMRI/FED068/T1_MPRAGE_SAG_ISO_0_9_0005']
# 63

# %% [markdown]
# Convert .IMA files to NIFTI

# %%
# use sequence-list as source_dir and save output of converter in parent dir

# iterate over sequence and subject dirs, create nodes and run them to create NIFTI files
for i,j in zip(sequencedirs, subdirs):
    print(i,j)
    # create DICOM-to-NIFTI converter node
    converter=Node(Dcm2niix(), name='converter')
    converter.inputs.compress='n' # do not compress -> SPM options etc.
    converter.inputs.source_dir=i
    converter.inputs.output_dir=j
    converter.run()
# Out:
# /fMRI/FED006/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED006
# 200211-06:41:25,795 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpp1bm2xvf/converter".
# 200211-06:41:25,800 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED006 -s n -v n /fMRI/FED006/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:25,986 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:25.986720:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:25,988 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:25.986720:Found 192 DICOM file(s)
# 200211-06:41:25,988 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:25.986720:Convert 192 DICOM as /fMRI/FED006/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141106153429_5 (256x256x192x1)
# 200211-06:41:26,77 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.077669:Conversion required 0.240901 seconds (0.240586 for core code).
# 200211-06:41:26,129 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED007/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED007
# 200211-06:41:26,132 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp0dqfnrwo/converter".
# 200211-06:41:26,136 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED007 -s n -v n /fMRI/FED007/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:26,290 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.290088:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:26,291 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.290088:Found 192 DICOM file(s)
# 200211-06:41:26,292 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.290088:Convert 192 DICOM as /fMRI/FED007/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141107104226_5 (256x256x192x1)
# 200211-06:41:26,410 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.410803:Conversion required 0.253253 seconds (0.253171 for core code).
# 200211-06:41:26,462 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED008/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED008
# 200211-06:41:26,464 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp04y1lucy/converter".
# 200211-06:41:26,469 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED008 -s n -v n /fMRI/FED008/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:26,621 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.621157:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:26,622 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.621157:Found 192 DICOM file(s)
# 200211-06:41:26,623 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.621157:Convert 192 DICOM as /fMRI/FED008/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141112155009_5 (256x256x192x1)
# 200211-06:41:26,877 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:26.876995:Conversion required 0.387493 seconds (0.387204 for core code).
# 200211-06:41:26,932 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED009/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED009
# 200211-06:41:26,935 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp72voz80x/converter".
# 200211-06:41:26,938 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED009 -s n -v n /fMRI/FED009/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:27,95 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.095254:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:27,96 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.095254:Found 192 DICOM file(s)
# 200211-06:41:27,97 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.095254:Convert 192 DICOM as /fMRI/FED009/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5 (256x256x192x1)
# 200211-06:41:27,224 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.224421:Conversion required 0.265605 seconds (0.263514 for core code).
# 200211-06:41:27,274 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED010/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED010
# 200211-06:41:27,277 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp49gpm78r/converter".
# 200211-06:41:27,282 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED010 -s n -v n /fMRI/FED010/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:27,430 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.430760:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:27,432 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.430760:Found 192 DICOM file(s)
# 200211-06:41:27,432 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.430760:Convert 192 DICOM as /fMRI/FED010/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5 (256x256x192x1)
# 200211-06:41:27,699 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.699561:Conversion required 0.392548 seconds (0.392411 for core code).
# 200211-06:41:27,753 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED011/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED011
# 200211-06:41:27,755 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp7o07bzya/converter".
# 200211-06:41:27,759 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED011 -s n -v n /fMRI/FED011/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:27,902 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.902172:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:27,903 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.902172:Found 192 DICOM file(s)
# 200211-06:41:27,904 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:27.902172:Convert 192 DICOM as /fMRI/FED011/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5 (256x256x192x1)
# 200211-06:41:28,60 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.060475:Conversion required 0.276228 seconds (0.276115 for core code).
# 200211-06:41:28,111 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED012/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED012
# 200211-06:41:28,113 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpmrjmz3yn/converter".
# 200211-06:41:28,119 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED012 -s n -v n /fMRI/FED012/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:28,262 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.262657:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:28,263 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.262657:Found 192 DICOM file(s)
# 200211-06:41:28,264 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.262657:Convert 192 DICOM as /fMRI/FED012/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5 (256x256x192x1)
# 200211-06:41:28,332 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.332812:Conversion required 0.193256 seconds (0.193176 for core code).
# 200211-06:41:28,377 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED013/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED013
# 200211-06:41:28,380 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpw1_daczz/converter".
# 200211-06:41:28,384 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED013 -s n -v n /fMRI/FED013/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:28,524 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.524121:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:28,525 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.524121:Found 192 DICOM file(s)
# 200211-06:41:28,526 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.524121:Convert 192 DICOM as /fMRI/FED013/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5 (256x256x192x1)
# 200211-06:41:28,700 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.700080:Conversion required 0.296045 seconds (0.295973 for core code).
# 200211-06:41:28,750 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED014/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED014
# 200211-06:41:28,752 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp1hj1k_wi/converter".
# 200211-06:41:28,756 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED014 -s n -v n /fMRI/FED014/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:28,896 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.896756:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:28,898 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.896756:Found 192 DICOM file(s)
# 200211-06:41:28,899 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:28.896756:Convert 192 DICOM as /fMRI/FED014/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5 (256x256x192x1)
# 200211-06:41:29,149 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.149640:Conversion required 0.369550 seconds (0.369513 for core code).
# 200211-06:41:29,202 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED015/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED015
# 200211-06:41:29,204 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpuq4k7b65/converter".
# 200211-06:41:29,208 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED015 -s n -v n /fMRI/FED015/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:29,350 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.350713:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:29,352 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.350713:Found 192 DICOM file(s)
# 200211-06:41:29,352 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.350713:Convert 192 DICOM as /fMRI/FED015/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5 (256x256x192x1)
# 200211-06:41:29,420 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.420126:Conversion required 0.183541 seconds (0.183508 for core code).
# 200211-06:41:29,465 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED016/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED016
# 200211-06:41:29,467 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmph_pux0b7/converter".
# 200211-06:41:29,471 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED016 -s n -v n /fMRI/FED016/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:29,610 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.609930:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:29,611 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.609930:Found 192 DICOM file(s)
# 200211-06:41:29,612 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.609930:Convert 192 DICOM as /fMRI/FED016/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5 (256x256x192x1)
# 200211-06:41:29,851 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:29.851200:Conversion required 0.359904 seconds (0.359846 for core code).
# 200211-06:41:29,905 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED017/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED017
# 200211-06:41:29,906 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpws7r98sd/converter".
# 200211-06:41:29,911 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED017 -s n -v n /fMRI/FED017/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:30,64 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.064280:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:30,65 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.064280:Found 192 DICOM file(s)
# 200211-06:41:30,66 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.064280:Convert 192 DICOM as /fMRI/FED017/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5 (256x256x192x1)
# 200211-06:41:30,134 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.134332:Conversion required 0.202431 seconds (0.202380 for core code).
# 200211-06:41:30,180 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED018/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED018
# 200211-06:41:30,182 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpa3ybrbsn/converter".
# 200211-06:41:30,186 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED018 -s n -v n /fMRI/FED018/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:30,326 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.326297:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:30,327 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.326297:Found 192 DICOM file(s)
# 200211-06:41:30,328 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.326297:Convert 192 DICOM as /fMRI/FED018/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5 (256x256x192x1)
# 200211-06:41:30,399 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.399458:Conversion required 0.193385 seconds (0.193320 for core code).
# 200211-06:41:30,444 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED019/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED019
# 200211-06:41:30,447 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpmpfclpm4/converter".
# 200211-06:41:30,451 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED019 -s n -v n /fMRI/FED019/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:30,591 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.591543:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:30,592 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.591543:Found 192 DICOM file(s)
# 200211-06:41:30,593 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.591543:Convert 192 DICOM as /fMRI/FED019/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5 (256x256x192x1)
# 200211-06:41:30,660 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.660192:Conversion required 0.188560 seconds (0.188481 for core code).
# 200211-06:41:30,707 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED020/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED020
# 200211-06:41:30,708 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpj0w9yszp/converter".
# 200211-06:41:30,713 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED020 -s n -v n /fMRI/FED020/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:30,865 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.865086:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:30,866 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.865086:Found 192 DICOM file(s)
# 200211-06:41:30,867 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:30.865086:Convert 192 DICOM as /fMRI/FED020/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5 (256x256x192x1)
# 200211-06:41:31,9 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.009753:Conversion required 0.272732 seconds (0.272637 for core code).
# 200211-06:41:31,61 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED021/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED021
# 200211-06:41:31,63 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpc5slg1nz/converter".
# 200211-06:41:31,67 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED021 -s n -v n /fMRI/FED021/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:31,210 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.210274:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:31,211 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.210274:Found 192 DICOM file(s)
# 200211-06:41:31,212 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.210274:Convert 192 DICOM as /fMRI/FED021/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5 (256x256x192x1)
# 200211-06:41:31,280 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.280233:Conversion required 0.192522 seconds (0.192460 for core code).
# 200211-06:41:31,322 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED022/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED022
# 200211-06:41:31,324 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpvf_pq79c/converter".
# 200211-06:41:31,328 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED022 -s n -v n /fMRI/FED022/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:31,552 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.552573:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:31,553 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.552573:Found 384 DICOM file(s)
# 200211-06:41:31,554 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.552573:192 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 200211-06:41:31,555 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.552573:Convert 192 DICOM as /fMRI/FED022/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5 (256x256x192x1)
# 200211-06:41:31,622 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.621967:Conversion required 0.267745 seconds (0.267630 for core code).
# 200211-06:41:31,668 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED023/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED023
# 200211-06:41:31,670 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8czv8xd_/converter".
# 200211-06:41:31,674 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED023 -s n -v n /fMRI/FED023/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:31,818 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.818235:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:31,819 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.818235:Found 192 DICOM file(s)
# 200211-06:41:31,820 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.818235:Convert 192 DICOM as /fMRI/FED023/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5 (256x256x192x1)
# 200211-06:41:31,891 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:31.891277:Conversion required 0.196962 seconds (0.196813 for core code).
# 200211-06:41:31,937 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED024/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED024
# 200211-06:41:31,939 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4qo7n9b2/converter".
# 200211-06:41:31,943 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED024 -s n -v n /fMRI/FED024/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:32,95 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.095461:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:32,96 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.095461:Found 192 DICOM file(s)
# 200211-06:41:32,97 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.095461:Convert 192 DICOM as /fMRI/FED024/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5 (256x256x192x1)
# 200211-06:41:32,338 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.338387:Conversion required 0.364795 seconds (0.364726 for core code).
# 200211-06:41:32,391 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED025/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED025
# 200211-06:41:32,393 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpb8udqfnu/converter".
# 200211-06:41:32,397 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED025 -s n -v n /fMRI/FED025/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:32,562 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.562791:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:32,564 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.562791:Found 192 DICOM file(s)
# 200211-06:41:32,565 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.562791:Convert 192 DICOM as /fMRI/FED025/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5 (256x256x192x1)
# 200211-06:41:32,632 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.632227:Conversion required 0.208940 seconds (0.208701 for core code).
# 200211-06:41:32,679 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED026/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED026
# 200211-06:41:32,682 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpg6yml_1v/converter".
# 200211-06:41:32,686 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED026 -s n -v n /fMRI/FED026/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:32,832 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.832698:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:32,833 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.832698:Found 192 DICOM file(s)
# 200211-06:41:32,834 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:32.832698:Convert 192 DICOM as /fMRI/FED026/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5 (256x256x192x1)
# 200211-06:41:33,83 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.083284:Conversion required 0.376457 seconds (0.376281 for core code).
# 200211-06:41:33,132 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED027/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED027
# 200211-06:41:33,135 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpqzn6h4lv/converter".
# 200211-06:41:33,139 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED027 -s n -v n /fMRI/FED027/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:33,280 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.280211:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:33,281 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.280211:Found 192 DICOM file(s)
# 200211-06:41:33,282 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.280211:Convert 192 DICOM as /fMRI/FED027/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150218162601_5 (256x256x192x1)
# 200211-06:41:33,349 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.349638:Conversion required 0.189312 seconds (0.189259 for core code).
# 200211-06:41:33,392 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED028/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED028
# 200211-06:41:33,393 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpwrtc4yy8/converter".
# 200211-06:41:33,398 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED028 -s n -v n /fMRI/FED028/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:33,553 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.553083:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:33,554 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.553083:Found 192 DICOM file(s)
# 200211-06:41:33,555 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.553083:Convert 192 DICOM as /fMRI/FED028/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150219142148_5 (256x256x192x1)
# 200211-06:41:33,622 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.622427:Conversion required 0.197395 seconds (0.197236 for core code).
# 200211-06:41:33,668 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED029/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED029
# 200211-06:41:33,670 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpxem5thsx/converter".
# 200211-06:41:33,674 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED029 -s n -v n /fMRI/FED029/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:33,824 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.824868:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:33,826 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.824868:Found 192 DICOM file(s)
# 200211-06:41:33,826 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.824868:Convert 192 DICOM as /fMRI/FED029/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150226091949_5 (256x256x192x1)
# 200211-06:41:33,896 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:33.896686:Conversion required 0.202178 seconds (0.202136 for core code).
# 200211-06:41:33,941 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED030/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED030
# 200211-06:41:33,943 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpkdghzw30/converter".
# 200211-06:41:33,947 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED030 -s n -v n /fMRI/FED030/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:34,103 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.103838:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:34,105 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.103838:Found 192 DICOM file(s)
# 200211-06:41:34,105 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.103838:Convert 192 DICOM as /fMRI/FED030/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150226154844_5 (256x256x192x1)
# 200211-06:41:34,351 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.350981:Conversion required 0.376897 seconds (0.376828 for core code).
# 200211-06:41:34,399 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED031/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED031
# 200211-06:41:34,402 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp5l25_q09/converter".
# 200211-06:41:34,406 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED031 -s n -v n /fMRI/FED031/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:34,549 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.549718:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:34,551 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.549718:Found 192 DICOM file(s)
# 200211-06:41:34,551 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.549718:Convert 192 DICOM as /fMRI/FED031/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150310152650_5 (256x256x192x1)
# 200211-06:41:34,632 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.632075:Conversion required 0.204875 seconds (0.204801 for core code).
# 200211-06:41:34,676 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED032/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED032
# 200211-06:41:34,677 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpsgaoupqb/converter".
# 200211-06:41:34,682 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED032 -s n -v n /fMRI/FED032/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:34,835 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.835308:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:34,836 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.835308:Found 192 DICOM file(s)
# 200211-06:41:34,837 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.835308:Convert 192 DICOM as /fMRI/FED032/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150313125246_5 (256x256x192x1)
# 200211-06:41:34,904 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:34.904785:Conversion required 0.198025 seconds (0.197961 for core code).
# 200211-06:41:34,949 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED033/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED033
# 200211-06:41:34,951 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp5c5dtnl9/converter".
# 200211-06:41:34,955 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED033 -s n -v n /fMRI/FED033/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:35,98 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.098353:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:35,99 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.098353:Found 192 DICOM file(s)
# 200211-06:41:35,100 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.098353:Convert 192 DICOM as /fMRI/FED033/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150326151309_5 (256x256x192x1)
# 200211-06:41:35,167 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.167512:Conversion required 0.188522 seconds (0.188467 for core code).
# 200211-06:41:35,210 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED034/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED034
# 200211-06:41:35,212 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmptng1zzta/converter".
# 200211-06:41:35,217 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED034 -s n -v n /fMRI/FED034/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:35,381 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.381307:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:35,382 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.381307:Found 192 DICOM file(s)
# 200211-06:41:35,383 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.381307:Convert 192 DICOM as /fMRI/FED034/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150909125805_5 (256x256x192x1)
# 200211-06:41:35,450 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.450075:Conversion required 0.211466 seconds (0.211429 for core code).
# 200211-06:41:35,493 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED035/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED035
# 200211-06:41:35,495 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpg5ji8pdp/converter".
# 200211-06:41:35,499 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED035 -s n -v n /fMRI/FED035/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:35,663 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.663387:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:35,666 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.663387:Found 192 DICOM file(s)
# 200211-06:41:35,666 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.663387:Convert 192 DICOM as /fMRI/FED035/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150917120306_5 (256x256x192x1)
# 200211-06:41:35,733 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.733430:Conversion required 0.210013 seconds (0.209942 for core code).
# 200211-06:41:35,775 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED036/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED036
# 200211-06:41:35,777 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpahbv52gn/converter".
# 200211-06:41:35,781 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED036 -s n -v n /fMRI/FED036/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:35,961 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.961454:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:35,962 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.961454:Found 192 DICOM file(s)
# 200211-06:41:35,963 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:35.961454:Convert 192 DICOM as /fMRI/FED036/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150924172133_5 (256x256x192x1)
# 200211-06:41:36,30 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.029996:Conversion required 0.226367 seconds (0.222840 for core code).
# 200211-06:41:36,75 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED037/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED037
# 200211-06:41:36,76 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmplsh3c635/converter".
# 200211-06:41:36,81 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED037 -s n -v n /fMRI/FED037/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:36,244 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.244221:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:36,245 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.244221:Found 192 DICOM file(s)
# 200211-06:41:36,246 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.244221:Convert 192 DICOM as /fMRI/FED037/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150929162030_5 (256x256x192x1)
# 200211-06:41:36,313 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.313470:Conversion required 0.211999 seconds (0.211889 for core code).
# 200211-06:41:36,358 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED038/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED038
# 200211-06:41:36,359 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpdgpect4x/converter".
# 200211-06:41:36,364 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED038 -s n -v n /fMRI/FED038/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:36,524 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.523915:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:36,525 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.523915:Found 192 DICOM file(s)
# 200211-06:41:36,526 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.523915:Convert 192 DICOM as /fMRI/FED038/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151001125857_5 (256x256x192x1)
# 200211-06:41:36,593 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.592999:Conversion required 0.208389 seconds (0.208340 for core code).
# 200211-06:41:36,635 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED039/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED039
# 200211-06:41:36,637 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpo1617sbk/converter".
# 200211-06:41:36,641 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED039 -s n -v n /fMRI/FED039/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:36,793 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.793851:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:36,795 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.793851:Found 192 DICOM file(s)
# 200211-06:41:36,796 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.793851:Convert 192 DICOM as /fMRI/FED039/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151001173950_5 (256x256x192x1)
# 200211-06:41:36,867 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:36.867218:Conversion required 0.204964 seconds (0.204883 for core code).
# 200211-06:41:36,913 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED040/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED040
# 200211-06:41:36,915 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpbs95e00v/converter".
# 200211-06:41:36,921 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED040 -s n -v n /fMRI/FED040/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:37,64 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.064137:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:37,65 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.064137:Found 192 DICOM file(s)
# 200211-06:41:37,66 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.064137:Convert 192 DICOM as /fMRI/FED040/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151009111760_5 (256x256x192x1)
# 200211-06:41:37,133 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.133387:Conversion required 0.191718 seconds (0.191575 for core code).
# 200211-06:41:37,177 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED041/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED041
# 200211-06:41:37,179 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp3h8npuvm/converter".
# 200211-06:41:37,184 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED041 -s n -v n /fMRI/FED041/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:37,326 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.326327:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:37,327 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.326327:Found 192 DICOM file(s)
# 200211-06:41:37,328 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.326327:Convert 192 DICOM as /fMRI/FED041/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151009164129_5 (256x256x192x1)
# 200211-06:41:37,398 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.398497:Conversion required 0.193059 seconds (0.193031 for core code).
# 200211-06:41:37,446 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED042/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED042
# 200211-06:41:37,447 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8fyy2iru/converter".
# 200211-06:41:37,452 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED042 -s n -v n /fMRI/FED042/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:37,595 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.595488:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:37,596 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.595488:Found 192 DICOM file(s)
# 200211-06:41:37,598 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.595488:Convert 192 DICOM as /fMRI/FED042/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151013110112_5 (256x256x192x1)
# 200211-06:41:37,805 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:37.805002:Conversion required 0.332378 seconds (0.332244 for core code).
# 200211-06:41:37,851 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED043/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED043
# 200211-06:41:37,853 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpj2y3j9il/converter".
# 200211-06:41:37,857 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED043 -s n -v n /fMRI/FED043/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:38,0 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.000585:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:38,1 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.000585:Found 192 DICOM file(s)
# 200211-06:41:38,2 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.000585:Convert 192 DICOM as /fMRI/FED043/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151015122011_5 (256x256x192x1)
# 200211-06:41:38,69 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.069727:Conversion required 0.185971 seconds (0.185839 for core code).
# 200211-06:41:38,112 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED044/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED044
# 200211-06:41:38,114 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp6ntbbskd/converter".
# 200211-06:41:38,120 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED044 -s n -v n /fMRI/FED044/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:38,262 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.262789:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:38,264 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.262789:Found 192 DICOM file(s)
# 200211-06:41:38,264 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.262789:Convert 192 DICOM as /fMRI/FED044/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151029121235_5 (256x256x192x1)
# 200211-06:41:38,442 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.442276:Conversion required 0.301691 seconds (0.301616 for core code).
# 200211-06:41:38,495 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED045/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED045
# 200211-06:41:38,497 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpxhu1o6kj/converter".
# 200211-06:41:38,501 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED045 -s n -v n /fMRI/FED045/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:38,646 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.646675:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:38,648 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.646675:Found 192 DICOM file(s)
# 200211-06:41:38,648 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.646675:Convert 192 DICOM as /fMRI/FED045/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151105173027_5 (256x256x192x1)
# 200211-06:41:38,779 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:38.779587:Conversion required 0.255992 seconds (0.255946 for core code).
# 200211-06:41:38,828 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED046/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED046
# 200211-06:41:38,830 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp7ql28lds/converter".
# 200211-06:41:38,835 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED046 -s n -v n /fMRI/FED046/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:39,58 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.058654:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:39,60 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.058654:Found 384 DICOM file(s)
# 200211-06:41:39,60 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.058654:192 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 200211-06:41:39,61 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.058654:Convert 192 DICOM as /fMRI/FED046/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151106125904_5 (256x256x192x1)
# 200211-06:41:39,130 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.130121:Conversion required 0.272954 seconds (0.272867 for core code).
# 200211-06:41:39,177 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED047/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED047
# 200211-06:41:39,179 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpfwpaq7xu/converter".
# 200211-06:41:39,183 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED047 -s n -v n /fMRI/FED047/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:39,324 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.324230:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:39,325 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.324230:Found 192 DICOM file(s)
# 200211-06:41:39,326 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.324230:Convert 192 DICOM as /fMRI/FED047/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151116144126_5 (256x256x192x1)
# 200211-06:41:39,557 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.557275:Conversion required 0.352680 seconds (0.352591 for core code).
# 200211-06:41:39,605 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED048/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED048
# 200211-06:41:39,607 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpit0_jkjd/converter".
# 200211-06:41:39,611 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED048 -s n -v n /fMRI/FED048/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:39,766 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.765990:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:39,767 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.765990:Found 192 DICOM file(s)
# 200211-06:41:39,767 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.765990:Convert 192 DICOM as /fMRI/FED048/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151118152060_5 (256x256x192x1)
# 200211-06:41:39,837 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:39.837410:Conversion required 0.202589 seconds (0.202553 for core code).
# 200211-06:41:39,880 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED049/T1_MPRAGE_SAG_ISO_0_9_0009 /fMRI/FED049
# 200211-06:41:39,883 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpf81gsyqr/converter".
# 200211-06:41:39,887 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED049 -s n -v n /fMRI/FED049/T1_MPRAGE_SAG_ISO_0_9_0009
# 200211-06:41:40,332 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:40.332794:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:40,334 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:40.332794:Found 192 DICOM file(s)
# 200211-06:41:40,334 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:40.332794:Convert 192 DICOM as /fMRI/FED049/T1_MPRAGE_SAG_ISO_0_9_0009_t1_mprage_sag_iso_0.9_20151123115353_9 (256x256x192x1)
# 200211-06:41:40,402 nipype.interface INFO:
# ...
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED054 -s n -v n /fMRI/FED054/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:41,979 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:41.979021:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:41,980 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:41.979021:Found 192 DICOM file(s)
# 200211-06:41:41,981 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:41.979021:Convert 192 DICOM as /fMRI/FED054/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151208140706_5 (256x256x192x1)
# 200211-06:41:42,168 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.168282:Conversion required 0.332169 seconds (0.332064 for core code).
# 200211-06:41:42,218 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED055/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED055
# 200211-06:41:42,219 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8dn_kwk0/converter".
# 200211-06:41:42,224 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED055 -s n -v n /fMRI/FED055/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:42,380 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.380222:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:42,381 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.380222:Found 192 DICOM file(s)
# 200211-06:41:42,382 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.380222:Convert 192 DICOM as /fMRI/FED055/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151214092109_5 (256x256x192x1)
# 200211-06:41:42,508 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.508132:Conversion required 0.263512 seconds (0.263369 for core code).
# 200211-06:41:42,558 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED056/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED056
# 200211-06:41:42,560 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpnd4rnvb4/converter".
# 200211-06:41:42,565 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED056 -s n -v n /fMRI/FED056/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:42,721 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.721562:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:42,722 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.721562:Found 192 DICOM file(s)
# 200211-06:41:42,725 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.721562:Convert 192 DICOM as /fMRI/FED056/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151215155556_5 (256x256x192x1)
# 200211-06:41:42,793 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.793477:Conversion required 0.199644 seconds (0.198164 for core code).
# 200211-06:41:42,836 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED057/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED057
# 200211-06:41:42,838 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmphlba27nb/converter".
# 200211-06:41:42,842 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED057 -s n -v n /fMRI/FED057/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:42,996 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.996216:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:42,997 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.996216:Found 192 DICOM file(s)
# 200211-06:41:42,998 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:42.996216:Convert 192 DICOM as /fMRI/FED057/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20151216154455_5 (256x256x192x1)
# 200211-06:41:43,72 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.072090:Conversion required 0.209902 seconds (0.209764 for core code).
# 200211-06:41:43,114 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED058/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED058
# 200211-06:41:43,117 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpphlzr672/converter".
# 200211-06:41:43,121 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED058 -s n -v n /fMRI/FED058/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:43,264 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.264197:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:43,265 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.264197:Found 192 DICOM file(s)
# 200211-06:41:43,266 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.264197:Convert 192 DICOM as /fMRI/FED058/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160217151251_5 (256x256x192x1)
# 200211-06:41:43,497 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.497567:Conversion required 0.353823 seconds (0.353717 for core code).
# 200211-06:41:43,547 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED059/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED059
# 200211-06:41:43,549 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpsf2l32pg/converter".
# 200211-06:41:43,554 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED059 -s n -v n /fMRI/FED059/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:43,694 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.694830:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:43,696 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.694830:Found 192 DICOM file(s)
# 200211-06:41:43,697 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.694830:Convert 192 DICOM as /fMRI/FED059/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160218100702_5 (256x256x192x1)
# 200211-06:41:43,764 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.764257:Conversion required 0.189137 seconds (0.189086 for core code).
# 200211-06:41:43,806 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED060/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED060
# 200211-06:41:43,809 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4uy16hec/converter".
# 200211-06:41:43,813 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED060 -s n -v n /fMRI/FED060/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:43,960 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.959987:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:43,961 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.959987:Found 192 DICOM file(s)
# 200211-06:41:43,962 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:43.959987:Convert 192 DICOM as /fMRI/FED060/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160224151260_5 (256x256x192x1)
# 200211-06:41:44,31 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.031735:Conversion required 0.196463 seconds (0.195914 for core code).
# 200211-06:41:44,79 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED061/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED061
# 200211-06:41:44,82 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpjhvuz0za/converter".
# 200211-06:41:44,88 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED061 -s n -v n /fMRI/FED061/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:44,228 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.228262:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:44,229 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.228262:Found 192 DICOM file(s)
# 200211-06:41:44,230 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.228262:Convert 192 DICOM as /fMRI/FED061/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160301111011_5 (256x256x192x1)
# 200211-06:41:44,296 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.296664:Conversion required 0.189037 seconds (0.188969 for core code).
# 200211-06:41:44,339 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED062/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED062
# 200211-06:41:44,341 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmprfpt2ud3/converter".
# 200211-06:41:44,345 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED062 -s n -v n /fMRI/FED062/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:44,510 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.509926:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:44,511 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.509926:Found 192 DICOM file(s)
# 200211-06:41:44,511 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.509926:Convert 192 DICOM as /fMRI/FED062/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160301164049_5 (256x256x192x1)
# 200211-06:41:44,580 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.580784:Conversion required 0.214498 seconds (0.214456 for core code).
# 200211-06:41:44,627 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED063/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED063
# 200211-06:41:44,628 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpm34lay_t/converter".
# 200211-06:41:44,633 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED063 -s n -v n /fMRI/FED063/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:44,773 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.773095:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:44,774 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.773095:Found 192 DICOM file(s)
# 200211-06:41:44,774 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.773095:Convert 192 DICOM as /fMRI/FED063/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5 (256x256x192x1)
# 200211-06:41:44,844 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:44.844525:Conversion required 0.191573 seconds (0.191511 for core code).
# 200211-06:41:44,892 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED064/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED064
# 200211-06:41:44,894 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpv4t7jrd6/converter".
# 200211-06:41:44,899 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED064 -s n -v n /fMRI/FED064/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:45,40 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.040714:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:45,41 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.040714:Found 192 DICOM file(s)
# 200211-06:41:45,42 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.040714:Convert 192 DICOM as /fMRI/FED064/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5 (256x256x192x1)
# 200211-06:41:45,175 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.175397:Conversion required 0.256298 seconds (0.256256 for core code).
# 200211-06:41:45,223 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED065/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED065
# 200211-06:41:45,225 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp17__edim/converter".
# 200211-06:41:45,229 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED065 -s n -v n /fMRI/FED065/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:45,385 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.385801:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:45,387 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.385801:Found 192 DICOM file(s)
# 200211-06:41:45,387 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.385801:Convert 192 DICOM as /fMRI/FED065/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5 (256x256x192x1)
# 200211-06:41:45,455 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.455472:Conversion required 0.201945 seconds (0.201893 for core code).
# 200211-06:41:45,498 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED066/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED066
# 200211-06:41:45,502 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpltv708fz/converter".
# 200211-06:41:45,506 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED066 -s n -v n /fMRI/FED066/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:45,644 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.644593:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:45,645 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.644593:Found 192 DICOM file(s)
# 200211-06:41:45,646 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.644593:Convert 192 DICOM as /fMRI/FED066/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5 (256x256x192x1)
# 200211-06:41:45,714 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.714094:Conversion required 0.188229 seconds (0.188111 for core code).
# 200211-06:41:45,757 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED067/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED067
# 200211-06:41:45,759 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpyb693wqf/converter".
# 200211-06:41:45,763 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED067 -s n -v n /fMRI/FED067/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:45,954 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.954773:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:45,956 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.954773:Found 192 DICOM file(s)
# 200211-06:41:45,956 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:45.954773:Convert 192 DICOM as /fMRI/FED067/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5 (256x256x192x1)
# 200211-06:41:46,25 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:46.025065:Conversion required 0.233929 seconds (0.233718 for core code).
# 200211-06:41:46,68 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED068/T1_MPRAGE_SAG_ISO_0_9_0005 /fMRI/FED068
# 200211-06:41:46,70 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpkb4b7yrx/converter".
# 200211-06:41:46,74 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /fMRI/FED068 -s n -v n /fMRI/FED068/T1_MPRAGE_SAG_ISO_0_9_0005
# 200211-06:41:46,417 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:46.417810:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200211-06:41:46,419 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:46.417810:Found 192 DICOM file(s)
# 200211-06:41:46,420 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:46.417810:Convert 192 DICOM as /fMRI/FED068/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5 (256x256x192x1)
# 200211-06:41:46,496 nipype.interface INFO:
# 	 stdout 2020-02-11T06:41:46.496830:Conversion required 0.399093 seconds (0.256399 for core code).
# 200211-06:41:46,543 nipype.workflow INFO:
# 	 [Node] Finished "converter".

# %% [markdown]
# For testing or re-doing single subjects:

# %%
# print sequencedirs + subdirs and crop, if testing
sequencedir=sequencedirs[43]
subdir=subdirs[43]

print(sequencedir, subdir)
# Out:
# /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009 /VBM/FED049

# %%
# use sequence-list as source_dir and save output of converter in parent dir

# insert the two variable values directly, create nodes and run them to create NIFTI files

# create DICOM-to-NIFTI converter node
converter=Node(Dcm2niix(), name='converter')
converter.inputs.compress='n' # do not compress -> SPM options etc.
converter.inputs.source_dir=sequencedir
converter.inputs.output_dir=subdir
converter.run()
# Out:
# 200124-15:38:14,358 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpjnxkds55/converter".
# 200124-15:38:14,362 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z n -x n -t n -m n -o /VBM/FED049 -s n -v n /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009
# 200124-15:38:14,833 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Chris Rorden's dcm2niiX version v1.0.20190902  (JP2:OpenJPEG) GCC6.3.0 (64-bit Linux)
# 200124-15:38:14,835 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Found 192 DICOM file(s)
# 200124-15:38:14,836 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:14.833851:Convert 192 DICOM as /VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009_t1_mprage_sag_iso_0.9_20151123115353_9 (256x256x192x1)
# 200124-15:38:15,102 nipype.interface INFO:
# 	 stdout 2020-01-24T15:38:15.102243:Conversion required 0.712450 seconds (0.546249 for core code).
# 200124-15:38:15,135 nipype.workflow INFO:
# 	 [Node] Finished "converter".
