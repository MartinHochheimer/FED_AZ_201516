# %%
# import everything you need
import numpy as np
import scipy as sp
import pandas as pd
# activate inline magics
# %matplotlib inline 
# import matplotlib.pyplot as plt
# import matplotlib.image as mpl_img
import seaborn as sns
# specific fo statistics
import pingouin as pg

# %% [markdown]
# Define neccesary parameters

# %%
data_file = "FED_fMRI_fullcodesfixed_final.xls"
covariate_file = "FED_Subject_Covariates.xls"

# %% [markdown]
# Create the neccessary factors and sort all variables appropriately

# %%
# extract - data from list in .xls file(s). Outliers and all known errors have already been corrected (see recent "ALLCODESFIXED")
# read relevant content
anova = pd.read_excel(data_file, sheet_name="Sheet1",
                      usecols = ['Subject', 'Condition', 'RT'])
covariates = pd.read_excel(covariate_file, sheet_name="analysis",
                           usecols = ['FED_ID', 'BDI_22_Score', 'Gender', 'Age', 'Race'])

# remove first six subjects
anova = anova[(anova.Subject.isin(range(7, 69)))]
covariates = covariates[(covariates.FED_ID.isin(range(7, 69)))]

# create variables cue_valence and cue_validity after Condition and assign values according to trial codings (neg, pos, neu) (valid, invalid)
neg, pos, neu = [1, 4, 7, 10], [2, 5, 8, 11], [3, 6, 9, 12]
valid, invalid = [val for val in range(7, 13)], [val for val in range(1, 7)]
# create list of group, valence and validity numerical indices
group_cats, valence_cats, validity_cats = ["dep", "con"], ["neg", "pos", "neu"], ["valid", "invalid"]
# copy Condition list and replace
anova['Cue_Valence'] = anova['Condition']
for valence, name in zip([neg, pos, neu], valence_cats):
    anova.loc[anova['Condition'].isin(valence), 'Cue_Valence'] = name

anova['Cue_Validity'] = anova['Condition']
for validity, name in zip([valid, invalid], validity_cats):
    anova.loc[anova['Condition'].isin(validity), 'Cue_Validity'] = name

# create variable DStatus after Subject and replace each subject value with the corresponding group identity
# separate covariate FED_IDs by BDI22
mdd = covariates.FED_ID[covariates['BDI_22_Score'] == 1]
control = covariates.FED_ID[covariates['BDI_22_Score'] == 0]
# copy Subject list and replace
anova['DStatus'] = anova['Subject']
anova.loc[anova['Subject'].isin(mdd), 'DStatus'] = group_cats[0]
anova.loc[anova['Subject'].isin(control), 'DStatus'] = group_cats[1]

# sort values by DStatus, valence and validity (by factor, starting with largest increment)
anova.sort_values(['DStatus', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# %%
pd.set_option('display.max_rows', None)
print(anova)
# Out:
#             RT  Subject  Condition Cue_Valence Cue_Validity DStatus
# 1080    302.35        7          1         neg      invalid     con
# 1081    256.12        7          1         neg      invalid     con
# 1082    285.54        7          1         neg      invalid     con
# 1083    303.62        7          1         neg      invalid     con
# 1084    266.26        7          1         neg      invalid     con
# 1085    294.58        7          1         neg      invalid     con
# 1086    332.54        7          1         neg      invalid     con
# 1087   -490.68        7          1         neg      invalid     con
# 1088    281.30        7          1         neg      invalid     con
# 1099    577.72        7          1         neg      invalid     con
# 1100    296.54        7          1         neg      invalid     con
# 1101    360.85        7          1         neg      invalid     con
# 1102    321.91        7          1         neg      invalid     con
# 1103    321.38        7          1         neg      invalid     con
# 1135    291.56        7          4         neg      invalid     con
# 1136    304.64        7          4         neg      invalid     con
# 1137    382.01        7          4         neg      invalid     con
# 1138    297.99        7          4         neg      invalid     con
# 1139    279.34        7          4         neg      invalid     con
# 1140    283.17        7          4         neg      invalid     con
# 1141    372.85        7          4         neg      invalid     con
# 1142    295.59        7          4         neg      invalid     con
# 1143    328.68        7          4         neg      invalid     con
# 1144    295.68        7          4         neg      invalid     con
# 1145    320.88        7          4         neg      invalid     con
# 1146    343.44        7          4         neg      invalid     con
# 1147    257.86        7          4         neg      invalid     con
# 1148    282.57        7          4         neg      invalid     con
# 1149    430.83        7          4         neg      invalid     con
# 1260    322.03        8          1         neg      invalid     con
# 1261    338.02        8          1         neg      invalid     con
# 1262    306.22        8          1         neg      invalid     con
# 1263    347.89        8          1         neg      invalid     con
# 1264    294.32        8          1         neg      invalid     con
# 1265    328.05        8          1         neg      invalid     con
# 1266    359.20        8          1         neg      invalid     con
# 1267    288.23        8          1         neg      invalid     con
# 1268    329.90        8          1         neg      invalid     con
# 1279    321.45        8          1         neg      invalid     con
# 1280    323.08        8          1         neg      invalid     con
# 1281    311.41        8          1         neg      invalid     con
# 1282    332.89        8          1         neg      invalid     con
# 1283    249.62        8          1         neg      invalid     con
# 1315    361.95        8          4         neg      invalid     con
# 1316    306.65        8          4         neg      invalid     con
# 1317    287.26        8          4         neg      invalid     con
# 1318    334.88        8          4         neg      invalid     con
# 1319    435.39        8          4         neg      invalid     con
# 1320    319.75        8          4         neg      invalid     con
# 1321    256.22        8          4         neg      invalid     con
# 1322    445.43        8          4         neg      invalid     con
# 1323    349.87        8          4         neg      invalid     con
# 1324    282.72        8          4         neg      invalid     con
# 1325    312.14        8          4         neg      invalid     con
# 1326    325.33        8          4         neg      invalid     con
# 1327    302.12        8          4         neg      invalid     con
# 1328    336.29        8          4         neg      invalid     con
# 1329    299.29        8          4         neg      invalid     con
# 1440    315.42        9          1         neg      invalid     con
# 1441    248.50        9          1         neg      invalid     con
# 1442    282.02        9          1         neg      invalid     con
# 1443    313.45        9          1         neg      invalid     con
# 1444    402.82        9          1         neg      invalid     con
# 1445    261.76        9          1         neg      invalid     con
# 1446    269.93        9          1         neg      invalid     con
# 1447    454.29        9          1         neg      invalid     con
# 1448    260.76        9          1         neg      invalid     con
# 1459    234.00        9          1         neg      invalid     con
# 1460    292.81        9          1         neg      invalid     con
# 1461    281.05        9          1         neg      invalid     con
# 1462    335.00        9          1         neg      invalid     con
# 1463    422.43        9          1         neg      invalid     con
# 1495    359.13        9          4         neg      invalid     con
# 1496    314.73        9          4         neg      invalid     con
# 1497    270.00        9          4         neg      invalid     con
# 1498    255.13        9          4         neg      invalid     con
# 1499    297.40        9          4         neg      invalid     con
# 1500    342.59        9          4         neg      invalid     con
# 1501    304.91        9          4         neg      invalid     con
# 1502    268.03        9          4         neg      invalid     con
# 1503    283.81        9          4         neg      invalid     con
# 1504    233.00        9          4         neg      invalid     con
# 1505    578.74        9          4         neg      invalid     con
# 1506    243.96        9          4         neg      invalid     con
# 1507    250.71        9          4         neg      invalid     con
# 1508    318.50        9          4         neg      invalid     con
# 1509    358.13        9          4         neg      invalid     con
# 1620    297.33       10          1         neg      invalid     con
# 1621    277.27       10          1         neg      invalid     con
# 1622    395.74       10          1         neg      invalid     con
# 1623    246.95       10          1         neg      invalid     con
# 1624    304.64       10          1         neg      invalid     con
# 1625    627.85       10          1         neg      invalid     con
# 1626    321.74       10          1         neg      invalid     con
# 1627    257.91       10          1         neg      invalid     con
# 1628    312.37       10          1         neg      invalid     con
# 1639    255.65       10          1         neg      invalid     con
# 1640    296.17       10          1         neg      invalid     con
# 1641    313.09       10          1         neg      invalid     con
# 1642    296.91       10          1         neg      invalid     con
# 1643    286.29       10          1         neg      invalid     con
# 1675    341.30       10          4         neg      invalid     con
# 1676    233.60       10          4         neg      invalid     con
# 1677    362.36       10          4         neg      invalid     con
# 1678    278.35       10          4         neg      invalid     con
# 1679    352.67       10          4         neg      invalid     con
# 1680    376.51       10          4         neg      invalid     con
# 1681    307.04       10          4         neg      invalid     con
# 1682    311.36       10          4         neg      invalid     con
# 1683    325.37       10          4         neg      invalid     con
# 1684    301.59       10          4         neg      invalid     con
# 1685    388.75       10          4         neg      invalid     con
# 1686    307.59       10          4         neg      invalid     con
# 1687    311.62       10          4         neg      invalid     con
# 1688    396.42       10          4         neg      invalid     con
# 1689    537.64       10          4         neg      invalid     con
# 1980    320.16       12          1         neg      invalid     con
# 1981    313.54       12          1         neg      invalid     con
# 1982    261.29       12          1         neg      invalid     con
# 1983    322.63       12          1         neg      invalid     con
# 1984    296.69       12          1         neg      invalid     con
# 1985    300.62       12          1         neg      invalid     con
# 1986    456.86       12          1         neg      invalid     con
# 1987    311.81       12          1         neg      invalid     con
# 1988    304.81       12          1         neg      invalid     con
# 1999    251.78       12          1         neg      invalid     con
# 2000    311.06       12          1         neg      invalid     con
# 2001    279.73       12          1         neg      invalid     con
# 2002    325.03       12          1         neg      invalid     con
# 2003    316.20       12          1         neg      invalid     con
# 2035    374.47       12          4         neg      invalid     con
# 2036    289.87       12          4         neg      invalid     con
# 2037    265.73       12          4         neg      invalid     con
# 2038    298.58       12          4         neg      invalid     con
# 2039    317.36       12          4         neg      invalid     con
# 2040    278.59       12          4         neg      invalid     con
# 2041    285.04       12          4         neg      invalid     con
# 2042    278.44       12          4         neg      invalid     con
# 2043    390.02       12          4         neg      invalid     con
# 2044    316.44       12          4         neg      invalid     con
# 2045    367.25       12          4         neg      invalid     con
# 2046    346.24       12          4         neg      invalid     con
# 2047    314.80       12          4         neg      invalid     con
# 2048    437.89       12          4         neg      invalid     con
# 2049    284.61       12          4         neg      invalid     con
# 2160    222.74       13          1         neg      invalid     con
# 2161   -269.33       13          1         neg      invalid     con
# 2162    332.31       13          1         neg      invalid     con
# 2163    273.33       13          1         neg      invalid     con
# 2164    653.55       13          1         neg      invalid     con
# 2165    420.35       13          1         neg      invalid     con
# 2166    284.87       13          1         neg      invalid     con
# 2167    389.14       13          1         neg      invalid     con
# 2168    464.67       13          1         neg      invalid     con
# 2179    355.28       13          1         neg      invalid     con
# 2180    398.82       13          1         neg      invalid     con
# 2181    328.74       13          1         neg      invalid     con
# 2182    573.45       13          1         neg      invalid     con
# 2183    245.71       13          1         neg      invalid     con
# 2215    251.27       13          4         neg      invalid     con
# 2216   -341.77       13          4         neg      invalid     con
# 2217    300.54       13          4         neg      invalid     con
# 2218    394.50       13          4         neg      invalid     con
# 2219    250.04       13          4         neg      invalid     con
# 2220    395.05       13          4         neg      invalid     con
# 2221    233.70       13          4         neg      invalid     con
# 2222    430.49       13          4         neg      invalid     con
# 2223    413.46       13          4         neg      invalid     con
# 2224    262.72       13          4         neg      invalid     con
# 2225    511.27       13          4         neg      invalid     con
# 2226    744.09       13          4         neg      invalid     con
# 2227    328.51       13          4         neg      invalid     con
# 2228    551.68       13          4         neg      invalid     con
# 2229    434.46       13          4         neg      invalid     con
# 2520    339.58       15          1         neg      invalid     con
# 2521    390.46       15          1         neg      invalid     con
# 2522    455.41       15          1         neg      invalid     con
# 2523    319.17       15          1         neg      invalid     con
# 2524    389.03       15          1         neg      invalid     con
# 2525    407.94       15          1         neg      invalid     con
# 2526    386.01       15          1         neg      invalid     con
# 2527    439.45       15          1         neg      invalid     con
# 2528    475.79       15          1         neg      invalid     con
# 2539    443.47       15          1         neg      invalid     con
# 2540    304.17       15          1         neg      invalid     con
# 2541    442.34       15          1         neg      invalid     con
# 2542    514.57       15          1         neg      invalid     con
# 2543    362.30       15          1         neg      invalid     con
# 2575    471.83       15          4         neg      invalid     con
# 2576    497.71       15          4         neg      invalid     con
# 2577    489.20       15          4         neg      invalid     con
# 2578    443.84       15          4         neg      invalid     con
# 2579    629.33       15          4         neg      invalid     con
# 2580    429.00       15          4         neg      invalid     con
# 2581    399.85       15          4         neg      invalid     con
# 2582    453.10       15          4         neg      invalid     con
# 2583    397.42       15          4         neg      invalid     con
# 2584    375.15       15          4         neg      invalid     con
# 2585    375.02       15          4         neg      invalid     con
# 2586    316.31       15          4         neg      invalid     con
# 2587    364.37       15          4         neg      invalid     con
# 2588    407.44       15          4         neg      invalid     con
# 2589    360.98       15          4         neg      invalid     con
# 2700    277.35       16          1         neg      invalid     con
# 2701    352.25       16          1         neg      invalid     con
# 2702    330.85       16          1         neg      invalid     con
# 2703    251.39       16          1         neg      invalid     con
# 2704    267.24       16          1         neg      invalid     con
# 2705    238.11       16          1         neg      invalid     con
# 2706    242.77       16          1         neg      invalid     con
# 2707    275.94       16          1         neg      invalid     con
# 2708    297.32       16          1         neg      invalid     con
# 2719    307.14       16          1         neg      invalid     con
# 2720    336.36       16          1         neg      invalid     con
# 2721    228.74       16          1         neg      invalid     con
# 2722    299.13       16          1         neg      invalid     con
# 2723    290.43       16          1         neg      invalid     con
# 2755    301.28       16          4         neg      invalid     con
# 2756    196.31       16          4         neg      invalid     con
# 2757    311.91       16          4         neg      invalid     con
# 2758    407.36       16          4         neg      invalid     con
# 2759    211.99       16          4         neg      invalid     con
# 2760    247.18       16          4         neg      invalid     con
# 2761    316.75       16          4         neg      invalid     con
# 2762    283.87       16          4         neg      invalid     con
# 2763    257.31       16          4         neg      invalid     con
# 2764    256.09       16          4         neg      invalid     con
# 2765    272.42       16          4         neg      invalid     con
# 2766    233.56       16          4         neg      invalid     con
# 2767    266.58       16          4         neg      invalid     con
# 2768    257.79       16          4         neg      invalid     con
# 2769    216.70       16          4         neg      invalid     con
# 2880    254.18       17          1         neg      invalid     con
# 2881    278.09       17          1         neg      invalid     con
# 2882    274.19       17          1         neg      invalid     con
# 2883    279.47       17          1         neg      invalid     con
# 2884    325.89       17          1         neg      invalid     con
# 2885    249.55       17          1         neg      invalid     con
# 2886    231.50       17          1         neg      invalid     con
# 2887    250.59       17          1         neg      invalid     con
# 2888    304.75       17          1         neg      invalid     con
# 2899    292.00       17          1         neg      invalid     con
# 2900    280.41       17          1         neg      invalid     con
# 2901    287.69       17          1         neg      invalid     con
# 2902    277.63       17          1         neg      invalid     con
# 2903    206.69       17          1         neg      invalid     con
# 2935    303.40       17          4         neg      invalid     con
# 2936    261.15       17          4         neg      invalid     con
# 2937    270.57       17          4         neg      invalid     con
# 2938    250.99       17          4         neg      invalid     con
# 2939    246.45       17          4         neg      invalid     con
# 2940    251.66       17          4         neg      invalid     con
# 2941    257.49       17          4         neg      invalid     con
# 2942    254.34       17          4         neg      invalid     con
# 2943    284.68       17          4         neg      invalid     con
# 2944    251.62       17          4         neg      invalid     con
# 2945    230.86       17          4         neg      invalid     con
# 2946    251.22       17          4         neg      invalid     con
# 2947    226.18       17          4         neg      invalid     con
# 2948    237.85       17          4         neg      invalid     con
# 2949    336.22       17          4         neg      invalid     con
# 3240    271.50       19          1         neg      invalid     con
# 3241    346.26       19          1         neg      invalid     con
# 3242    305.29       19          1         neg      invalid     con
# 3243    256.07       19          1         neg      invalid     con
# 3244    297.62       19          1         neg      invalid     con
# 3245    265.66       19          1         neg      invalid     con
# 3246    557.94       19          1         neg      invalid     con
# 3247    256.57       19          1         neg      invalid     con
# 3248    266.34       19          1         neg      invalid     con
# 3259    424.59       19          1         neg      invalid     con
# 3260    329.23       19          1         neg      invalid     con
# 3261    367.54       19          1         neg      invalid     con
# 3262    254.89       19          1         neg      invalid     con
# 3263    289.66       19          1         neg      invalid     con
# 3295    307.83       19          4         neg      invalid     con
# 3296    354.08       19          4         neg      invalid     con
# 3297    275.54       19          4         neg      invalid     con
# 3298    310.59       19          4         neg      invalid     con
# 3299    360.30       19          4         neg      invalid     con
# 3300    345.10       19          4         neg      invalid     con
# 3301    308.15       19          4         neg      invalid     con
# 3302    291.30       19          4         neg      invalid     con
# 3303    339.37       19          4         neg      invalid     con
# 3304    317.85       19          4         neg      invalid     con
# 3305    264.77       19          4         neg      invalid     con
# 3306    601.76       19          4         neg      invalid     con
# 3307    311.83       19          4         neg      invalid     con
# 3308    351.61       19          4         neg      invalid     con
# 3309    265.83       19          4         neg      invalid     con
# 3420    249.64       20          1         neg      invalid     con
# 3421    323.94       20          1         neg      invalid     con
# 3422    285.21       20          1         neg      invalid     con
# 3423    237.66       20          1         neg      invalid     con
# 3424    314.85       20          1         neg      invalid     con
# 3425    296.65       20          1         neg      invalid     con
# 3426    267.08       20          1         neg      invalid     con
# 3427    232.01       20          1         neg      invalid     con
# 3428    239.41       20          1         neg      invalid     con
# 3439    254.67       20          1         neg      invalid     con
# 3440    255.37       20          1         neg      invalid     con
# 3441    229.93       20          1         neg      invalid     con
# 3442    214.18       20          1         neg      invalid     con
# 3443   -205.07       20          1         neg      invalid     con
# 3475    255.99       20          4         neg      invalid     con
# 3476    300.25       20          4         neg      invalid     con
# 3477    295.32       20          4         neg      invalid     con
# 3478    269.15       20          4         neg      invalid     con
# 3479    282.85       20          4         neg      invalid     con
# 3480    292.23       20          4         neg      invalid     con
# 3481    254.54       20          4         neg      invalid     con
# 3482    -96.77       20          4         neg      invalid     con
# 3483    247.44       20          4         neg      invalid     con
# 3484    289.23       20          4         neg      invalid     con
# 3485    270.88       20          4         neg      invalid     con
# 3486    255.90       20          4         neg      invalid     con
# 3487    281.43       20          4         neg      invalid     con
# 3488    237.83       20          4         neg      invalid     con
# 3489    284.62       20          4         neg      invalid     con
# 3600    525.57       21          1         neg      invalid     con
# 3601    277.27       21          1         neg      invalid     con
# 3602    401.99       21          1         neg      invalid     con
# 3603    429.34       21          1         neg      invalid     con
# 3604    394.14       21          1         neg      invalid     con
# 3605    385.93       21          1         neg      invalid     con
# 3606    384.64       21          1         neg      invalid     con
# 3607    346.61       21          1         neg      invalid     con
# 3608    303.53       21          1         neg      invalid     con
# 3619    650.59       21          1         neg      invalid     con
# 3620    307.43       21          1         neg      invalid     con
# 3621    342.25       21          1         neg      invalid     con
# 3622    352.87       21          1         neg      invalid     con
# 3623    333.01       21          1         neg      invalid     con
# 3655    340.73       21          4         neg      invalid     con
# 3656    417.67       21          4         neg      invalid     con
# 3657    377.57       21          4         neg      invalid     con
# 3658    351.60       21          4         neg      invalid     con
# 3659    357.16       21          4         neg      invalid     con
# 3660    359.46       21          4         neg      invalid     con
# 3661    314.12       21          4         neg      invalid     con
# 3662    351.35       21          4         neg      invalid     con
# 3663    353.71       21          4         neg      invalid     con
# 3664    424.20       21          4         neg      invalid     con
# 3665    366.62       21          4         neg      invalid     con
# 3666    356.16       21          4         neg      invalid     con
# 3667    439.09       21          4         neg      invalid     con
# 3668    333.41       21          4         neg      invalid     con
# 3669    370.30       21          4         neg      invalid     con
# 3780    291.69       22          1         neg      invalid     con
# 3781    247.73       22          1         neg      invalid     con
# 3782    324.65       22          1         neg      invalid     con
# 3783    261.33       22          1         neg      invalid     con
# 3784    311.93       22          1         neg      invalid     con
# 3785    282.35       22          1         neg      invalid     con
# 3786    270.03       22          1         neg      invalid     con
# 3787    293.57       22          1         neg      invalid     con
# 3788    288.45       22          1         neg      invalid     con
# 3799    244.09       22          1         neg      invalid     con
# 3800    313.88       22          1         neg      invalid     con
# 3801    354.75       22          1         neg      invalid     con
# 3802   -188.80       22          1         neg      invalid     con
# 3803    290.99       22          1         neg      invalid     con
# 3835    385.44       22          4         neg      invalid     con
# 3836    283.21       22          4         neg      invalid     con
# 3837    246.86       22          4         neg      invalid     con
# 3838    298.00       22          4         neg      invalid     con
# 3839    303.96       22          4         neg      invalid     con
# 3840    260.52       22          4         neg      invalid     con
# 3841    302.97       22          4         neg      invalid     con
# 3842    295.13       22          4         neg      invalid     con
# 3843    314.35       22          4         neg      invalid     con
# 3844    312.76       22          4         neg      invalid     con
# 3845    339.74       22          4         neg      invalid     con
# 3846    263.53       22          4         neg      invalid     con
# 3847    352.82       22          4         neg      invalid     con
# 3848    291.95       22          4         neg      invalid     con
# 3849    310.03       22          4         neg      invalid     con
# 3960    254.39       23          1         neg      invalid     con
# 3961    335.74       23          1         neg      invalid     con
# 3962    288.97       23          1         neg      invalid     con
# 3963    264.44       23          1         neg      invalid     con
# 3964    275.37       23          1         neg      invalid     con
# 3965    317.33       23          1         neg      invalid     con
# 3966    276.51       23          1         neg      invalid     con
# 3967    280.26       23          1         neg      invalid     con
# 3968    266.13       23          1         neg      invalid     con
# 3979    252.10       23          1         neg      invalid     con
# 3980    283.53       23          1         neg      invalid     con
# 3981    303.10       23          1         neg      invalid     con
# 3982    274.71       23          1         neg      invalid     con
# 3983    276.89       23          1         neg      invalid     con
# 4015    354.40       23          4         neg      invalid     con
# 4016    251.33       23          4         neg      invalid     con
# 4017    273.84       23          4         neg      invalid     con
# 4018    310.15       23          4         neg      invalid     con
# 4019    323.22       23          4         neg      invalid     con
# 4020    320.96       23          4         neg      invalid     con
# 4021    281.92       23          4         neg      invalid     con
# 4022    273.06       23          4         neg      invalid     con
# 4023    260.34       23          4         neg      invalid     con
# 4024    284.01       23          4         neg      invalid     con
# 4025    408.12       23          4         neg      invalid     con
# 4026    310.01       23          4         neg      invalid     con
# 4027    318.11       23          4         neg      invalid     con
# 4028    276.57       23          4         neg      invalid     con
# 4029    334.78       23          4         neg      invalid     con
# 4140    343.54       24          1         neg      invalid     con
# 4141    269.73       24          1         neg      invalid     con
# 4142    224.96       24          1         neg      invalid     con
# 4143    354.32       24          1         neg      invalid     con
# 4144    302.26       24          1         neg      invalid     con
# 4145    296.97       24          1         neg      invalid     con
# 4146    280.55       24          1         neg      invalid     con
# 4147    375.02       24          1         neg      invalid     con
# 4148    239.83       24          1         neg      invalid     con
# 4159    338.60       24          1         neg      invalid     con
# 4160    344.82       24          1         neg      invalid     con
# 4161    290.35       24          1         neg      invalid     con
# 4162    281.01       24          1         neg      invalid     con
# 4163    245.22       24          1         neg      invalid     con
# 4195    275.88       24          4         neg      invalid     con
# 4196    335.92       24          4         neg      invalid     con
# 4197    353.09       24          4         neg      invalid     con
# 4198    261.71       24          4         neg      invalid     con
# 4199    314.50       24          4         neg      invalid     con
# 4200    600.01       24          4         neg      invalid     con
# 4201    244.59       24          4         neg      invalid     con
# 4202    335.29       24          4         neg      invalid     con
# 4203    327.26       24          4         neg      invalid     con
# 4204    299.04       24          4         neg      invalid     con
# 4205    319.54       24          4         neg      invalid     con
# 4206    328.32       24          4         neg      invalid     con
# 4207    246.85       24          4         neg      invalid     con
# 4208    403.87       24          4         neg      invalid     con
# 4209    345.42       24          4         neg      invalid     con
# 4320    319.06       25          1         neg      invalid     con
# 4321    276.66       25          1         neg      invalid     con
# 4322    317.91       25          1         neg      invalid     con
# 4323    301.71       25          1         neg      invalid     con
# 4324    302.86       25          1         neg      invalid     con
# 4325    260.06       25          1         neg      invalid     con
# 4326    294.80       25          1         neg      invalid     con
# 4327    343.11       25          1         neg      invalid     con
# 4328    283.07       25          1         neg      invalid     con
# 4339    394.38       25          1         neg      invalid     con
# 4340    268.16       25          1         neg      invalid     con
# 4341    370.72       25          1         neg      invalid     con
# 4342    302.09       25          1         neg      invalid     con
# 4343    280.00       25          1         neg      invalid     con
# 4375    312.10       25          4         neg      invalid     con
# 4376    283.28       25          4         neg      invalid     con
# 4377    367.18       25          4         neg      invalid     con
# 4378    282.59       25          4         neg      invalid     con
# 4379    314.05       25          4         neg      invalid     con
# 4380    365.19       25          4         neg      invalid     con
# 4381    328.48       25          4         neg      invalid     con
# 4382    350.14       25          4         neg      invalid     con
# 4383    261.33       25          4         neg      invalid     con
# 4384    330.25       25          4         neg      invalid     con
# 4385    232.63       25          4         neg      invalid     con
# 4386    388.60       25          4         neg      invalid     con
# 4387    342.51       25          4         neg      invalid     con
# 4388    321.41       25          4         neg      invalid     con
# 4389    314.62       25          4         neg      invalid     con
# 4500    327.26       26          1         neg      invalid     con
# 4501    466.91       26          1         neg      invalid     con
# 4502    225.21       26          1         neg      invalid     con
# 4503    392.06       26          1         neg      invalid     con
# 4504    390.23       26          1         neg      invalid     con
# 4505    279.86       26          1         neg      invalid     con
# 4506    361.14       26          1         neg      invalid     con
# 4507    232.91       26          1         neg      invalid     con
# 4508    301.61       26          1         neg      invalid     con
# 4519    296.03       26          1         neg      invalid     con
# 4520    313.44       26          1         neg      invalid     con
# 4521    378.09       26          1         neg      invalid     con
# 4522    371.14       26          1         neg      invalid     con
# 4523    288.88       26          1         neg      invalid     con
# 4555    342.73       26          4         neg      invalid     con
# 4556    378.59       26          4         neg      invalid     con
# 4557    391.33       26          4         neg      invalid     con
# 4558    501.67       26          4         neg      invalid     con
# 4559    419.95       26          4         neg      invalid     con
# 4560    335.04       26          4         neg      invalid     con
# 4561    325.05       26          4         neg      invalid     con
# 4562    355.25       26          4         neg      invalid     con
# 4563    422.43       26          4         neg      invalid     con
# 4564    333.17       26          4         neg      invalid     con
# 4565    315.73       26          4         neg      invalid     con
# 4566    341.96       26          4         neg      invalid     con
# 4567    315.96       26          4         neg      invalid     con
# 4568    340.34       26          4         neg      invalid     con
# 4569    353.57       26          4         neg      invalid     con
# 8640    498.23       49          1         neg      invalid     con
# 8641    284.01       49          1         neg      invalid     con
# 8642    304.98       49          1         neg      invalid     con
# 8643    350.01       49          1         neg      invalid     con
# 8644    304.04       49          1         neg      invalid     con
# 8645    267.72       49          1         neg      invalid     con
# 8646    295.56       49          1         neg      invalid     con
# 8647    369.33       49          1         neg      invalid     con
# 8648    372.93       49          1         neg      invalid     con
# 8659    506.51       49          1         neg      invalid     con
# 8660    348.32       49          1         neg      invalid     con
# 8661    436.40       49          1         neg      invalid     con
# 8662    289.62       49          1         neg      invalid     con
# 8663    410.11       49          1         neg      invalid     con
# 8695    382.10       49          4         neg      invalid     con
# 8696    422.19       49          4         neg      invalid     con
# 8697    275.84       49          4         neg      invalid     con
# 8698    343.71       49          4         neg      invalid     con
# 8699    304.79       49          4         neg      invalid     con
# 8700    442.55       49          4         neg      invalid     con
# 8701    191.49       49          4         neg      invalid     con
# 8702    344.36       49          4         neg      invalid     con
# 8703    281.38       49          4         neg      invalid     con
# 8704    271.61       49          4         neg      invalid     con
# 8705    266.19       49          4         neg      invalid     con
# 8706    284.63       49          4         neg      invalid     con
# 8707    263.35       49          4         neg      invalid     con
# 8708    384.61       49          4         neg      invalid     con
# 8709    431.03       49          4         neg      invalid     con
# 8820    260.66       50          1         neg      invalid     con
# 8821    224.34       50          1         neg      invalid     con
# 8822    282.90       50          1         neg      invalid     con
# 8823    308.58       50          1         neg      invalid     con
# 8824    237.16       50          1         neg      invalid     con
# 8825    245.36       50          1         neg      invalid     con
# 8826    306.87       50          1         neg      invalid     con
# 8827    287.37       50          1         neg      invalid     con
# 8828    307.84       50          1         neg      invalid     con
# 8839    258.30       50          1         neg      invalid     con
# 8840    245.18       50          1         neg      invalid     con
# 8841    274.96       50          1         neg      invalid     con
# 8842    276.15       50          1         neg      invalid     con
# 8843    238.56       50          1         neg      invalid     con
# 8875    257.05       50          4         neg      invalid     con
# 8876    239.69       50          4         neg      invalid     con
# 8877    343.29       50          4         neg      invalid     con
# 8878    257.15       50          4         neg      invalid     con
# 8879    507.49       50          4         neg      invalid     con
# 8880    291.34       50          4         neg      invalid     con
# 8881    314.81       50          4         neg      invalid     con
# 8882    312.74       50          4         neg      invalid     con
# 8883    286.85       50          4         neg      invalid     con
# 8884    335.83       50          4         neg      invalid     con
# 8885    261.57       50          4         neg      invalid     con
# 8886    301.08       50          4         neg      invalid     con
# 8887    297.43       50          4         neg      invalid     con
# 8888    286.60       50          4         neg      invalid     con
# 8889    306.35       50          4         neg      invalid     con
# 9360    333.63       53          1         neg      invalid     con
# 9361    500.75       53          1         neg      invalid     con
# 9362    508.93       53          1         neg      invalid     con
# 9363    332.09       53          1         neg      invalid     con
# 9364    533.55       53          1         neg      invalid     con
# 9365    399.07       53          1         neg      invalid     con
# 9366    509.48       53          1         neg      invalid     con
# 9367    413.80       53          1         neg      invalid     con
# 9368    350.95       53          1         neg      invalid     con
# 9379    508.48       53          1         neg      invalid     con
# 9380    460.90       53          1         neg      invalid     con
# 9381    477.12       53          1         neg      invalid     con
# 9382    377.12       53          1         neg      invalid     con
# 9383    518.75       53          1         neg      invalid     con
# 9415    436.18       53          4         neg      invalid     con
# 9416    427.13       53          4         neg      invalid     con
# 9417    310.16       53          4         neg      invalid     con
# 9418    334.07       53          4         neg      invalid     con
# 9419    422.03       53          4         neg      invalid     con
# 9420    332.84       53          4         neg      invalid     con
# 9421    377.38       53          4         neg      invalid     con
# 9422    495.64       53          4         neg      invalid     con
# 9423    331.68       53          4         neg      invalid     con
# 9424    357.41       53          4         neg      invalid     con
# 9425    359.50       53          4         neg      invalid     con
# 9426    375.72       53          4         neg      invalid     con
# 9427    526.95       53          4         neg      invalid     con
# 9428    284.09       53          4         neg      invalid     con
# 9429    574.78       53          4         neg      invalid     con
# 9540    239.19       54          1         neg      invalid     con
# 9541    278.43       54          1         neg      invalid     con
# 9542    267.81       54          1         neg      invalid     con
# 9543    317.88       54          1         neg      invalid     con
# 9544    251.03       54          1         neg      invalid     con
# 9545    285.73       54          1         neg      invalid     con
# 9546    283.37       54          1         neg      invalid     con
# 9547    291.39       54          1         neg      invalid     con
# 9548    265.42       54          1         neg      invalid     con
# 9559    224.08       54          1         neg      invalid     con
# 9560    275.18       54          1         neg      invalid     con
# 9561    460.59       54          1         neg      invalid     con
# 9562    250.44       54          1         neg      invalid     con
# 9563    262.36       54          1         neg      invalid     con
# 9595    384.44       54          4         neg      invalid     con
# 9596    261.97       54          4         neg      invalid     con
# 9597    257.75       54          4         neg      invalid     con
# 9598    317.26       54          4         neg      invalid     con
# 9599    303.13       54          4         neg      invalid     con
# 9600    320.42       54          4         neg      invalid     con
# 9601    262.17       54          4         neg      invalid     con
# 9602    288.06       54          4         neg      invalid     con
# 9603    389.91       54          4         neg      invalid     con
# 9604    253.17       54          4         neg      invalid     con
# 9605    251.12       54          4         neg      invalid     con
# 9606    264.00       54          4         neg      invalid     con
# 9607    264.07       54          4         neg      invalid     con
# 9608    286.69       54          4         neg      invalid     con
# 9609    281.73       54          4         neg      invalid     con
# 9900    271.13       56          1         neg      invalid     con
# 9901    272.62       56          1         neg      invalid     con
# 9902    299.92       56          1         neg      invalid     con
# 9903    344.03       56          1         neg      invalid     con
# 9904    326.54       56          1         neg      invalid     con
# 9905    309.08       56          1         neg      invalid     con
# 9906    299.67       56          1         neg      invalid     con
# 9907    266.37       56          1         neg      invalid     con
# 9908    313.80       56          1         neg      invalid     con
# 9919    335.48       56          1         neg      invalid     con
# 9920    325.10       56          1         neg      invalid     con
# 9921    303.91       56          1         neg      invalid     con
# 9922    290.79       56          1         neg      invalid     con
# 9923    330.01       56          1         neg      invalid     con
# 9955    408.13       56          4         neg      invalid     con
# 9956    332.49       56          4         neg      invalid     con
# 9957    287.74       56          4         neg      invalid     con
# 9958    287.48       56          4         neg      invalid     con
# 9959    425.16       56          4         neg      invalid     con
# 9960    297.00       56          4         neg      invalid     con
# 9961    379.24       56          4         neg      invalid     con
# 9962    417.14       56          4         neg      invalid     con
# 9963    298.03       56          4         neg      invalid     con
# 9964    299.70       56          4         neg      invalid     con
# 9965    250.07       56          4         neg      invalid     con
# 9966    337.62       56          4         neg      invalid     con
# 9967    337.42       56          4         neg      invalid     con
# 9968    336.93       56          4         neg      invalid     con
# 9969    283.08       56          4         neg      invalid     con
# 10260   340.19       58          1         neg      invalid     con
# 10261   306.30       58          1         neg      invalid     con
# 10262   308.75       58          1         neg      invalid     con
# 10263   256.78       58          1         neg      invalid     con
# 10264   355.62       58          1         neg      invalid     con
# 10265   274.46       58          1         neg      invalid     con
# 10266   270.31       58          1         neg      invalid     con
# 10267   288.18       58          1         neg      invalid     con
# 10268   303.74       58          1         neg      invalid     con
# 10279   366.77       58          1         neg      invalid     con
# 10280   266.69       58          1         neg      invalid     con
# 10281   271.24       58          1         neg      invalid     con
# 10282   324.32       58          1         neg      invalid     con
# 10283   279.28       58          1         neg      invalid     con
# 10315   253.49       58          4         neg      invalid     con
# 10316   451.61       58          4         neg      invalid     con
# 10317   318.19       58          4         neg      invalid     con
# 10318   296.28       58          4         neg      invalid     con
# 10319   302.42       58          4         neg      invalid     con
# 10320   309.21       58          4         neg      invalid     con
# 10321   247.69       58          4         neg      invalid     con
# 10322   411.55       58          4         neg      invalid     con
# 10323   337.67       58          4         neg      invalid     con
# 10324  2770.18       58          4         neg      invalid     con
# 10325   301.95       58          4         neg      invalid     con
# 10326   315.26       58          4         neg      invalid     con
# 10327   274.01       58          4         neg      invalid     con
# 10328   504.98       58          4         neg      invalid     con
# 10329   318.01       58          4         neg      invalid     con
# 10620   329.86       60          1         neg      invalid     con
# 10621   362.44       60          1         neg      invalid     con
# 10622   374.03       60          1         neg      invalid     con
# 10623   381.70       60          1         neg      invalid     con
# 10624   546.19       60          1         neg      invalid     con
# 10625   409.82       60          1         neg      invalid     con
# 10626   398.92       60          1         neg      invalid     con
# 10627   384.13       60          1         neg      invalid     con
# 10628   405.19       60          1         neg      invalid     con
# 10639   331.47       60          1         neg      invalid     con
# 10640   359.10       60          1         neg      invalid     con
# 10641   329.56       60          1         neg      invalid     con
# 10642   337.79       60          1         neg      invalid     con
# 10643   346.43       60          1         neg      invalid     con
# 10675   443.10       60          4         neg      invalid     con
# 10676   365.33       60          4         neg      invalid     con
# 10677   406.81       60          4         neg      invalid     con
# 10678   381.77       60          4         neg      invalid     con
# 10679   347.12       60          4         neg      invalid     con
# 10680   398.02       60          4         neg      invalid     con
# 10681   434.68       60          4         neg      invalid     con
# 10682   338.78       60          4         neg      invalid     con
# 10683   360.08       60          4         neg      invalid     con
# 10684   370.04       60          4         neg      invalid     con
# 10685   356.30       60          4         neg      invalid     con
# 10686   397.85       60          4         neg      invalid     con
# 10687   422.23       60          4         neg      invalid     con
# 10688   342.34       60          4         neg      invalid     con
# 10689   381.78       60          4         neg      invalid     con
# 10800   347.16       61          1         neg      invalid     con
# 10801   289.36       61          1         neg      invalid     con
# 10802   295.35       61          1         neg      invalid     con
# 10803   292.25       61          1         neg      invalid     con
# 10804   341.77       61          1         neg      invalid     con
# 10805   279.85       61          1         neg      invalid     con
# 10806   272.35       61          1         neg      invalid     con
# 10807   273.86       61          1         neg      invalid     con
# ...
# 8390    252.58       47          8         pos        valid     dep
# 8391    285.40       47          8         pos        valid     dep
# 8392    391.01       47          8         pos        valid     dep
# 8393    394.72       47          8         pos        valid     dep
# 8394    282.22       47          8         pos        valid     dep
# 8395    410.61       47          8         pos        valid     dep
# 8396    400.67       47          8         pos        valid     dep
# 8397    319.26       47          8         pos        valid     dep
# 8398    303.77       47          8         pos        valid     dep
# 8399    352.21       47          8         pos        valid     dep
# 8430    374.45       47         11         pos        valid     dep
# 8431    592.17       47         11         pos        valid     dep
# 8432    368.76       47         11         pos        valid     dep
# 8433    346.47       47         11         pos        valid     dep
# 8434    243.75       47         11         pos        valid     dep
# 8435    314.92       47         11         pos        valid     dep
# 8436    355.17       47         11         pos        valid     dep
# 8437    260.26       47         11         pos        valid     dep
# 8438    330.57       47         11         pos        valid     dep
# 8439    545.59       47         11         pos        valid     dep
# 8440    318.84       47         11         pos        valid     dep
# 8441    417.28       47         11         pos        valid     dep
# 8442    272.56       47         11         pos        valid     dep
# 8443    295.08       47         11         pos        valid     dep
# 8444    284.18       47         11         pos        valid     dep
# 8478    394.12       48          8         pos        valid     dep
# 8566    476.03       48          8         pos        valid     dep
# 8567    545.78       48          8         pos        valid     dep
# 8568    400.24       48          8         pos        valid     dep
# 8569    517.39       48          8         pos        valid     dep
# 8570    371.68       48          8         pos        valid     dep
# 8571    361.97       48          8         pos        valid     dep
# 8572    483.87       48          8         pos        valid     dep
# 8573    430.63       48          8         pos        valid     dep
# 8574    385.94       48          8         pos        valid     dep
# 8575    302.98       48          8         pos        valid     dep
# 8576    388.77       48          8         pos        valid     dep
# 8577    424.52       48          8         pos        valid     dep
# 8578    323.07       48          8         pos        valid     dep
# 8579    480.22       48          8         pos        valid     dep
# 8610    369.29       48         11         pos        valid     dep
# 8611    302.65       48         11         pos        valid     dep
# 8612    396.21       48         11         pos        valid     dep
# 8613    426.09       48         11         pos        valid     dep
# 8614    369.76       48         11         pos        valid     dep
# 8615    365.23       48         11         pos        valid     dep
# 8616    321.65       48         11         pos        valid     dep
# 8617    477.21       48         11         pos        valid     dep
# 8618    353.77       48         11         pos        valid     dep
# 8619    447.29       48         11         pos        valid     dep
# 8620    351.59       48         11         pos        valid     dep
# 8621    270.78       48         11         pos        valid     dep
# 8622    351.83       48         11         pos        valid     dep
# 8623    366.20       48         11         pos        valid     dep
# 8624    334.99       48         11         pos        valid     dep
# 9018    337.28       51          8         pos        valid     dep
# 9106    290.68       51          8         pos        valid     dep
# 9107    279.59       51          8         pos        valid     dep
# 9108    277.82       51          8         pos        valid     dep
# 9109    275.65       51          8         pos        valid     dep
# 9110    229.77       51          8         pos        valid     dep
# 9111    281.95       51          8         pos        valid     dep
# 9112    299.44       51          8         pos        valid     dep
# 9113    359.85       51          8         pos        valid     dep
# 9114    331.10       51          8         pos        valid     dep
# 9115    306.12       51          8         pos        valid     dep
# 9116    462.75       51          8         pos        valid     dep
# 9117    230.54       51          8         pos        valid     dep
# 9118    534.86       51          8         pos        valid     dep
# 9119    298.94       51          8         pos        valid     dep
# 9150    296.63       51         11         pos        valid     dep
# 9151    234.74       51         11         pos        valid     dep
# 9152    349.19       51         11         pos        valid     dep
# 9153    227.13       51         11         pos        valid     dep
# 9154    291.38       51         11         pos        valid     dep
# 9155    245.64       51         11         pos        valid     dep
# 9156    288.45       51         11         pos        valid     dep
# 9157    293.01       51         11         pos        valid     dep
# 9158    382.49       51         11         pos        valid     dep
# 9159    281.91       51         11         pos        valid     dep
# 9160    546.03       51         11         pos        valid     dep
# 9161    300.64       51         11         pos        valid     dep
# 9162    204.63       51         11         pos        valid     dep
# 9163    281.25       51         11         pos        valid     dep
# 9164    257.06       51         11         pos        valid     dep
# 9198    330.92       52          8         pos        valid     dep
# 9286    350.67       52          8         pos        valid     dep
# 9287    335.63       52          8         pos        valid     dep
# 9288    285.61       52          8         pos        valid     dep
# 9289    410.03       52          8         pos        valid     dep
# 9290    326.51       52          8         pos        valid     dep
# 9291    356.51       52          8         pos        valid     dep
# 9292    333.09       52          8         pos        valid     dep
# 9293    308.95       52          8         pos        valid     dep
# 9294    306.63       52          8         pos        valid     dep
# 9295    367.63       52          8         pos        valid     dep
# 9296    316.86       52          8         pos        valid     dep
# 9297    296.90       52          8         pos        valid     dep
# 9298    292.86       52          8         pos        valid     dep
# 9299    376.04       52          8         pos        valid     dep
# 9330    305.26       52         11         pos        valid     dep
# 9331    221.70       52         11         pos        valid     dep
# 9332    264.54       52         11         pos        valid     dep
# 9333    357.52       52         11         pos        valid     dep
# 9334    270.33       52         11         pos        valid     dep
# 9335    371.71       52         11         pos        valid     dep
# 9336    323.32       52         11         pos        valid     dep
# 9337    285.95       52         11         pos        valid     dep
# 9338    296.63       52         11         pos        valid     dep
# 9339    409.36       52         11         pos        valid     dep
# 9340    280.62       52         11         pos        valid     dep
# 9341    313.60       52         11         pos        valid     dep
# 9342    360.60       52         11         pos        valid     dep
# 9343    309.81       52         11         pos        valid     dep
# 9344    338.49       52         11         pos        valid     dep
# 9738    356.68       55          8         pos        valid     dep
# 9826    498.94       55          8         pos        valid     dep
# 9827    440.32       55          8         pos        valid     dep
# 9828    319.13       55          8         pos        valid     dep
# 9829    309.42       55          8         pos        valid     dep
# 9830    362.49       55          8         pos        valid     dep
# 9831    250.77       55          8         pos        valid     dep
# 9832    377.21       55          8         pos        valid     dep
# 9833    313.86       55          8         pos        valid     dep
# 9834    268.02       55          8         pos        valid     dep
# 9835    524.40       55          8         pos        valid     dep
# 9836    418.46       55          8         pos        valid     dep
# 9837    479.45       55          8         pos        valid     dep
# 9838    532.61       55          8         pos        valid     dep
# 9839    306.77       55          8         pos        valid     dep
# 9870    273.68       55         11         pos        valid     dep
# 9871    237.72       55         11         pos        valid     dep
# 9872    372.04       55         11         pos        valid     dep
# 9873    311.36       55         11         pos        valid     dep
# 9874    394.86       55         11         pos        valid     dep
# 9875    249.87       55         11         pos        valid     dep
# 9876    263.84       55         11         pos        valid     dep
# 9877    353.17       55         11         pos        valid     dep
# 9878    263.53       55         11         pos        valid     dep
# 9879    369.55       55         11         pos        valid     dep
# 9880    342.73       55         11         pos        valid     dep
# 9881    368.16       55         11         pos        valid     dep
# 9882    285.17       55         11         pos        valid     dep
# 9883    211.28       55         11         pos        valid     dep
# 9884    319.89       55         11         pos        valid     dep
# 10098   505.50       57          8         pos        valid     dep
# 10186   357.53       57          8         pos        valid     dep
# 10187   346.91       57          8         pos        valid     dep
# 10188   569.31       57          8         pos        valid     dep
# 10189   457.30       57          8         pos        valid     dep
# 10190   277.06       57          8         pos        valid     dep
# 10191   316.70       57          8         pos        valid     dep
# 10192   405.64       57          8         pos        valid     dep
# 10193   422.87       57          8         pos        valid     dep
# 10194   337.31       57          8         pos        valid     dep
# 10195   385.38       57          8         pos        valid     dep
# 10196   394.58       57          8         pos        valid     dep
# 10197   407.19       57          8         pos        valid     dep
# 10198   404.13       57          8         pos        valid     dep
# 10199   355.59       57          8         pos        valid     dep
# 10230   418.25       57         11         pos        valid     dep
# 10231   353.98       57         11         pos        valid     dep
# 10232   413.67       57         11         pos        valid     dep
# 10233   451.70       57         11         pos        valid     dep
# 10234   346.84       57         11         pos        valid     dep
# 10235   529.62       57         11         pos        valid     dep
# 10236   326.28       57         11         pos        valid     dep
# 10237   389.67       57         11         pos        valid     dep
# 10238   411.41       57         11         pos        valid     dep
# 10239   455.09       57         11         pos        valid     dep
# 10240   381.36       57         11         pos        valid     dep
# 10241   346.45       57         11         pos        valid     dep
# 10242   495.08       57         11         pos        valid     dep
# 10243   400.79       57         11         pos        valid     dep
# 10244   565.63       57         11         pos        valid     dep
# 10458   499.14       59          8         pos        valid     dep
# 10546   290.38       59          8         pos        valid     dep
# 10547   389.26       59          8         pos        valid     dep
# 10548   365.53       59          8         pos        valid     dep
# 10549   291.95       59          8         pos        valid     dep
# 10550   444.22       59          8         pos        valid     dep
# 10551   320.30       59          8         pos        valid     dep
# 10552   366.09       59          8         pos        valid     dep
# 10553   416.24       59          8         pos        valid     dep
# 10554   453.24       59          8         pos        valid     dep
# 10555   409.56       59          8         pos        valid     dep
# 10556   348.53       59          8         pos        valid     dep
# 10557   373.41       59          8         pos        valid     dep
# 10558   364.26       59          8         pos        valid     dep
# 10559   444.69       59          8         pos        valid     dep
# 10590   301.20       59         11         pos        valid     dep
# 10591   253.61       59         11         pos        valid     dep
# 10592   376.31       59         11         pos        valid     dep
# 10593   313.99       59         11         pos        valid     dep
# 10594   251.57       59         11         pos        valid     dep
# 10595   313.44       59         11         pos        valid     dep
# 10596   413.49       59         11         pos        valid     dep
# 10597   271.98       59         11         pos        valid     dep
# 10598   313.40       59         11         pos        valid     dep
# 10599   344.56       59         11         pos        valid     dep
# 10600   298.81       59         11         pos        valid     dep
# 10601   247.05       59         11         pos        valid     dep
# 10602   322.99       59         11         pos        valid     dep
# 10603   333.63       59         11         pos        valid     dep
# 10604   282.78       59         11         pos        valid     dep
# 11718   379.68       66          8         pos        valid     dep
# 11806   404.43       66          8         pos        valid     dep
# 11807   387.37       66          8         pos        valid     dep
# 11808   342.88       66          8         pos        valid     dep
# 11809   337.53       66          8         pos        valid     dep
# 11810   347.73       66          8         pos        valid     dep
# 11811   431.99       66          8         pos        valid     dep
# 11812   467.12       66          8         pos        valid     dep
# 11813   280.34       66          8         pos        valid     dep
# 11814   373.02       66          8         pos        valid     dep
# 11815   462.52       66          8         pos        valid     dep
# 11816   485.14       66          8         pos        valid     dep
# 11817   418.06       66          8         pos        valid     dep
# 11818   400.26       66          8         pos        valid     dep
# 11819   419.16       66          8         pos        valid     dep
# 11850   343.15       66         11         pos        valid     dep
# 11851   475.19       66         11         pos        valid     dep
# 11852   265.69       66         11         pos        valid     dep
# 11853   304.74       66         11         pos        valid     dep
# 11854   416.85       66         11         pos        valid     dep
# 11855   472.41       66         11         pos        valid     dep
# 11856   351.21       66         11         pos        valid     dep
# 11857   440.16       66         11         pos        valid     dep
# 11858   360.61       66         11         pos        valid     dep
# 11859   346.80       66         11         pos        valid     dep
# 11860   357.65       66         11         pos        valid     dep
# 11861   476.21       66         11         pos        valid     dep
# 11862  1804.19       66         11         pos        valid     dep
# 11863   450.18       66         11         pos        valid     dep
# 11864   441.85       66         11         pos        valid     dep

# %%
# ANOVA above uses all raw RTs per subject across each UV level.
# Create RT means for smallest increment (validity) t get single values per subject (ANOVA error variance dofs)
# copy data to avoid accidents
anova_submeans = anova.copy().drop('Condition', axis=1)

# define list of subject numbers
fed_nums = [num for num in range(7, 69)]

# list RT by subject, valence and validity, respectively
for sub in anova_submeans['Subject'].unique():
    for valence in anova_submeans['Cue_Valence'].unique():
        for valid in anova_submeans['Cue_Validity'].unique():
            anova_submeans.loc[(anova_submeans['Subject'] == sub) & (anova_submeans['Cue_Valence'] == valence)
                                                                  & (anova_submeans['Cue_Validity'] == valid),
                               # replace the individual RT values with the mean by subject, valence and validity
                               'RT'] = anova_submeans["RT"][(anova_submeans['Subject'] == sub)
                                                          & (anova_submeans['Cue_Valence'] == valence)
                                                          & (anova_submeans['Cue_Validity'] == valid)].mean()

# drop duplicate lines from the dataframe
anova_submeans = anova_submeans.drop_duplicates()

# %%
pd.set_option('display.max_rows', None)
print(anova_submeans)
# Out:
#                RT  Subject Cue_Valence Cue_Validity DStatus
# 1080   292.314483        7         neg      invalid     con
# 1260   324.400000        8         neg      invalid     con
# 1440   312.172759        9         neg      invalid     con
# 1620   331.795862       10         neg      invalid     con
# 1980   317.846207       12         neg      invalid     con
# 2160   339.091034       13         neg      invalid     con
# 2520   416.560000       15         neg      invalid     con
# 2700   276.969655       16         neg      invalid     con
# 2880   265.769310       17         neg      invalid     con
# 3240   327.416207       19         neg      invalid     con
# 3420   238.497241       20         neg      invalid     con
# 3600   377.528276       21         neg      invalid     con
# 3780   280.962414       22         neg      invalid     con
# 3960   294.147931       23         neg      invalid     con
# 4140   316.498966       24         neg      invalid     con
# 4320   314.101724       25         neg      invalid     con
# 4500   348.191034       26         neg      invalid     con
# 8640   342.331034       49         neg      invalid     con
# 8820   288.051724       50         neg      invalid     con
# 9360   419.661379       53         neg      invalid     con
# 9540   287.544483       54         neg      invalid     con
# 9900   319.506207       56         neg      invalid     con
# 10260  400.866552       58         neg      invalid     con
# 10620  380.788276       60         neg      invalid     con
# 10800  307.869310       61         neg      invalid     con
# 10980  237.881034       62         neg      invalid     con
# 11160  306.021724       63         neg      invalid     con
# 11340  296.858621       64         neg      invalid     con
# 11520  357.506552       65         neg      invalid     con
# 11880  290.185862       67         neg      invalid     con
# 12060  464.927586       68         neg      invalid     con
# 1089   305.904000        7         neg        valid     con
# 1269   294.690667        8         neg        valid     con
# 1449   297.159667        9         neg        valid     con
# 1629   298.891667       10         neg        valid     con
# 1989   284.416333       12         neg        valid     con
# 2169   284.279000       13         neg        valid     con
# 2529   364.484000       15         neg        valid     con
# 2709   266.601667       16         neg        valid     con
# 2889   260.156667       17         neg        valid     con
# 3249   325.453000       19         neg        valid     con
# 3429   247.291333       20         neg        valid     con
# 3609   359.666667       21         neg        valid     con
# 3789   303.870333       22         neg        valid     con
# 3969   272.076333       23         neg        valid     con
# 4149   288.285000       24         neg        valid     con
# 4329   327.835333       25         neg        valid     con
# 4509   318.151000       26         neg        valid     con
# 8649   365.929667       49         neg        valid     con
# 8829   272.876333       50         neg        valid     con
# 9369   386.911333       53         neg        valid     con
# 9549   269.424667       54         neg        valid     con
# 9909   275.729667       56         neg        valid     con
# 10269  304.695000       58         neg        valid     con
# 10629  355.168667       60         neg        valid     con
# 10809  350.114333       61         neg        valid     con
# 10989  236.720667       62         neg        valid     con
# 11169  340.056667       63         neg        valid     con
# 11349  327.612333       64         neg        valid     con
# 11529  262.862333       65         neg        valid     con
# 11889  268.159000       67         neg        valid     con
# 12069  405.040000       68         neg        valid     con
# 1120   315.266667        7         neu      invalid     con
# 1300   316.182000        8         neu      invalid     con
# 1480   280.067667        9         neu      invalid     con
# 1660   313.384333       10         neu      invalid     con
# 2020   305.716333       12         neu      invalid     con
# 2200   354.405667       13         neu      invalid     con
# 2560   417.682333       15         neu      invalid     con
# 2740   276.886667       16         neu      invalid     con
# 2920   278.177000       17         neu      invalid     con
# 3280   346.478000       19         neu      invalid     con
# 3460   245.263333       20         neu      invalid     con
# 3640   393.374333       21         neu      invalid     con
# 3820   288.265667       22         neu      invalid     con
# 4000   309.581333       23         neu      invalid     con
# 4180   318.537000       24         neu      invalid     con
# 4360   324.120667       25         neu      invalid     con
# 4540   336.445000       26         neu      invalid     con
# 8680   309.379000       49         neu      invalid     con
# 8860   277.945333       50         neu      invalid     con
# 9400   415.350000       53         neu      invalid     con
# 9580   299.628000       54         neu      invalid     con
# 9940   306.361333       56         neu      invalid     con
# 10300  324.349000       58         neu      invalid     con
# 10660  364.263333       60         neu      invalid     con
# 10840  294.679667       61         neu      invalid     con
# 11020  258.294333       62         neu      invalid     con
# 11200  277.885000       63         neu      invalid     con
# 11380  343.182667       64         neu      invalid     con
# 11560  401.240333       65         neu      invalid     con
# 11920  301.766333       67         neu      invalid     con
# 12100  408.426667       68         neu      invalid     con
# 1200   305.138000        7         neu        valid     con
# 1380   338.160333        8         neu        valid     con
# 1560   320.115333        9         neu        valid     con
# 1740   332.143667       10         neu        valid     con
# 2100   315.801333       12         neu        valid     con
# 2280   328.573667       13         neu        valid     con
# 2640   382.909333       15         neu        valid     con
# 2820   311.266667       16         neu        valid     con
# 3000   276.344333       17         neu        valid     con
# 3360   370.872333       19         neu        valid     con
# 3540   281.577000       20         neu        valid     con
# 3720   383.860333       21         neu        valid     con
# 3900   319.423667       22         neu        valid     con
# 4080   264.627667       23         neu        valid     con
# 4260   307.522667       24         neu        valid     con
# 4440   314.020667       25         neu        valid     con
# 4620   351.457000       26         neu        valid     con
# 8760   370.629667       49         neu        valid     con
# 8940   282.540000       50         neu        valid     con
# 9480   407.208667       53         neu        valid     con
# 9660   315.194000       54         neu        valid     con
# 10020  309.915000       56         neu        valid     con
# 10380  324.955333       58         neu        valid     con
# 10740  370.531333       60         neu        valid     con
# 10920  347.645333       61         neu        valid     con
# 11100  264.026333       62         neu        valid     con
# 11280  280.900000       63         neu        valid     con
# 11460  314.477333       64         neu        valid     con
# 11640  367.266333       65         neu        valid     con
# 12000  313.886667       67         neu        valid     con
# 12180  430.051333       68         neu        valid     con
# 1104   325.835484        7         pos      invalid     con
# 1284   303.778387        8         pos      invalid     con
# 1464   314.757742        9         pos      invalid     con
# 1644   326.933871       10         pos      invalid     con
# 2004   318.009032       12         pos      invalid     con
# 2184   305.090323       13         pos      invalid     con
# 2544   421.454516       15         pos      invalid     con
# 2724   292.164194       16         pos      invalid     con
# 2904   266.866774       17         pos      invalid     con
# 3264   309.716774       19         pos      invalid     con
# 3444   247.884839       20         pos      invalid     con
# 3624   369.239677       21         pos      invalid     con
# 3804   297.857097       22         pos      invalid     con
# 3984   296.847097       23         pos      invalid     con
# 4164   312.996452       24         pos      invalid     con
# 4344   311.771935       25         pos      invalid     con
# 4524   360.020968       26         pos      invalid     con
# 8664   304.706452       49         pos      invalid     con
# 8844   260.864194       50         pos      invalid     con
# 9384   379.599355       53         pos      invalid     con
# 9564   292.966129       54         pos      invalid     con
# 9924   290.710323       56         pos      invalid     con
# 10284  311.284194       58         pos      invalid     con
# 10644  359.786129       60         pos      invalid     con
# 10824  310.765484       61         pos      invalid     con
# 11004  265.311613       62         pos      invalid     con
# 11184  323.329032       63         pos      invalid     con
# 11364  363.402258       64         pos      invalid     con
# 11544  357.510968       65         pos      invalid     con
# 11904  296.734839       67         pos      invalid     con
# 12084  442.317419       68         pos      invalid     con
# 1098   313.915333        7         pos        valid     con
# 1278   318.435000        8         pos        valid     con
# 1458   332.902333        9         pos        valid     con
# 1638   333.318000       10         pos        valid     con
# 1998   321.696000       12         pos        valid     con
# 2178   337.156000       13         pos        valid     con
# 2538   401.683000       15         pos        valid     con
# 2718   275.235333       16         pos        valid     con
# 2898   288.931333       17         pos        valid     con
# 3258   326.688667       19         pos        valid     con
# 3438   269.030667       20         pos        valid     con
# 3618   395.710000       21         pos        valid     con
# 3798   327.475333       22         pos        valid     con
# 3978   290.912667       23         pos        valid     con
# 4158   313.123333       24         pos        valid     con
# 4338   330.540333       25         pos        valid     con
# 4518   340.486667       26         pos        valid     con
# 8658   367.140667       49         pos        valid     con
# 8838   273.628333       50         pos        valid     con
# 9378   389.377667       53         pos        valid     con
# 9558   303.158333       54         pos        valid     con
# 9918   317.205667       56         pos        valid     con
# 10278  317.243000       58         pos        valid     con
# 10638  365.213667       60         pos        valid     con
# 10818  383.586333       61         pos        valid     con
# 10998  272.982333       62         pos        valid     con
# 11178  303.263333       63         pos        valid     con
# 11358  305.617333       64         pos        valid     con
# 11538  346.285667       65         pos        valid     con
# 11898  321.192000       67         pos        valid     con
# 12078  427.051000       68         pos        valid     con
# 1800   316.105172       11         neg      invalid     dep
# 2340   370.077586       14         neg      invalid     dep
# 3060   378.976207       18         neg      invalid     dep
# 4680   351.699310       27         neg      invalid     dep
# 4860   333.860690       28         neg      invalid     dep
# 5040   375.796897       29         neg      invalid     dep
# 5220   355.587586       30         neg      invalid     dep
# 5400   302.141379       31         neg      invalid     dep
# 5580   351.453448       32         neg      invalid     dep
# 5760   349.541034       33         neg      invalid     dep
# 5940   366.191034       34         neg      invalid     dep
# 6120   277.116897       35         neg      invalid     dep
# 6300   265.238276       36         neg      invalid     dep
# 6480   278.237931       37         neg      invalid     dep
# 6660   321.455862       38         neg      invalid     dep
# 6840   352.560345       39         neg      invalid     dep
# 7020   315.880000       40         neg      invalid     dep
# 7200   291.198966       41         neg      invalid     dep
# 7380   130.864828       42         neg      invalid     dep
# 7560   278.867586       43         neg      invalid     dep
# 7740   403.429310       44         neg      invalid     dep
# 7920   358.032414       45         neg      invalid     dep
# 8100   -80.622414       46         neg      invalid     dep
# 8280   368.318621       47         neg      invalid     dep
# 8460   346.720690       48         neg      invalid     dep
# 9000   313.423448       51         neg      invalid     dep
# 9180   290.897586       52         neg      invalid     dep
# 9720   326.317241       55         neg      invalid     dep
# 10080  387.320345       57         neg      invalid     dep
# 10440  313.764138       59         neg      invalid     dep
# 11700  402.684483       66         neg      invalid     dep
# 1809   295.529333       11         neg        valid     dep
# 2349   419.061333       14         neg        valid     dep
# 3069   332.442667       18         neg        valid     dep
# 4689   328.877333       27         neg        valid     dep
# 4869   442.922000       28         neg        valid     dep
# 5049   444.528000       29         neg        valid     dep
# 5229   333.715000       30         neg        valid     dep
# 5409   326.153000       31         neg        valid     dep
# 5589   326.205000       32         neg        valid     dep
# 5769   324.237000       33         neg        valid     dep
# 5949   326.618667       34         neg        valid     dep
# 6129   307.734667       35         neg        valid     dep
# 6309   260.612000       36         neg        valid     dep
# 6489   272.880000       37         neg        valid     dep
# 6669   267.041000       38         neg        valid     dep
# 6849   325.848667       39         neg        valid     dep
# 7029   297.938333       40         neg        valid     dep
# 7209   272.684000       41         neg        valid     dep
# 7389   218.820333       42         neg        valid     dep
# 7569   262.974333       43         neg        valid     dep
# 7749   286.435667       44         neg        valid     dep
# 7929   338.314667       45         neg        valid     dep
# 8109  -250.126667       46         neg        valid     dep
# 8289   363.146000       47         neg        valid     dep
# 8469   340.560667       48         neg        valid     dep
# 9009   283.173667       51         neg        valid     dep
# 9189   310.133000       52         neg        valid     dep
# 9729   304.630667       55         neg        valid     dep
# 10089  357.382333       57         neg        valid     dep
# 10449  278.277333       59         neg        valid     dep
# 11709  349.259333       66         neg        valid     dep
# 1840   322.280667       11         neu      invalid     dep
# 2380   385.082333       14         neu      invalid     dep
# 3100   323.015000       18         neu      invalid     dep
# 4720   342.486333       27         neu      invalid     dep
# 4900   358.274667       28         neu      invalid     dep
# 5080   337.570333       29         neu      invalid     dep
# 5260   343.643333       30         neu      invalid     dep
# 5440   318.855333       31         neu      invalid     dep
# 5620   321.847000       32         neu      invalid     dep
# 5800   339.463667       33         neu      invalid     dep
# 5980   365.939000       34         neu      invalid     dep
# 6160   298.723000       35         neu      invalid     dep
# 6340   296.055333       36         neu      invalid     dep
# 6520   274.501333       37         neu      invalid     dep
# 6700   314.745000       38         neu      invalid     dep
# 6880   343.766000       39         neu      invalid     dep
# 7060   318.440333       40         neu      invalid     dep
# 7240   311.730000       41         neu      invalid     dep
# 7420   250.256667       42         neu      invalid     dep
# 7600   261.404667       43         neu      invalid     dep
# 7780   444.531333       44         neu      invalid     dep
# 7960   343.240333       45         neu      invalid     dep
# 8140  -285.968000       46         neu      invalid     dep
# 8320   369.561000       47         neu      invalid     dep
# 8500   308.524333       48         neu      invalid     dep
# 9040   307.016667       51         neu      invalid     dep
# 9220   257.453000       52         neu      invalid     dep
# 9760   297.094333       55         neu      invalid     dep
# 10120  369.488667       57         neu      invalid     dep
# 10480  315.963333       59         neu      invalid     dep
# 11740  386.706000       66         neu      invalid     dep
# 1920   308.902333       11         neu        valid     dep
# 2460   431.922667       14         neu        valid     dep
# 3180   324.833333       18         neu        valid     dep
# 4800   358.401667       27         neu        valid     dep
# 4980   425.397333       28         neu        valid     dep
# 5160   363.257667       29         neu        valid     dep
# 5340   360.567667       30         neu        valid     dep
# 5520   313.775333       31         neu        valid     dep
# 5700   354.821667       32         neu        valid     dep
# 5880   371.523000       33         neu        valid     dep
# 6060   382.769333       34         neu        valid     dep
# 6240   335.738667       35         neu        valid     dep
# 6420   298.161333       36         neu        valid     dep
# 6600   307.334333       37         neu        valid     dep
# 6780   304.639667       38         neu        valid     dep
# 6960   349.995333       39         neu        valid     dep
# 7140   283.848000       40         neu        valid     dep
# 7320   271.203000       41         neu        valid     dep
# 7500   211.210000       42         neu        valid     dep
# 7680   257.052333       43         neu        valid     dep
# 7860   372.764000       44         neu        valid     dep
# 8040   353.009333       45         neu        valid     dep
# 8220  -266.443667       46         neu        valid     dep
# 8400   362.310333       47         neu        valid     dep
# 8580   394.935000       48         neu        valid     dep
# 9120   327.362000       51         neu        valid     dep
# 9300   316.600333       52         neu        valid     dep
# 9840   343.945000       55         neu        valid     dep
# 10200  386.877333       57         neu        valid     dep
# 10560  313.294000       59         neu        valid     dep
# 11820  402.262000       66         neu        valid     dep
# 1824   326.660645       11         pos      invalid     dep
# 2364   392.892581       14         pos      invalid     dep
# 3084   331.972903       18         pos      invalid     dep
# 4704   329.570323       27         pos      invalid     dep
# 4884   369.502258       28         pos      invalid     dep
# 5064   446.793548       29         pos      invalid     dep
# 5244   327.102581       30         pos      invalid     dep
# 5424   337.680323       31         pos      invalid     dep
# 5604   333.780323       32         pos      invalid     dep
# 5784   344.170000       33         pos      invalid     dep
# 5964   319.146452       34         pos      invalid     dep
# 6144   269.159677       35         pos      invalid     dep
# 6324   271.473548       36         pos      invalid     dep
# 6504   227.468065       37         pos      invalid     dep
# 6684   308.971935       38         pos      invalid     dep
# 6864   337.377097       39         pos      invalid     dep
# 7044   316.297742       40         pos      invalid     dep
# 7224   291.410000       41         pos      invalid     dep
# 7404   232.202903       42         pos      invalid     dep
# 7584   288.919032       43         pos      invalid     dep
# 7764   400.769355       44         pos      invalid     dep
# 7944   340.972258       45         pos      invalid     dep
# 8124  -370.372258       46         pos      invalid     dep
# 8304   340.794839       47         pos      invalid     dep
# 8484   366.731613       48         pos      invalid     dep
# 9024   294.156774       51         pos      invalid     dep
# 9204   293.062258       52         pos      invalid     dep
# 9744   300.167097       55         pos      invalid     dep
# 10104  388.081935       57         pos      invalid     dep
# 10464  281.248387       59         pos      invalid     dep
# 11724  392.815806       66         pos      invalid     dep
# 1818   300.193333       11         pos        valid     dep
# 2358   434.666000       14         pos        valid     dep
# 3078   330.251333       18         pos        valid     dep
# 4698   342.149000       27         pos        valid     dep
# 4878   427.721000       28         pos        valid     dep
# 5058   366.826667       29         pos        valid     dep
# 5238   316.122000       30         pos        valid     dep
# 5418   304.679667       31         pos        valid     dep
# 5598   350.151000       32         pos        valid     dep
# 5778   364.363000       33         pos        valid     dep
# 5958   381.116667       34         pos        valid     dep
# 6138   326.426667       35         pos        valid     dep
# 6318   295.334000       36         pos        valid     dep
# 6498   293.179000       37         pos        valid     dep
# 6678   324.088000       38         pos        valid     dep
# 6858   363.442000       39         pos        valid     dep
# 7038   306.763000       40         pos        valid     dep
# 7218   301.845333       41         pos        valid     dep
# 7398   241.362667       42         pos        valid     dep
# 7578   262.280333       43         pos        valid     dep
# 7758   377.708000       44         pos        valid     dep
# 7938   345.743667       45         pos        valid     dep
# 8118  -282.881667       46         pos        valid     dep
# 8298   347.954000       47         pos        valid     dep
# 8478   393.058333       48         pos        valid     dep
# 9018   309.217333       51         pos        valid     dep
# 9198   323.476000       52         pos        valid     dep
# 9738   345.846000       55         pos        valid     dep
# 10098  407.627333       57         pos        valid     dep
# 10458  347.187000       59         pos        valid     dep
# 11718  441.470667       66         pos        valid     dep

# %%
# put both datasets into one list and compare the performance and outcome of the ANOVA testing
anovas = [anova, anova_submeans]

# %%
# set seaborn visual style
sns.set(style="darkgrid")
# Draw a pointplot to show pulse as a function of three categorical factors
for dataset in anovas:
    interact_plot = sns.catplot(x="Cue_Valence", y="RT", hue="DStatus", col="Cue_Validity",
                                capsize=.2, palette="muted", height=6, aspect=.75, kind="point", data=dataset)
    interact_plot.despine(left=True)
    # # save plot
    # interact_plot.savefig("RT_322_interact.png")

# %% [markdown]
# Build three-way ANOVA design and calculate the F-test

# %%
# check whether variances are equal using Levene tests
for dataset in anovas:
    homoscedast_DStatus = pg.homoscedasticity(data=anova, dv='RT', group='DStatus')
    homoscedast_Valence = pg.homoscedasticity(data=anova, dv='RT', group='Cue_Valence')
    homoscedast_Validity = pg.homoscedasticity(data=anova, dv='RT', group='Cue_Validity')
    # put all into list
    homoscedast = [homoscedast_DStatus, homoscedast_Valence, homoscedast_Validity]
    # inspect the results
    for test in homoscedast:
        print(test)
# Out:
#                 W          pval  equal_var
# levene  102.77696  4.767290e-24      False
#                 W          pval  equal_var
# levene  15.035238  3.013443e-07      False
#                W      pval  equal_var
# levene  4.963112  0.025913      False
#                 W          pval  equal_var
# levene  102.77696  4.767290e-24      False
#                 W          pval  equal_var
# levene  15.035238  3.013443e-07      False
#                W      pval  equal_var
# levene  4.963112  0.025913      False

# %%
# run the full ANOVA
FED_anova = pg.anova(data=anova, dv='RT', between=['DStatus', 'Cue_Valence', 'Cue_Validity'], ss_type=3).round(3)  # round to three place digits
FED_meanRTs_anova = pg.anova(data=anova_submeans, dv='RT', between=['DStatus', 'Cue_Valence', 'Cue_Validity'], ss_type=3).round(3)  # round to three place digits

# %%
# main effect DStatus significant, Interaction Valence-Validity too, BUT neither of their main effects! -> simple effects!^^
# fix the error variance (residual variance  from full ANOVA)
err_MS = FED_anova.MS[FED_anova.Source == 'Residual'].values
err_dof = FED_anova.DF[FED_anova.Source == 'Residual'].values

# -> simple effects as two-way ANOVA only for valid trials
simpleeff_valid = pg.anova(data=anova[anova['Cue_Validity'] == "valid"], dv='RT', between=['DStatus', 'Cue_Valence'], ss_type=3).round(3)  # round to three place digits
# calculate corrected F value using the residual variance  from full ANOVA
vale_MS = simpleeff_valid.MS[simpleeff_valid.Source == 'Cue_Valence'].values
vale_dof = simpleeff_valid.DF[simpleeff_valid.Source == 'Cue_Valence'].values
correctF_valence = vale_MS / err_MS
correctp_valence = 1 - sp.stats.f.cdf(correctF_valence, vale_dof, err_dof)
# insert the correct value into dataframe
simpleeff_valid.insert(6, 'F_corr', [np.nan, *correctF_valence, np.nan, np.nan])  # lose the brackets^^
simpleeff_valid.insert(7, 'p_corr', [np.nan, *correctp_valence, np.nan, np.nan])  # lose the brackets^^

# -> simple effects as two-way ANOVA only for invalid trials
simpleeff_invalid = pg.anova(data=anova[anova['Cue_Validity'] == "invalid"], dv='RT', between=['DStatus', 'Cue_Valence'], ss_type=3).round(3)  # round to three place digits
# calculate corrected F value using the residual variance  from full ANOVA
vale_MS = simpleeff_invalid.MS[simpleeff_invalid.Source == 'Cue_Valence'].values
vale_dof = simpleeff_invalid.DF[simpleeff_invalid.Source == 'Cue_Valence'].values
correctF_valence = vale_MS / err_MS
correctp_valence = 1 - sp.stats.f.cdf(correctF_valence, vale_dof, err_dof)
# insert the correct value into dataframe
simpleeff_invalid.insert(6, 'F_corr', [np.nan, *correctF_valence, np.nan, np.nan])  # lose the brackets^^
simpleeff_invalid.insert(7, 'p_corr', [np.nan, *correctp_valence, np.nan, np.nan])  # lose the brackets^^

# %% [markdown]
# Plot three-way ANOVA results

# %%
FED_anova
# Out:
#                                  Source            SS       DF          MS  \
# 0                               DStatus  2.989308e+05      1.0  298930.835
# 1                           Cue_Valence  1.261261e+05      2.0   63063.037
# 2                          Cue_Validity  1.356578e+04      1.0   13565.783
# 3                 DStatus * Cue_Valence  1.276030e+04      2.0    6380.152
# 4                DStatus * Cue_Validity  2.688208e+04      1.0   26882.075
# 5            Cue_Valence * Cue_Validity  4.719226e+05      2.0  235961.279
# 6  DStatus * Cue_Valence * Cue_Validity  3.986043e+03      2.0    1993.021
# 7                              Residual  2.737710e+08  11148.0   24557.861
#
#         F  p-unc    np2
# 0  12.173  0.000  0.001
# 1   2.568  0.077  0.000
# 2   0.552  0.457  0.000
# 3   0.260  0.771  0.000
# 4   1.095  0.295  0.000
# 5   9.608  0.000  0.002
# 6   0.081  0.922  0.000
# 7     NaN    NaN    NaN

# %%
simpleeff_valid
# Out:
#                   Source            SS    DF          MS       F  p-unc  \
# 0                DStatus  7.329054e+04     1   73290.544   2.872  0.090
# 1            Cue_Valence  5.413986e+05     2  270699.289  10.609  0.000
# 2  DStatus * Cue_Valence  2.846830e+03     2    1423.415   0.056  0.946
# 3               Residual  1.422220e+08  5574   25515.243     NaN    NaN
#
#       F_corr    p_corr    np2
# 0        NaN       NaN  0.001
# 1  11.022918  0.000017  0.004
# 2        NaN       NaN  0.000
# 3        NaN       NaN    NaN

# %%
simpleeff_invalid
# Out:
#                   Source            SS      DF          MS       F  p-unc  \
# 0                DStatus  2.524560e+05     1.0  252455.959  10.697  0.001
# 1            Cue_Valence  6.087552e+04     2.0   30437.761   1.290  0.275
# 2  DStatus * Cue_Valence  1.383800e+04     2.0    6918.998   0.293  0.746
# 3               Residual  1.315491e+08  5574.0   23600.479     NaN    NaN
#
#     F_corr    p_corr    np2
# 0      NaN       NaN  0.002
# 1  1.23943  0.289589  0.000
# 2      NaN       NaN  0.000
# 3      NaN       NaN    NaN

# %%
FED_meanRTs_anova
# Out:
#                                  Source           SS     DF        MS      F  \
# 0                               DStatus     9968.056    1.0  9968.056  1.274
# 1                           Cue_Valence     4244.277    2.0  2122.138  0.271
# 2                          Cue_Validity      452.360    1.0   452.360  0.058
# 3                 DStatus * Cue_Valence      429.211    2.0   214.605  0.027
# 4                DStatus * Cue_Validity      896.401    1.0   896.401  0.115
# 5            Cue_Valence * Cue_Validity    15846.357    2.0  7923.179  1.012
# 6  DStatus * Cue_Valence * Cue_Validity      132.629    2.0    66.315  0.008
# 7                              Residual  2817420.849  360.0  7826.169    NaN
#
#    p-unc    np2
# 0  0.260  0.004
# 1  0.763  0.002
# 2  0.810  0.000
# 3  0.973  0.000
# 4  0.735  0.000
# 5  0.364  0.006
# 6  0.992  0.000
# 7    NaN    NaN

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(FED_anova, tablefmt="latex")
pg.print_table(simpleeff_valid, tablefmt="latex")
pg.print_table(simpleeff_invalid, tablefmt="latex")
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# \begin{tabular}{lrrrrrr}
# \hline
#  Source                               &            SS &        DF &         MS &       F &   p-unc &     np2 \\
# \hline
#  DStatus                              &    298930.835 &     1.000 & 298930.835 &  12.173 &   0.000 &   0.001 \\
#  Cue\_Valence                          &    126126.075 &     2.000 &  63063.037 &   2.568 &   0.077 &   0.000 \\
#  Cue\_Validity                         &     13565.783 &     1.000 &  13565.783 &   0.552 &   0.457 &   0.000 \\
#  DStatus * Cue\_Valence                &     12760.303 &     2.000 &   6380.152 &   0.260 &   0.771 &   0.000 \\
#  DStatus * Cue\_Validity               &     26882.075 &     1.000 &  26882.075 &   1.095 &   0.295 &   0.000 \\
#  Cue\_Valence * Cue\_Validity           &    471922.558 &     2.000 & 235961.279 &   9.608 &   0.000 &   0.002 \\
#  DStatus * Cue\_Valence * Cue\_Validity &      3986.043 &     2.000 &   1993.021 &   0.081 &   0.922 &   0.000 \\
#  Residual                             & 273771031.918 & 11148.000 &  24557.861 & nan     & nan     & nan     \\
# \hline
# \end{tabular}
#
#
# =============
# ANOVA SUMMARY
# =============
#
# \begin{tabular}{lrrrrrrrr}
# \hline
#  Source                &            SS &   DF &         MS &       F &   p-unc &   F\_corr &   p\_corr &     np2 \\
# \hline
#  DStatus               &     73290.544 &    1 &  73290.544 &   2.872 &   0.090 &  nan     &  nan     &   0.001 \\
#  Cue\_Valence           &    541398.577 &    2 & 270699.289 &  10.609 &   0.000 &   11.023 &    0.000 &   0.004 \\
#  DStatus * Cue\_Valence &      2846.830 &    2 &   1423.415 &   0.056 &   0.946 &  nan     &  nan     &   0.000 \\
#  Residual              & 142221963.880 & 5574 &  25515.243 & nan     & nan     &  nan     &  nan     & nan     \\
# \hline
# \end{tabular}
#
#
# =============
# ANOVA SUMMARY
# =============
#
# \begin{tabular}{lrrrrrrrr}
# \hline
#  Source                &            SS &       DF &         MS &       F &   p-unc &   F\_corr &   p\_corr &     np2 \\
# \hline
#  DStatus               &    252455.959 &    1.000 & 252455.959 &  10.697 &   0.001 &  nan     &  nan     &   0.002 \\
#  Cue\_Valence           &     60875.522 &    2.000 &  30437.761 &   1.290 &   0.275 &    1.239 &    0.290 &   0.000 \\
#  DStatus * Cue\_Valence &     13837.997 &    2.000 &   6918.998 &   0.293 &   0.746 &  nan     &  nan     &   0.000 \\
#  Residual              & 131549068.038 & 5574.000 &  23600.479 & nan     & nan     &  nan     &  nan     & nan     \\
# \hline
# \end{tabular}

# %% [markdown]
# Calculate Enhanced cue Validity (ECV), Attentional Engagement (AE), and Difficulty in Attentional Disengagement (DAD) based on subject RT means for each condition

# %%
# create RT means for smallest increment (validity)
# copy data to avoid accidents
eect_ttest = anova.copy()

# define list of subject numbers
fed_nums = [num for num in range(7, 69)]

# sort data by subject, valence and validity
eect_ttest.sort_values(['Subject', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# list RT by subject, valence and validity, respectively
rts = {}
for sub in eect_ttest['Subject'].unique():
    for valence in eect_ttest['Cue_Valence'].unique():
        for valid in eect_ttest['Cue_Validity'].unique():
            rts[f"{sub}_{valence}_{valid}"] = eect_ttest.loc[(eect_ttest['Subject'] == sub)
                                                           & (eect_ttest['Cue_Valence'] == valence) 
                                                           & (eect_ttest['Cue_Validity'] == valid), 'RT'].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ba50473b3491> in <module>
#       1 # create RT means for smallest increment (validity)
#       2 # copy data to avoid accidents
# ----> 3 eect_ttest = anova.copy()
#       4
#       5 # define list of subject numbers
#
# NameError: name 'anova' is not defined

# %%
# calculate ECV for each valence per subject
mean_ecv = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    for val in valence_cats:
        # create list for validity-referenced combos
        validity = []
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # fix the subject ID
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1]) == val:
                # collect validities
                validity.append(combo)
        print(validity)
        # calculate the mean of the inv-v difference by valence
        mean_ecv[f"{sub}_{val}"] = np.mean([inv - v for inv, v in zip(rts[validity[0]], rts[validity[1]])])

# transfer to pd.dataframe
mean_ecv = (pd.DataFrame.from_dict(mean_ecv, orient='index', columns=['mean_ECV']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate AE for each valence per subject
mean_ae = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set valid neutral reference
            reference = f"{sub}_{ref}_valid"
            # fix the subject ID, and validity to valid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "valid":
                # print(reference, combo)
                # calculate the mean of the vneu-vemo difference by valence
                mean_ae[f"{sub}_{val}"] = np.mean([vneu - vemo for vneu, vemo in zip(rts[reference], rts[combo])])

# transfer to pd.dataframe
mean_ae = (pd.DataFrame.from_dict(mean_ae, orient='index', columns=['mean_AE']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate DAD for each valence per subject
mean_dad = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set invalid neutral reference
            reference = f"{sub}_{ref}_invalid"
            # fix the subject ID, and validity to invalid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "invalid":
                # print(reference, combo)
                # calculate the mean of the invemo-invneu difference by valence
                mean_dad[f"{sub}_{val}"] = np.mean([invemo - invneu for invemo, invneu in zip(rts[combo], rts[reference])])

# transfer to pd.dataframe
mean_dad = (pd.DataFrame.from_dict(mean_dad, orient='index', columns=['mean_DAD']).rename_axis('FEDbyvalence').reset_index())

# %%
# JAY's ORIGINAL QUOTE FROM 5 YEARS AGO:
# What I did was to run the CV equation on the individual subject means instead of the overall mean by condition. In MATLAB, it looked like this for positive CV:

# datastruct.CV_POS = (datastruct.RT_POS_INVAL - datastruct.RT_POS_VALID);
# CV_Positive = mean(datastruct.CV_POS(1,:));

# So datastruct.CV_POS has the cue validity score for positive stimuli for each subject. Then I take the mean with the next line, and those are the CV scores I sent you guys last night.

# %%
# create RT means for smallest increment (validity)
# copy data to avoid accidents
eect_ttest = anova_submeans.copy()

# define list of subject numbers
fed_nums = [num for num in range(7, 69)]

# sort data by subject, valence and validity
eect_ttest.sort_values(['Subject', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# list RT by subject, valence and validity, respectively
rts = {}
for sub in eect_ttest['Subject'].unique():
    for valence in eect_ttest['Cue_Valence'].unique():
        for valid in eect_ttest['Cue_Validity'].unique():
            rts[f"{sub}_{valence}_{valid}"] = eect_ttest.loc[(eect_ttest['Subject'] == sub)
                                                           & (eect_ttest['Cue_Valence'] == valence) 
                                                           & (eect_ttest['Cue_Validity'] == valid), 'RT'].tolist()

# %%
# calculate ECV for each valence per subject
mean_ecv = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    for val in valence_cats:
        # create list for validity-referenced combos
        validity = []
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # fix the subject ID
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1]) == val:
                # collect validities
                validity.append(combo)
        #print(validity)
        # calculate the inv-v difference by valence
        mean_ecv[f"{sub}_{val}"] = [inv - v for inv, v in zip(rts[validity[0]], rts[validity[1]])]

# transfer to pd.dataframe
mean_ecv = (pd.DataFrame.from_dict(mean_ecv, orient='index', columns=['mean_ECV']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate AE for each valence per subject
mean_ae = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set valid neutral reference
            reference = f"{sub}_{ref}_valid"
            # fix the subject ID, and validity to valid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "valid":
                #print(reference, combo)
                # calculate the vneu-vemo difference by valence
                mean_ae[f"{sub}_{val}"] = [vneu - vemo for vneu, vemo in zip(rts[reference], rts[combo])]

# transfer to pd.dataframe
mean_ae = (pd.DataFrame.from_dict(mean_ae, orient='index', columns=['mean_AE']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate DAD for each valence per subject
mean_dad = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set invalid neutral reference
            reference = f"{sub}_{ref}_invalid"
            # fix the subject ID, and validity to invalid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "invalid":
                #print(combo, reference)
                # calculate the invemo-invneu difference by valence
                mean_dad[f"{sub}_{val}"] = [invemo - invneu for invemo, invneu in zip(rts[combo], rts[reference])]

# transfer to pd.dataframe
mean_dad = (pd.DataFrame.from_dict(mean_dad, orient='index', columns=['mean_DAD']).rename_axis('FEDbyvalence').reset_index())

# %%
# add group column to each variable's dataframe
for frame in [mean_ecv, mean_ae, mean_dad]:
    # copy Subject, Condition lists and transform to integers
    frame['FED'] = frame['FEDbyvalence'].apply(lambda x: x.split('_', 1)[0])
    frame['Valence'] = frame['FEDbyvalence'].apply(lambda x: x.split('_', 1)[1])
    # copy FED again to obtain DStatus list
    frame['DStatus'] = frame['FED']
    # check and change by group
    frame.loc[frame['FED'].astype(int).isin(mdd), 'DStatus'] = "dep"
    frame.loc[frame['FED'].astype(int).isin(control), 'DStatus'] = "con"
    # finally, sort the dataframe by DStatus and FED
    frame.sort_values(['DStatus', 'Valence', 'FED'], inplace = True)
    # drop FEDbyCondition
    frame.drop(columns='FEDbyvalence', inplace=True)

# %% [markdown]
# Inspect and make sure that all variables look OK

# %%
mean_ecv
# Out:
#       mean_ECV FED Valence DStatus
# 9    32.904195  10     neg     con
# 15   33.429874  12     neg     con
# 18   54.812034  13     neg     con
# 24   52.076000  15     neg     con
# 27   10.367989  16     neg     con
# ..         ...  ..     ...     ...
# 136 -30.413742  52     pos     dep
# 145 -45.678903  55     pos     dep
# 151 -19.545398  57     pos     dep
# 157 -65.938613  59     pos     dep
# 178 -48.654860  66     pos     dep
#
# [186 rows x 4 columns]

# %%
mean_ae
# Out:
#        mean_AE FED Valence DStatus
# 6    33.252000  10     neg     con
# 10   31.385000  12     neg     con
# 12   44.294667  13     neg     con
# 16   18.425333  15     neg     con
# 18   44.665000  16     neg     con
# ..         ...  ..     ...     ...
# 91   -6.875667  52     pos     dep
# 97   -1.901000  55     pos     dep
# 101 -20.750000  57     pos     dep
# 105 -33.893000  59     pos     dep
# 119 -39.208667  66     pos     dep
#
# [124 rows x 4 columns]

# %%
mean_dad
# Out:
#       mean_DAD FED Valence DStatus
# 6    18.411529  10     neg     con
# 10   12.129874  12     neg     con
# 12  -15.314632  13     neg     con
# 16   -1.122333  15     neg     con
# 18    0.082989  16     neg     con
# ..         ...  ..     ...     ...
# 91   35.609258  52     pos     dep
# 97    3.072763  55     pos     dep
# 101  18.593269  57     pos     dep
# 105 -34.714946  59     pos     dep
# 119   6.109806  66     pos     dep
#
# [124 rows x 4 columns]

# %% [markdown]
# Calculate two-sided t-tests (un)like Koster (2005)

# %%
# calculate cauchy scaling factor of Koster et al. (2005)
# - original: https://doi.org/10.3758/PBR.16.2.225; recent implimentation: https://doi.org/10.1080/00031305.2018.1562983

# transfer t_vals to cohens d for basing on propability density function
smallest_t = 2.15
largest_t = 2.72
small_cohen = pg.compute_effsize_from_t(smallest_t, nx=20, ny=20, eftype='cohen')
large_cohen = pg.compute_effsize_from_t(largest_t, N=15, eftype='cohen')
# spectrum based on Exp1 & Exp2 results
# t-values are between 0 and 1.4, round up
value_halfwidth = 2
# set scaling factor required for estimated 80% probability that the true effect sizes lie within the spectrum (+2 - -2)
cauchy_r = 0.707
# control the probability
effect_prob_est = sp.stats.cauchy.cdf(value_halfwidth, 0, cauchy_r) - sp.stats.cauchy.cdf(-value_halfwidth, 0, cauchy_r)

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for ECV
# neg
ecvneg_mdd = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "neg") & (mean_ecv['DStatus'] == "dep")].tolist()
ecvneg_con = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "neg") & (mean_ecv['DStatus'] == "con")].tolist()
# pos
ecvpos_mdd = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "pos") & (mean_ecv['DStatus'] == "dep")].tolist()
ecvpos_con = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "pos") & (mean_ecv['DStatus'] == "con")].tolist()
# neu
ecvneu_mdd = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "neu") & (mean_ecv['DStatus'] == "dep")].tolist()
ecvneu_con = mean_ecv['mean_ECV'][(mean_ecv['Valence'] == "neu") & (mean_ecv['DStatus'] == "con")].tolist()
# put all into tupled list
ecv_testbtw = [(ecvneg_mdd, ecvneg_con), (ecvpos_mdd, ecvpos_con), (ecvneu_mdd, ecvneu_con)]
ecv_testwithin = [[group[0] for group in ecv_testbtw], [group[1] for group in ecv_testbtw]]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_ecv_all = []
# first compare valences between groups with a 2-sample t-test
for valence in ecv_testbtw:
    ttests_ecv = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_ecv.insert(0, "ConditionID", f"ecv_btw_{valence_cats[ecv_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_ecv.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_ecv_all.append(ttests_ecv)

# Now look at the valences within groups with a paired t-test
for group in ecv_testwithin:
    # compare neg and pos against neu
    for valence in [0, 1]:
        ttests_ecv = pg.ttest(group[valence], group[2], paired=True, tail='two-sided', r=cauchy_r, confidence=0.95)
        # add condition and group ID (0 means control^^)
        ttests_ecv.insert(0, "ConditionID", f"ecv_within_{group_cats[ecv_testwithin.index(group)]}_{valence_cats[[0, 1].index(valence)]}")
        # add (partial) eta-squared estimate to the dataframe
        ttests_ecv.insert(7, "eta-squared", pg.compute_effsize(group[valence], group[2], paired=True, eftype='eta-square'))
        # put the finish dataframe into list
        ttests_ecv_all.append(ttests_ecv)

# concat list to dataframe
ttests_ecv_all = pd.concat(ttests_ecv_all)

# %%
# test whether or not all t-test RT lists have the same length
for group in ecv_testwithin:
    print(f"Negative ECV {len(group[0])}; Positive ECV {len(group[1])}; Neutral ECV {len(group[2])}")
# Out:
# Negative ECV 31; Positive ECV 31; Neutral ECV 31
# Negative ECV 31; Positive ECV 31; Neutral ECV 31

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for AE
# neg
aeneg_mdd = mean_ae['mean_AE'][(mean_ae['Valence'] == "neg") & (mean_ae['DStatus'] == "dep")].tolist()
aeneg_con = mean_ae['mean_AE'][(mean_ae['Valence'] == "neg") & (mean_ae['DStatus'] == "con")].tolist()
# pos
aepos_mdd = mean_ae['mean_AE'][(mean_ae['Valence'] == "pos") & (mean_ae['DStatus'] == "dep")].tolist()
aepos_con = mean_ae['mean_AE'][(mean_ae['Valence'] == "pos") & (mean_ae['DStatus'] == "con")].tolist()
# put all into tupled list (no within comparisons here)
ae_testbtw = [(aeneg_mdd, aeneg_con), (aepos_mdd, aepos_con)]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_ae_all = []
# first compare valences between groups with a 2-sample t-test
for valence in ae_testbtw:
    ttests_ae = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_ae.insert(0, "ConditionID", f"ae_btw_{valence_cats[ae_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_ae.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_ae_all.append(ttests_ae)

# concat list to dataframe
ttests_ae_all = pd.concat(ttests_ae_all)

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for DAD
# neg
dadneg_mdd = mean_dad['mean_DAD'][(mean_dad['Valence'] == "neg") & (mean_dad['DStatus'] == "dep")].tolist()
dadneg_con = mean_dad['mean_DAD'][(mean_dad['Valence'] == "neg") & (mean_dad['DStatus'] == "con")].tolist()
# pos
dadpos_mdd = mean_dad['mean_DAD'][(mean_dad['Valence'] == "pos") & (mean_dad['DStatus'] == "dep")].tolist()
dadpos_con = mean_dad['mean_DAD'][(mean_dad['Valence'] == "pos") & (mean_dad['DStatus'] == "con")].tolist()
# put all into tupled list (no within comparisons here)
dad_testbtw = [(dadneg_mdd, dadneg_con), (dadpos_mdd, dadpos_con)]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_dad_all = []
# first compare valences between groups with a 2-sample t-test
for valence in dad_testbtw:
    ttests_dad = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_dad.insert(0, "ConditionID", f"dad_btw_{valence_cats[dad_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_dad.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_dad_all.append(ttests_dad)

# concat list to dataframe
ttests_dad_all = pd.concat(ttests_dad_all)

# %% [markdown]
# Plot t-test results

# %%
# view respective ttest dicts to make sure everything looks as it should
ttests_ecv_all
# Out:
#                ConditionID         T  dof       tail     p-val  \
# T-test         ecv_btw_neg -0.313372   60  two-sided  0.755085
# T-test         ecv_btw_pos -1.198356   60  two-sided  0.235491
# T-test         ecv_btw_neu -0.776735   60  two-sided  0.440366
# T-test  ecv_within_dep_neg  2.811179   30  two-sided  0.008614
# T-test  ecv_within_dep_pos -0.863944   30  two-sided  0.394474
# T-test  ecv_within_con_neg  4.086420   30  two-sided  0.000301
# T-test  ecv_within_con_pos -0.516283   30  two-sided  0.609441
#
#                   CI95%   cohen-d  eta-squared    BF10     power
# T-test  [-25.87, 18.86]  0.079597     0.001581    0.27  0.060964
# T-test   [-24.86, 6.23]  0.304383     0.022638   0.473  0.218326
# T-test   [-20.77, 9.15]  0.197291     0.009637   0.334  0.119147
# T-test    [7.29, 45.99]  0.607867     0.084564   5.056  0.905631
# T-test   [-19.29, 7.82]  0.167889     0.006997    0.27  0.147826
# T-test   [12.17, 36.49]  0.817726     0.143226  95.617  0.992716
# T-test    [-11.06, 6.6]  0.088506     0.001955   0.217  0.076469

# %%
ttests_ae_all
# Out:
#        ConditionID         T  dof       tail     p-val            CI95%  \
# T-test  ae_btw_neg -0.467297   60  two-sided  0.641980  [-18.44, 11.46]
# T-test  ae_btw_pos -0.429936   60  two-sided  0.668782   [-10.93, 7.06]
#
#          cohen-d  eta-squared   BF10     power
# T-test  0.118694     0.003510  0.284  0.074558
# T-test  0.109204     0.002973   0.28  0.070747

# %%
ttests_dad_all
# Out:
#         ConditionID         T  dof       tail     p-val            CI95%  \
# T-test  dad_btw_neg  0.591074   60  two-sided  0.556691  [-13.83, 25.42]
# T-test  dad_btw_pos -0.210060   60  two-sided  0.834333  [-16.51, 13.37]
#
#          cohen-d  eta-squared   BF10     power
# T-test  0.150133     0.005603    0.3  0.089572
# T-test  0.053355     0.000711  0.264  0.054909

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(ttests_ecv_all, tablefmt="latex")
pg.print_table(ttests_ae_all, tablefmt="latex")
pg.print_table(ttests_dad_all, tablefmt="latex")
# Out:
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID        &      T &   dof & tail      &   p-val & CI95\%           &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  ecv\_btw\_neg        & -0.313 &    60 & two-sided &   0.755 & [-25.87  18.86] &     0.080 &         0.002 &  0.270 &   0.061 \\
#  ecv\_btw\_pos        & -1.198 &    60 & two-sided &   0.235 & [-24.86   6.23] &     0.304 &         0.023 &  0.473 &   0.218 \\
#  ecv\_btw\_neu        & -0.777 &    60 & two-sided &   0.440 & [-20.77   9.15] &     0.197 &         0.010 &  0.334 &   0.119 \\
#  ecv\_within\_dep\_neg &  2.811 &    30 & two-sided &   0.009 & [ 7.29 45.99]   &     0.608 &         0.085 &  5.056 &   0.906 \\
#  ecv\_within\_dep\_pos & -0.864 &    30 & two-sided &   0.394 & [-19.29   7.82] &     0.168 &         0.007 &  0.270 &   0.148 \\
#  ecv\_within\_con\_neg &  4.086 &    30 & two-sided &   0.000 & [12.17 36.49]   &     0.818 &         0.143 & 95.617 &   0.993 \\
#  ecv\_within\_con\_pos & -0.516 &    30 & two-sided &   0.609 & [-11.06   6.6 ] &     0.089 &         0.002 &  0.217 &   0.076 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID   &      T &   dof & tail      &   p-val & CI95\%           &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  ae\_btw\_neg    & -0.467 &    60 & two-sided &   0.642 & [-18.44  11.46] &     0.119 &         0.004 &  0.284 &   0.075 \\
#  ae\_btw\_pos    & -0.430 &    60 & two-sided &   0.669 & [-10.93   7.06] &     0.109 &         0.003 &  0.280 &   0.071 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID   &      T &   dof & tail      &   p-val & CI95\%           &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  dad\_btw\_neg   &  0.591 &    60 & two-sided &   0.557 & [-13.83  25.42] &     0.150 &         0.006 &  0.300 &   0.090 \\
#  dad\_btw\_pos   & -0.210 &    60 & two-sided &   0.834 & [-16.51  13.37] &     0.053 &         0.001 &  0.264 &   0.055 \\
# \hline
# \end{tabular}

# %% [markdown]
# Calculate Enhanced cue Validity (ECV), Attentional Engagement (AE), and Difficulty in Attentional Disengagement (DAD) - group means

# %%
# create mean_{variable} by valence for each group
# collect all single values in a dict for extraction into table
Group_vars_decript = {"MDD_mean": {}, "MDD_std": {}, "CON_mean": {}, "CON_std": {}}

for frame in [("mean_ECV", mean_ecv), ("mean_AE", mean_ae), ("mean_DAD", mean_dad)]:
    # locate Valence and DStatus in frame and set group column to mean_ECV across FEDs for those parameters
    for valence in valence_cats:
        # for MDD
        Group_vars_decript["MDD_mean"][f"{frame[0].split('_', 1)[1]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "dep") & (frame[1]['Valence'] == valence)].mean()
        Group_vars_decript["MDD_std"][f"{frame[0].split('_', 1)[1]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "dep") & (frame[1]['Valence'] == valence)].std()
        # for control
        Group_vars_decript["CON_mean"][f"{frame[0].split('_', 1)[1]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "con") & (frame[1]['Valence'] == valence)].mean()
        Group_vars_decript["CON_std"][f"{frame[0].split('_', 1)[1]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "con") & (frame[1]['Valence'] == valence)].std()

# drop all items with nan values (neutral valences for AE, DAD)
for group in Group_vars_decript.keys():
    for item in list(Group_vars_decript[group].items()):
        if item[1] is np.NaN:
            Group_vars_decript[group].pop(item[0])

# transfer dict to pd.dataframe
Group_vars_decript = pd.DataFrame.from_dict(Group_vars_decript, orient='columns')
# make index its own column
Group_vars_decript.insert(0, "Var_Valence", Group_vars_decript.index)

# %% [markdown]
# Build summary tables for each variable by group, valence (and validity, if needed)

# %%
print(Group_vars_decript)
# Out:
#         Var_Valence   MDD_mean    MDD_std   CON_mean    CON_std
# ECV_neg     ECV_neg  14.358954  52.468369  17.862907  33.508716
# ECV_pos     ECV_pos -18.012495  35.315569  -8.699090  25.004939
# ECV_neu     ECV_neu -12.276753  32.972100  -6.466333  25.447304
# AE_neg       AE_neg  18.524548  31.432013  22.017032  27.269306
# AE_pos       AE_pos  -2.164419  17.974284  -0.230452  17.441070
# DAD_neg     DAD_neg   8.111158  48.154358   2.312208  25.787730
# DAD_pos     DAD_pos  -3.571323  34.892993  -2.002305  22.627973

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(Group_vars_decript, tablefmt="latex")
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Var\_Valence   &   MDD\_mean &   MDD\_std &   CON\_mean &   CON\_std \\
# \hline
#  ECV\_neg       &     14.359 &    52.468 &     17.863 &    33.509 \\
#  ECV\_pos       &    -18.012 &    35.316 &     -8.699 &    25.005 \\
#  ECV\_neu       &    -12.277 &    32.972 &     -6.466 &    25.447 \\
#  AE\_neg        &     18.525 &    31.432 &     22.017 &    27.269 \\
#  AE\_pos        &     -2.164 &    17.974 &     -0.230 &    17.441 \\
#  DAD\_neg       &      8.111 &    48.154 &      2.312 &    25.788 \\
#  DAD\_pos       &     -3.571 &    34.893 &     -2.002 &    22.628 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Testing Zone

# %%
# # transfer to pd.dataframe
# rts_pd = (pd.DataFrame.from_dict(rts, orient='index', columns=['mean_RT']).rename_axis('condition').reset_index())
