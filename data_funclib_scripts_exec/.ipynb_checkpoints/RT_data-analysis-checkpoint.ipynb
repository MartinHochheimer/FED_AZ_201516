# %%
# import everything you need
import numpy as np
import scipy as sp
import pandas as pd
# activate inline magics
# %matplotlib inline 
# import matplotlib.pyplot as plt
# import matplotlib.image as mpl_img
import seaborn as sns
# specific fo statistics
import pingouin as pg

# %% [markdown]
# Define neccesary parameters

# %%
# "Fixed file from Jay still containt wrong/missing values for 46, switched to the most recent file Jay sent me (gmail)"
data_file = "FED_fMRI_fullcodesfixed_final_II.xls"
covariate_file = "FED_Subject_Covariates.xls"

# %% [markdown]
# Create the neccessary factors and sort all variables appropriately

# %%
# taken from Koster et al (2005)
# RTs < 200 ms and RTs > 750 ms were considered outliers, indicating anticipatory responding and delayed responding, respectively.
# Also, RTs deviating more than 3 SDs from the individual mean RT were excluded.
# -> See what conditions are met in the final data file and adapt if necessary!!!

# %%
# extract - data from list in .xls file(s). Outliers and all known errors have already been corrected (see recent "ALLCODESFIXED")
# read relevant content
anova = pd.read_excel(data_file, sheet_name="Final",
                      usecols = ['Subject', 'Condition', 'RT', 'Accuracy'])
covariates = pd.read_excel(covariate_file, sheet_name="analysis",
                           usecols = ['FED_ID', 'BDI_22_Score', 'Gender', 'Age', 'Race'])

# remove all inaccurate (val = 2) trials
anova = anova.loc[anova["Accuracy"] == 1]
# and drop the column
anova = anova.drop('Accuracy', axis = 1)

# remove  200 > RT data > 750
anova = anova.loc[(anova["RT"] >= 200) & (anova["RT"] <= 750)]

# define list of subject numbers
fed_nums = [num for num in range(7, 69)]
# remove first six subjects
anova = anova[(anova.Subject.isin(fed_nums))]
covariates = covariates[(covariates.FED_ID.isin(fed_nums))]

# create variables cue_valence and cue_validity after Condition and assign values according to trial codings (neg, pos, neu) (valid, invalid)
neg, pos, neu = [1, 4, 7, 10], [2, 5, 8, 11], [3, 6, 9, 12]
valid, invalid = [val for val in range(7, 13)], [val for val in range(1, 7)]
# create list of group, valence and validity numerical indices
group_cats, valence_cats, validity_cats = ["dep", "con"], ["neg", "pos", "neu"], ["valid", "invalid"]
# copy Condition list and replace
anova['Cue_Valence'] = anova['Condition']
for valence, name in zip([neg, pos, neu], valence_cats):
    anova.loc[anova['Condition'].isin(valence), 'Cue_Valence'] = name

anova['Cue_Validity'] = anova['Condition']
for validity, name in zip([valid, invalid], validity_cats):
    anova.loc[anova['Condition'].isin(validity), 'Cue_Validity'] = name

# create variable DStatus after Subject and replace each subject value with the corresponding group identity
# separate covariate FED_IDs by BDI22
mdd = covariates.FED_ID[covariates['BDI_22_Score'] == 1]
control = covariates.FED_ID[covariates['BDI_22_Score'] == 0]
# copy Subject list and replace
anova['DStatus'] = anova['Subject']
anova.loc[anova['Subject'].isin(mdd), 'DStatus'] = group_cats[0]
anova.loc[anova['Subject'].isin(control), 'DStatus'] = group_cats[1]

# sort values by DStatus, valence and validity (by factor, starting with largest increment)
anova.sort_values(['DStatus', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# %%
pd.set_option('display.max_rows', None)
print(anova)
# Out:
#            RT  Subject  Condition Cue_Valence Cue_Validity DStatus
# 1071   302.35        7          1         neg      invalid     con
# 1072   256.12        7          1         neg      invalid     con
# 1073   285.54        7          1         neg      invalid     con
# 1074   303.62        7          1         neg      invalid     con
# 1075   266.26        7          1         neg      invalid     con
# 1076   294.58        7          1         neg      invalid     con
# 1077   332.54        7          1         neg      invalid     con
# 1079   281.30        7          1         neg      invalid     con
# 1090   577.72        7          1         neg      invalid     con
# 1091   296.54        7          1         neg      invalid     con
# 1092   360.85        7          1         neg      invalid     con
# 1093   321.91        7          1         neg      invalid     con
# 1094   321.38        7          1         neg      invalid     con
# 1126   291.56        7          4         neg      invalid     con
# 1127   304.64        7          4         neg      invalid     con
# 1128   382.01        7          4         neg      invalid     con
# 1129   297.99        7          4         neg      invalid     con
# 1130   279.34        7          4         neg      invalid     con
# 1131   283.17        7          4         neg      invalid     con
# 1132   372.85        7          4         neg      invalid     con
# 1133   295.59        7          4         neg      invalid     con
# 1134   328.68        7          4         neg      invalid     con
# 1135   295.68        7          4         neg      invalid     con
# 1136   320.88        7          4         neg      invalid     con
# 1137   343.44        7          4         neg      invalid     con
# 1138   257.86        7          4         neg      invalid     con
# 1139   282.57        7          4         neg      invalid     con
# 1140   430.83        7          4         neg      invalid     con
# 1251   322.03        8          1         neg      invalid     con
# 1252   338.02        8          1         neg      invalid     con
# 1253   306.22        8          1         neg      invalid     con
# 1254   347.89        8          1         neg      invalid     con
# 1255   294.32        8          1         neg      invalid     con
# 1256   328.05        8          1         neg      invalid     con
# 1257   359.20        8          1         neg      invalid     con
# 1258   288.23        8          1         neg      invalid     con
# 1259   329.90        8          1         neg      invalid     con
# 1270   321.45        8          1         neg      invalid     con
# 1271   323.08        8          1         neg      invalid     con
# 1272   311.41        8          1         neg      invalid     con
# 1273   332.89        8          1         neg      invalid     con
# 1274   249.62        8          1         neg      invalid     con
# 1306   361.95        8          4         neg      invalid     con
# 1307   306.65        8          4         neg      invalid     con
# 1308   287.26        8          4         neg      invalid     con
# 1309   334.88        8          4         neg      invalid     con
# 1310   435.39        8          4         neg      invalid     con
# 1311   319.75        8          4         neg      invalid     con
# 1312   256.22        8          4         neg      invalid     con
# 1313   445.43        8          4         neg      invalid     con
# 1314   349.87        8          4         neg      invalid     con
# 1315   282.72        8          4         neg      invalid     con
# 1316   312.14        8          4         neg      invalid     con
# 1317   325.33        8          4         neg      invalid     con
# 1318   302.12        8          4         neg      invalid     con
# 1319   336.29        8          4         neg      invalid     con
# 1320   299.29        8          4         neg      invalid     con
# 1431   315.42        9          1         neg      invalid     con
# 1432   248.50        9          1         neg      invalid     con
# 1433   282.02        9          1         neg      invalid     con
# 1434   313.45        9          1         neg      invalid     con
# 1435   402.82        9          1         neg      invalid     con
# 1436   261.76        9          1         neg      invalid     con
# 1437   269.93        9          1         neg      invalid     con
# 1438   454.29        9          1         neg      invalid     con
# 1439   260.76        9          1         neg      invalid     con
# 1450   234.00        9          1         neg      invalid     con
# 1451   292.81        9          1         neg      invalid     con
# 1452   281.05        9          1         neg      invalid     con
# 1453   335.00        9          1         neg      invalid     con
# 1454   422.43        9          1         neg      invalid     con
# 1485   359.13        9          4         neg      invalid     con
# 1486   314.73        9          4         neg      invalid     con
# 1487   270.00        9          4         neg      invalid     con
# 1488   255.13        9          4         neg      invalid     con
# 1489   297.40        9          4         neg      invalid     con
# 1490   342.59        9          4         neg      invalid     con
# 1491   304.91        9          4         neg      invalid     con
# 1492   268.03        9          4         neg      invalid     con
# 1493   283.81        9          4         neg      invalid     con
# 1494   233.00        9          4         neg      invalid     con
# 1495   243.96        9          4         neg      invalid     con
# 1496   250.71        9          4         neg      invalid     con
# 1497   318.50        9          4         neg      invalid     con
# 1498   358.13        9          4         neg      invalid     con
# 1608   297.33       10          1         neg      invalid     con
# 1609   277.27       10          1         neg      invalid     con
# 1610   395.74       10          1         neg      invalid     con
# 1611   246.95       10          1         neg      invalid     con
# 1612   304.64       10          1         neg      invalid     con
# 1613   321.74       10          1         neg      invalid     con
# 1614   257.91       10          1         neg      invalid     con
# 1615   312.37       10          1         neg      invalid     con
# 1626   255.65       10          1         neg      invalid     con
# 1627   296.17       10          1         neg      invalid     con
# 1628   313.09       10          1         neg      invalid     con
# 1629   296.91       10          1         neg      invalid     con
# 1630   286.29       10          1         neg      invalid     con
# 1662   341.30       10          4         neg      invalid     con
# 1663   233.60       10          4         neg      invalid     con
# 1664   362.36       10          4         neg      invalid     con
# 1665   278.35       10          4         neg      invalid     con
# 1666   352.67       10          4         neg      invalid     con
# 1667   376.51       10          4         neg      invalid     con
# 1668   307.04       10          4         neg      invalid     con
# 1669   311.36       10          4         neg      invalid     con
# 1670   325.37       10          4         neg      invalid     con
# 1671   301.59       10          4         neg      invalid     con
# 1672   388.75       10          4         neg      invalid     con
# 1673   307.59       10          4         neg      invalid     con
# 1674   311.62       10          4         neg      invalid     con
# 1675   396.42       10          4         neg      invalid     con
# 1676   537.64       10          4         neg      invalid     con
# 1966   320.16       12          1         neg      invalid     con
# 1967   313.54       12          1         neg      invalid     con
# 1968   261.29       12          1         neg      invalid     con
# 1969   322.63       12          1         neg      invalid     con
# 1970   296.69       12          1         neg      invalid     con
# 1971   300.62       12          1         neg      invalid     con
# 1972   456.86       12          1         neg      invalid     con
# 1973   311.81       12          1         neg      invalid     con
# 1974   304.81       12          1         neg      invalid     con
# 1985   251.78       12          1         neg      invalid     con
# 1986   311.06       12          1         neg      invalid     con
# 1987   279.73       12          1         neg      invalid     con
# 1988   325.03       12          1         neg      invalid     con
# 1989   316.20       12          1         neg      invalid     con
# 2021   374.47       12          4         neg      invalid     con
# 2022   289.87       12          4         neg      invalid     con
# 2023   265.73       12          4         neg      invalid     con
# 2024   298.58       12          4         neg      invalid     con
# 2025   317.36       12          4         neg      invalid     con
# 2026   278.59       12          4         neg      invalid     con
# 2027   285.04       12          4         neg      invalid     con
# 2028   278.44       12          4         neg      invalid     con
# 2029   390.02       12          4         neg      invalid     con
# 2030   316.44       12          4         neg      invalid     con
# 2031   367.25       12          4         neg      invalid     con
# 2032   346.24       12          4         neg      invalid     con
# 2033   314.80       12          4         neg      invalid     con
# 2034   437.89       12          4         neg      invalid     con
# 2035   284.61       12          4         neg      invalid     con
# 2145   222.74       13          1         neg      invalid     con
# 2147   332.31       13          1         neg      invalid     con
# 2148   273.33       13          1         neg      invalid     con
# 2149   653.55       13          1         neg      invalid     con
# 2150   420.35       13          1         neg      invalid     con
# 2151   284.87       13          1         neg      invalid     con
# 2152   389.14       13          1         neg      invalid     con
# 2153   464.67       13          1         neg      invalid     con
# 2163   355.28       13          1         neg      invalid     con
# 2164   398.82       13          1         neg      invalid     con
# 2165   328.74       13          1         neg      invalid     con
# 2166   573.45       13          1         neg      invalid     con
# 2167   245.71       13          1         neg      invalid     con
# 2199   251.27       13          4         neg      invalid     con
# 2201   300.54       13          4         neg      invalid     con
# 2202   394.50       13          4         neg      invalid     con
# 2203   250.04       13          4         neg      invalid     con
# 2204   395.05       13          4         neg      invalid     con
# 2205   233.70       13          4         neg      invalid     con
# 2206   430.49       13          4         neg      invalid     con
# 2207   413.46       13          4         neg      invalid     con
# 2208   262.72       13          4         neg      invalid     con
# 2209   511.27       13          4         neg      invalid     con
# 2210   328.51       13          4         neg      invalid     con
# 2211   551.68       13          4         neg      invalid     con
# 2212   434.46       13          4         neg      invalid     con
# 2492   339.58       15          1         neg      invalid     con
# 2493   390.46       15          1         neg      invalid     con
# 2494   455.41       15          1         neg      invalid     con
# 2495   319.17       15          1         neg      invalid     con
# 2496   389.03       15          1         neg      invalid     con
# 2497   407.94       15          1         neg      invalid     con
# 2498   386.01       15          1         neg      invalid     con
# 2499   439.45       15          1         neg      invalid     con
# 2500   475.79       15          1         neg      invalid     con
# 2511   443.47       15          1         neg      invalid     con
# 2512   304.17       15          1         neg      invalid     con
# 2513   442.34       15          1         neg      invalid     con
# 2514   514.57       15          1         neg      invalid     con
# 2515   362.30       15          1         neg      invalid     con
# 2547   471.83       15          4         neg      invalid     con
# 2548   497.71       15          4         neg      invalid     con
# 2549   489.20       15          4         neg      invalid     con
# 2550   443.84       15          4         neg      invalid     con
# 2551   629.33       15          4         neg      invalid     con
# 2552   429.00       15          4         neg      invalid     con
# 2553   399.85       15          4         neg      invalid     con
# 2554   453.10       15          4         neg      invalid     con
# 2555   397.42       15          4         neg      invalid     con
# 2556   375.15       15          4         neg      invalid     con
# 2557   375.02       15          4         neg      invalid     con
# 2558   316.31       15          4         neg      invalid     con
# 2559   364.37       15          4         neg      invalid     con
# 2560   407.44       15          4         neg      invalid     con
# 2561   360.98       15          4         neg      invalid     con
# 2671   277.35       16          1         neg      invalid     con
# 2672   352.25       16          1         neg      invalid     con
# 2673   330.85       16          1         neg      invalid     con
# 2674   251.39       16          1         neg      invalid     con
# 2675   267.24       16          1         neg      invalid     con
# 2676   238.11       16          1         neg      invalid     con
# 2677   242.77       16          1         neg      invalid     con
# 2678   275.94       16          1         neg      invalid     con
# 2679   297.32       16          1         neg      invalid     con
# 2689   307.14       16          1         neg      invalid     con
# 2690   336.36       16          1         neg      invalid     con
# 2691   228.74       16          1         neg      invalid     con
# 2692   299.13       16          1         neg      invalid     con
# 2693   290.43       16          1         neg      invalid     con
# 2722   301.28       16          4         neg      invalid     con
# 2723   311.91       16          4         neg      invalid     con
# 2724   407.36       16          4         neg      invalid     con
# 2725   211.99       16          4         neg      invalid     con
# 2726   247.18       16          4         neg      invalid     con
# 2727   316.75       16          4         neg      invalid     con
# 2728   283.87       16          4         neg      invalid     con
# 2729   257.31       16          4         neg      invalid     con
# 2730   256.09       16          4         neg      invalid     con
# 2731   272.42       16          4         neg      invalid     con
# 2732   233.56       16          4         neg      invalid     con
# 2733   266.58       16          4         neg      invalid     con
# 2734   257.79       16          4         neg      invalid     con
# 2735   216.70       16          4         neg      invalid     con
# 2842   254.18       17          1         neg      invalid     con
# 2843   278.09       17          1         neg      invalid     con
# 2844   274.19       17          1         neg      invalid     con
# 2845   279.47       17          1         neg      invalid     con
# 2846   325.89       17          1         neg      invalid     con
# 2847   249.55       17          1         neg      invalid     con
# 2848   231.50       17          1         neg      invalid     con
# 2849   250.59       17          1         neg      invalid     con
# 2850   304.75       17          1         neg      invalid     con
# 2861   292.00       17          1         neg      invalid     con
# 2862   280.41       17          1         neg      invalid     con
# 2863   287.69       17          1         neg      invalid     con
# 2864   277.63       17          1         neg      invalid     con
# 2865   206.69       17          1         neg      invalid     con
# 2897   303.40       17          4         neg      invalid     con
# 2898   261.15       17          4         neg      invalid     con
# 2899   270.57       17          4         neg      invalid     con
# 2900   250.99       17          4         neg      invalid     con
# 2901   246.45       17          4         neg      invalid     con
# 2902   251.66       17          4         neg      invalid     con
# 2903   257.49       17          4         neg      invalid     con
# 2904   254.34       17          4         neg      invalid     con
# 2905   284.68       17          4         neg      invalid     con
# 2906   251.62       17          4         neg      invalid     con
# 2907   230.86       17          4         neg      invalid     con
# 2908   251.22       17          4         neg      invalid     con
# 2909   226.18       17          4         neg      invalid     con
# 2910   237.85       17          4         neg      invalid     con
# 2911   336.22       17          4         neg      invalid     con
# 3198   271.50       19          1         neg      invalid     con
# 3199   346.26       19          1         neg      invalid     con
# 3200   305.29       19          1         neg      invalid     con
# 3201   256.07       19          1         neg      invalid     con
# 3202   297.62       19          1         neg      invalid     con
# 3203   265.66       19          1         neg      invalid     con
# 3204   557.94       19          1         neg      invalid     con
# 3205   256.57       19          1         neg      invalid     con
# 3206   266.34       19          1         neg      invalid     con
# 3217   424.59       19          1         neg      invalid     con
# 3218   329.23       19          1         neg      invalid     con
# 3219   367.54       19          1         neg      invalid     con
# 3220   254.89       19          1         neg      invalid     con
# 3221   289.66       19          1         neg      invalid     con
# 3253   307.83       19          4         neg      invalid     con
# 3254   354.08       19          4         neg      invalid     con
# 3255   275.54       19          4         neg      invalid     con
# 3256   310.59       19          4         neg      invalid     con
# 3257   360.30       19          4         neg      invalid     con
# 3258   345.10       19          4         neg      invalid     con
# 3259   308.15       19          4         neg      invalid     con
# 3260   291.30       19          4         neg      invalid     con
# 3261   339.37       19          4         neg      invalid     con
# 3262   317.85       19          4         neg      invalid     con
# 3263   264.77       19          4         neg      invalid     con
# 3264   601.76       19          4         neg      invalid     con
# 3265   311.83       19          4         neg      invalid     con
# 3266   351.61       19          4         neg      invalid     con
# 3267   265.83       19          4         neg      invalid     con
# 3377   249.64       20          1         neg      invalid     con
# 3378   323.94       20          1         neg      invalid     con
# 3379   285.21       20          1         neg      invalid     con
# 3380   237.66       20          1         neg      invalid     con
# 3381   314.85       20          1         neg      invalid     con
# 3382   296.65       20          1         neg      invalid     con
# 3383   267.08       20          1         neg      invalid     con
# 3384   232.01       20          1         neg      invalid     con
# 3385   239.41       20          1         neg      invalid     con
# 3396   254.67       20          1         neg      invalid     con
# 3397   255.37       20          1         neg      invalid     con
# 3398   229.93       20          1         neg      invalid     con
# 3399   214.18       20          1         neg      invalid     con
# 3431   255.99       20          4         neg      invalid     con
# 3432   300.25       20          4         neg      invalid     con
# 3433   295.32       20          4         neg      invalid     con
# 3434   269.15       20          4         neg      invalid     con
# 3435   282.85       20          4         neg      invalid     con
# 3436   292.23       20          4         neg      invalid     con
# 3437   254.54       20          4         neg      invalid     con
# 3439   247.44       20          4         neg      invalid     con
# 3440   289.23       20          4         neg      invalid     con
# 3441   270.88       20          4         neg      invalid     con
# 3442   255.90       20          4         neg      invalid     con
# 3443   281.43       20          4         neg      invalid     con
# 3444   237.83       20          4         neg      invalid     con
# 3445   284.62       20          4         neg      invalid     con
# 3552   525.57       21          1         neg      invalid     con
# 3553   277.27       21          1         neg      invalid     con
# 3554   401.99       21          1         neg      invalid     con
# 3555   429.34       21          1         neg      invalid     con
# 3556   394.14       21          1         neg      invalid     con
# 3557   385.93       21          1         neg      invalid     con
# 3558   384.64       21          1         neg      invalid     con
# 3559   346.61       21          1         neg      invalid     con
# 3560   303.53       21          1         neg      invalid     con
# 3571   650.59       21          1         neg      invalid     con
# 3572   307.43       21          1         neg      invalid     con
# 3573   342.25       21          1         neg      invalid     con
# 3574   352.87       21          1         neg      invalid     con
# 3575   333.01       21          1         neg      invalid     con
# 3607   340.73       21          4         neg      invalid     con
# 3608   417.67       21          4         neg      invalid     con
# 3609   377.57       21          4         neg      invalid     con
# 3610   351.60       21          4         neg      invalid     con
# 3611   357.16       21          4         neg      invalid     con
# 3612   359.46       21          4         neg      invalid     con
# 3613   314.12       21          4         neg      invalid     con
# 3614   351.35       21          4         neg      invalid     con
# 3615   353.71       21          4         neg      invalid     con
# 3616   424.20       21          4         neg      invalid     con
# 3617   366.62       21          4         neg      invalid     con
# 3618   356.16       21          4         neg      invalid     con
# 3619   439.09       21          4         neg      invalid     con
# 3620   333.41       21          4         neg      invalid     con
# 3621   370.30       21          4         neg      invalid     con
# 3731   291.69       22          1         neg      invalid     con
# 3732   247.73       22          1         neg      invalid     con
# 3733   324.65       22          1         neg      invalid     con
# 3734   261.33       22          1         neg      invalid     con
# 3735   311.93       22          1         neg      invalid     con
# 3736   282.35       22          1         neg      invalid     con
# 3737   270.03       22          1         neg      invalid     con
# 3738   293.57       22          1         neg      invalid     con
# 3739   288.45       22          1         neg      invalid     con
# 3750   244.09       22          1         neg      invalid     con
# 3751   313.88       22          1         neg      invalid     con
# 3752   354.75       22          1         neg      invalid     con
# 3754   290.99       22          1         neg      invalid     con
# 3785   385.44       22          4         neg      invalid     con
# 3786   283.21       22          4         neg      invalid     con
# 3787   246.86       22          4         neg      invalid     con
# 3788   298.00       22          4         neg      invalid     con
# 3789   303.96       22          4         neg      invalid     con
# 3790   260.52       22          4         neg      invalid     con
# 3791   302.97       22          4         neg      invalid     con
# 3792   295.13       22          4         neg      invalid     con
# 3793   314.35       22          4         neg      invalid     con
# 3794   312.76       22          4         neg      invalid     con
# 3795   339.74       22          4         neg      invalid     con
# 3796   263.53       22          4         neg      invalid     con
# 3797   352.82       22          4         neg      invalid     con
# 3798   291.95       22          4         neg      invalid     con
# 3799   310.03       22          4         neg      invalid     con
# 3909   254.39       23          1         neg      invalid     con
# 3910   335.74       23          1         neg      invalid     con
# 3911   288.97       23          1         neg      invalid     con
# 3912   264.44       23          1         neg      invalid     con
# 3913   275.37       23          1         neg      invalid     con
# 3914   317.33       23          1         neg      invalid     con
# 3915   276.51       23          1         neg      invalid     con
# 3916   280.26       23          1         neg      invalid     con
# 3917   266.13       23          1         neg      invalid     con
# 3928   252.10       23          1         neg      invalid     con
# 3929   283.53       23          1         neg      invalid     con
# 3930   303.10       23          1         neg      invalid     con
# 3931   274.71       23          1         neg      invalid     con
# 3932   276.89       23          1         neg      invalid     con
# 3964   354.40       23          4         neg      invalid     con
# 3965   251.33       23          4         neg      invalid     con
# 3966   273.84       23          4         neg      invalid     con
# 3967   310.15       23          4         neg      invalid     con
# 3968   323.22       23          4         neg      invalid     con
# 3969   320.96       23          4         neg      invalid     con
# 3970   281.92       23          4         neg      invalid     con
# 3971   273.06       23          4         neg      invalid     con
# 3972   260.34       23          4         neg      invalid     con
# 3973   284.01       23          4         neg      invalid     con
# 3974   408.12       23          4         neg      invalid     con
# 3975   310.01       23          4         neg      invalid     con
# 3976   318.11       23          4         neg      invalid     con
# 3977   276.57       23          4         neg      invalid     con
# 3978   334.78       23          4         neg      invalid     con
# 4085   343.54       24          1         neg      invalid     con
# 4086   269.73       24          1         neg      invalid     con
# 4087   224.96       24          1         neg      invalid     con
# 4088   354.32       24          1         neg      invalid     con
# 4089   302.26       24          1         neg      invalid     con
# 4090   296.97       24          1         neg      invalid     con
# 4091   280.55       24          1         neg      invalid     con
# 4092   375.02       24          1         neg      invalid     con
# 4093   239.83       24          1         neg      invalid     con
# 4104   338.60       24          1         neg      invalid     con
# 4105   344.82       24          1         neg      invalid     con
# 4106   290.35       24          1         neg      invalid     con
# 4107   281.01       24          1         neg      invalid     con
# 4108   245.22       24          1         neg      invalid     con
# 4139   275.88       24          4         neg      invalid     con
# 4140   335.92       24          4         neg      invalid     con
# 4141   353.09       24          4         neg      invalid     con
# 4142   261.71       24          4         neg      invalid     con
# 4143   314.50       24          4         neg      invalid     con
# 4144   244.59       24          4         neg      invalid     con
# 4145   335.29       24          4         neg      invalid     con
# 4146   327.26       24          4         neg      invalid     con
# 4147   299.04       24          4         neg      invalid     con
# 4148   319.54       24          4         neg      invalid     con
# 4149   328.32       24          4         neg      invalid     con
# 4150   246.85       24          4         neg      invalid     con
# 4151   403.87       24          4         neg      invalid     con
# 4152   345.42       24          4         neg      invalid     con
# 4262   319.06       25          1         neg      invalid     con
# 4263   319.06       25          1         neg      invalid     con
# 4264   276.66       25          1         neg      invalid     con
# 4265   276.66       25          1         neg      invalid     con
# 4266   317.91       25          1         neg      invalid     con
# 4267   317.91       25          1         neg      invalid     con
# 4268   301.71       25          1         neg      invalid     con
# 4269   301.71       25          1         neg      invalid     con
# 4270   302.86       25          1         neg      invalid     con
# 4271   302.86       25          1         neg      invalid     con
# 4272   260.06       25          1         neg      invalid     con
# 4273   260.06       25          1         neg      invalid     con
# 4274   294.80       25          1         neg      invalid     con
# 4275   294.80       25          1         neg      invalid     con
# 4276   343.11       25          1         neg      invalid     con
# 4277   343.11       25          1         neg      invalid     con
# 4278   283.07       25          1         neg      invalid     con
# 4279   283.07       25          1         neg      invalid     con
# 4300   394.38       25          1         neg      invalid     con
# 4301   394.38       25          1         neg      invalid     con
# 4302   268.16       25          1         neg      invalid     con
# 4303   268.16       25          1         neg      invalid     con
# 4304   370.72       25          1         neg      invalid     con
# 4305   370.72       25          1         neg      invalid     con
# 4306   302.09       25          1         neg      invalid     con
# 4307   302.09       25          1         neg      invalid     con
# 4308   280.00       25          1         neg      invalid     con
# 4309   280.00       25          1         neg      invalid     con
# 4370   312.10       25          4         neg      invalid     con
# 4371   312.10       25          4         neg      invalid     con
# 4372   283.28       25          4         neg      invalid     con
# 4373   283.28       25          4         neg      invalid     con
# 4374   367.18       25          4         neg      invalid     con
# 4375   367.18       25          4         neg      invalid     con
# 4376   282.59       25          4         neg      invalid     con
# 4377   282.59       25          4         neg      invalid     con
# 4378   314.05       25          4         neg      invalid     con
# 4379   314.05       25          4         neg      invalid     con
# 4380   365.19       25          4         neg      invalid     con
# 4381   365.19       25          4         neg      invalid     con
# 4382   328.48       25          4         neg      invalid     con
# 4383   328.48       25          4         neg      invalid     con
# 4384   350.14       25          4         neg      invalid     con
# 4385   350.14       25          4         neg      invalid     con
# 4386   261.33       25          4         neg      invalid     con
# 4387   261.33       25          4         neg      invalid     con
# 4388   330.25       25          4         neg      invalid     con
# 4389   330.25       25          4         neg      invalid     con
# 4390   232.63       25          4         neg      invalid     con
# 4391   232.63       25          4         neg      invalid     con
# 4392   388.60       25          4         neg      invalid     con
# 4393   388.60       25          4         neg      invalid     con
# 4394   342.51       25          4         neg      invalid     con
# 4395   342.51       25          4         neg      invalid     con
# 4396   321.41       25          4         neg      invalid     con
# 4397   321.41       25          4         neg      invalid     con
# 4398   314.62       25          4         neg      invalid     con
# 4399   314.62       25          4         neg      invalid     con
# 4620   327.26       26          1         neg      invalid     con
# 4621   466.91       26          1         neg      invalid     con
# 4622   225.21       26          1         neg      invalid     con
# 4623   392.06       26          1         neg      invalid     con
# 4624   390.23       26          1         neg      invalid     con
# 4625   279.86       26          1         neg      invalid     con
# 4626   361.14       26          1         neg      invalid     con
# 4627   232.91       26          1         neg      invalid     con
# 4628   301.61       26          1         neg      invalid     con
# 4639   296.03       26          1         neg      invalid     con
# 4640   313.44       26          1         neg      invalid     con
# 4641   378.09       26          1         neg      invalid     con
# 4642   371.14       26          1         neg      invalid     con
# 4643   288.88       26          1         neg      invalid     con
# 4675   342.73       26          4         neg      invalid     con
# 4676   378.59       26          4         neg      invalid     con
# 4677   391.33       26          4         neg      invalid     con
# 4678   501.67       26          4         neg      invalid     con
# 4679   419.95       26          4         neg      invalid     con
# 4680   335.04       26          4         neg      invalid     con
# 4681   325.05       26          4         neg      invalid     con
# 4682   355.25       26          4         neg      invalid     con
# 4683   422.43       26          4         neg      invalid     con
# 4684   333.17       26          4         neg      invalid     con
# 4685   315.73       26          4         neg      invalid     con
# 4686   341.96       26          4         neg      invalid     con
# 4687   315.96       26          4         neg      invalid     con
# 4688   340.34       26          4         neg      invalid     con
# 4689   353.57       26          4         neg      invalid     con
# 8674   498.23       49          1         neg      invalid     con
# 8675   284.01       49          1         neg      invalid     con
# 8676   304.98       49          1         neg      invalid     con
# 8677   350.01       49          1         neg      invalid     con
# 8678   304.04       49          1         neg      invalid     con
# 8679   267.72       49          1         neg      invalid     con
# 8680   295.56       49          1         neg      invalid     con
# 8681   369.33       49          1         neg      invalid     con
# 8682   372.93       49          1         neg      invalid     con
# 8693   506.51       49          1         neg      invalid     con
# 8694   348.32       49          1         neg      invalid     con
# 8695   436.40       49          1         neg      invalid     con
# 8696   289.62       49          1         neg      invalid     con
# 8697   410.11       49          1         neg      invalid     con
# 8729   382.10       49          4         neg      invalid     con
# 8730   422.19       49          4         neg      invalid     con
# 8731   275.84       49          4         neg      invalid     con
# 8732   343.71       49          4         neg      invalid     con
# 8733   304.79       49          4         neg      invalid     con
# 8734   442.55       49          4         neg      invalid     con
# 8735   344.36       49          4         neg      invalid     con
# 8736   281.38       49          4         neg      invalid     con
# 8737   271.61       49          4         neg      invalid     con
# 8738   266.19       49          4         neg      invalid     con
# 8739   284.63       49          4         neg      invalid     con
# 8740   263.35       49          4         neg      invalid     con
# 8741   384.61       49          4         neg      invalid     con
# 8742   431.03       49          4         neg      invalid     con
# 8851   260.66       50          1         neg      invalid     con
# 8852   224.34       50          1         neg      invalid     con
# 8853   282.90       50          1         neg      invalid     con
# 8854   308.58       50          1         neg      invalid     con
# 8855   237.16       50          1         neg      invalid     con
# 8856   245.36       50          1         neg      invalid     con
# 8857   306.87       50          1         neg      invalid     con
# 8858   287.37       50          1         neg      invalid     con
# 8859   307.84       50          1         neg      invalid     con
# 8870   258.30       50          1         neg      invalid     con
# 8871   245.18       50          1         neg      invalid     con
# 8872   274.96       50          1         neg      invalid     con
# 8873   276.15       50          1         neg      invalid     con
# 8874   238.56       50          1         neg      invalid     con
# 8906   257.05       50          4         neg      invalid     con
# 8907   239.69       50          4         neg      invalid     con
# 8908   343.29       50          4         neg      invalid     con
# 8909   257.15       50          4         neg      invalid     con
# 8910   291.34       50          4         neg      invalid     con
# 8911   314.81       50          4         neg      invalid     con
# 8912   312.74       50          4         neg      invalid     con
# 8913   286.85       50          4         neg      invalid     con
# 8914   335.83       50          4         neg      invalid     con
# 8915   261.57       50          4         neg      invalid     con
# 8916   301.08       50          4         neg      invalid     con
# 8917   297.43       50          4         neg      invalid     con
# 8918   286.60       50          4         neg      invalid     con
# 8919   306.35       50          4         neg      invalid     con
# 9386   333.63       53          1         neg      invalid     con
# 9387   500.75       53          1         neg      invalid     con
# 9388   508.93       53          1         neg      invalid     con
# 9389   332.09       53          1         neg      invalid     con
# 9390   533.55       53          1         neg      invalid     con
# 9391   399.07       53          1         neg      invalid     con
# 9392   509.48       53          1         neg      invalid     con
# 9393   413.80       53          1         neg      invalid     con
# 9394   350.95       53          1         neg      invalid     con
# 9405   508.48       53          1         neg      invalid     con
# 9406   460.90       53          1         neg      invalid     con
# 9407   477.12       53          1         neg      invalid     con
# 9408   377.12       53          1         neg      invalid     con
# 9409   518.75       53          1         neg      invalid     con
# 9441   436.18       53          4         neg      invalid     con
# 9442   427.13       53          4         neg      invalid     con
# 9443   310.16       53          4         neg      invalid     con
# 9444   334.07       53          4         neg      invalid     con
# 9445   422.03       53          4         neg      invalid     con
# 9446   332.84       53          4         neg      invalid     con
# 9447   377.38       53          4         neg      invalid     con
# 9448   495.64       53          4         neg      invalid     con
# 9449   331.68       53          4         neg      invalid     con
# 9450   357.41       53          4         neg      invalid     con
# 9451   359.50       53          4         neg      invalid     con
# 9452   375.72       53          4         neg      invalid     con
# 9453   526.95       53          4         neg      invalid     con
# 9454   284.09       53          4         neg      invalid     con
# 9455   574.78       53          4         neg      invalid     con
# 9566   239.19       54          1         neg      invalid     con
# 9567   278.43       54          1         neg      invalid     con
# 9568   267.81       54          1         neg      invalid     con
# 9569   317.88       54          1         neg      invalid     con
# 9570   251.03       54          1         neg      invalid     con
# 9571   285.73       54          1         neg      invalid     con
# 9572   283.37       54          1         neg      invalid     con
# 9573   291.39       54          1         neg      invalid     con
# 9574   265.42       54          1         neg      invalid     con
# 9585   224.08       54          1         neg      invalid     con
# 9586   275.18       54          1         neg      invalid     con
# 9587   460.59       54          1         neg      invalid     con
# 9588   250.44       54          1         neg      invalid     con
# 9589   262.36       54          1         neg      invalid     con
# 9621   384.44       54          4         neg      invalid     con
# 9622   261.97       54          4         neg      invalid     con
# 9623   257.75       54          4         neg      invalid     con
# 9624   317.26       54          4         neg      invalid     con
# 9625   303.13       54          4         neg      invalid     con
# 9626   320.42       54          4         neg      invalid     con
# 9627   262.17       54          4         neg      invalid     con
# 9628   288.06       54          4         neg      invalid     con
# 9629   389.91       54          4         neg      invalid     con
# 9630   253.17       54          4         neg      invalid     con
# 9631   251.12       54          4         neg      invalid     con
# 9632   264.00       54          4         neg      invalid     con
# 9633   264.07       54          4         neg      invalid     con
# 9634   286.69       54          4         neg      invalid     con
# 9635   281.73       54          4         neg      invalid     con
# 9924   271.13       56          1         neg      invalid     con
# 9925   272.62       56          1         neg      invalid     con
# 9926   299.92       56          1         neg      invalid     con
# 9927   344.03       56          1         neg      invalid     con
# 9928   326.54       56          1         neg      invalid     con
# 9929   309.08       56          1         neg      invalid     con
# 9930   299.67       56          1         neg      invalid     con
# 9931   266.37       56          1         neg      invalid     con
# 9932   313.80       56          1         neg      invalid     con
# 9943   335.48       56          1         neg      invalid     con
# 9944   325.10       56          1         neg      invalid     con
# 9945   303.91       56          1         neg      invalid     con
# 9946   290.79       56          1         neg      invalid     con
# 9947   330.01       56          1         neg      invalid     con
# 9979   408.13       56          4         neg      invalid     con
# 9980   332.49       56          4         neg      invalid     con
# 9981   287.74       56          4         neg      invalid     con
# 9982   287.48       56          4         neg      invalid     con
# 9983   425.16       56          4         neg      invalid     con
# 9984   297.00       56          4         neg      invalid     con
# 9985   379.24       56          4         neg      invalid     con
# 9986   417.14       56          4         neg      invalid     con
# 9987   298.03       56          4         neg      invalid     con
# 9988   299.70       56          4         neg      invalid     con
# 9989   250.07       56          4         neg      invalid     con
# 9990   337.62       56          4         neg      invalid     con
# 9991   337.42       56          4         neg      invalid     con
# 9992   336.93       56          4         neg      invalid     con
# 9993   283.08       56          4         neg      invalid     con
# 10284  340.19       58          1         neg      invalid     con
# 10285  306.30       58          1         neg      invalid     con
# 10286  308.75       58          1         neg      invalid     con
# 10287  256.78       58          1         neg      invalid     con
# 10288  355.62       58          1         neg      invalid     con
# 10289  274.46       58          1         neg      invalid     con
# 10290  270.31       58          1         neg      invalid     con
# 10291  288.18       58          1         neg      invalid     con
# 10292  303.74       58          1         neg      invalid     con
# 10303  366.77       58          1         neg      invalid     con
# 10304  266.69       58          1         neg      invalid     con
# 10305  271.24       58          1         neg      invalid     con
# 10306  324.32       58          1         neg      invalid     con
# 10307  279.28       58          1         neg      invalid     con
# 10339  253.49       58          4         neg      invalid     con
# 10340  451.61       58          4         neg      invalid     con
# 10341  318.19       58          4         neg      invalid     con
# 10342  296.28       58          4         neg      invalid     con
# 10343  302.42       58          4         neg      invalid     con
# 10344  309.21       58          4         neg      invalid     con
# 10345  247.69       58          4         neg      invalid     con
# 10346  411.55       58          4         neg      invalid     con
# 10347  337.67       58          4         neg      invalid     con
# 10348  301.95       58          4         neg      invalid     con
# 10349  315.26       58          4         neg      invalid     con
# 10350  274.01       58          4         neg      invalid     con
# 10351  504.98       58          4         neg      invalid     con
# 10352  318.01       58          4         neg      invalid     con
# 10640  329.86       60          1         neg      invalid     con
# 10641  362.44       60          1         neg      invalid     con
# 10642  374.03       60          1         neg      invalid     con
# 10643  381.70       60          1         neg      invalid     con
# 10644  546.19       60          1         neg      invalid     con
# 10645  409.82       60          1         neg      invalid     con
# 10646  398.92       60          1         neg      invalid     con
# 10647  384.13       60          1         neg      invalid     con
# 10648  405.19       60          1         neg      invalid     con
# 10659  331.47       60          1         neg      invalid     con
# 10660  359.10       60          1         neg      invalid     con
# 10661  329.56       60          1         neg      invalid     con
# 10662  337.79       60          1         neg      invalid     con
# 10663  346.43       60          1         neg      invalid     con
# 10695  443.10       60          4         neg      invalid     con
# 10696  365.33       60          4         neg      invalid     con
# 10697  406.81       60          4         neg      invalid     con
# 10698  381.77       60          4         neg      invalid     con
# 10699  347.12       60          4         neg      invalid     con
# 10700  398.02       60          4         neg      invalid     con
# 10701  434.68       60          4         neg      invalid     con
# 10702  338.78       60          4         neg      invalid     con
# 10703  360.08       60          4         neg      invalid     con
# 10704  370.04       60          4         neg      invalid     con
# 10705  356.30       60          4         neg      invalid     con
# 10706  397.85       60          4         neg      invalid     con
# 10707  422.23       60          4         neg      invalid     con
# 10708  342.34       60          4         neg      invalid     con
# 10709  381.78       60          4         neg      invalid     con
# 10819  347.16       61          1         neg      invalid     con
# 10820  289.36       61          1         neg      invalid     con
# 10821  295.35       61          1         neg      invalid     con
# 10822  292.25       61          1         neg      invalid     con
# ...
# 8422   412.95       47          8         pos        valid     dep
# 8423   346.19       47          8         pos        valid     dep
# 8424   299.78       47          8         pos        valid     dep
# 8425   412.68       47          8         pos        valid     dep
# 8426   252.58       47          8         pos        valid     dep
# 8427   285.40       47          8         pos        valid     dep
# 8428   391.01       47          8         pos        valid     dep
# 8429   394.72       47          8         pos        valid     dep
# 8430   282.22       47          8         pos        valid     dep
# 8431   410.61       47          8         pos        valid     dep
# 8432   400.67       47          8         pos        valid     dep
# 8433   319.26       47          8         pos        valid     dep
# 8434   303.77       47          8         pos        valid     dep
# 8435   352.21       47          8         pos        valid     dep
# 8464   374.45       47         11         pos        valid     dep
# 8465   592.17       47         11         pos        valid     dep
# 8466   368.76       47         11         pos        valid     dep
# 8467   346.47       47         11         pos        valid     dep
# 8468   243.75       47         11         pos        valid     dep
# 8469   314.92       47         11         pos        valid     dep
# 8470   355.17       47         11         pos        valid     dep
# 8471   260.26       47         11         pos        valid     dep
# 8472   330.57       47         11         pos        valid     dep
# 8473   545.59       47         11         pos        valid     dep
# 8474   318.84       47         11         pos        valid     dep
# 8475   417.28       47         11         pos        valid     dep
# 8476   272.56       47         11         pos        valid     dep
# 8477   295.08       47         11         pos        valid     dep
# 8478   284.18       47         11         pos        valid     dep
# 8512   394.12       48          8         pos        valid     dep
# 8600   476.03       48          8         pos        valid     dep
# 8601   545.78       48          8         pos        valid     dep
# 8602   400.24       48          8         pos        valid     dep
# 8603   517.39       48          8         pos        valid     dep
# 8604   371.68       48          8         pos        valid     dep
# 8605   361.97       48          8         pos        valid     dep
# 8606   483.87       48          8         pos        valid     dep
# 8607   430.63       48          8         pos        valid     dep
# 8608   385.94       48          8         pos        valid     dep
# 8609   302.98       48          8         pos        valid     dep
# 8610   388.77       48          8         pos        valid     dep
# 8611   424.52       48          8         pos        valid     dep
# 8612   323.07       48          8         pos        valid     dep
# 8613   480.22       48          8         pos        valid     dep
# 8644   369.29       48         11         pos        valid     dep
# 8645   302.65       48         11         pos        valid     dep
# 8646   396.21       48         11         pos        valid     dep
# 8647   426.09       48         11         pos        valid     dep
# 8648   369.76       48         11         pos        valid     dep
# 8649   365.23       48         11         pos        valid     dep
# 8650   321.65       48         11         pos        valid     dep
# 8651   477.21       48         11         pos        valid     dep
# 8652   353.77       48         11         pos        valid     dep
# 8653   447.29       48         11         pos        valid     dep
# 8654   351.59       48         11         pos        valid     dep
# 8655   270.78       48         11         pos        valid     dep
# 8656   351.83       48         11         pos        valid     dep
# 8657   366.20       48         11         pos        valid     dep
# 8658   334.99       48         11         pos        valid     dep
# 9046   337.28       51          8         pos        valid     dep
# 9133   290.68       51          8         pos        valid     dep
# 9134   279.59       51          8         pos        valid     dep
# 9135   277.82       51          8         pos        valid     dep
# 9136   275.65       51          8         pos        valid     dep
# 9137   229.77       51          8         pos        valid     dep
# 9138   281.95       51          8         pos        valid     dep
# 9139   299.44       51          8         pos        valid     dep
# 9140   359.85       51          8         pos        valid     dep
# 9141   331.10       51          8         pos        valid     dep
# 9142   306.12       51          8         pos        valid     dep
# 9143   462.75       51          8         pos        valid     dep
# 9144   230.54       51          8         pos        valid     dep
# 9145   534.86       51          8         pos        valid     dep
# 9146   298.94       51          8         pos        valid     dep
# 9177   296.63       51         11         pos        valid     dep
# 9178   234.74       51         11         pos        valid     dep
# 9179   349.19       51         11         pos        valid     dep
# 9180   227.13       51         11         pos        valid     dep
# 9181   291.38       51         11         pos        valid     dep
# 9182   245.64       51         11         pos        valid     dep
# 9183   288.45       51         11         pos        valid     dep
# 9184   293.01       51         11         pos        valid     dep
# 9185   382.49       51         11         pos        valid     dep
# 9186   281.91       51         11         pos        valid     dep
# 9187   546.03       51         11         pos        valid     dep
# 9188   300.64       51         11         pos        valid     dep
# 9189   204.63       51         11         pos        valid     dep
# 9190   281.25       51         11         pos        valid     dep
# 9191   257.06       51         11         pos        valid     dep
# 9224   330.92       52          8         pos        valid     dep
# 9312   350.67       52          8         pos        valid     dep
# 9313   335.63       52          8         pos        valid     dep
# 9314   285.61       52          8         pos        valid     dep
# 9315   410.03       52          8         pos        valid     dep
# 9316   326.51       52          8         pos        valid     dep
# 9317   356.51       52          8         pos        valid     dep
# 9318   333.09       52          8         pos        valid     dep
# 9319   308.95       52          8         pos        valid     dep
# 9320   306.63       52          8         pos        valid     dep
# 9321   367.63       52          8         pos        valid     dep
# 9322   316.86       52          8         pos        valid     dep
# 9323   296.90       52          8         pos        valid     dep
# 9324   292.86       52          8         pos        valid     dep
# 9325   376.04       52          8         pos        valid     dep
# 9356   305.26       52         11         pos        valid     dep
# 9357   221.70       52         11         pos        valid     dep
# 9358   264.54       52         11         pos        valid     dep
# 9359   357.52       52         11         pos        valid     dep
# 9360   270.33       52         11         pos        valid     dep
# 9361   371.71       52         11         pos        valid     dep
# 9362   323.32       52         11         pos        valid     dep
# 9363   285.95       52         11         pos        valid     dep
# 9364   296.63       52         11         pos        valid     dep
# 9365   409.36       52         11         pos        valid     dep
# 9366   280.62       52         11         pos        valid     dep
# 9367   313.60       52         11         pos        valid     dep
# 9368   360.60       52         11         pos        valid     dep
# 9369   309.81       52         11         pos        valid     dep
# 9370   338.49       52         11         pos        valid     dep
# 9763   356.68       55          8         pos        valid     dep
# 9850   498.94       55          8         pos        valid     dep
# 9851   440.32       55          8         pos        valid     dep
# 9852   319.13       55          8         pos        valid     dep
# 9853   309.42       55          8         pos        valid     dep
# 9854   362.49       55          8         pos        valid     dep
# 9855   250.77       55          8         pos        valid     dep
# 9856   377.21       55          8         pos        valid     dep
# 9857   313.86       55          8         pos        valid     dep
# 9858   268.02       55          8         pos        valid     dep
# 9859   524.40       55          8         pos        valid     dep
# 9860   418.46       55          8         pos        valid     dep
# 9861   479.45       55          8         pos        valid     dep
# 9862   532.61       55          8         pos        valid     dep
# 9863   306.77       55          8         pos        valid     dep
# 9894   273.68       55         11         pos        valid     dep
# 9895   237.72       55         11         pos        valid     dep
# 9896   372.04       55         11         pos        valid     dep
# 9897   311.36       55         11         pos        valid     dep
# 9898   394.86       55         11         pos        valid     dep
# 9899   249.87       55         11         pos        valid     dep
# 9900   263.84       55         11         pos        valid     dep
# 9901   353.17       55         11         pos        valid     dep
# 9902   263.53       55         11         pos        valid     dep
# 9903   369.55       55         11         pos        valid     dep
# 9904   342.73       55         11         pos        valid     dep
# 9905   368.16       55         11         pos        valid     dep
# 9906   285.17       55         11         pos        valid     dep
# 9907   211.28       55         11         pos        valid     dep
# 9908   319.89       55         11         pos        valid     dep
# 10122  505.50       57          8         pos        valid     dep
# 10210  357.53       57          8         pos        valid     dep
# 10211  346.91       57          8         pos        valid     dep
# 10212  569.31       57          8         pos        valid     dep
# 10213  457.30       57          8         pos        valid     dep
# 10214  277.06       57          8         pos        valid     dep
# 10215  316.70       57          8         pos        valid     dep
# 10216  405.64       57          8         pos        valid     dep
# 10217  422.87       57          8         pos        valid     dep
# 10218  337.31       57          8         pos        valid     dep
# 10219  385.38       57          8         pos        valid     dep
# 10220  394.58       57          8         pos        valid     dep
# 10221  407.19       57          8         pos        valid     dep
# 10222  404.13       57          8         pos        valid     dep
# 10223  355.59       57          8         pos        valid     dep
# 10254  418.25       57         11         pos        valid     dep
# 10255  353.98       57         11         pos        valid     dep
# 10256  413.67       57         11         pos        valid     dep
# 10257  451.70       57         11         pos        valid     dep
# 10258  346.84       57         11         pos        valid     dep
# 10259  529.62       57         11         pos        valid     dep
# 10260  326.28       57         11         pos        valid     dep
# 10261  389.67       57         11         pos        valid     dep
# 10262  411.41       57         11         pos        valid     dep
# 10263  455.09       57         11         pos        valid     dep
# 10264  381.36       57         11         pos        valid     dep
# 10265  346.45       57         11         pos        valid     dep
# 10266  495.08       57         11         pos        valid     dep
# 10267  400.79       57         11         pos        valid     dep
# 10268  565.63       57         11         pos        valid     dep
# 10480  499.14       59          8         pos        valid     dep
# 10566  290.38       59          8         pos        valid     dep
# 10567  389.26       59          8         pos        valid     dep
# 10568  365.53       59          8         pos        valid     dep
# 10569  291.95       59          8         pos        valid     dep
# 10570  444.22       59          8         pos        valid     dep
# 10571  320.30       59          8         pos        valid     dep
# 10572  366.09       59          8         pos        valid     dep
# 10573  416.24       59          8         pos        valid     dep
# 10574  453.24       59          8         pos        valid     dep
# 10575  409.56       59          8         pos        valid     dep
# 10576  348.53       59          8         pos        valid     dep
# 10577  373.41       59          8         pos        valid     dep
# 10578  364.26       59          8         pos        valid     dep
# 10579  444.69       59          8         pos        valid     dep
# 10610  301.20       59         11         pos        valid     dep
# 10611  253.61       59         11         pos        valid     dep
# 10612  376.31       59         11         pos        valid     dep
# 10613  313.99       59         11         pos        valid     dep
# 10614  251.57       59         11         pos        valid     dep
# 10615  313.44       59         11         pos        valid     dep
# 10616  413.49       59         11         pos        valid     dep
# 10617  271.98       59         11         pos        valid     dep
# 10618  313.40       59         11         pos        valid     dep
# 10619  344.56       59         11         pos        valid     dep
# 10620  298.81       59         11         pos        valid     dep
# 10621  247.05       59         11         pos        valid     dep
# 10622  322.99       59         11         pos        valid     dep
# 10623  333.63       59         11         pos        valid     dep
# 10624  282.78       59         11         pos        valid     dep
# 11714  379.68       66          8         pos        valid     dep
# 11802  404.43       66          8         pos        valid     dep
# 11803  387.37       66          8         pos        valid     dep
# 11804  342.88       66          8         pos        valid     dep
# 11805  337.53       66          8         pos        valid     dep
# 11806  347.73       66          8         pos        valid     dep
# 11807  431.99       66          8         pos        valid     dep
# 11808  467.12       66          8         pos        valid     dep
# 11809  280.34       66          8         pos        valid     dep
# 11810  373.02       66          8         pos        valid     dep
# 11811  462.52       66          8         pos        valid     dep
# 11812  485.14       66          8         pos        valid     dep
# 11813  418.06       66          8         pos        valid     dep
# 11814  400.26       66          8         pos        valid     dep
# 11815  419.16       66          8         pos        valid     dep
# 11846  343.15       66         11         pos        valid     dep
# 11847  475.19       66         11         pos        valid     dep
# 11848  265.69       66         11         pos        valid     dep
# 11849  304.74       66         11         pos        valid     dep
# 11850  416.85       66         11         pos        valid     dep
# 11851  472.41       66         11         pos        valid     dep
# 11852  351.21       66         11         pos        valid     dep
# 11853  440.16       66         11         pos        valid     dep
# 11854  360.61       66         11         pos        valid     dep
# 11855  346.80       66         11         pos        valid     dep
# 11856  357.65       66         11         pos        valid     dep
# 11857  476.21       66         11         pos        valid     dep
# 11858  450.18       66         11         pos        valid     dep
# 11859  441.85       66         11         pos        valid     dep

# %%
# ANOVA above uses all raw RTs per subject across each UV level.
# Create RT means for smallest increment (validity) t get single values per subject (ANOVA error variance dofs)
# copy data to avoid accidents
anova_submeans = anova.copy().drop('Condition', axis=1)

# list RT by subject, valence and validity, respectively
for sub in anova_submeans['Subject'].unique():
    for valence in anova_submeans['Cue_Valence'].unique():
        for valid in anova_submeans['Cue_Validity'].unique():
            # fix the mean at the beginning of each condition to avoid bias towards the first subject in case this assigns sequentially
            sub_mean = anova_submeans["RT"][(anova_submeans['Subject'] == sub)
                                          & (anova_submeans['Cue_Valence'] == valence)
                                          & (anova_submeans['Cue_Validity'] == valid)].mean()
            # locate and replace the individual RT values with the mean by subject, valence and validity
            anova_submeans.loc[(anova_submeans['Subject'] == sub) & (anova_submeans['Cue_Valence'] == valence)
                                                                  & (anova_submeans['Cue_Validity'] == valid), 'RT'] = sub_mean

# drop duplicate lines from the dataframe
anova_submeans = anova_submeans.drop_duplicates()

# %%
pd.set_option('display.max_rows', None)
print(anova_submeans)
# Out:
#                RT  Subject Cue_Valence Cue_Validity DStatus
# 1071   320.278571        7         neg      invalid     con
# 1251   324.400000        8         neg      invalid     con
# 1431   302.652500        9         neg      invalid     con
# 1608   321.222500       10         neg      invalid     con
# 1966   317.846207       12         neg      invalid     con
# 2145   373.101923       13         neg      invalid     con
# 2492   416.560000       15         neg      invalid     con
# 2671   279.850357       16         neg      invalid     con
# 2842   265.769310       17         neg      invalid     con
# 3198   327.416207       19         neg      invalid     con
# 3377   267.342963       20         neg      invalid     con
# 3552   377.528276       21         neg      invalid     con
# 3731   297.739643       22         neg      invalid     con
# 3909   294.147931       23         neg      invalid     con
# 4085   306.373571       24         neg      invalid     con
# 4262   314.101724       25         neg      invalid     con
# 4620   348.191034       26         neg      invalid     con
# 8674   347.718214       49         neg      invalid     con
# 8851   280.214643       50         neg      invalid     con
# 9386   419.661379       53         neg      invalid     con
# 9566   287.544483       54         neg      invalid     con
# 9924   319.506207       56         neg      invalid     con
# 10284  316.248214       58         neg      invalid     con
# 10640  380.788276       60         neg      invalid     con
# 10819  307.869310       61         neg      invalid     con
# 10995  258.690769       62         neg      invalid     con
# 11172  306.021724       63         neg      invalid     con
# 11342  342.605185       64         neg      invalid     con
# 11519  380.503214       65         neg      invalid     con
# 11875  310.700000       67         neg      invalid     con
# 12054  433.910000       68         neg      invalid     con
# 1080   327.918621        7         neg        valid     con
# 1260   340.083214        8         neg        valid     con
# 1440   322.635714        9         neg        valid     con
# 1616   320.021034       10         neg        valid     con
# 1975   305.526207       12         neg        valid     con
# 2154   368.255417       13         neg        valid     con
# 2501   394.409655       15         neg        valid     con
# 2680   291.926667       16         neg        valid     con
# 2851   276.784138       17         neg        valid     con
# 3207   345.827931       19         neg        valid     con
# 3386   273.328889       20         neg        valid     con
# 3561   381.399655       21         neg        valid     con
# 3740   323.881034       22         neg        valid     con
# 3918   292.668966       23         neg        valid     con
# 4094   307.974138       24         neg        valid     con
# 4280   349.934828       25         neg        valid     con
# 4629   338.995862       26         neg        valid     con
# 8683   380.514286       49         neg        valid     con
# 8860   284.464643       50         neg        valid     con
# 9395   413.384138       53         neg        valid     con
# 9575   310.391071       54         neg        valid     con
# 9933   296.323793       56         neg        valid     con
# 10293  327.195517       58         neg        valid     con
# 10649  371.539643       60         neg        valid     con
# 10828  363.821071       61         neg        valid     con
# 11003  257.200714       62         neg        valid     con
# 11181  328.775000       63         neg        valid     con
# 11351  353.808621       64         neg        valid     con
# 11528  361.390000       65         neg        valid     con
# 11884  288.905517       67         neg        valid     con
# 12061  419.703929       68         neg        valid     con
# 1111   315.266667        7         neu      invalid     con
# 1291   316.182000        8         neu      invalid     con
# 1470   280.067667        9         neu      invalid     con
# 1647   313.384333       10         neu      invalid     con
# 2006   305.716333       12         neu      invalid     con
# 2184   366.598889       13         neu      invalid     con
# 2532   417.682333       15         neu      invalid     con
# 2709   282.712143       16         neu      invalid     con
# 2882   269.597586       17         neu      invalid     con
# 3238   333.991379       19         neu      invalid     con
# 3417   267.295000       20         neu      invalid     con
# 3592   393.374333       21         neu      invalid     con
# 3771   291.424828       22         neu      invalid     con
# 3949   309.581333       23         neu      invalid     con
# 4124   310.247586       24         neu      invalid     con
# 4342   309.835862       25         neu      invalid     con
# 4660   336.445000       26         neu      invalid     con
# 8714   309.379000       49         neu      invalid     con
# 8891   277.945333       50         neu      invalid     con
# 9426   415.350000       53         neu      invalid     con
# 9606   289.413103       54         neu      invalid     con
# 9964   306.361333       56         neu      invalid     con
# 10324  324.349000       58         neu      invalid     con
# 10680  364.263333       60         neu      invalid     con
# 10859  294.679667       61         neu      invalid     con
# 11033  258.294333       62         neu      invalid     con
# 11212  299.986786       63         neu      invalid     con
# 11381  343.182667       64         neu      invalid     con
# 11559  401.240333       65         neu      invalid     con
# 11915  301.766333       67         neu      invalid     con
# 12091  408.426667       68         neu      invalid     con
# 1191   305.138000        7         neu        valid     con
# 1371   338.160333        8         neu        valid     con
# 1549   320.115333        9         neu        valid     con
# 1726   332.143667       10         neu        valid     con
# 2086   306.165517       12         neu        valid     con
# 2258   352.928889       13         neu        valid     con
# 2612   382.909333       15         neu        valid     con
# 2786   299.225357       16         neu        valid     con
# 2960   279.733103       17         neu        valid     con
# 3317   370.872333       19         neu        valid     con
# 3496   285.431034       20         neu        valid     con
# 3671   383.860333       21         neu        valid     con
# 3849   319.423667       22         neu        valid     con
# 4028   272.564815       23         neu        valid     con
# 4202   307.522667       24         neu        valid     con
# 4500   340.860000       25         neu        valid     con
# 4740   351.457000       26         neu        valid     con
# 8792   359.124138       49         neu        valid     con
# 8970   282.540000       50         neu        valid     con
# 9506   407.208667       53         neu        valid     con
# 9685   315.194000       54         neu        valid     con
# 10044  309.915000       56         neu        valid     con
# 10403  329.605172       58         neu        valid     con
# 10760  370.531333       60         neu        valid     con
# 10937  347.645333       61         neu        valid     con
# 11113  264.026333       62         neu        valid     con
# 11287  323.810000       63         neu        valid     con
# 11460  338.892069       64         neu        valid     con
# 11638  373.907241       65         neu        valid     con
# 11995  343.572143       67         neu        valid     con
# 12171  419.804828       68         neu        valid     con
# 1095   325.835484        7         pos      invalid     con
# 1275   303.778387        8         pos      invalid     con
# 1455   297.763667        9         pos      invalid     con
# 1631   317.900333       10         pos      invalid     con
# 1990   318.009032       12         pos      invalid     con
# 2168   344.258846       13         pos      invalid     con
# 2516   421.454516       15         pos      invalid     con
# 2694   285.471333       16         pos      invalid     con
# 2866   269.136000       17         pos      invalid     con
# 3222   309.716774       19         pos      invalid     con
# 3401   261.336333       20         pos      invalid     con
# 3576   375.909310       21         pos      invalid     con
# 3755   289.337333       22         pos      invalid     con
# 3933   296.847097       23         pos      invalid     con
# 4109   316.958000       24         pos      invalid     con
# 4310   311.771935       25         pos      invalid     con
# 4644   360.020968       26         pos      invalid     con
# 8698   304.706452       49         pos      invalid     con
# 8875   275.564333       50         pos      invalid     con
# 9410   379.599355       53         pos      invalid     con
# 9590   292.966129       54         pos      invalid     con
# 9948   290.710323       56         pos      invalid     con
# 10308  311.284194       58         pos      invalid     con
# 10664  378.214000       60         pos      invalid     con
# 10843  310.765484       61         pos      invalid     con
# 11017  265.311613       62         pos      invalid     con
# 11196  323.329032       63         pos      invalid     con
# 11366  355.809655       64         pos      invalid     con
# 11543  374.309667       65         pos      invalid     con
# 11899  296.734839       67         pos      invalid     con
# 12076  433.709333       68         pos      invalid     con
# 1089   313.915333        7         pos        valid     con
# 1269   318.435000        8         pos        valid     con
# 1449   332.902333        9         pos        valid     con
# 1625   333.318000       10         pos        valid     con
# 1984   321.696000       12         pos        valid     con
# 2162   367.628214       13         pos        valid     con
# 2510   388.740345       15         pos        valid     con
# 2688   278.330690       16         pos        valid     con
# 2860   288.931333       17         pos        valid     con
# 3216   352.957241       19         pos        valid     con
# 3395   292.179643       20         pos        valid     con
# 3570   395.710000       21         pos        valid     con
# 3749   327.475333       22         pos        valid     con
# 3927   294.062414       23         pos        valid     con
# 4103   313.123333       24         pos        valid     con
# 4298   330.540333       25         pos        valid     con
# 4638   340.486667       26         pos        valid     con
# 8692   367.140667       49         pos        valid     con
# 8869   273.628333       50         pos        valid     con
# 9404   389.377667       53         pos        valid     con
# 9584   303.158333       54         pos        valid     con
# 9942   317.205667       56         pos        valid     con
# 10302  317.243000       58         pos        valid     con
# 10658  365.213667       60         pos        valid     con
# 10837  352.748519       61         pos        valid     con
# 11012  272.982333       62         pos        valid     con
# 11190  326.321200       63         pos        valid     con
# 11360  331.195000       64         pos        valid     con
# 11537  358.268929       65         pos        valid     con
# 11893  321.192000       67         pos        valid     con
# 12070  427.051000       68         pos        valid     con
# 1786   316.105172       11         neg      invalid     dep
# 2315   370.077586       14         neg      invalid     dep
# 3019   378.976207       18         neg      invalid     dep
# 4800   351.699310       27         neg      invalid     dep
# 4980   358.856071       28         neg      invalid     dep
# 5157   337.133214       29         neg      invalid     dep
# 5329   355.587586       30         neg      invalid     dep
# 5509   302.141379       31         neg      invalid     dep
# 5687   342.563571       32         neg      invalid     dep
# 5865   349.541034       33         neg      invalid     dep
# 6045   366.191034       34         neg      invalid     dep
# 6222   298.010357       35         neg      invalid     dep
# 6402   284.956786       36         neg      invalid     dep
# 6581   281.824286       37         neg      invalid     dep
# 6756   321.455862       38         neg      invalid     dep
# 6936   352.560345       39         neg      invalid     dep
# 7114   335.570357       40         neg      invalid     dep
# 7292   307.042143       41         neg      invalid     dep
# 7467   242.622857       42         neg      invalid     dep
# 7624   298.722222       43         neg      invalid     dep
# 7799   370.294074       44         neg      invalid     dep
# 7969   358.032414       45         neg      invalid     dep
# 8148   397.065600       46         neg      invalid     dep
# 8317   368.318621       47         neg      invalid     dep
# 8494   346.720690       48         neg      invalid     dep
# 9029   318.516429       51         neg      invalid     dep
# 9206   290.897586       52         neg      invalid     dep
# 9745   326.317241       55         neg      invalid     dep
# 10104  387.320345       57         neg      invalid     dep
# 10462  313.764138       59         neg      invalid     dep
# 11697  385.241071       66         neg      invalid     dep
# 1795   316.422759       11         neg        valid     dep
# 2324   397.616071       14         neg        valid     dep
# 3029   377.753929       18         neg        valid     dep
# 4809   349.126207       27         neg        valid     dep
# 4989   407.936786       28         neg        valid     dep
# 5166   355.979259       29         neg        valid     dep
# 5338   357.366897       30         neg        valid     dep
# 5518   339.006071       31         neg        valid     dep
# 5696   348.217586       32         neg        valid     dep
# 5874   346.045517       33         neg        valid     dep
# 6054   348.211034       34         neg        valid     dep
# 6231   329.381034       35         neg        valid     dep
# 6411   283.121071       36         neg        valid     dep
# 6589   340.310769       37         neg        valid     dep
# 6765   306.281786       38         neg        valid     dep
# 6945   342.707778       39         neg        valid     dep
# 7122   317.670000       40         neg        valid     dep
# 7301   308.688800       41         neg        valid     dep
# 7473   258.571905       42         neg        valid     dep
# 7633   282.385172       43         neg        valid     dep
# 7807   358.921852       44         neg        valid     dep
# 7978   362.212759       45         neg        valid     dep
# 8156   360.025000       46         neg        valid     dep
# 8326   361.351852       47         neg        valid     dep
# 8503   392.056071       48         neg        valid     dep
# 9038   311.306786       51         neg        valid     dep
# 9215   330.586207       52         neg        valid     dep
# 9754   325.153793       55         neg        valid     dep
# 10113  384.640000       57         neg        valid     dep
# 10471  344.095926       59         neg        valid     dep
# 11705  369.743448       66         neg        valid     dep
# 1826   322.280667       11         neu      invalid     dep
# 2355   385.082333       14         neu      invalid     dep
# 3059   340.330690       18         neu      invalid     dep
# 4840   342.486333       27         neu      invalid     dep
# 5019   358.274667       28         neu      invalid     dep
# 5194   337.570333       29         neu      invalid     dep
# 5369   343.643333       30         neu      invalid     dep
# 5548   318.855333       31         neu      invalid     dep
# 5727   321.847000       32         neu      invalid     dep
# 5905   339.463667       33         neu      invalid     dep
# 6085   365.939000       34         neu      invalid     dep
# 6262   298.723000       35         neu      invalid     dep
# 6441   296.055333       36         neu      invalid     dep
# 6619   274.501333       37         neu      invalid     dep
# 6796   314.745000       38         neu      invalid     dep
# 6976   343.766000       39         neu      invalid     dep
# 7153   318.440333       40         neu      invalid     dep
# 7328   323.048519       41         neu      invalid     dep
# 7500   252.023103       42         neu      invalid     dep
# 7664   287.667407       43         neu      invalid     dep
# 7836   381.900370       44         neu      invalid     dep
# 8009   343.240333       45         neu      invalid     dep
# 8185   394.912222       46         neu      invalid     dep
# 8357   377.922500       47         neu      invalid     dep
# 8534   358.256429       48         neu      invalid     dep
# 9068   307.016667       51         neu      invalid     dep
# 9246   294.774643       52         neu      invalid     dep
# 9785   320.900714       55         neu      invalid     dep
# 10144  369.488667       57         neu      invalid     dep
# 10502  320.033793       59         neu      invalid     dep
# 11736  386.706000       66         neu      invalid     dep
# 1906   308.902333       11         neu        valid     dep
# 2434   419.177586       14         neu        valid     dep
# 3138   324.833333       18         neu        valid     dep
# 4920   358.401667       27         neu        valid     dep
# 5099   425.397333       28         neu        valid     dep
# 5269   363.257667       29         neu        valid     dep
# 5449   360.567667       30         neu        valid     dep
# 5628   313.775333       31         neu        valid     dep
# 5806   342.347586       32         neu        valid     dep
# 5985   371.523000       33         neu        valid     dep
# 6165   377.201852       34         neu        valid     dep
# 6342   335.738667       35         neu        valid     dep
# 6521   298.161333       36         neu        valid     dep
# 6698   311.793103       37         neu        valid     dep
# 6876   304.639667       38         neu        valid     dep
# 7055   349.995333       39         neu        valid     dep
# 7233   314.425357       40         neu        valid     dep
# 7405   297.547143       41         neu        valid     dep
# 7576   260.876522       42         neu        valid     dep
# 7740   276.075000       43         neu        valid     dep
# 7911   388.490000       44         neu        valid     dep
# 8089   360.773214       45         neu        valid     dep
# 8260   377.644643       46         neu        valid     dep
# 8436   362.310333       47         neu        valid     dep
# 8614   394.935000       48         neu        valid     dep
# 9147   312.081724       51         neu        valid     dep
# 9326   316.600333       52         neu        valid     dep
# 9864   343.945000       55         neu        valid     dep
# 10224  386.877333       57         neu        valid     dep
# 10580  337.120000       59         neu        valid     dep
# 11816  402.262000       66         neu        valid     dep
# 1810   326.660645       11         pos      invalid     dep
# 2339   392.892581       14         pos      invalid     dep
# 3043   331.972903       18         pos      invalid     dep
# 4824   353.058667       27         pos      invalid     dep
# 5003   369.502258       28         pos      invalid     dep
# 5179   335.657692       29         pos      invalid     dep
# 5353   327.102581       30         pos      invalid     dep
# 5533   328.734333       31         pos      invalid     dep
# 5711   333.780323       32         pos      invalid     dep
# 5889   344.170000       33         pos      invalid     dep
# 6069   369.336552       34         pos      invalid     dep
# 6246   287.285000       35         pos      invalid     dep
# 6426   290.573333       36         pos      invalid     dep
# 6604   269.332222       37         pos      invalid     dep
# 6780   308.971935       38         pos      invalid     dep
# 6960   337.377097       39         pos      invalid     dep
# 7137   316.297742       40         pos      invalid     dep
# 7313   298.172667       41         pos      invalid     dep
# 7485   247.738966       42         pos      invalid     dep
# 7648   303.726333       43         pos      invalid     dep
# 7821   386.657667       44         pos      invalid     dep
# 7993   340.972258       45         pos      invalid     dep
# 8170   388.096071       46         pos      invalid     dep
# 8341   340.794839       47         pos      invalid     dep
# 8518   366.731613       48         pos      invalid     dep
# 9052   309.939000       51         pos      invalid     dep
# 9230   293.062258       52         pos      invalid     dep
# 9769   319.446333       55         pos      invalid     dep
# 10128  388.081935       57         pos      invalid     dep
# 10486  302.821034       59         pos      invalid     dep
# 11720  392.815806       66         pos      invalid     dep
# 1804   300.193333       11         pos        valid     dep
# 2333   421.665172       14         pos        valid     dep
# 3037   318.080690       18         pos        valid     dep
# 4818   342.149000       27         pos        valid     dep
# 5085   422.310370       28         pos        valid     dep
# 5173   366.826667       29         pos        valid     dep
# 5347   345.658621       30         pos        valid     dep
# 5527   304.679667       31         pos        valid     dep
# 5705   350.151000       32         pos        valid     dep
# 5883   364.363000       33         pos        valid     dep
# 6063   360.135172       34         pos        valid     dep
# 6240   326.426667       35         pos        valid     dep
# 6419   295.334000       36         pos        valid     dep
# 6598   318.413929       37         pos        valid     dep
# 6774   324.088000       38         pos        valid     dep
# 6954   350.150000       39         pos        valid     dep
# 7131   306.763000       40         pos        valid     dep
# 7307   301.845333       41         pos        valid     dep
# 7562   255.290800       42         pos        valid     dep
# 7642   280.053214       43         pos        valid     dep
# 7816   378.720370       44         pos        valid     dep
# 7987   345.743667       45         pos        valid     dep
# 8165   352.551379       46         pos        valid     dep
# 8335   347.954000       47         pos        valid     dep
# 8512   393.058333       48         pos        valid     dep
# 9046   309.217333       51         pos        valid     dep
# 9224   323.476000       52         pos        valid     dep
# 9763   345.846000       55         pos        valid     dep
# 10122  407.627333       57         pos        valid     dep
# 10480  347.187000       59         pos        valid     dep
# 11714  394.480345       66         pos        valid     dep

# %%
# put both datasets into one list and compare the performance and outcome of the ANOVA testing
anovas = [anova, anova_submeans]

# %%
# set seaborn visual style
sns.set(style="darkgrid")
# Draw a pointplot to show pulse as a function of three categorical factors
for dataset in anovas:
    interact_plot = sns.catplot(x="Cue_Valence", y="RT", hue="DStatus", col="Cue_Validity", ci=95, n_boot=1000,
                                capsize=.2, palette="muted", height=6, aspect=.75, kind="point", data=dataset)
    interact_plot.despine(left=True)
    # # save plot
    # interact_plot.savefig("RT_322_interact.png")

# %% [markdown]
# Build three-way ANOVA design and calculate the F-test

# %%
# check whether variances are equal using Levene tests
for dataset in anovas:
    homoscedast_DStatus = pg.homoscedasticity(data=anova, dv='RT', group='DStatus')
    homoscedast_Valence = pg.homoscedasticity(data=anova, dv='RT', group='Cue_Valence')
    homoscedast_Validity = pg.homoscedasticity(data=anova, dv='RT', group='Cue_Validity')
    # put all into list
    homoscedast = [homoscedast_DStatus, homoscedast_Valence, homoscedast_Validity]
    # inspect the results
    for test in homoscedast:
        print(test)
# Out:
#                W      pval  equal_var
# levene  8.206733  0.004181      False
#                W      pval  equal_var
# levene  0.235934  0.789836       True
#                W      pval  equal_var
# levene  0.150284  0.698272       True
#                W      pval  equal_var
# levene  8.206733  0.004181      False
#                W      pval  equal_var
# levene  0.235934  0.789836       True
#                W      pval  equal_var
# levene  0.150284  0.698272       True

# %%
# run the full ANOVA
FED_anova = pg.anova(data=anova, dv='RT', between=['DStatus', 'Cue_Valence', 'Cue_Validity'], ss_type=3).round(3)  # round to three place digits
FED_meanRTs_anova = pg.anova(data=anova_submeans, dv='RT', between=['DStatus', 'Cue_Valence', 'Cue_Validity'], ss_type=3).round(3)  # round to three place digits

# %%
# main effect DStatus significant, Interaction Valence-Validity too, BUT neither of their main effects! -> simple effects!^^
# fix the error variance (residual variance  from full ANOVA)
err_MS = FED_anova.MS[FED_anova.Source == 'Residual'].values
err_dof = FED_anova.DF[FED_anova.Source == 'Residual'].values

# -> simple effects as two-way ANOVA only for valid trials
simpleeff_valid = pg.anova(data=anova[anova['Cue_Validity'] == "valid"], dv='RT', between=['DStatus', 'Cue_Valence'], ss_type=3).round(3)  # round to three place digits
# calculate corrected F value using the residual variance  from full ANOVA
vale_MS = simpleeff_valid.MS[simpleeff_valid.Source == 'Cue_Valence'].values
vale_dof = simpleeff_valid.DF[simpleeff_valid.Source == 'Cue_Valence'].values
correctF_valence = vale_MS / err_MS
correctp_valence = 1 - sp.stats.f.cdf(correctF_valence, vale_dof, err_dof)
# insert the correct value into dataframe
simpleeff_valid.insert(6, 'F_corr', [np.nan, *correctF_valence, np.nan, np.nan])  # lose the brackets^^
simpleeff_valid.insert(7, 'p_corr', [np.nan, *correctp_valence, np.nan, np.nan])  # lose the brackets^^

# -> simple effects as two-way ANOVA only for invalid trials
simpleeff_invalid = pg.anova(data=anova[anova['Cue_Validity'] == "invalid"], dv='RT', between=['DStatus', 'Cue_Valence'], ss_type=3).round(3)  # round to three place digits
# calculate corrected F value using the residual variance  from full ANOVA
vale_MS = simpleeff_invalid.MS[simpleeff_invalid.Source == 'Cue_Valence'].values
vale_dof = simpleeff_invalid.DF[simpleeff_invalid.Source == 'Cue_Valence'].values
correctF_valence = vale_MS / err_MS
correctp_valence = 1 - sp.stats.f.cdf(correctF_valence, vale_dof, err_dof)
# insert the correct value into dataframe
simpleeff_invalid.insert(6, 'F_corr', [np.nan, *correctF_valence, np.nan, np.nan])  # lose the brackets^^
simpleeff_invalid.insert(7, 'p_corr', [np.nan, *correctp_valence, np.nan, np.nan])  # lose the brackets^^

# %% [markdown]
# Plot three-way ANOVA results

# %%
FED_anova
# Out:
#                                  Source            SS       DF          MS  \
# 0                               DStatus  2.946410e+05      1.0  294640.982
# 1                           Cue_Valence  1.347941e+04      2.0    6739.707
# 2                          Cue_Validity  2.391998e+05      1.0  239199.782
# 3                 DStatus * Cue_Valence  1.181615e+03      2.0     590.808
# 4                DStatus * Cue_Validity  5.632000e+00      1.0       5.632
# 5            Cue_Valence * Cue_Validity  1.294360e+04      2.0    6471.801
# 6  DStatus * Cue_Valence * Cue_Validity  8.186550e+02      2.0     409.328
# 7                              Residual  5.641018e+07  10982.0    5136.604
#
#         F  p-unc    np2
# 0  57.361  0.000  0.005
# 1   1.312  0.269  0.000
# 2  46.568  0.000  0.004
# 3   0.115  0.891  0.000
# 4   0.001  0.974  0.000
# 5   1.260  0.284  0.000
# 6   0.080  0.923  0.000
# 7     NaN    NaN    NaN

# %%
simpleeff_valid
# Out:
#                   Source            SS    DF          MS       F  p-unc  \
# 0                DStatus  7.329054e+04     1   73290.544   2.872  0.090
# 1            Cue_Valence  5.413986e+05     2  270699.289  10.609  0.000
# 2  DStatus * Cue_Valence  2.846830e+03     2    1423.415   0.056  0.946
# 3               Residual  1.422220e+08  5574   25515.243     NaN    NaN
#
#       F_corr    p_corr    np2
# 0        NaN       NaN  0.001
# 1  11.022918  0.000017  0.004
# 2        NaN       NaN  0.000
# 3        NaN       NaN    NaN

# %%
simpleeff_invalid
# Out:
#                   Source            SS      DF          MS       F  p-unc  \
# 0                DStatus  2.524560e+05     1.0  252455.959  10.697  0.001
# 1            Cue_Valence  6.087552e+04     2.0   30437.761   1.290  0.275
# 2  DStatus * Cue_Valence  1.383800e+04     2.0    6918.998   0.293  0.746
# 3               Residual  1.315491e+08  5574.0   23600.479     NaN    NaN
#
#     F_corr    p_corr    np2
# 0      NaN       NaN  0.002
# 1  1.23943  0.289589  0.000
# 2      NaN       NaN  0.000
# 3      NaN       NaN    NaN

# %%
FED_meanRTs_anova
# Out:
#                                  Source          SS     DF        MS      F  \
# 0                               DStatus    9113.873    1.0  9113.873  5.757
# 1                           Cue_Valence     318.802    2.0   159.401  0.101
# 2                          Cue_Validity    7430.727    1.0  7430.727  4.694
# 3                 DStatus * Cue_Valence      72.308    2.0    36.154  0.023
# 4                DStatus * Cue_Validity       6.156    1.0     6.156  0.004
# 5            Cue_Valence * Cue_Validity     421.751    2.0   210.876  0.133
# 6  DStatus * Cue_Valence * Cue_Validity      12.831    2.0     6.416  0.004
# 7                              Residual  569905.125  360.0  1583.070    NaN
#
#    p-unc    np2
# 0  0.017  0.016
# 1  0.904  0.001
# 2  0.031  0.013
# 3  0.977  0.000
# 4  0.950  0.000
# 5  0.875  0.001
# 6  0.996  0.000
# 7    NaN    NaN

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(FED_meanRTs_anova, tablefmt="latex")
# pg.print_table(simpleeff_valid, tablefmt="latex")
# pg.print_table(simpleeff_invalid, tablefmt="latex")
# Out:
# =============
# ANOVA SUMMARY
# =============
#
# \begin{tabular}{lrrrrrr}
# \hline
#  Source                               &         SS &      DF &       MS &       F &   p-unc &     np2 \\
# \hline
#  DStatus                              &   9113.873 &   1.000 & 9113.873 &   5.757 &   0.017 &   0.016 \\
#  Cue\_Valence                          &    318.802 &   2.000 &  159.401 &   0.101 &   0.904 &   0.001 \\
#  Cue\_Validity                         &   7430.727 &   1.000 & 7430.727 &   4.694 &   0.031 &   0.013 \\
#  DStatus * Cue\_Valence                &     72.308 &   2.000 &   36.154 &   0.023 &   0.977 &   0.000 \\
#  DStatus * Cue\_Validity               &      6.156 &   1.000 &    6.156 &   0.004 &   0.950 &   0.000 \\
#  Cue\_Valence * Cue\_Validity           &    421.751 &   2.000 &  210.876 &   0.133 &   0.875 &   0.001 \\
#  DStatus * Cue\_Valence * Cue\_Validity &     12.831 &   2.000 &    6.416 &   0.004 &   0.996 &   0.000 \\
#  Residual                             & 569905.125 & 360.000 & 1583.070 & nan     & nan     & nan     \\
# \hline
# \end{tabular}

# %% [markdown]
# Calculate Cue Validity (CV), Attentional Engagement (AE), and Difficulty in Attentional Disengagement (DAD) based on subject RT means for each condition

# %%
# create RT means for smallest increment (validity)
# copy data to avoid accidents
eect_ttest = anova.copy()

# define list of subject numbers
fed_nums = [num for num in range(7, 69)]

# sort data by subject, valence and validity
eect_ttest.sort_values(['Subject', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# list RT by subject, valence and validity, respectively
rts = {}
for sub in eect_ttest['Subject'].unique():
    for valence in eect_ttest['Cue_Valence'].unique():
        for valid in eect_ttest['Cue_Validity'].unique():
            rts[f"{sub}_{valence}_{valid}"] = eect_ttest.loc[(eect_ttest['Subject'] == sub)
                                                           & (eect_ttest['Cue_Valence'] == valence) 
                                                           & (eect_ttest['Cue_Validity'] == valid), 'RT'].tolist()

# %%
# calculate CV for each valence per subject
cv = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    for val in valence_cats:
        # create list for validity-referenced combos
        validity = []
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # fix the subject ID
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1]) == val:
                # collect validities
                validity.append(combo)
        #print(validity)
        # calculate the mean of the inv-v difference by valence
        cv[f"{sub}_{val}"] = np.mean([inv - v for inv, v in zip(rts[validity[0]], rts[validity[1]])])

# transfer to pd.dataframe
cv = (pd.DataFrame.from_dict(cv, orient='index', columns=['mean_CV']).rename_axis('FEDbyvalence').reset_index())
# Out:
# ['7_neg_invalid', '7_neg_valid']
# ['7_pos_invalid', '7_pos_valid']
# ['7_neu_invalid', '7_neu_valid']
# ['8_neg_invalid', '8_neg_valid']
# ['8_pos_invalid', '8_pos_valid']
# ['8_neu_invalid', '8_neu_valid']
# ['9_neg_invalid', '9_neg_valid']
# ['9_pos_invalid', '9_pos_valid']
# ['9_neu_invalid', '9_neu_valid']
# ['10_neg_invalid', '10_neg_valid']
# ['10_pos_invalid', '10_pos_valid']
# ['10_neu_invalid', '10_neu_valid']
# ['11_neg_invalid', '11_neg_valid']
# ['11_pos_invalid', '11_pos_valid']
# ['11_neu_invalid', '11_neu_valid']
# ['12_neg_invalid', '12_neg_valid']
# ['12_pos_invalid', '12_pos_valid']
# ['12_neu_invalid', '12_neu_valid']
# ['13_neg_invalid', '13_neg_valid']
# ['13_pos_invalid', '13_pos_valid']
# ['13_neu_invalid', '13_neu_valid']
# ['14_neg_invalid', '14_neg_valid']
# ['14_pos_invalid', '14_pos_valid']
# ['14_neu_invalid', '14_neu_valid']
# ['15_neg_invalid', '15_neg_valid']
# ['15_pos_invalid', '15_pos_valid']
# ['15_neu_invalid', '15_neu_valid']
# ['16_neg_invalid', '16_neg_valid']
# ['16_pos_invalid', '16_pos_valid']
# ['16_neu_invalid', '16_neu_valid']
# ['17_neg_invalid', '17_neg_valid']
# ['17_pos_invalid', '17_pos_valid']
# ['17_neu_invalid', '17_neu_valid']
# ['18_neg_invalid', '18_neg_valid']
# ['18_pos_invalid', '18_pos_valid']
# ['18_neu_invalid', '18_neu_valid']
# ['19_neg_invalid', '19_neg_valid']
# ['19_pos_invalid', '19_pos_valid']
# ['19_neu_invalid', '19_neu_valid']
# ['20_neg_invalid', '20_neg_valid']
# ['20_pos_invalid', '20_pos_valid']
# ['20_neu_invalid', '20_neu_valid']
# ['21_neg_invalid', '21_neg_valid']
# ['21_pos_invalid', '21_pos_valid']
# ['21_neu_invalid', '21_neu_valid']
# ['22_neg_invalid', '22_neg_valid']
# ['22_pos_invalid', '22_pos_valid']
# ['22_neu_invalid', '22_neu_valid']
# ['23_neg_invalid', '23_neg_valid']
# ['23_pos_invalid', '23_pos_valid']
# ['23_neu_invalid', '23_neu_valid']
# ['24_neg_invalid', '24_neg_valid']
# ['24_pos_invalid', '24_pos_valid']
# ['24_neu_invalid', '24_neu_valid']
# ['25_neg_invalid', '25_neg_valid']
# ['25_pos_invalid', '25_pos_valid']
# ['25_neu_invalid', '25_neu_valid']
# ['26_neg_invalid', '26_neg_valid']
# ['26_pos_invalid', '26_pos_valid']
# ['26_neu_invalid', '26_neu_valid']
# ['27_neg_invalid', '27_neg_valid']
# ['27_pos_invalid', '27_pos_valid']
# ['27_neu_invalid', '27_neu_valid']
# ['28_neg_invalid', '28_neg_valid']
# ['28_pos_invalid', '28_pos_valid']
# ['28_neu_invalid', '28_neu_valid']
# ['29_neg_invalid', '29_neg_valid']
# ['29_pos_invalid', '29_pos_valid']
# ['29_neu_invalid', '29_neu_valid']
# ['30_neg_invalid', '30_neg_valid']
# ['30_pos_invalid', '30_pos_valid']
# ['30_neu_invalid', '30_neu_valid']
# ['31_neg_invalid', '31_neg_valid']
# ['31_pos_invalid', '31_pos_valid']
# ['31_neu_invalid', '31_neu_valid']
# ['32_neg_invalid', '32_neg_valid']
# ['32_pos_invalid', '32_pos_valid']
# ['32_neu_invalid', '32_neu_valid']
# ['33_neg_invalid', '33_neg_valid']
# ['33_pos_invalid', '33_pos_valid']
# ['33_neu_invalid', '33_neu_valid']
# ['34_neg_invalid', '34_neg_valid']
# ['34_pos_invalid', '34_pos_valid']
# ['34_neu_invalid', '34_neu_valid']
# ['35_neg_invalid', '35_neg_valid']
# ['35_pos_invalid', '35_pos_valid']
# ['35_neu_invalid', '35_neu_valid']
# ['36_neg_invalid', '36_neg_valid']
# ['36_pos_invalid', '36_pos_valid']
# ['36_neu_invalid', '36_neu_valid']
# ['37_neg_invalid', '37_neg_valid']
# ['37_pos_invalid', '37_pos_valid']
# ['37_neu_invalid', '37_neu_valid']
# ['38_neg_invalid', '38_neg_valid']
# ['38_pos_invalid', '38_pos_valid']
# ['38_neu_invalid', '38_neu_valid']
# ['39_neg_invalid', '39_neg_valid']
# ['39_pos_invalid', '39_pos_valid']
# ['39_neu_invalid', '39_neu_valid']
# ['40_neg_invalid', '40_neg_valid']
# ['40_pos_invalid', '40_pos_valid']
# ['40_neu_invalid', '40_neu_valid']
# ['41_neg_invalid', '41_neg_valid']
# ['41_pos_invalid', '41_pos_valid']
# ['41_neu_invalid', '41_neu_valid']
# ['42_neg_invalid', '42_neg_valid']
# ['42_pos_invalid', '42_pos_valid']
# ['42_neu_invalid', '42_neu_valid']
# ['43_neg_invalid', '43_neg_valid']
# ['43_pos_invalid', '43_pos_valid']
# ['43_neu_invalid', '43_neu_valid']
# ['44_neg_invalid', '44_neg_valid']
# ['44_pos_invalid', '44_pos_valid']
# ['44_neu_invalid', '44_neu_valid']
# ['45_neg_invalid', '45_neg_valid']
# ['45_pos_invalid', '45_pos_valid']
# ['45_neu_invalid', '45_neu_valid']
# ['46_neg_invalid', '46_neg_valid']
# ['46_pos_invalid', '46_pos_valid']
# ['46_neu_invalid', '46_neu_valid']
# ['47_neg_invalid', '47_neg_valid']
# ['47_pos_invalid', '47_pos_valid']
# ['47_neu_invalid', '47_neu_valid']
# ['48_neg_invalid', '48_neg_valid']
# ['48_pos_invalid', '48_pos_valid']
# ['48_neu_invalid', '48_neu_valid']
# ['49_neg_invalid', '49_neg_valid']
# ['49_pos_invalid', '49_pos_valid']
# ['49_neu_invalid', '49_neu_valid']
# ['50_neg_invalid', '50_neg_valid']
# ['50_pos_invalid', '50_pos_valid']
# ['50_neu_invalid', '50_neu_valid']
# ['51_neg_invalid', '51_neg_valid']
# ['51_pos_invalid', '51_pos_valid']
# ['51_neu_invalid', '51_neu_valid']
# ['52_neg_invalid', '52_neg_valid']
# ['52_pos_invalid', '52_pos_valid']
# ['52_neu_invalid', '52_neu_valid']
# ['53_neg_invalid', '53_neg_valid']
# ['53_pos_invalid', '53_pos_valid']
# ['53_neu_invalid', '53_neu_valid']
# ['54_neg_invalid', '54_neg_valid']
# ['54_pos_invalid', '54_pos_valid']
# ['54_neu_invalid', '54_neu_valid']
# ['55_neg_invalid', '55_neg_valid']
# ['55_pos_invalid', '55_pos_valid']
# ['55_neu_invalid', '55_neu_valid']
# ['56_neg_invalid', '56_neg_valid']
# ['56_pos_invalid', '56_pos_valid']
# ['56_neu_invalid', '56_neu_valid']
# ['57_neg_invalid', '57_neg_valid']
# ['57_pos_invalid', '57_pos_valid']
# ['57_neu_invalid', '57_neu_valid']
# ['58_neg_invalid', '58_neg_valid']
# ['58_pos_invalid', '58_pos_valid']
# ['58_neu_invalid', '58_neu_valid']
# ['59_neg_invalid', '59_neg_valid']
# ['59_pos_invalid', '59_pos_valid']
# ['59_neu_invalid', '59_neu_valid']
# ['60_neg_invalid', '60_neg_valid']
# ['60_pos_invalid', '60_pos_valid']
# ['60_neu_invalid', '60_neu_valid']
# ['61_neg_invalid', '61_neg_valid']
# ['61_pos_invalid', '61_pos_valid']
# ['61_neu_invalid', '61_neu_valid']
# ['62_neg_invalid', '62_neg_valid']
# ['62_pos_invalid', '62_pos_valid']
# ['62_neu_invalid', '62_neu_valid']
# ['63_neg_invalid', '63_neg_valid']
# ['63_pos_invalid', '63_pos_valid']
# ['63_neu_invalid', '63_neu_valid']
# ['64_neg_invalid', '64_neg_valid']
# ['64_pos_invalid', '64_pos_valid']
# ['64_neu_invalid', '64_neu_valid']
# ['65_neg_invalid', '65_neg_valid']
# ['65_pos_invalid', '65_pos_valid']
# ['65_neu_invalid', '65_neu_valid']
# ['66_neg_invalid', '66_neg_valid']
# ['66_pos_invalid', '66_pos_valid']
# ['66_neu_invalid', '66_neu_valid']
# ['67_neg_invalid', '67_neg_valid']
# ['67_pos_invalid', '67_pos_valid']
# ['67_neu_invalid', '67_neu_valid']
# ['68_neg_invalid', '68_neg_valid']
# ['68_pos_invalid', '68_pos_valid']
# ['68_neu_invalid', '68_neu_valid']

# %%
# calculate AE for each valence per subject
ae = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set valid neutral reference
            reference = f"{sub}_{ref}_valid"
            # fix the subject ID, and validity to valid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "valid":
                # print(reference, combo)
                # calculate the mean of the vneu-vemo difference by valence
                ae[f"{sub}_{val}"] = np.mean([vneu - vemo for vneu, vemo in zip(rts[reference], rts[combo])])

# transfer to pd.dataframe
ae = (pd.DataFrame.from_dict(ae, orient='index', columns=['AE']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate DAD for each valence per subject
dad = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set invalid neutral reference
            reference = f"{sub}_{ref}_invalid"
            # fix the subject ID, and validity to invalid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "invalid":
                # print(reference, combo)
                # calculate the mean of the invemo-invneu difference by valence
                dad[f"{sub}_{val}"] = np.mean([invemo - invneu for invemo, invneu in zip(rts[combo], rts[reference])])

# transfer to pd.dataframe
dad = (pd.DataFrame.from_dict(dad, orient='index', columns=['mean_DAD']).rename_axis('FEDbyvalence').reset_index())

# %%
# JAY's ORIGINAL QUOTE FROM 5 YEARS AGO:
# What I did was to run the CV equation on the individual subject means instead of the overall mean by condition. In MATLAB, it looked like this for positive CV:

# datastruct.CV_POS = (datastruct.RT_POS_INVAL - datastruct.RT_POS_VALID);
# CV_Positive = mean(datastruct.CV_POS(1,:));

# So datastruct.CV_POS has the cue validity score for positive stimuli for each subject. Then I take the mean with the next line,
# and those are the CV scores I sent you guys last night.

# %%
# create RT means for smallest increment (validity)
# copy data to avoid accidents
eect_ttest = anova_submeans.copy()

# sort data by subject, valence and validity
eect_ttest.sort_values(['Subject', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# list RT by subject, valence and validity, respectively
rts = {}
for sub in eect_ttest['Subject'].unique():
    for valence in eect_ttest['Cue_Valence'].unique():
        for valid in eect_ttest['Cue_Validity'].unique():
            rts[f"{sub}_{valence}_{valid}"] = eect_ttest.loc[(eect_ttest['Subject'] == sub)
                                                           & (eect_ttest['Cue_Valence'] == valence) 
                                                           & (eect_ttest['Cue_Validity'] == valid), 'RT'].tolist()

# %%
# calculate CV for each valence per subject
cv = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    for val in valence_cats:
        # create list for validity-referenced combos
        validity = []
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # fix the subject ID
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1]) == val:
                # collect validities
                validity.append(combo)
        #print(validity)
        # calculate the inv-v difference by valence
        cv[f"{sub}_{val}"] = [inv - v for inv, v in zip(rts[validity[0]], rts[validity[1]])]

# transfer to pd.dataframe
cv = (pd.DataFrame.from_dict(cv, orient='index', columns=['CV']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate AE for each valence per subject
ae = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set valid neutral reference
            reference = f"{sub}_{ref}_valid"
            # fix the subject ID, and validity to valid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "valid":
                #print(reference, combo)
                # calculate the vneu-vemo difference by valence
                ae[f"{sub}_{val}"] = [vneu - vemo for vneu, vemo in zip(rts[reference], rts[combo])]

# transfer to pd.dataframe
ae = (pd.DataFrame.from_dict(ae, orient='index', columns=['AE']).rename_axis('FEDbyvalence').reset_index())

# %%
# calculate DAD for each valence per subject
dad = {}
# start at subject index level
for sub in fed_nums:
    # iterate across valences
    ref = valence_cats[-1]  # neutral is always reference
    for val in valence_cats[:-1]:
        # go through combinations of conditions by subject
        for combo in rts.keys():
            # set invalid neutral reference
            reference = f"{sub}_{ref}_invalid"
            # fix the subject ID, and validity to invalid
            if (int(combo.split('_', 1)[0]) == sub and combo.split('_', 2)[1] == val and combo.rsplit('_', 1)[1]) == "invalid":
                #print(combo, reference)
                # calculate the invemo-invneu difference by valence
                dad[f"{sub}_{val}"] = [invemo - invneu for invemo, invneu in zip(rts[combo], rts[reference])]

# transfer to pd.dataframe
dad = (pd.DataFrame.from_dict(dad, orient='index', columns=['DAD']).rename_axis('FEDbyvalence').reset_index())

# %%
# add group column to each variable's dataframe
for frame in [cv, ae, dad]:
    # copy Subject, Condition lists and transform to integers
    frame['FED'] = frame['FEDbyvalence'].apply(lambda x: x.split('_', 1)[0])
    frame['Valence'] = frame['FEDbyvalence'].apply(lambda x: x.split('_', 1)[1])
    # copy FED again to obtain DStatus list
    frame['DStatus'] = frame['FED']
    # check and change by group
    frame.loc[frame['FED'].astype(int).isin(mdd), 'DStatus'] = "dep"
    frame.loc[frame['FED'].astype(int).isin(control), 'DStatus'] = "con"
    # finally, sort the dataframe by DStatus and FED
    frame.sort_values(['DStatus', 'Valence', 'FED'], inplace = True)
    # drop FEDbyvalence
    frame.drop(columns='FEDbyvalence', inplace=True)

# %% [markdown]
# Inspect and make sure that all variables look OK

# %%
pd.set_option('display.max_rows', None)
cv
# Out:
#             CV FED Valence DStatus
# 9     1.201466  10     neg     con
# 15   12.320000  12     neg     con
# 18    4.846506  13     neg     con
# 24   22.150345  15     neg     con
# 27  -12.076310  16     neg     con
# 30  -11.014828  17     neg     con
# 36  -18.411724  19     neg     con
# 39   -5.985926  20     neg     con
# 42   -3.871379  21     neg     con
# 45  -26.141392  22     neg     con
# 48    1.478966  23     neg     con
# 51   -1.600567  24     neg     con
# 54  -35.833103  25     neg     con
# 57    9.195172  26     neg     con
# 126 -32.796071  49     neg     con
# 129  -4.250000  50     neg     con
# 138   6.277241  53     neg     con
# 141 -22.846589  54     neg     con
# 147  23.182414  56     neg     con
# 153 -10.947303  58     neg     con
# 159   9.248633  60     neg     con
# 162 -55.951761  61     neg     con
# 165   1.490055  62     neg     con
# 168 -22.753276  63     neg     con
# 171 -11.203436  64     neg     con
# 174  19.113214  65     neg     con
# 180  21.794483  67     neg     con
# 183  14.206071  68     neg     con
# 0    -7.640049   7     neg     con
# 3   -15.683214   8     neg     con
# 6   -19.983214   9     neg     con
# 11  -18.759333  10     neu     con
# 17   -0.449184  12     neu     con
# 20   13.670000  13     neu     con
# 26   34.773000  15     neu     con
# 29  -16.513214  16     neu     con
# 32  -10.135517  17     neu     con
# 38  -36.880954  19     neu     con
# 41  -18.136034  20     neu     con
# 44    9.514000  21     neu     con
# 47  -27.998839  22     neu     con
# 50   37.016519  23     neu     con
# 53    2.724920  24     neu     con
# 56  -31.024138  25     neu     con
# 59  -15.012000  26     neu     con
# 128 -49.745138  49     neu     con
# 131  -4.594667  50     neu     con
# 140   8.141333  53     neu     con
# 143 -25.780897  54     neu     con
# 149  -3.553667  56     neu     con
# 155  -5.256172  58     neu     con
# 161  -6.268000  60     neu     con
# 164 -52.965667  61     neu     con
# 167  -5.732000  62     neu     con
# 170 -23.823214  63     neu     con
# 173   4.290598  64     neu     con
# 176  27.333092  65     neu     con
# 182 -41.805810  67     neu     con
# 185 -11.378161  68     neu     con
# 2    10.128667   7     neu     con
# 5   -21.978333   8     neu     con
# 8   -40.047667   9     neu     con
# 10  -15.417667  10     pos     con
# 16   -3.686968  12     pos     con
# 19  -23.369368  13     pos     con
# 25   32.714171  15     pos     con
# 28    7.140644  16     pos     con
# 31  -19.795333  17     pos     con
# 37  -43.240467  19     pos     con
# 40  -30.843310  20     pos     con
# 43  -19.800690  21     pos     con
# 46  -38.138000  22     pos     con
# 49    2.784683  23     pos     con
# 52    3.834667  24     pos     con
# 55  -18.768398  25     pos     con
# 58   19.534301  26     pos     con
# 127 -62.434215  49     pos     con
# 130   1.936000  50     pos     con
# 139  -9.778312  53     pos     con
# 142 -10.192204  54     pos     con
# 148 -26.495344  56     pos     con
# 154  -5.958806  58     pos     con
# 160  13.000333  60     pos     con
# 163 -41.983035  61     pos     con
# 166  -7.670720  62     pos     con
# 169  -2.992168  63     pos     con
# 172  24.614655  64     pos     con
# 175  16.040738  65     pos     con
# 181 -24.457161  67     pos     con
# 184   6.658333  68     pos     con
# 1    11.920151   7     pos     con
# 4   -14.656613   8     pos     con
# 7   -35.138667   9     pos     con
# 12   -0.317586  11     neg     dep
# 21  -27.538485  14     neg     dep
# 33    1.222278  18     neg     dep
# 60    2.573103  27     neg     dep
# 63  -49.080714  28     neg     dep
# 66  -18.846045  29     neg     dep
# 69   -1.779310  30     neg     dep
# 72  -36.864692  31     neg     dep
# 75   -5.654015  32     neg     dep
# 78    3.495517  33     neg     dep
# 81   17.980000  34     neg     dep
# 84  -31.370677  35     neg     dep
# 87    1.835714  36     neg     dep
# 90  -58.486484  37     neg     dep
# 93   15.174076  38     neg     dep
# 96    9.852567  39     neg     dep
# 99   17.900357  40     neg     dep
# 102  -1.646657  41     neg     dep
# 105 -15.949048  42     neg     dep
# 108  16.337050  43     neg     dep
# 111  11.372222  44     neg     dep
# 114  -4.180345  45     neg     dep
# 117  37.040600  46     neg     dep
# 120   6.966769  47     neg     dep
# 123 -45.335382  48     neg     dep
# 132   7.209643  51     neg     dep
# 135 -39.688621  52     neg     dep
# 144   1.163448  55     neg     dep
# 150   2.680345  57     neg     dep
# 156 -30.331788  59     neg     dep
# 177  15.497623  66     neg     dep
# 14   13.378333  11     neu     dep
# 23  -34.095253  14     neu     dep
# 35   15.497356  18     neu     dep
# 62  -15.915333  27     neu     dep
# 65  -67.122667  28     neu     dep
# 68  -25.687333  29     neu     dep
# 71  -16.924333  30     neu     dep
# 74    5.080000  31     neu     dep
# 77  -20.500586  32     neu     dep
# 80  -32.059333  33     neu     dep
# 83  -11.262852  34     neu     dep
# 86  -37.015667  35     neu     dep
# 89   -2.106000  36     neu     dep
# 92  -37.291770  37     neu     dep
# 95   10.105333  38     neu     dep
# 98   -6.229333  39     neu     dep
# 101   4.014976  40     neu     dep
# 104  25.501376  41     neu     dep
# 107  -8.853418  42     neu     dep
# 110  11.592407  43     neu     dep
# 113  -6.589630  44     neu     dep
# 116 -17.532881  45     neu     dep
# 119  17.267579  46     neu     dep
# 122  15.612167  47     neu     dep
# 125 -36.678571  48     neu     dep
# 134  -5.065057  51     neu     dep
# 137 -21.825690  52     neu     dep
# 146 -23.044286  55     neu     dep
# 152 -17.388667  57     neu     dep
# 158 -17.086207  59     neu     dep
# 179 -15.556000  66     neu     dep
# 13   26.467312  11     pos     dep
# 22  -28.772592  14     pos     dep
# 34   13.892214  18     pos     dep
# 61   10.909667  27     pos     dep
# 64  -52.808112  28     pos     dep
# 67  -31.168974  29     pos     dep
# 70  -18.556040  30     pos     dep
# 73   24.054667  31     pos     dep
# 76  -16.370677  32     pos     dep
# 79  -20.193000  33     pos     dep
# 82    9.201379  34     pos     dep
# 85  -39.141667  35     pos     dep
# 88   -4.760667  36     pos     dep
# 91  -49.081706  37     pos     dep
# 94  -15.116065  38     pos     dep
# 97  -12.772903  39     pos     dep
# 100   9.534742  40     pos     dep
# 103  -3.672667  41     pos     dep
# 106  -7.551834  42     pos     dep
# 109  23.673119  43     pos     dep
# 112   7.937296  44     pos     dep
# 115  -4.771409  45     pos     dep
# 118  35.544692  46     pos     dep
# 121  -7.159161  47     pos     dep
# 124 -26.326720  48     pos     dep
# 133   0.721667  51     pos     dep
# 136 -30.413742  52     pos     dep
# 145 -26.399667  55     pos     dep
# 151 -19.545398  57     pos     dep
# 157 -44.365966  59     pos     dep
# 178  -1.664538  66     pos     dep

# %%
ae
# Out:
#             AE FED Valence DStatus
# 6    12.122632  10     neg     con
# 10    0.639310  12     neg     con
# 12  -15.326528  13     neg     con
# 16  -11.500322  15     neg     con
# 18    7.298690  16     neg     con
# 20    2.948966  17     neg     con
# 24   25.044402  19     neg     con
# 26   12.102146  20     neg     con
# 28    2.460678  21     neg     con
# 30   -4.457368  22     neg     con
# 32  -20.104151  23     neg     con
# 34   -0.451471  24     neg     con
# 36   -9.074828  25     neg     con
# 38   12.461138  26     neg     con
# 84  -21.390148  49     neg     con
# 86   -1.924643  50     neg     con
# 92   -6.175471  53     neg     con
# 94    4.802929  54     neg     con
# 98   13.591207  56     neg     con
# 102   2.409655  58     neg     con
# 106  -1.008310  60     neg     con
# 108 -16.175738  61     neg     con
# 110   6.825619  62     neg     con
# 112  -4.965000  63     neg     con
# 114 -14.916552  64     neg     con
# 116  12.517241  65     neg     con
# 120  54.666626  67     neg     con
# 122   0.100899  68     neg     con
# 0   -22.780621   7     neg     con
# 2    -1.922881   8     neg     con
# 4    -2.520381   9     neg     con
# 7    -1.174333  10     pos     con
# 11  -15.530483  12     pos     con
# 13  -14.699325  13     pos     con
# 17   -5.831011  15     pos     con
# 19   20.894667  16     pos     con
# 21   -9.198230  17     pos     con
# 25   17.915092  19     pos     con
# 27   -6.748608  20     pos     con
# 29  -11.849667  21     pos     con
# 31   -8.051667  22     pos     con
# 33  -21.497599  23     pos     con
# 35   -5.600667  24     pos     con
# 37   10.319667  25     pos     con
# 39   10.970333  26     pos     con
# 85   -8.016529  49     pos     con
# 87    8.911667  50     pos     con
# 93   17.831000  53     pos     con
# 95   12.035667  54     pos     con
# 99   -7.290667  56     pos     con
# 103  12.362172  58     pos     con
# 107   5.317667  60     pos     con
# 109  -5.103185  61     pos     con
# 111  -8.956000  62     pos     con
# 113  -2.511200  63     pos     con
# 115   7.697069  64     pos     con
# 117  15.638313  65     pos     con
# 121  22.380143  67     pos     con
# 123  -7.246172  68     pos     con
# 1    -8.777333   7     pos     con
# 3    19.725333   8     pos     con
# 5   -12.787000   9     pos     con
# 8    -7.520425  11     neg     dep
# 14   21.561515  14     neg     dep
# 22  -52.920595  18     neg     dep
# 40    9.275460  27     neg     dep
# 42   17.460548  28     neg     dep
# 44    7.278407  29     neg     dep
# 46    3.200770  30     neg     dep
# 48  -25.230738  31     neg     dep
# 50   -5.870000  32     neg     dep
# 52   25.477483  33     neg     dep
# 54   28.990817  34     neg     dep
# 56    6.357632  35     neg     dep
# 58   15.040262  36     neg     dep
# 60  -28.517666  37     neg     dep
# 62   -1.642119  38     neg     dep
# 64    7.287556  39     neg     dep
# 66   -3.244643  40     neg     dep
# 68  -11.141657  41     neg     dep
# 70    2.304617  42     neg     dep
# 72   -6.310172  43     neg     dep
# 74   29.568148  44     neg     dep
# 76   -1.439544  45     neg     dep
# 78   17.619643  46     neg     dep
# 80    0.958481  47     neg     dep
# 82    2.878929  48     neg     dep
# 88    0.774938  51     neg     dep
# 90  -13.985874  52     neg     dep
# 96   18.791207  55     neg     dep
# 100   2.237333  57     neg     dep
# 104  -6.975926  59     neg     dep
# 118  32.518552  66     neg     dep
# 9     8.709000  11     pos     dep
# 15   -2.487586  14     pos     dep
# 23    6.752644  18     pos     dep
# 41   16.252667  27     pos     dep
# 43    3.086963  28     pos     dep
# 45   -3.569000  29     pos     dep
# 47   14.909046  30     pos     dep
# 49    9.095667  31     pos     dep
# 51   -7.803414  32     pos     dep
# 53    7.160000  33     pos     dep
# 55   17.066679  34     pos     dep
# 57    9.312000  35     pos     dep
# 59    2.827333  36     pos     dep
# 61   -6.620825  37     pos     dep
# 63  -19.448333  38     pos     dep
# 65   -0.154667  39     pos     dep
# 67    7.662357  40     pos     dep
# 69   -4.298190  41     pos     dep
# 71    5.585722  42     pos     dep
# 73   -3.978214  43     pos     dep
# 75    9.769630  44     pos     dep
# 77   15.029548  45     pos     dep
# 79   25.093264  46     pos     dep
# 81   14.356333  47     pos     dep
# 83    1.876667  48     pos     dep
# 89    2.864391  51     pos     dep
# 91   -6.875667  52     pos     dep
# 97   -1.901000  55     pos     dep
# 101 -20.750000  57     pos     dep
# 105 -10.067000  59     pos     dep
# 119   7.781655  66     pos     dep

# %%
dad
# Out:
#            DAD FED Valence DStatus
# 6     7.838167  10     neg     con
# 10   12.129874  12     neg     con
# 12    6.503034  13     neg     con
# 16   -1.122333  15     neg     con
# 18   -2.861786  16     neg     con
# 20   -3.828276  17     neg     con
# 24   -6.575172  19     neg     con
# 26    0.047963  20     neg     con
# 28  -15.846057  21     neg     con
# 30    6.314815  22     neg     con
# 32  -15.433402  23     neg     con
# 34   -3.874015  24     neg     con
# 36    4.265862  25     neg     con
# 38   11.746034  26     neg     con
# 84   38.339214  49     neg     con
# 86    2.269310  50     neg     con
# 92    4.311379  53     neg     con
# 94   -1.868621  54     neg     con
# 98   13.144874  56     neg     con
# 102  -8.100786  58     neg     con
# 106  16.524943  60     neg     con
# 108  13.189644  61     neg     con
# 110   0.396436  62     neg     con
# 112   6.034938  63     neg     con
# 114  -0.577481  64     neg     con
# 116 -20.737119  65     neg     con
# 120   8.933667  67     neg     con
# 122  25.483333  68     neg     con
# 0     5.011905   7     neg     con
# 2     8.218000   8     neg     con
# 4    22.584833   9     neg     con
# 7     4.516000  10     pos     con
# 11   12.292699  12     pos     con
# 13  -22.340043  13     pos     con
# 17    3.772183  15     pos     con
# 19    2.759190  16     pos     con
# 21   -0.461586  17     pos     con
# 25  -24.274605  19     pos     con
# 27   -5.958667  20     pos     con
# 29  -17.465023  21     pos     con
# 31   -2.087494  22     pos     con
# 33  -12.734237  23     pos     con
# 35    6.710414  24     pos     con
# 37    1.936073  25     pos     con
# 39   23.575968  26     pos     con
# 85   -4.672548  49     pos     con
# 87   -2.381000  50     pos     con
# 93  -35.750645  53     pos     con
# 95    3.553026  54     pos     con
# 99  -15.651011  56     pos     con
# 103 -13.064806  58     pos     con
# 107  13.950667  60     pos     con
# 109  16.085817  61     pos     con
# 111   7.017280  62     pos     con
# 113  23.342247  63     pos     con
# 115  12.626989  64     pos     con
# 117 -26.930667  65     pos     con
# 121  -5.031495  67     pos     con
# 123  25.282667  68     pos     con
# 1    10.568817   7     pos     con
# 3   -12.403613   8     pos     con
# 5    17.696000   9     pos     con
# 8    -6.175494  11     neg     dep
# 14  -15.004747  14     neg     dep
# 22   38.645517  18     neg     dep
# 40    9.212977  27     neg     dep
# 42    0.581405  28     neg     dep
# 44   -0.437119  29     neg     dep
# 46   11.944253  30     neg     dep
# 48  -16.713954  31     neg     dep
# 50   20.716571  32     neg     dep
# 52   10.077368  33     neg     dep
# 54    0.252034  34     neg     dep
# 56   -0.712643  35     neg     dep
# 58  -11.098548  36     neg     dep
# 60    7.322952  37     neg     dep
# 62    6.710862  38     neg     dep
# 64    8.794345  39     neg     dep
# 66   17.130024  40     neg     dep
# 68  -16.006376  41     neg     dep
# 70   -9.400246  42     neg     dep
# 72   11.054815  43     neg     dep
# 74  -11.606296  44     neg     dep
# 76   14.792080  45     neg     dep
# 78    2.153378  46     neg     dep
# 80   -9.603879  47     neg     dep
# 82  -11.535739  48     neg     dep
# 88   11.499762  51     neg     dep
# 90   -3.877057  52     neg     dep
# 96    5.416527  55     neg     dep
# 100  17.831678  57     neg     dep
# 104  -6.269655  59     neg     dep
# 118  -1.464929  66     neg     dep
# 9     4.379978  11     pos     dep
# 15    7.810247  14     pos     dep
# 23   -8.357786  18     pos     dep
# 41   10.572333  27     pos     dep
# 43   11.227591  28     pos     dep
# 45   -1.912641  29     pos     dep
# 47  -16.540753  30     pos     dep
# 49    9.879000  31     pos     dep
# 51   11.933323  32     pos     dep
# 53    4.706333  33     pos     dep
# 55    3.397552  34     pos     dep
# 57  -11.438000  35     pos     dep
# 59   -5.482000  36     pos     dep
# 61   -5.169111  37     pos     dep
# 63   -5.773065  38     pos     dep
# 65   -6.388903  39     pos     dep
# 67   -2.142591  40     pos     dep
# 69  -24.875852  41     pos     dep
# 71   -4.284138  42     pos     dep
# 73   16.058926  43     pos     dep
# 75    4.757296  44     pos     dep
# 77   -2.268075  45     pos     dep
# 79   -6.816151  46     pos     dep
# 81  -37.127661  47     pos     dep
# 83    8.475184  48     pos     dep
# 89    2.922333  51     pos     dep
# 91   -1.712385  52     pos     dep
# 97   -1.454381  55     pos     dep
# 101  18.593269  57     pos     dep
# 105 -17.212759  59     pos     dep
# 119   6.109806  66     pos     dep

# %% [markdown]
# Calculate two-sided t-tests (un)like Koster (2005)

# %%
# calculate cauchy scaling factor of Koster et al. (2005)
# - original: https://doi.org/10.3758/PBR.16.2.225; recent implimentation: https://doi.org/10.1080/00031305.2018.1562983

# transfer t_vals to cohens d for basing on propability density function
smallest_t = 2.15
largest_t = 2.72
small_cohen = pg.compute_effsize_from_t(smallest_t, nx=20, ny=20, eftype='cohen')
large_cohen = pg.compute_effsize_from_t(largest_t, N=15, eftype='cohen')
# spectrum based on Exp1 & Exp2 results
# t-values are between 0 and 1.4, round up
value_halfwidth = 2
# set scaling factor required for estimated 80% probability that the true effect sizes lie within the spectrum (+2 - -2)
cauchy_r = 0.707
# control the probability
effect_prob_est = sp.stats.cauchy.cdf(value_halfwidth, 0, cauchy_r) - sp.stats.cauchy.cdf(-value_halfwidth, 0, cauchy_r)

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for CV
# neg
cvneg_mdd = cv['CV'][(cv['Valence'] == "neg") & (cv['DStatus'] == "dep")].tolist()
cvneg_con = cv['CV'][(cv['Valence'] == "neg") & (cv['DStatus'] == "con")].tolist()
# pos
cvpos_mdd = cv['CV'][(cv['Valence'] == "pos") & (cv['DStatus'] == "dep")].tolist()
cvpos_con = cv['CV'][(cv['Valence'] == "pos") & (cv['DStatus'] == "con")].tolist()
# neu
cvneu_mdd = cv['CV'][(cv['Valence'] == "neu") & (cv['DStatus'] == "dep")].tolist()
cvneu_con = cv['CV'][(cv['Valence'] == "neu") & (cv['DStatus'] == "con")].tolist()
# put all into tupled list
cv_testbtw = [(cvneg_mdd, cvneg_con), (cvpos_mdd, cvpos_con), (cvneu_mdd, cvneu_con)]
cv_testwithin = [[group[0] for group in cv_testbtw], [group[1] for group in cv_testbtw]]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_cv_all = []
# first compare valences between groups with a 2-sample t-test
for valence in cv_testbtw:
    ttests_cv = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_cv.insert(0, "ConditionID", f"cv_btw_{valence_cats[cv_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_cv.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_cv_all.append(ttests_cv)

# Now look at the valences within groups with a paired t-test
for group in cv_testwithin:
    # compare neg and pos against neu
    for valence in [0, 1]:
        ttests_cv = pg.ttest(group[valence], group[2], paired=True, tail='two-sided', r=cauchy_r, confidence=0.95)
        # add condition and group ID (0 means control^^)
        ttests_cv.insert(0, "ConditionID", f"cv_within_{group_cats[cv_testwithin.index(group)]}_{valence_cats[[0, 1].index(valence)]}")
        # add (partial) eta-squared estimate to the dataframe
        ttests_cv.insert(7, "eta-squared", pg.compute_effsize(group[valence], group[2], paired=True, eftype='eta-square'))
        # put the finish dataframe into list
        ttests_cv_all.append(ttests_cv)

# concat list to dataframe
ttests_cv_all = pd.concat(ttests_cv_all)

# %%
# test whether or not all t-test RT lists have the same length
for group in cv_testwithin:
    print(f"Negative CV {len(group[0])}; Positive CV {len(group[1])}; Neutral CV {len(group[2])}")
# Out:
# Negative CV 31; Positive CV 31; Neutral CV 31
# Negative CV 31; Positive CV 31; Neutral CV 31

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for AE
# neg
aeneg_mdd = ae['AE'][(ae['Valence'] == "neg") & (ae['DStatus'] == "dep")].tolist()
aeneg_con = ae['AE'][(ae['Valence'] == "neg") & (ae['DStatus'] == "con")].tolist()
# pos
aepos_mdd = ae['AE'][(ae['Valence'] == "pos") & (ae['DStatus'] == "dep")].tolist()
aepos_con = ae['AE'][(ae['Valence'] == "pos") & (ae['DStatus'] == "con")].tolist()
# put all into tupled list (no within comparisons here)
ae_testbtw = [(aeneg_mdd, aeneg_con), (aepos_mdd, aepos_con)]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_ae_all = []
# first compare valences between groups with a 2-sample t-test
for valence in ae_testbtw:
    ttests_ae = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_ae.insert(0, "ConditionID", f"ae_btw_{valence_cats[ae_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_ae.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_ae_all.append(ttests_ae)

# concat list to dataframe
ttests_ae_all = pd.concat(ttests_ae_all)

# %%
# run a two-sided t-test with appropriate p-level threshold (unlike Koster ...)
# for DAD
# neg
dadneg_mdd = dad['DAD'][(dad['Valence'] == "neg") & (dad['DStatus'] == "dep")].tolist()
dadneg_con = dad['DAD'][(dad['Valence'] == "neg") & (dad['DStatus'] == "con")].tolist()
# pos
dadpos_mdd = dad['DAD'][(dad['Valence'] == "pos") & (dad['DStatus'] == "dep")].tolist()
dadpos_con = dad['DAD'][(dad['Valence'] == "pos") & (dad['DStatus'] == "con")].tolist()
# put all into tupled list (no within comparisons here)
dad_testbtw = [(dadneg_mdd, dadneg_con), (dadpos_mdd, dadpos_con)]

# test all valences separately between and within group
# build empty list to hold all tests
ttests_dad_all = []
# first compare valences between groups with a 2-sample t-test
for valence in dad_testbtw:
    ttests_dad = pg.ttest(valence[0], valence[1], paired=False, tail='two-sided', r=cauchy_r, confidence=0.95)
    # add condition ID
    ttests_dad.insert(0, "ConditionID", f"dad_btw_{valence_cats[dad_testbtw.index(valence)]}")
    # add (partial) eta-squared estimate to the dataframe
    ttests_dad.insert(7, "eta-squared", pg.compute_effsize(valence[0], valence[1], paired=False, eftype='eta-square'))
    # put the finish dataframe into list
    ttests_dad_all.append(ttests_dad)

# concat list to dataframe
ttests_dad_all = pd.concat(ttests_dad_all)

# %% [markdown]
# Plot t-test results

# %%
# view respective ttest dicts to make sure everything looks as it should
ttests_cv_all
# Out:
#               ConditionID         T  dof       tail     p-val  \
# T-test         cv_btw_neg -0.159356   60  two-sided  0.873924
# T-test         cv_btw_pos  0.090614   60  two-sided  0.928101
# T-test         cv_btw_neu -0.220119   60  two-sided  0.826526
# T-test  cv_within_dep_neg  1.557682   30  two-sided  0.129797
# T-test  cv_within_dep_pos  0.736282   30  two-sided  0.467278
# T-test  cv_within_con_neg  1.468960   30  two-sided  0.152253
# T-test  cv_within_con_pos  0.057506   30  two-sided  0.954523
#
#                   CI95%   cohen-d  eta-squared   BF10     power
# T-test   [-11.49, 9.79]  0.040476     0.000409  0.262  0.052822
# T-test  [-10.85, 11.88]  0.023016     0.000132   0.26  0.050911
# T-test   [-12.21, 9.79]  0.055910     0.000781  0.264  0.055392
# T-test    [-1.6, 11.85]  0.234799     0.013595  0.568  0.244373
# T-test     [-3.38, 7.2]  0.087939     0.001930  0.246  0.076127
# T-test   [-1.86, 11.39]  0.229729     0.013022  0.505  0.235954
# T-test    [-6.24, 6.61]  0.008095     0.000016  0.192  0.050218

# %%
ttests_ae_all
# Out:
#        ConditionID         T  dof       tail     p-val           CI95%  \
# T-test  ae_btw_neg  0.526888   60  two-sided  0.600214  [-6.27, 10.75]
# T-test  ae_btw_pos  0.836960   60  two-sided  0.405936   [-3.41, 8.32]
#
#          cohen-d  eta-squared   BF10     power
# T-test  0.133830     0.004458  0.291  0.081324
# T-test  0.212588     0.011172  0.348  0.130595

# %%
ttests_dad_all
# Out:
#         ConditionID         T  dof       tail     p-val          CI95%  \
# T-test  dad_btw_neg -0.596261   60  two-sided  0.553244  [-8.18, 4.42]
# T-test  dad_btw_pos -0.206835   60  two-sided  0.836839  [-7.78, 6.32]
#
#          cohen-d  eta-squared   BF10     power
# T-test  0.151450     0.005702  0.301  0.090283
# T-test  0.052536     0.000690  0.264  0.054760

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(ttests_cv_all, tablefmt="latex")
pg.print_table(ttests_ae_all, tablefmt="latex")
pg.print_table(ttests_dad_all, tablefmt="latex")
# Out:
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID       &      T &   dof & tail      &   p-val & CI95\%           &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  cv\_btw\_neg        & -0.159 &    60 & two-sided &   0.874 & [-11.49   9.79] &     0.040 &         0.000 &  0.262 &   0.053 \\
#  cv\_btw\_pos        &  0.091 &    60 & two-sided &   0.928 & [-10.85  11.88] &     0.023 &         0.000 &  0.260 &   0.051 \\
#  cv\_btw\_neu        & -0.220 &    60 & two-sided &   0.827 & [-12.21   9.79] &     0.056 &         0.001 &  0.264 &   0.055 \\
#  cv\_within\_dep\_neg &  1.558 &    30 & two-sided &   0.130 & [-1.6  11.85]   &     0.235 &         0.014 &  0.568 &   0.244 \\
#  cv\_within\_dep\_pos &  0.736 &    30 & two-sided &   0.467 & [-3.38  7.2 ]   &     0.088 &         0.002 &  0.246 &   0.076 \\
#  cv\_within\_con\_neg &  1.469 &    30 & two-sided &   0.152 & [-1.86 11.39]   &     0.230 &         0.013 &  0.505 &   0.236 \\
#  cv\_within\_con\_pos &  0.058 &    30 & two-sided &   0.955 & [-6.24  6.61]   &     0.008 &         0.000 &  0.192 &   0.050 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID   &     T &   dof & tail      &   p-val & CI95\%         &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  ae\_btw\_neg    & 0.527 &    60 & two-sided &   0.600 & [-6.27 10.75] &     0.134 &         0.004 &  0.291 &   0.081 \\
#  ae\_btw\_pos    & 0.837 &    60 & two-sided &   0.406 & [-3.41  8.32] &     0.213 &         0.011 &  0.348 &   0.131 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{lrrlrlrrrr}
# \hline
#  ConditionID   &      T &   dof & tail      &   p-val & CI95\%         &   cohen-d &   eta-squared &   BF10 &   power \\
# \hline
#  dad\_btw\_neg   & -0.596 &    60 & two-sided &   0.553 & [-8.18  4.42] &     0.151 &         0.006 &  0.301 &   0.090 \\
#  dad\_btw\_pos   & -0.207 &    60 & two-sided &   0.837 & [-7.78  6.32] &     0.053 &         0.001 &  0.264 &   0.055 \\
# \hline
# \end{tabular}

# %% [markdown]
# Calculate Cue Validity (CV), Attentional Engagement (AE), and Difficulty in Attentional Disengagement (DAD) - group means

# %%
# create mean_{variable} by valence for each group
# collect all single values in a dict for extraction into table
Group_vars_decript = {"MDD_mean": {}, "MDD_std": {}, "CON_mean": {}, "CON_std": {}}

for frame in [("CV", cv), ("AE", ae), ("DAD", dad)]:
    # locate Valence and DStatus in frame and set group column to CV across FEDs for those parameters
    for valence in valence_cats:
        # for MDD
        Group_vars_decript["MDD_mean"][f"{frame[0]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "dep")
                                                                                                    & (frame[1]['Valence'] == valence)].mean()
        Group_vars_decript["MDD_std"][f"{frame[0]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "dep")
                                                                                                    & (frame[1]['Valence'] == valence)].std()
        # for control
        Group_vars_decript["CON_mean"][f"{frame[0]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "con")
                                                                                                    & (frame[1]['Valence'] == valence)].mean()
        Group_vars_decript["CON_std"][f"{frame[0]}_{valence}"] = frame[1][frame[0]][(frame[1]['DStatus'] == "con")
                                                                                                    & (frame[1]['Valence'] == valence)].std()

# drop all items with nan values (neutral valences for AE, DAD)
for group in Group_vars_decript.keys():
    for item in list(Group_vars_decript[group].items()):
        if item[1] is np.NaN:
            Group_vars_decript[group].pop(item[0])

# transfer dict to pd.dataframe
Group_vars_decript = pd.DataFrame.from_dict(Group_vars_decript, orient='columns')
# make index its own column
Group_vars_decript.insert(0, "Var_Valence", Group_vars_decript.index)

# %% [markdown]
# Build summary tables for each variable by group, valence (and validity, if needed)

# %%
print(Group_vars_decript)
# Out:
#         Var_Valence   MDD_mean    MDD_std   CON_mean    CON_std
# CV_neg       CV_neg  -6.411888  23.082647  -5.564051  18.566053
# CV_pos       CV_pos  -9.634734  22.768890 -10.149638  21.966951
# CV_neu       CV_neu -11.541334  20.535267 -10.330532  22.721796
# AE_neg       AE_neg   2.734933  18.144643   0.493475  15.225081
# AE_pos       AE_pos   3.136699  10.441404   0.681584  12.558729
# DAD_neg     DAD_neg   2.394512  12.644671   4.273006  12.157273
# DAD_pos     DAD_pos  -1.230099  11.931374  -0.500690  15.593869

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(Group_vars_decript, tablefmt="latex")
# Out:
# \begin{tabular}{lrrrr}
# \hline
#  Var\_Valence   &   MDD\_mean &   MDD\_std &   CON\_mean &   CON\_std \\
# \hline
#  CV\_neg        &     -6.412 &    23.083 &     -5.564 &    18.566 \\
#  CV\_pos        &     -9.635 &    22.769 &    -10.150 &    21.967 \\
#  CV\_neu        &    -11.541 &    20.535 &    -10.331 &    22.722 \\
#  AE\_neg        &      2.735 &    18.145 &      0.493 &    15.225 \\
#  AE\_pos        &      3.137 &    10.441 &      0.682 &    12.559 \\
#  DAD\_neg       &      2.395 &    12.645 &      4.273 &    12.157 \\
#  DAD\_pos       &     -1.230 &    11.931 &     -0.501 &    15.594 \\
# \hline
# \end{tabular}

# %% [markdown]
# Plot the ANOVA data's descriptives per cell

# %%
pd.set_option('display.max_rows', None)
anova_submeans
# Out:
#                RT  Subject Cue_Valence Cue_Validity DStatus
# 1080   320.278571        7         neg      invalid     con
# 1260   324.400000        8         neg      invalid     con
# 1440   312.172759        9         neg      invalid     con
# 1620   331.795862       10         neg      invalid     con
# 1980   317.846207       12         neg      invalid     con
# 2160   386.842222       13         neg      invalid     con
# 2520   416.560000       15         neg      invalid     con
# 2700   279.850357       16         neg      invalid     con
# 2880   265.769310       17         neg      invalid     con
# 3240   327.416207       19         neg      invalid     con
# 3420   267.342963       20         neg      invalid     con
# 3600   377.528276       21         neg      invalid     con
# 3780   297.739643       22         neg      invalid     con
# 3960   294.147931       23         neg      invalid     con
# 4140   316.498966       24         neg      invalid     con
# 4320   314.101724       25         neg      invalid     con
# 4500   348.191034       26         neg      invalid     con
# 8640   347.718214       49         neg      invalid     con
# 8820   288.051724       50         neg      invalid     con
# 9360   419.661379       53         neg      invalid     con
# 9540   287.544483       54         neg      invalid     con
# 9900   319.506207       56         neg      invalid     con
# 10260  316.248214       58         neg      invalid     con
# 10620  380.788276       60         neg      invalid     con
# 10800  307.869310       61         neg      invalid     con
# 10980  258.690769       62         neg      invalid     con
# 11160  306.021724       63         neg      invalid     con
# 11340  342.605185       64         neg      invalid     con
# 11520  380.503214       65         neg      invalid     con
# 11880  310.700000       67         neg      invalid     con
# 12060  443.444643       68         neg      invalid     con
# 1089   327.918621        7         neg        valid     con
# 1269   340.083214        8         neg        valid     con
# 1449   322.635714        9         neg        valid     con
# 1629   320.021034       10         neg        valid     con
# 1989   305.526207       12         neg        valid     con
# 2170   368.255417       13         neg        valid     con
# 2529   394.409655       15         neg        valid     con
# 2710   291.926667       16         neg        valid     con
# 2889   276.784138       17         neg        valid     con
# 3249   345.827931       19         neg        valid     con
# 3429   273.328889       20         neg        valid     con
# 3609   381.399655       21         neg        valid     con
# 3789   323.881034       22         neg        valid     con
# 3969   292.668966       23         neg        valid     con
# 4149   307.974138       24         neg        valid     con
# 4329   349.934828       25         neg        valid     con
# 4509   338.995862       26         neg        valid     con
# 8649   389.544483       49         neg        valid     con
# 8829   292.812069       50         neg        valid     con
# 9369   413.384138       53         neg        valid     con
# 9549   310.391071       54         neg        valid     con
# 9909   296.323793       56         neg        valid     con
# 10269  327.195517       58         neg        valid     con
# 10629  381.936897       60         neg        valid     con
# 10809  374.567931       61         neg        valid     con
# 10989  257.200714       62         neg        valid     con
# 11169  328.775000       63         neg        valid     con
# 11349  353.808621       64         neg        valid     con
# 11529  361.390000       65         neg        valid     con
# 11889  288.905517       67         neg        valid     con
# 12069  419.703929       68         neg        valid     con
# 1120   315.266667        7         neu      invalid     con
# 1300   316.182000        8         neu      invalid     con
# 1480   280.067667        9         neu      invalid     con
# 1660   313.384333       10         neu      invalid     con
# 2020   305.716333       12         neu      invalid     con
# 2200   366.598889       13         neu      invalid     con
# 2560   417.682333       15         neu      invalid     con
# 2740   282.712143       16         neu      invalid     con
# 2920   278.177000       17         neu      invalid     con
# 3280   346.478000       19         neu      invalid     con
# 3460   267.295000       20         neu      invalid     con
# 3640   393.374333       21         neu      invalid     con
# 3820   291.424828       22         neu      invalid     con
# 4000   309.581333       23         neu      invalid     con
# 4180   318.537000       24         neu      invalid     con
# 4360   324.120667       25         neu      invalid     con
# 4540   336.445000       26         neu      invalid     con
# 8680   309.379000       49         neu      invalid     con
# 8860   277.945333       50         neu      invalid     con
# 9400   415.350000       53         neu      invalid     con
# 9580   299.628000       54         neu      invalid     con
# 9940   306.361333       56         neu      invalid     con
# 10300  324.349000       58         neu      invalid     con
# 10660  364.263333       60         neu      invalid     con
# 10840  294.679667       61         neu      invalid     con
# 11020  258.294333       62         neu      invalid     con
# 11200  299.986786       63         neu      invalid     con
# 11380  343.182667       64         neu      invalid     con
# 11560  401.240333       65         neu      invalid     con
# 11920  301.766333       67         neu      invalid     con
# 12100  408.426667       68         neu      invalid     con
# 1200   305.138000        7         neu        valid     con
# 1380   338.160333        8         neu        valid     con
# 1560   320.115333        9         neu        valid     con
# 1740   332.143667       10         neu        valid     con
# 2100   315.801333       12         neu        valid     con
# 2281   352.928889       13         neu        valid     con
# 2640   382.909333       15         neu        valid     con
# 2820   311.266667       16         neu        valid     con
# 3000   279.733103       17         neu        valid     con
# 3360   370.872333       19         neu        valid     con
# 3540   285.431034       20         neu        valid     con
# 3720   383.860333       21         neu        valid     con
# 3900   319.423667       22         neu        valid     con
# 4080   272.564815       23         neu        valid     con
# 4260   307.522667       24         neu        valid     con
# 4440   340.860000       25         neu        valid     con
# 4620   351.457000       26         neu        valid     con
# 8760   370.629667       49         neu        valid     con
# 8940   282.540000       50         neu        valid     con
# 9480   407.208667       53         neu        valid     con
# 9660   315.194000       54         neu        valid     con
# 10020  309.915000       56         neu        valid     con
# 10380  329.605172       58         neu        valid     con
# 10740  370.531333       60         neu        valid     con
# 10920  347.645333       61         neu        valid     con
# 11100  264.026333       62         neu        valid     con
# 11280  323.810000       63         neu        valid     con
# 11460  338.892069       64         neu        valid     con
# 11640  373.907241       65         neu        valid     con
# 12000  343.572143       67         neu        valid     con
# 12180  430.051333       68         neu        valid     con
# 1104   325.835484        7         pos      invalid     con
# 1284   303.778387        8         pos      invalid     con
# 1464   297.763667        9         pos      invalid     con
# 1644   326.933871       10         pos      invalid     con
# 2004   318.009032       12         pos      invalid     con
# 2184   344.258846       13         pos      invalid     con
# 2544   421.454516       15         pos      invalid     con
# 2724   292.164194       16         pos      invalid     con
# 2904   269.136000       17         pos      invalid     con
# 3264   309.716774       19         pos      invalid     con
# 3444   261.336333       20         pos      invalid     con
# 3624   375.909310       21         pos      invalid     con
# 3804   297.857097       22         pos      invalid     con
# 3984   296.847097       23         pos      invalid     con
# 4164   316.958000       24         pos      invalid     con
# 4344   311.771935       25         pos      invalid     con
# 4524   360.020968       26         pos      invalid     con
# 8664   304.706452       49         pos      invalid     con
# 8844   275.564333       50         pos      invalid     con
# 9384   379.599355       53         pos      invalid     con
# 9564   292.966129       54         pos      invalid     con
# 9924   290.710323       56         pos      invalid     con
# 10284  311.284194       58         pos      invalid     con
# 10644  378.214000       60         pos      invalid     con
# 10824  310.765484       61         pos      invalid     con
# 11004  265.311613       62         pos      invalid     con
# 11184  323.329032       63         pos      invalid     con
# 11364  368.852000       64         pos      invalid     con
# 11544  374.309667       65         pos      invalid     con
# 11904  296.734839       67         pos      invalid     con
# 12084  442.317419       68         pos      invalid     con
# 1098   313.915333        7         pos        valid     con
# 1278   318.435000        8         pos        valid     con
# 1458   332.902333        9         pos        valid     con
# 1638   333.318000       10         pos        valid     con
# 1998   321.696000       12         pos        valid     con
# 2178   367.628214       13         pos        valid     con
# 2538   388.740345       15         pos        valid     con
# 2718   278.330690       16         pos        valid     con
# 2898   288.931333       17         pos        valid     con
# 3258   352.957241       19         pos        valid     con
# 3438   292.179643       20         pos        valid     con
# 3618   395.710000       21         pos        valid     con
# 3798   327.475333       22         pos        valid     con
# 3978   294.062414       23         pos        valid     con
# 4158   313.123333       24         pos        valid     con
# 4338   330.540333       25         pos        valid     con
# 4518   340.486667       26         pos        valid     con
# 8658   367.140667       49         pos        valid     con
# 8838   273.628333       50         pos        valid     con
# 9378   389.377667       53         pos        valid     con
# 9558   303.158333       54         pos        valid     con
# 9918   317.205667       56         pos        valid     con
# 10278  317.243000       58         pos        valid     con
# 10638  365.213667       60         pos        valid     con
# 10818  383.586333       61         pos        valid     con
# 10998  272.982333       62         pos        valid     con
# 11178  326.321200       63         pos        valid     con
# 11358  331.195000       64         pos        valid     con
# 11538  370.452414       65         pos        valid     con
# 11898  321.192000       67         pos        valid     con
# 12078  427.051000       68         pos        valid     con
# 1800   316.105172       11         neg      invalid     dep
# 2340   370.077586       14         neg      invalid     dep
# 3060   378.976207       18         neg      invalid     dep
# 4680   351.699310       27         neg      invalid     dep
# 4860   358.856071       28         neg      invalid     dep
# 5040   337.133214       29         neg      invalid     dep
# 5220   355.587586       30         neg      invalid     dep
# 5400   302.141379       31         neg      invalid     dep
# 5580   351.453448       32         neg      invalid     dep
# 5760   349.541034       33         neg      invalid     dep
# 5940   366.191034       34         neg      invalid     dep
# 6120   298.010357       35         neg      invalid     dep
# 6300   284.956786       36         neg      invalid     dep
# 6480   281.824286       37         neg      invalid     dep
# 6660   321.455862       38         neg      invalid     dep
# 6840   352.560345       39         neg      invalid     dep
# 7021   335.570357       40         neg      invalid     dep
# 7200   307.042143       41         neg      invalid     dep
# 7383   242.622857       42         neg      invalid     dep
# 7560   298.722222       43         neg      invalid     dep
# 7741   370.294074       44         neg      invalid     dep
# 7920   358.032414       45         neg      invalid     dep
# 8280   368.318621       47         neg      invalid     dep
# 8460   346.720690       48         neg      invalid     dep
# 9000   318.516429       51         neg      invalid     dep
# 9180   290.897586       52         neg      invalid     dep
# 9720   326.317241       55         neg      invalid     dep
# 10080  387.320345       57         neg      invalid     dep
# 10440  313.764138       59         neg      invalid     dep
# 11701  385.241071       66         neg      invalid     dep
# 1809   316.422759       11         neg        valid     dep
# 2349   397.616071       14         neg        valid     dep
# 3070   377.753929       18         neg        valid     dep
# 4689   349.126207       27         neg        valid     dep
# 4869   407.936786       28         neg        valid     dep
# 5051   355.979259       29         neg        valid     dep
# 5229   357.366897       30         neg        valid     dep
# 5409   346.852069       31         neg        valid     dep
# 5589   348.217586       32         neg        valid     dep
# 5769   346.045517       33         neg        valid     dep
# 5949   348.211034       34         neg        valid     dep
# 6129   329.381034       35         neg        valid     dep
# 6309   283.121071       36         neg        valid     dep
# 6489   340.310769       37         neg        valid     dep
# 6669   306.281786       38         neg        valid     dep
# 6849   354.098571       39         neg        valid     dep
# 7029   317.670000       40         neg        valid     dep
# 7209   308.688800       41         neg        valid     dep
# 7390   258.571905       42         neg        valid     dep
# 7569   282.385172       43         neg        valid     dep
# 7749   358.921852       44         neg        valid     dep
# 7929   362.212759       45         neg        valid     dep
# 8117   388.770000       46         neg        valid     dep
# 8289   373.633929       47         neg        valid     dep
# 8469   392.056071       48         neg        valid     dep
# 9009   311.306786       51         neg        valid     dep
# 9189   330.586207       52         neg        valid     dep
# 9729   325.153793       55         neg        valid     dep
# 10089  384.640000       57         neg        valid     dep
# 10449  344.095926       59         neg        valid     dep
# 11709  369.743448       66         neg        valid     dep
# 1840   322.280667       11         neu      invalid     dep
# 2380   385.082333       14         neu      invalid     dep
# 3100   340.330690       18         neu      invalid     dep
# 4720   342.486333       27         neu      invalid     dep
# 4900   358.274667       28         neu      invalid     dep
# 5080   337.570333       29         neu      invalid     dep
# 5260   343.643333       30         neu      invalid     dep
# 5440   318.855333       31         neu      invalid     dep
# 5620   321.847000       32         neu      invalid     dep
# 5800   339.463667       33         neu      invalid     dep
# 5980   365.939000       34         neu      invalid     dep
# 6160   298.723000       35         neu      invalid     dep
# 6340   296.055333       36         neu      invalid     dep
# 6520   274.501333       37         neu      invalid     dep
# 6700   314.745000       38         neu      invalid     dep
# 6880   343.766000       39         neu      invalid     dep
# 7060   318.440333       40         neu      invalid     dep
# 7240   334.518929       41         neu      invalid     dep
# 7420   252.023103       42         neu      invalid     dep
# 7600   287.667407       43         neu      invalid     dep
# 7780   393.727143       44         neu      invalid     dep
# 7960   343.240333       45         neu      invalid     dep
# 8142   470.310000       46         neu      invalid     dep
# 8320   390.193448       47         neu      invalid     dep
# 8500   358.256429       48         neu      invalid     dep
# 9040   307.016667       51         neu      invalid     dep
# 9220   294.774643       52         neu      invalid     dep
# 9760   320.900714       55         neu      invalid     dep
# 10120  369.488667       57         neu      invalid     dep
# 10480  320.033793       59         neu      invalid     dep
# 11740  386.706000       66         neu      invalid     dep
# 1920   308.902333       11         neu        valid     dep
# 2460   419.177586       14         neu        valid     dep
# 3180   324.833333       18         neu        valid     dep
# 4800   358.401667       27         neu        valid     dep
# 4980   425.397333       28         neu        valid     dep
# 5160   363.257667       29         neu        valid     dep
# 5340   360.567667       30         neu        valid     dep
# 5520   313.775333       31         neu        valid     dep
# 5700   354.821667       32         neu        valid     dep
# 5880   371.523000       33         neu        valid     dep
# 6060   389.146786       34         neu        valid     dep
# 6240   335.738667       35         neu        valid     dep
# 6420   298.161333       36         neu        valid     dep
# 6600   311.793103       37         neu        valid     dep
# 6780   304.639667       38         neu        valid     dep
# 6960   349.995333       39         neu        valid     dep
# 7140   314.425357       40         neu        valid     dep
# 7320   297.547143       41         neu        valid     dep
# 7500   260.876522       42         neu        valid     dep
# 7680   276.075000       43         neu        valid     dep
# 7860   388.490000       44         neu        valid     dep
# 8040   369.632759       45         neu        valid     dep
# 8274   747.980000       46         neu        valid     dep
# 8400   362.310333       47         neu        valid     dep
# 8580   394.935000       48         neu        valid     dep
# 9120   312.081724       51         neu        valid     dep
# 9300   316.600333       52         neu        valid     dep
# 9840   343.945000       55         neu        valid     dep
# 10200  386.877333       57         neu        valid     dep
# 10560  337.120000       59         neu        valid     dep
# 11820  402.262000       66         neu        valid     dep
# 1824   326.660645       11         pos      invalid     dep
# 2364   392.892581       14         pos      invalid     dep
# 3084   331.972903       18         pos      invalid     dep
# 4704   353.058667       27         pos      invalid     dep
# 4884   369.502258       28         pos      invalid     dep
# 5064   348.722222       29         pos      invalid     dep
# 5244   327.102581       30         pos      invalid     dep
# 5424   337.680323       31         pos      invalid     dep
# 5604   333.780323       32         pos      invalid     dep
# 5784   344.170000       33         pos      invalid     dep
# 5964   369.336552       34         pos      invalid     dep
# 6144   287.285000       35         pos      invalid     dep
# 6325   290.573333       36         pos      invalid     dep
# 6504   269.332222       37         pos      invalid     dep
# 6684   308.971935       38         pos      invalid     dep
# 6864   337.377097       39         pos      invalid     dep
# 7044   316.297742       40         pos      invalid     dep
# 7224   298.172667       41         pos      invalid     dep
# 7404   247.738966       42         pos      invalid     dep
# 7584   303.726333       43         pos      invalid     dep
# 7764   386.657667       44         pos      invalid     dep
# 7944   340.972258       45         pos      invalid     dep
# 8136   620.600000       46         pos      invalid     dep
# 8304   340.794839       47         pos      invalid     dep
# 8484   366.731613       48         pos      invalid     dep
# 9024   309.939000       51         pos      invalid     dep
# 9204   293.062258       52         pos      invalid     dep
# 9744   319.446333       55         pos      invalid     dep
# 10104  388.081935       57         pos      invalid     dep
# 10464  302.821034       59         pos      invalid     dep
# 11724  392.815806       66         pos      invalid     dep
# 1818   300.193333       11         pos        valid     dep
# 2358   421.665172       14         pos        valid     dep
# 3078   330.251333       18         pos        valid     dep
# 4698   342.149000       27         pos        valid     dep
# 4966   433.045357       28         pos        valid     dep
# 5058   366.826667       29         pos        valid     dep
# 5238   345.658621       30         pos        valid     dep
# 5418   304.679667       31         pos        valid     dep
# 5598   350.151000       32         pos        valid     dep
# 5778   364.363000       33         pos        valid     dep
# 5958   360.135172       34         pos        valid     dep
# 6138   326.426667       35         pos        valid     dep
# 6318   295.334000       36         pos        valid     dep
# 6498   318.413929       37         pos        valid     dep
# 6678   324.088000       38         pos        valid     dep
# 6858   363.442000       39         pos        valid     dep
# 7038   306.763000       40         pos        valid     dep
# 7218   301.845333       41         pos        valid     dep
# 7486   255.290800       42         pos        valid     dep
# 7578   280.053214       43         pos        valid     dep
# 7758   391.294643       44         pos        valid     dep
# 7938   345.743667       45         pos        valid     dep
# 8207   410.450000       46         pos        valid     dep
# 8298   347.954000       47         pos        valid     dep
# 8478   393.058333       48         pos        valid     dep
# 9018   309.217333       51         pos        valid     dep
# 9198   323.476000       52         pos        valid     dep
# 9738   345.846000       55         pos        valid     dep
# 10098  407.627333       57         pos        valid     dep
# 10458  347.187000       59         pos        valid     dep
# 11718  394.480345       66         pos        valid     dep

# %%
# copy data to avoid accidents
anova_summary = anova_submeans.copy().drop('Subject', axis=1)

# list RT by group, valence and validity, respectively
for group in anova_summary['DStatus'].unique():
    for valence in anova_summary['Cue_Valence'].unique():
        for valid in anova_summary['Cue_Validity'].unique():
            # define mean and std, as they will otherwise change during the iterative re-assignment
            cat_mean = anova_summary["RT"][(anova_summary['DStatus'] == group)
                                         & (anova_summary['Cue_Valence'] == valence)
                                         & (anova_summary['Cue_Validity'] == valid)].mean()
            cat_std = anova_summary["RT"][(anova_summary['DStatus'] == group)
                                        & (anova_summary['Cue_Valence'] == valence)
                                        & (anova_summary['Cue_Validity'] == valid)].std()

            # locate and replace the individual sub_mean RT values with the mean by valence and validity
            anova_summary.loc[(anova_summary['DStatus'] == group) & (anova_summary['Cue_Valence'] == valence)
                                                                  & (anova_summary['Cue_Validity'] == valid), 'RT_mean'] = cat_mean
            # locate and replace the individual sub_mean RT values with the std by valence and validity
            anova_summary.loc[(anova_summary['DStatus'] == group) & (anova_summary['Cue_Valence'] == valence)
                                                                  & (anova_summary['Cue_Validity'] == valid), 'RT_std'] = cat_std

# drop the sub_mean RT column
anova_summary = anova_summary.drop('RT', axis=1)

# drop duplicate lines
anova_summary = anova_summary.drop_duplicates()

# sort
anova_summary.sort_values(['DStatus', 'Cue_Valence', 'Cue_Validity'], inplace = True)

# %%
# full list of table plotting formats in pingouin:
# "plain" "simple" "github""grid" "fancy_grid" "pipe""orgtbl" "jira""presto" "pretty""psql" "rst" "mediawiki" "moinmoin" "youtrack" "html" "unsafehtml" "latex"
# "latex_raw" "latex_booktabs" "latex_longtable" "textile""tsv"
pg.print_table(anova_summary, tablefmt="latex")
# Out:
# \begin{tabular}{lllrr}
# \hline
#  Cue\_Valence   & Cue\_Validity   & DStatus   &   RT\_mean &   RT\_std \\
# \hline
#  neg           & invalid        & con       &   327.307 &   45.485 \\
#  neg           & valid          & con       &   332.871 &   41.456 \\
#  neu           & invalid        & con       &   323.034 &   45.167 \\
#  neu           & valid          & con       &   333.364 &   38.790 \\
#  pos           & invalid        & con       &   322.533 &   43.472 \\
#  pos           & valid          & con       &   332.683 &   37.371 \\
#  neg           & invalid        & dep       &   335.940 &   36.421 \\
#  neg           & valid          & dep       &   342.351 &   34.119 \\
#  neu           & invalid        & dep       &   333.545 &   34.724 \\
#  neu           & valid          & dep       &   345.086 &   40.902 \\
#  pos           & invalid        & dep       &   332.315 &   37.427 \\
#  pos           & valid          & dep       &   341.950 &   40.102 \\
# \hline
# \end{tabular}

# %%
anova_summary
# Out:
#      Cue_Valence Cue_Validity DStatus     RT_mean     RT_std
# 1080         neg      invalid     con  329.285012  46.231972
# 1089         neg        valid     con  334.113279  42.192822
# 1120         neu      invalid     con  324.770849  44.644736
# 1200         neu        valid     con  334.765058  39.401027
# 1104         pos      invalid     con  324.013431  44.236475
# 1098         pos        valid     con  334.070317  38.642927
# 1800         neg      invalid     dep  334.198329  35.313924
# 1809         neg        valid     dep  344.295419  35.314445
# 1840         neu      invalid     dep  337.124569  42.082432
# 1920         neu        valid     dep  358.106161  83.176610
# 1824         pos      invalid     dep  340.525068  63.299256
# 1818         pos        valid     dep  345.390643  42.950660

# %% [markdown]
# # Testing Zone
