# %% [markdown]
# # Segment raw images to get gray matter before normalising.
# This is to prevent errors in normalisation down the line (e.g. enlargement of ventricles: GM WM growth or shrinkage?)

# %%
# import everything you need
from nipype import Node, Workflow
import nipype.interfaces.spm as spm
import numpy as np
import pandas as pd
import os, re, random
# Out:
# 200122-14:21:11,947 nipype.utils INFO:
# 	 Running nipype version 1.4.0-dev (latest: 1.4.0)

# %%
# define useful functions

# get subject directories from parent directory
def get_subdirs(dir):
    subdirs=[]
    for i in os.listdir(dir):
        # verify subject number in directory and exclude other dirs
        match=re.match(r'(.*\d{3}$)', i)
        if os.path.isdir(os.path.join(dir, i)) and match:
            subdirs.append(os.path.join(dir, match.group(0)))
    return sorted(subdirs)

# %%
subdirs=get_subdirs("/VBM/")
print(subdirs)
# Out:
# ['/VBM/FED006', '/VBM/FED007', '/VBM/FED008', '/VBM/FED009', '/VBM/FED010', '/VBM/FED011', '/VBM/FED012', '/VBM/FED013', '/VBM/FED014', '/VBM/FED015', '/VBM/FED016', '/VBM/FED017', '/VBM/FED018', '/VBM/FED019', '/VBM/FED020', '/VBM/FED021', '/VBM/FED022', '/VBM/FED023', '/VBM/FED024', '/VBM/FED025', '/VBM/FED026', '/VBM/FED027', '/VBM/FED028', '/VBM/FED029', '/VBM/FED030', '/VBM/FED031', '/VBM/FED032', '/VBM/FED033', '/VBM/FED034', '/VBM/FED035', '/VBM/FED036', '/VBM/FED037', '/VBM/FED038', '/VBM/FED039', '/VBM/FED040', '/VBM/FED041', '/VBM/FED042', '/VBM/FED043', '/VBM/FED044', '/VBM/FED045', '/VBM/FED046', '/VBM/FED047', '/VBM/FED048', '/VBM/FED049', '/VBM/FED050', '/VBM/FED051', '/VBM/FED052', '/VBM/FED053', '/VBM/FED054', '/VBM/FED055', '/VBM/FED056', '/VBM/FED057', '/VBM/FED058', '/VBM/FED059', '/VBM/FED060', '/VBM/FED061', '/VBM/FED062', '/VBM/FED063', '/VBM/FED064', '/VBM/FED065', '/VBM/FED066', '/VBM/FED067', '/VBM/FED068']

# %%
# make dict with all T1-images as pathlike objects
images_T1={}
for i in subdirs:
    for j in os.listdir(i):
        match=re.match(r'(.*T1_MPRAGE.*\d{14,}.*.nii)', j)
        if match:
            images_T1[i]=os.path.join(i, match.group(0))

print(images_T1)
# Out:
# {'/VBM/FED006': '/VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005_20141106153429_5.nii', '/VBM/FED007': '/VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005_20141107104226_5.nii', '/VBM/FED008': '/VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005_20141112155009_5.nii', '/VBM/FED009': '/VBM/FED009/T1_MPRAGE_SAG_ISO_0_9_0005_20141117154954_5.nii', '/VBM/FED010': '/VBM/FED010/T1_MPRAGE_SAG_ISO_0_9_0005_20141119091904_5.nii', '/VBM/FED011': '/VBM/FED011/T1_MPRAGE_SAG_ISO_0_9_0005_20141119161708_5.nii', '/VBM
ii', '/VBM/FED039': '/VBM/FED039/T1_MPRAGE_SAG_ISO_0_9_0005_20151001173950_5.nii', '/VBM/FED040': '/VBM/FED040/T1_MPRAGE_SAG_ISO_0_9_0005_20151009111760_5.nii', '/VBM/FED041': '/VBM/FED041/T1_MPRAGE_SAG_ISO_0_9_0005_20151009164129_5.nii', '/VBM/FED042': '/VBM/FED042/T1_MPRAGE_SAG_ISO_0_9_0005_20151013110112_5.nii', '/VBM/FED043': '/VBM/FED043/T1_MPRAGE_SAG_ISO_0_9_0005_20151015122011_5.nii', '/VBM/FED044': '/VBM/FED044/T1_MPRAGE_SAG_ISO_0_9_0005_20151029121235_5.nii', '/VBM/FED045': '/VBM/FED045/T1_MPRAGE_SAG_ISO_0_9_0005_20151105173027_5.nii', '/VBM/FED046': '/VBM/FED046/T1_MPRAGE_SAG_ISO_0_9_0005_20151106125904_5.nii', '/VBM/FED047': '/VBM/FED047/T1_MPRAGE_SAG_ISO_0_9_0005_20151116144126_5.nii', '/VBM/FED048': '/VBM/FED048/T1_MPRAGE_SAG_ISO_0_9_0005_20151118152060_5.nii', '/VBM/FED049': '/VBM/FED049/T1_MPRAGE_SAG_ISO_0_9_0009_20151123115353_9.nii', '/VBM/FED050': '/VBM/FED050/T1_MPRAGE_SAG_ISO_0_9_0005_20151201165820_5.nii', '/VBM/FED051': '/VBM/FED051/T1_MPRAGE_SAG_ISO_0_9_0005_20151202153410_5.nii', '/VBM/FED052': '/VBM/FED052/T1_MPRAGE_SAG_ISO_0_9_0005_20151203172751_5.nii', '/VBM/FED053': '/VBM/FED053/T1_MPRAGE_SAG_ISO_0_9_0005_20151208115820_5.nii', '/VBM/FED054': '/VBM/FED054/T1_MPRAGE_SAG_ISO_0_9_0005_20151208140706_5.nii', '/VBM/FED055': '/VBM/FED055/T1_MPRAGE_SAG_ISO_0_9_0005_20151214092109_5.nii', '/VBM/FED056': '/VBM/FED056/T1_MPRAGE_SAG_ISO_0_9_0005_20151215155556_5.nii', '/VBM/FED057': '/VBM/ ...

# %% [raw]
# # fsl bash code with example T1 from FED006,07,08 -- see results in folders
# %%bash
# bet T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso*.nii T1_MPRAGE_SAG_ISO_bet2.nii &&
# bet T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso*.nii T1_MPRAGE_SAG_ISO_R_bcest.nii -R && bet T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso*.nii T1_MPRAGE_SAG_ISO_S_eyenerve.nii -S && bet T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso*.nii T1_MPRAGE_SAG_ISO_B_neckclean.nii -B

# %%
# use NewSegment from spm to segment unimportant anatomical landmarks and perform "brain-extraction" (TEST FED006)
#for i in images.keys(): use this when ready to segment full subject list

# classify tissues from tpm.nii
# need to perform segmentation with full tissue information, or brain will be classified as "soft tissue" etc. -> see examples in "/VBM/FED006/"
tissue1 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 1), 2, (True,True), (False, False)) # GM
tissue2 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 2), 2, (True,True), (False, False)) # WM
tissue3 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 3), 2, (True,True), (False, False)) # CSF
tissue4 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 4), 2, (False,False), (False, False)) # bone
tissue5 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 5), 2, (False,False), (False, False)) # soft tissue
tissue6 = (('/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii', 6), 2, (False,False), (False, False)) # air and background

# create SKULLSTRIP segment nodes for each subject
for i in images_T1.keys():
    segm_skullstrip_T1=Node(spm.preprocess.NewSegment(), name='segm_skullstrip_T1')
    segm_skullstrip_T1.inputs.tissues=[tissue1, tissue2, tissue3, tissue4, tissue5, tissue6]
    # do not generate SPM8 and higher compatible jobs
    segm_skullstrip_T1.inputs.use_v8struct=False
    segm_skullstrip_T1.inputs.affine_regularization='none'
    # write forward and inverse deformation fields
    #segm_skullstrip_T1.inputs.write_deformation_fields=[True, True]
    # establish input files from subject
    segm_skullstrip_T1.inputs.channel_files=images_T1[i]
    # establish basedir for output of subject node
    for j in subdirs:
        if j.rsplit('/', 1)[1]==i:
            segm_skullstrip_T1.base_dir=j
    results=segm_skullstrip_T1.run()
    print(results.outputs)
# Out:
# 200109-12:58:20,555 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED009/segm_skullstrip_T1".
# 200109-12:58:20,562 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:02:05,551 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED009/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], ['/VBM/FED009/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], ['/VBM/FED009/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED009/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], ['/VBM/FED009/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], ['/VBM/FED009/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED009/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5_seg8.mat
#
# 200109-13:02:05,557 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED010/segm_skullstrip_T1".
# 200109-13:02:05,563 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:05:49,490 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED010/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], ['/VBM/FED010/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], ['/VBM/FED010/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED010/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], ['/VBM/FED010/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], ['/VBM/FED010/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED010/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119091904_5_seg8.mat
#
# 200109-13:05:49,495 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED011/segm_skullstrip_T1".
# 200109-13:05:49,503 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:09:32,803 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED011/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], ['/VBM/FED011/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], ['/VBM/FED011/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED011/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], ['/VBM/FED011/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], ['/VBM/FED011/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED011/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141119161708_5_seg8.mat
#
# 200109-13:09:32,807 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED012/segm_skullstrip_T1".
# 200109-13:09:32,812 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:13:01,930 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED012/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], ['/VBM/FED012/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], ['/VBM/FED012/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED012/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], ['/VBM/FED012/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], ['/VBM/FED012/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED012/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5_seg8.mat
#
# 200109-13:13:01,934 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED013/segm_skullstrip_T1".
# 200109-13:13:01,940 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:16:46,611 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED013/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], ['/VBM/FED013/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], ['/VBM/FED013/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED013/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], ['/VBM/FED013/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], ['/VBM/FED013/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED013/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5_seg8.mat
#
# 200109-13:16:46,616 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED014/segm_skullstrip_T1".
# 200109-13:16:46,622 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:21:43,56 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED014/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], ['/VBM/FED014/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], ['/VBM/FED014/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED014/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], ['/VBM/FED014/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], ['/VBM/FED014/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED014/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125153216_5_seg8.mat
#
# 200109-13:21:43,61 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED015/segm_skullstrip_T1".
# 200109-13:21:43,67 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:25:39,850 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED015/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], ['/VBM/FED015/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], ['/VBM/FED015/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED015/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], ['/VBM/FED015/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], ['/VBM/FED015/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED015/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5_seg8.mat
#
# 200109-13:25:39,854 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED016/segm_skullstrip_T1".
# 200109-13:25:39,860 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:29:30,427 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED016/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], ['/VBM/FED016/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], ['/VBM/FED016/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED016/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], ['/VBM/FED016/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], ['/VBM/FED016/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED016/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5_seg8.mat
#
# 200109-13:29:30,431 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED017/segm_skullstrip_T1".
# 200109-13:29:30,439 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:33:17,144 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED017/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], ['/VBM/FED017/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], ['/VBM/FED017/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED017/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], ['/VBM/FED017/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], ['/VBM/FED017/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED017/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5_seg8.mat
#
# 200109-13:33:17,149 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED018/segm_skullstrip_T1".
# 200109-13:33:17,155 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:37:37,818 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED018/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], ['/VBM/FED018/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], ['/VBM/FED018/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED018/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], ['/VBM/FED018/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], ['/VBM/FED018/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED018/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141208163153_5_seg8.mat
#
# 200109-13:37:37,822 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED019/segm_skullstrip_T1".
# 200109-13:37:37,829 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:41:22,947 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED019/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], ['/VBM/FED019/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], ['/VBM/FED019/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED019/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], ['/VBM/FED019/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], ['/VBM/FED019/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED019/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5_seg8.mat
#
# 200109-13:41:22,953 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED020/segm_skullstrip_T1".
# 200109-13:41:22,959 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:44:56,950 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED020/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], ['/VBM/FED020/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], ['/VBM/FED020/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED020/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], ['/VBM/FED020/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], ['/VBM/FED020/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED020/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5_seg8.mat
#
# 200109-13:44:56,955 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED021/segm_skullstrip_T1".
# 200109-13:44:56,961 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:49:17,328 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED021/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], ['/VBM/FED021/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], ['/VBM/FED021/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED021/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], ['/VBM/FED021/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], ['/VBM/FED021/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED021/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211095930_5_seg8.mat
#
# 200109-13:49:17,333 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED022/segm_skullstrip_T1".
# 200109-13:49:17,344 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:52:53,277 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED022/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], ['/VBM/FED022/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], ['/VBM/FED022/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED022/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], ['/VBM/FED022/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], ['/VBM/FED022/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED022/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141211155503_5_seg8.mat
#
# 200109-13:52:53,281 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED023/segm_skullstrip_T1".
# 200109-13:52:53,287 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-13:56:46,873 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED023/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], ['/VBM/FED023/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], ['/VBM/FED023/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED023/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], ['/VBM/FED023/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], ['/VBM/FED023/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED023/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141216144604_5_seg8.mat
#
# 200109-13:56:46,878 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED024/segm_skullstrip_T1".
# 200109-13:56:46,884 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-14:01:02,453 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED024/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], ['/VBM/FED024/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], ['/VBM/FED024/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED024/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], ['/VBM/FED024/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], ['/VBM/FED024/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED024/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150204145018_5_seg8.mat
#
# 200109-14:01:02,457 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED025/segm_skullstrip_T1".
# 200109-14:01:02,465 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-14:04:58,425 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED025/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], ['/VBM/FED025/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], ['/VBM/FED025/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED025/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], ['/VBM/FED025/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], ['/VBM/FED025/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED025/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150206123507_5_seg8.mat
#
# 200109-14:04:58,431 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED026/segm_skullstrip_T1".
# 200109-14:04:58,437 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-14:08:54,397 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED026/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], ['/VBM/FED026/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], ['/VBM/FED026/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED026/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], ['/VBM/FED026/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], ['/VBM/FED026/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED026/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150211171144_5_seg8.mat
#
# 200109-14:08:54,402 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED027/segm_skullstrip_T1".
# 200109-14:08:54,409 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-14:12:47,519 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED027/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20150218162601_
nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED063/segm_skullstrip_T1".
# 200109-16:22:38,775 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:26:26,817 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED063/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], ['/VBM/FED063/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], ['/VBM/FED063/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED063/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], ['/VBM/FED063/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], ['/VBM/FED063/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED063/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160308162043_5_seg8.mat
#
# 200109-16:26:26,822 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED064/segm_skullstrip_T1".
# 200109-16:26:26,829 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:29:55,375 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED064/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], ['/VBM/FED064/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], ['/VBM/FED064/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED064/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], ['/VBM/FED064/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], ['/VBM/FED064/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED064/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160309173936_5_seg8.mat
#
# 200109-16:29:55,380 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED065/segm_skullstrip_T1".
# 200109-16:29:55,385 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:33:35,979 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED065/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], ['/VBM/FED065/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], ['/VBM/FED065/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED065/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], ['/VBM/FED065/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], ['/VBM/FED065/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED065/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310090712_5_seg8.mat
#
# 200109-16:33:35,984 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED066/segm_skullstrip_T1".
# 200109-16:33:35,989 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:37:30,337 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED066/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], ['/VBM/FED066/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], ['/VBM/FED066/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED066/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], ['/VBM/FED066/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], ['/VBM/FED066/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED066/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160310171152_5_seg8.mat
#
# 200109-16:37:30,341 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED067/segm_skullstrip_T1".
# 200109-16:37:30,347 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:41:10,117 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED067/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], ['/VBM/FED067/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], ['/VBM/FED067/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED067/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], ['/VBM/FED067/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], ['/VBM/FED067/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED067/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160311133810_5_seg8.mat
#
# 200109-16:41:10,121 nipype.workflow INFO:
# 	 [Node] Setting-up "segm_skullstrip_T1" in "/VBM/FED068/segm_skullstrip_T1".
# 200109-16:41:10,127 nipype.workflow INFO:
# 	 [Node] Running "segm_skullstrip_T1" ("nipype.interfaces.spm.preprocess.NewSegment")
# 200109-16:44:43,936 nipype.workflow INFO:
# 	 [Node] Finished "segm_skullstrip_T1".
#
# bias_corrected_images = <undefined>
# bias_field_images = <undefined>
# dartel_input_images = [['/VBM/FED068/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], ['/VBM/FED068/segm_skullstrip_T1/rc2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], ['/VBM/FED068/segm_skullstrip_T1/rc3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], [], [], []]
# forward_deformation_field = <undefined>
# inverse_deformation_field = <undefined>
# modulated_class_images = [[], [], [], [], [], []]
# native_class_images = [['/VBM/FED068/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], ['/VBM/FED068/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], ['/VBM/FED068/segm_skullstrip_T1/c3T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5.nii'], [], [], []]
# normalized_class_images = [[], [], [], [], [], []]
# transformation_mat = /VBM/FED068/segm_skullstrip_T1/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20160331140317_5_seg8.mat

# %%
# get segmentation directory for each subject

# define start of segmentation directory name
targetnode="segm"
taskdirs={}

for i in images_T1.keys():
    for j in subdirs:
        # match keys with subdir list
        if j == i: 
            for k in os.listdir(j):
                # go through content of subdirs and look for "true" directories
                if os.path.isdir(os.path.join(j, k)):
                    # regex functions match=exact match of pattern, search=finds elements that contain pattern
                    # regex matches entries in j with targetnode k
                    match=re.match(r'(' + targetnode + ').*', k)
                    # ? This is needed to recognize the attribute group from the regex output
                    if match: 
                        taskdirs[j]=os.path.join(j, match.group(0))

# %% [markdown]
# create GM template using SPM DARTEL

# %%
# split taskdirs in control and depressed

# define and load from .xls(x) files
sub_control_ID="FED_Subject_Assignments.xlsx"
control_ID=pd.read_excel(sub_control_ID, sheet_name="Sheet2").astype(str)
ID=control_ID['Sub Num FED_XXX'].str.zfill(3).tolist()
status=control_ID['0 = Control'].tolist()

control_taskdir={}
depress_taskdir={}

for i in taskdirs.keys():
    for x,y in zip(ID,status):
        if i.rsplit('/',1)[1] == "FED"+x and y == "0":
            control_taskdir[i]=taskdirs[i]

for i in taskdirs.keys():
    if i not in control_taskdir.keys():
        depress_taskdir[i]=taskdirs[i]

# check dicts
print(control_taskdir.keys())
print(depress_taskdir.keys())
# see, if sizes are about equal
print(len(control_taskdir.keys()), len(depress_taskdir.keys()))
# Out:
# dict_keys(['/VBM/FED006', '/VBM/FED007', '/VBM/FED008', '/VBM/FED009', '/VBM/FED012', '/VBM/FED013', '/VBM/FED015', '/VBM/FED016', '/VBM/FED017', '/VBM/FED019', '/VBM/FED020', '/VBM/FED021', '/VBM/FED022', '/VBM/FED023', '/VBM/FED024', '/VBM/FED025', '/VBM/FED026', '/VBM/FED049', '/VBM/FED053', '/VBM/FED054', '/VBM/FED056', '/VBM/FED058', '/VBM/FED060', '/VBM/FED061', '/VBM/FED062', '/VBM/FED063', '/VBM/FED064', '/VBM/FED067', '/VBM/FED068'])
# dict_keys(['/VBM/FED010', '/VBM/FED011', '/VBM/FED014', '/VBM/FED018', '/VBM/FED027', '/VBM/FED028', '/VBM/FED029', '/VBM/FED030', '/VBM/FED031', '/VBM/FED032', '/VBM/FED033', '/VBM/FED034', '/VBM/FED035', '/VBM/FED036', '/VBM/FED037', '/VBM/FED038', '/VBM/FED039', '/VBM/FED040', '/VBM/FED041', '/VBM/FED042', '/VBM/FED043', '/VBM/FED044', '/VBM/FED045', '/VBM/FED046', '/VBM/FED047', '/VBM/FED048', '/VBM/FED050', '/VBM/FED051', '/VBM/FED052', '/VBM/FED055', '/VBM/FED057', '/VBM/FED059', '/VBM/FED065', '/VBM/FED066'])
# 29 34

# %%
# create template dict
# collect random keys (29 from each group)

# only 29 controls, so take all into template
template_dirs=control_taskdir.copy()
keys=random.sample(list(depress_taskdir), 29)
# integrate both dicts for template_dirs
for i in keys:
    template_dirs[i]=depress_taskdir[i]

# get rc1 and rc2 files as path-like objects
rc1=[]
rc2=[]
# append files to lists
for k,v in template_dirs.items():
    for i in os.listdir(v):
        # look for rc1(GM)
        match1=re.match(r'(^rc1.*.nii)', i)
        if match1:
            rc1.append(os.path.join(v, match1.group(0)))
        # look for rc2(WM)
        match2=re.match(r'(^rc2.*.nii)', i)
        if match2:
            rc2.append(os.path.join(v, match2.group(0)))
# print lists
print(rc1, len(rc1))
print(rc2, len(rc2))
# Out:
# ['/VBM/FED006/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141106153429_5.nii', '/VBM/FED007/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141107104226_5.nii', '/VBM/FED008/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141112155009_5.nii', '/VBM/FED009/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141117154954_5.nii', '/VBM/FED012/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141124150148_5.nii', '/VBM/FED013/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141125093955_5.nii', '/VBM/FED015/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202145526_5.nii', '/VBM/FED016/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141202164821_5.nii', '/VBM/FED017/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141204151043_5.nii', '/VBM/FED019/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210090147_5.nii', '/VBM/FED020/segm_skullstrip_T1/rc1T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141210170232_5.n
# 	 [Node] Setting-up "dartel_template" in "/VBM/dartel_template".
# 200114-15:39:53,705 nipype.workflow INFO:
# 	 [Node] Running "dartel_template" ("nipype.interfaces.spm.preprocess.DARTEL")
# 200114-18:02:43,883 nipype.workflow INFO:
# 	 [Node] Finished "dartel_template".

# %% [markdown]
# normalise to MNI space

# %%
# get required file lists and check that theyre in the same order

# deformation flowfields from nonlinear registration
flowfields=[]
# GM and WM 
c1=[]
c2=[]

# append files to lists
# flowfields
finaltemplate_dir="/VBM/dartel_template/"
for i in os.listdir(finaltemplate_dir):
    # look for u_rc1
    match=re.match(r'(^u_rc1.*.nii)', i)
    if match:
        flowfields.append(os.path.join(finaltemplate_dir, match.group(0)))

# check flowfields against subject T1 images to see 
# which were picked to create the template
flowfields_matched={}
for k,v in images_T1.items():
    for i in flowfields:
        # if cropped u_rc1T1 and T1 overlap via sequence and reg-number,
        # associate FEDXXX to flowfields-value
            if i.rsplit('/',1)[1][5:48] == v.rsplit('/',1)[1][0:43]:
                flowfields_matched[k]=i

# bring matches into sorted order for final list
flowfields=[]
for k,v in flowfields_matched.items():
    flowfields.append(v)
    

# GM and WM
# create dict where flowfields_matched and taskdirs(segmentation) overlap
intemplate_dirs={}
for i in flowfields_matched.keys():
    for k,v in taskdirs.items():
        if i == k:
            intemplate_dirs[i]=v

# fill c1 and c2 lists
for k,v in intemplate_dirs.items():
    for i in os.listdir(v):
        # look for c1(GM)
        match1=re.match(r'(^c1.*.nii)', i)
        if match1:
            c1.append(os.path.join(v, match1.group(0)))
        # look for c2(WM)
        match2=re.match(r'(^c2.*.nii)', i)
        if match2:
            c2.append(os.path.join(v, match2.group(0)))

# %%
# check flowfields_matched
print(flowfields_matched.keys())
# Out:
# dict_keys(['/VBM/FED006', '/VBM/FED007', '/VBM/FED008', '/VBM/FED009', '/VBM/FED011', '/VBM/FED012', '/VBM/FED013', '/VBM/FED014', '/VBM/FED015', '/VBM/FED016', '/VBM/FED017', '/VBM/FED018', '/VBM/FED019', '/VBM/FED020', '/VBM/FED021', '/VBM/FED022', '/VBM/FED023', '/VBM/FED024', '/VBM/FED025', '/VBM/FED026', '/VBM/FED027', '/VBM/FED028', '/VBM/FED029', '/VBM/FED030', '/VBM/FED031', '/VBM/FED032', '/VBM/FED033', '/VBM/FED034', '/VBM/FED035', '/VBM/FED036', '/VBM/FED037', '/VBM/FED038', '/VBM/FED039', '/VBM/FED040', '/VBM/FED042', '/VBM/FED043', '/VBM/FED045', '/VBM/FED046', '/VBM/FED048', '/VBM/FED049', '/VBM/FED050', '/VBM/FED051', '/VBM/FED053', '/VBM/FED054', '/VBM/FED055', '/VBM/FED056', '/VBM/FED057', '/VBM/FED058', '/VBM/FED059', '/VBM/FED060', '/VBM/FED061', '/VBM/FED062', '/VBM/FED063', '/VBM/FED064', '/VBM/FED065', '/VBM/FED066', '/VBM/FED067', '/VBM/FED068'])

# %%
# check lists order
print(flowfields[0:3])
print(c1[0:3])
print(c2[0:3])
# Out:
# ['/VBM/dartel_template/u_rc1T1_MPRAGE_SAG_ISO_0_9_0005_20141106153429_5_FED_ConDepr-grouptemplate.nii', '/VBM/dartel_template/u_rc1T1_MPRAGE_SAG_ISO_0_9_0005_20141107104226_5_FED_ConDepr-grouptemplate.nii', '/VBM/dartel_template/u_rc1T1_MPRAGE_SAG_ISO_0_9_0005_20141112155009_5_FED_ConDepr-grouptemplate.nii']
# ['/VBM/FED006/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_20141106153429_5.nii', '/VBM/FED007/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_20141107104226_5.nii', '/VBM/FED008/segm_skullstrip_T1/c1T1_MPRAGE_SAG_ISO_0_9_0005_20141112155009_5.nii']
# ['/VBM/FED006/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_20141106153429_5.nii', '/VBM/FED007/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_20141107104226_5.nii', '/VBM/FED008/segm_skullstrip_T1/c2T1_MPRAGE_SAG_ISO_0_9_0005_20141112155009_5.nii']

# %%
# create DARTEL node to norm2MNI for Gm and WM
tissues={"c1": c1, "c2": c2}
for k,v in tissues.items():
    dartel_norm2mni=Node(spm.DARTELNorm2MNI(), name='dartel_norm2mni_'+str(k))
    dartel_norm2mni.inputs.template_file =str(finaltemplate_dir)+"FED_ConDepr-grouptemplate_6.nii"
    dartel_norm2mni.inputs.flowfield_files = flowfields
    dartel_norm2mni.inputs.apply_to_files = v
    dartel_norm2mni.inputs.modulate = True
    dartel_norm2mni.base_dir="/VBM"
    # think about smoothing kernel below ... ROI sizes?
    #dartel_norm2mni.inputs.fwhm =
    # do not generate SPM8 and higher compatible jobs
    dartel_norm2mni.inputs.use_v8struct=False
    results=dartel_norm2mni.run()
# Out:
# 200115-16:22:19,251 nipype.workflow INFO:
# 	 [Node] Setting-up "dartel_norm2mni_c1" in "/VBM/dartel_norm2mni_c1".
# 200115-16:22:19,278 nipype.workflow INFO:
# 	 [Node] Running "dartel_norm2mni_c1" ("nipype.interfaces.spm.preprocess.DARTELNorm2MNI")
# 200115-16:28:35,843 nipype.workflow INFO:
# 	 [Node] Finished "dartel_norm2mni_c1".
# 200115-16:28:35,850 nipype.workflow INFO:
# 	 [Node] Setting-up "dartel_norm2mni_c2" in "/VBM/dartel_norm2mni_c2".
# 200115-16:28:35,875 nipype.workflow INFO:
# 	 [Node] Running "dartel_norm2mni_c2" ("nipype.interfaces.spm.preprocess.DARTELNorm2MNI")
# 200115-16:34:48,271 nipype.workflow INFO:
# 	 [Node] Finished "dartel_norm2mni_c2".

# %% [markdown]
# Testing Zone:

# %%
# check lists order (function^^)
regex=re.compile('\d{14}')
for i in list(flowfields,c1,c2):
    nums=list(filter(regex.match, i))
# Out:
# <built-in method groupdict of re.Match object at 0x7fccfc286f30>
# <built-in method groupdict of re.Match object at 0x7fccfc128990>
# <built-in method groupdict of re.Match object at 0x7fccfc128a80>
# <built-in method groupdict of re.Match object at 0x7fccfc1287b0>
# <built-in method groupdict of re.Match object at 0x7fccfc0d7c60>
# <built-in method groupdict of re.Match object at 0x7fccfc0d7e40>
# <built-in method groupdict of re.Match object at 0x7fccfc0d76c0>
# <built-in method groupdict of re.Match object at 0x7fccfc0d7be8>
# <built-in method groupdict of re.Match object at 0x7fccfc0d7d50>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4648>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4558>
# <built-in method groupdict of re.Match object at 0x7fccfbdc46c0>
# <built-in method groupdict of re.Match object at 0x7fccfbdc43f0>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4120>
# <built-in method groupdict of re.Match object at 0x7fccfbdc40a8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4198>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4030>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4288>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4210>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4468>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4300>
# <built-in method groupdict of re.Match object at 0x7fccfbdc44e0>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4828>
# <built-in method groupdict of re.Match object at 0x7fccfbdc47b0>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4738>
# <built-in method groupdict of re.Match object at 0x7fccfbdc48a0>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4990>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4918>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4a08>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4a80>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4af8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4b70>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4be8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4c60>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4cd8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4d50>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4dc8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4e40>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4eb8>
# <built-in method groupdict of re.Match object at 0x7fccfbdc4f30>
# <built-in method groupdict of re.Match object at 0x7fccfba12030>
# <built-in method groupdict of re.Match object at 0x7fccfba120a8>
# <built-in method groupdict of re.Match object at 0x7fccfba12120>
# <built-in method groupdict of re.Match object at 0x7fccfba12198>
# <built-in method groupdict of re.Match object at 0x7fccfba12210>
# <built-in method groupdict of re.Match object at 0x7fccfba12288>
# <built-in method groupdict of re.Match object at 0x7fccfba12300>
# <built-in method groupdict of re.Match object at 0x7fccfba12378>
# <built-in method groupdict of re.Match object at 0x7fccfba123f0>
# <built-in method groupdict of re.Match object at 0x7fccfba12468>
# <built-in method groupdict of re.Match object at 0x7fccfba124e0>
# <built-in method groupdict of re.Match object at 0x7fccfba12558>
# <built-in method groupdict of re.Match object at 0x7fccfba125d0>
# <built-in method groupdict of re.Match object at 0x7fccfba12648>
# <built-in method groupdict of re.Match object at 0x7fccfba126c0>
# <built-in method groupdict of re.Match object at 0x7fccfba12738>
# <built-in method groupdict of re.Match object at 0x7fccfba127b0>
# <built-in method groupdict of re.Match object at 0x7fccfba12828>

# %%
# crop down images for testing (only FED006,07,08!!!)
images2=dict()
for i in sorted(images.keys())[0:3]:
    images2[i]=images[i]
    
print(images2.items())
# Out:
# dict_items([('FED006', '/VBM/FED006/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141106153429_5.nii'), ('FED007', '/VBM/FED007/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141107104226_5.nii'), ('FED008', '/VBM/FED008/T1_MPRAGE_SAG_ISO_0_9_0005_t1_mprage_sag_iso_0.9_20141112155009_5.nii')])

# %%
# perform operations on images using fslmaths
from nipype.interfaces.fsl import ImageMaths

# %%
# %%bash
# # check if operator -mul is even appropriate in this case
# fslmaths -h
# Out:
# Usage: fslmaths [-dt <datatype>] <first_input> [operations and inputs] <output> [-odt <datatype>]
#
# Datatype information:
#  -dt sets the datatype used internally for calculations (default float for all except double images)
#  -odt sets the output datatype ( default is float )
#  Possible datatypes are: char short int float double input
#  "input" will set the datatype to that of the original image
#
# Binary operations:
#   (some inputs can be either an image or a number)
#  -add   : add following input to current image
#  -sub   : subtract following input from current image
#  -mul   : multiply current image by following input
#  -div   : divide current image by following input
#  -rem   : modulus remainder - divide current image by following input and take remainder
#  -mas   : use (following image>0) to mask current image
#  -thr   : use following number to threshold current image (zero anything below the number)
#  -thrp  : use following percentage (0-100) of ROBUST RANGE to threshold current image (zero anything below the number)
#  -thrP  : use following percentage (0-100) of ROBUST RANGE of non-zero voxels and threshold below
#  -uthr  : use following number to upper-threshold current image (zero anything above the number)
#  -uthrp : use following percentage (0-100) of ROBUST RANGE to upper-threshold current image (zero anything above the number)
#  -uthrP : use following percentage (0-100) of ROBUST RANGE of non-zero voxels and threshold above
#  -max   : take maximum of following input and current image
#  -min   : take minimum of following input and current image
#  -seed  : seed random number generator with following number
#  -restart : replace the current image with input for future processing operations
#  -save : save the current working image to the input filename
#
# Basic unary operations:
#  -exp   : exponential
#  -log   : natural logarithm
#  -sin   : sine function
#  -cos   : cosine function
#  -tan   : tangent function
#  -asin  : arc sine function
#  -acos  : arc cosine function
#  -atan  : arc tangent function
#  -sqr   : square
#  -sqrt  : square root
#  -recip : reciprocal (1/current image)
#  -abs   : absolute value
#  -bin   : use (current image>0) to binarise
#  -binv  : binarise and invert (binarisation and logical inversion)
#  -fillh : fill holes in a binary mask (holes are internal - i.e. do not touch the edge of the FOV)
#  -fillh26 : fill holes using 26 connectivity
#  -index : replace each nonzero voxel with a unique (subject to wrapping) index number
#  -grid <value> <spacing> : add a 3D grid of intensity <value> with grid spacing <spacing>
#  -edge  : edge strength
#  -tfce <H> <E> <connectivity>: enhance with TFCE, e.g. -tfce 2 0.5 6 (maybe change 6 to 26 for skeletons)
#  -tfceS <H> <E> <connectivity> <X> <Y> <Z> <tfce_thresh>: show support area for voxel (X,Y,Z)
#  -nan   : replace NaNs (improper numbers) with 0
#  -nanm  : make NaN (improper number) mask with 1 for NaN voxels, 0 otherwise
#  -rand  : add uniform noise (range 0:1)
#  -randn : add Gaussian noise (mean=0 sigma=1)
#  -inm <mean> :  (-i i ip.c) intensity normalisation (per 3D volume mean)
#  -ing <mean> :  (-I i ip.c) intensity normalisation, global 4D mean)
#  -range : set the output calmin/max to full data range
#
# Matrix operations:
#  -tensor_decomp : convert a 4D (6-timepoint )tensor image into L1,2,3,FA,MD,MO,V1,2,3 (remaining image in pipeline is FA)
#
# Kernel operations (set BEFORE filtering operation if desired):
#  -kernel 3D : 3x3x3 box centered on target voxel (set as default kernel)
#  -kernel 2D : 3x3x1 box centered on target voxel
#  -kernel box    <size>     : all voxels in a cube of width <size> mm centered on target voxel
#  -kernel boxv   <size>     : all voxels in a cube of width <size> voxels centered on target voxel, CAUTION: size should be an odd number
#  -kernel boxv3  <X> <Y> <Z>: all voxels in a cuboid of dimensions X x Y x Z centered on target voxel, CAUTION: size should be an odd number
#  -kernel gauss  <sigma>    : gaussian kernel (sigma in mm, not voxels)
#  -kernel sphere <size>     : all voxels in a sphere of radius <size> mm centered on target voxel
#  -kernel file   <filename> : use external file as kernel
#
# Spatial Filtering operations: N.B. all options apart from -s use the default kernel or that _previously_ specified by -kernel
#  -dilM    : Mean Dilation of non-zero voxels
#  -dilD    : Modal Dilation of non-zero voxels
#  -dilF    : Maximum filtering of all voxels
#  -dilall  : Apply -dilM repeatedly until the entire FOV is covered
#  -ero     : Erode by zeroing non-zero voxels when zero voxels found in kernel
#  -eroF    : Minimum filtering of all voxels
#  -fmedian : Median Filtering
#  -fmean   : Mean filtering, kernel weighted (conventionally used with gauss kernel)
#  -fmeanu  : Mean filtering, kernel weighted, un-normalised (gives edge effects)
#  -s <sigma> : create a gauss kernel of sigma mm and perform mean filtering
#  -subsamp2  : downsamples image by a factor of 2 (keeping new voxels centred on old)
#  -subsamp2offc  : downsamples image by a factor of 2 (non-centred)
#
# Dimensionality reduction operations:
#   (the "T" can be replaced by X, Y or Z to collapse across a different dimension)
#  -Tmean   : mean across time
#  -Tstd    : standard deviation across time
#  -Tmax    : max across time
#  -Tmaxn   : time index of max across time
#  -Tmin    : min across time
#  -Tmedian : median across time
#  -Tperc <percentage> : nth percentile (0-100) of FULL RANGE across time
#  -Tar1    : temporal AR(1) coefficient (use -odt float and probably demean first)
#
# Basic statistical operations:
#  -pval    : Nonparametric uncorrected P-value, assuming timepoints are the permutations; first timepoint is actual (unpermuted) stats image
#  -pval0   : Same as -pval, but treat zeros as missing data
#  -cpval   : Same as -pval, but gives FWE corrected P-values
#  -ztop    : Convert Z-stat to (uncorrected) P
#  -ptoz    : Convert (uncorrected) P to Z
#  -rank    : Convert data to ranks (over T dim)
#  -ranknorm: Transform to Normal dist via ranks
#
# Multi-argument operations:
#  -roi <xmin> <xsize> <ymin> <ysize> <zmin> <zsize> <tmin> <tsize> : zero outside roi (using voxel coordinates). Inputting -1 for a size will set it to the full image extent for that dimension.
#  -bptf  <hp_sigma> <lp_sigma> : (-t in ip.c) Bandpass temporal filtering; nonlinear highpass and Gaussian linear lowpass (with sigmas in volumes, not seconds); set either sigma<0 to skip that filter
#  -roc <AROC-thresh> <outfile> [4Dnoiseonly] <truth> : take (normally binary) truth and test current image in ROC analysis against truth. <AROC-thresh> is usually 0.05 and is limit of Area-under-ROC measure FP axis. <outfile> is a text file of the ROC curve (triplets of values: FP TP threshold). If the truth image contains negative voxels these get excluded from all calculations. If <AROC-thresh> is positive then the [4Dnoiseonly] option needs to be set, and the FP rate is determined from this noise-only data, and is set to be the fraction of timepoints where any FP (anywhere) is seen, as found in the noise-only 4d-dataset. This is then controlling the FWE rate. If <AROC-thresh> is negative the FP rate is calculated from the zero-value parts of the <truth> image, this time averaging voxelwise FP rate over all timepoints. In both cases the TP rate is the average fraction of truth=positive voxels correctly found.
#
# Combining 4D and 3D images:
#  If you apply a Binary operation (one that takes the current image and a new image together), when one is 3D and the other is 4D,
#  the 3D image is cloned temporally to match the temporal dimensions of the 4D image.
#
# e.g. fslmaths inputVolume -add inputVolume2 output_volume
#      fslmaths inputVolume -add 2.5 output_volume
#      fslmaths inputVolume -add 2.5 -mul inputVolume2 output_volume
#
#      fslmaths 4D_inputVolume -Tmean -mul -1 -add 4D_inputVolume demeaned_4D_inputVolume
