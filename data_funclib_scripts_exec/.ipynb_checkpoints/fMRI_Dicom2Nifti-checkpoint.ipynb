# %% [markdown]
# # Convert DICOM to NIFTI

# %% [markdown]
# Gather necessary pre-requisites

# %%
# import everything you need
from nipype.interfaces.dcm2nii import Dcm2niix
from nipype import Node, Workflow
import os, re

# %%
# define useful functions
# get subject directories from parent directory
def get_subdirs(dir):
    """get subject directories from parent directory"""
    subdirs = []
    for i in os.listdir(dir):
        # verify subject number in directory and exclude other dirs
        if (os.path.isdir(os.path.join(dir, i))
        and re.match(r'(.*\d{3}$)', i)):
            subdirs.append(os.path.join(dir, i))
    return sorted(subdirs)

# get iterator to go over multiple objects at once
def grouped(iterable, n):
    """get iterator to go over multiple objects at once"""
    "s -> (s0,s1,s2,...sn-1), (sn,sn+1,sn+2,...s2n-1), (s2n,s2n+1,s2n+2,...s3n-1), ..."
    return zip(*[iter(iterable)] * n)

# %%
# get subject dir-list
subdirs = get_subdirs("/fMRI/")
print(subdirs)
print(len(subdirs))
# Out:
# ['/fMRI/FED006', '/fMRI/FED007', '/fMRI/FED008', '/fMRI/FED009', '/fMRI/FED010', '/fMRI/FED011', '/fMRI/FED012', '/fMRI/FED013', '/fMRI/FED014', '/fMRI/FED015', '/fMRI/FED016', '/fMRI/FED017', '/fMRI/FED018', '/fMRI/FED019', '/fMRI/FED020', '/fMRI/FED021', '/fMRI/FED022', '/fMRI/FED023', '/fMRI/FED024', '/fMRI/FED025', '/fMRI/FED026', '/fMRI/FED027', '/fMRI/FED028', '/fMRI/FED029', '/fMRI/FED030', '/fMRI/FED031', '/fMRI/FED032', '/fMRI/FED033', '/fMRI/FED034', '/fMRI/FED035', '/fMRI/FED036', '/fMRI/FED037', '/fMRI/FED038', '/fMRI/FED039', '/fMRI/FED040', '/fMRI/FED041', '/fMRI/FED042', '/fMRI/FED043', '/fMRI/FED044', '/fMRI/FED045', '/fMRI/FED046', '/fMRI/FED047', '/fMRI/FED048', '/fMRI/FED049', '/fMRI/FED050', '/fMRI/FED051', '/fMRI/FED052', '/fMRI/FED053', '/fMRI/FED054', '/fMRI/FED055', '/fMRI/FED056', '/fMRI/FED057', '/fMRI/FED058', '/fMRI/FED059', '/fMRI/FED060', '/fMRI/FED061', '/fMRI/FED062', '/fMRI/FED063', '/fMRI/FED064', '/fMRI/FED065', '/fMRI/FED066', '/fMRI/FED067', '/fMRI/FED068']
# 63

# %% [markdown]
# Select the required files

# %%
# get fMRI sequence dirs via subject lists
FMRIdirs = []
for i in subdirs:
    for j in os.listdir(i):
        if (os.path.isdir(os.path.join(i, j))
        and re.match(r'((WIP840|FMRI).*\d{4}$)', j)):
            FMRIdirs.append(os.path.join(i,j))

# get structural sequence dirs via subject lists
T1dirs = []
for i in subdirs:
    for j in os.listdir(i):
        if (os.path.isdir(os.path.join(i, j))
        and re.match(r'((T1_MPRAGE).*\d{4}$)', j)):
            T1dirs.append(os.path.join(i,j))

# same for gradient field maps
GREfielddirs = []
for i in subdirs:
    for j in os.listdir(i):
        if (os.path.isdir(os.path.join(i, j))
        and re.match(r'((GRE_FIELD).*\d{4}$)', j)):
            GREfielddirs.append(os.path.join(i, j))

# sort the list entries
FMRIdirs = sorted(FMRIdirs)
T1dirs = sorted(T1dirs)
GREfielddirs = sorted(GREfielddirs)

# define list for final task fMRI sequences
funcdirs = []
# extract the middle number of however many fMRI sequence dirs
# there are to select the functional runs
for i in subdirs:
    dirs = []
    for j in FMRIdirs:
        # match FED number and cpllect sequence directories per subject
        if i.rsplit('/', 1)[1] == j.rsplit('/', 2)[1]:
            dirs.append(j)
    # check list sizes and select task runs appropriately
    if len(dirs) == 3:
        # select middle as task
        print(i.rsplit('/', 1)[1], "selecting middle as task ...")
        funcdirs.append(sorted(dirs)[len(dirs) // 2])  # this will be rounded up
    elif len(dirs) == 2:
        # assume last RS to be missing
        print(i.rsplit('/', 1)[1], "selecting second as task (last RS likely missing) ...")
        funcdirs.append(sorted(dirs)[len(dirs) - 1])
    elif len(dirs) == 1:
        # assume only task
        print(i.rsplit('/', 1)[1], "selecting the only functional as task ...")
        funcdirs.append(sorted(dirs)[len(dirs) // 2])
    elif len(dirs) == 0:
        print(i.rsplit('/', 1)[1], "\n",
              "has no functional runs ... investigate")
    else:
        print("\n", i.rsplit('/', 1)[1], f"has more than 3({len(dirs)}) ",
              "functional runs ... investigate", "\n")
# Out:
# FED006 selecting middle as task ...
# FED007 selecting middle as task ...
# FED008 selecting middle as task ...
# FED009 selecting middle as task ...
# FED010 selecting second as task (last RS likely missing) ...
# FED011 selecting middle as task ...
# FED012 selecting middle as task ...
# FED013 selecting middle as task ...
# FED014 selecting middle as task ...
# FED015 selecting middle as task ...
# FED016 selecting middle as task ...
# FED017 selecting middle as task ...
# FED018 selecting middle as task ...
# FED019 selecting middle as task ...
# FED020 selecting middle as task ...
# FED021 selecting middle as task ...
# FED022 selecting middle as task ...
# FED023 selecting middle as task ...
# FED024 selecting middle as task ...
# FED025 selecting middle as task ...
# FED026 selecting middle as task ...
# FED027 selecting middle as task ...
# FED028 selecting middle as task ...
# FED029 selecting the only functional as task ...
#
#  FED030 has more than 3(5)  functional runs ... investigate
#
# FED031 selecting middle as task ...
# FED032 selecting second as task (last RS likely missing) ...
# FED033 selecting middle as task ...
# FED034 selecting middle as task ...
# FED035 selecting middle as task ...
# FED036 selecting middle as task ...
# FED037 selecting the only functional as task ...
# FED038 selecting middle as task ...
# FED039 selecting middle as task ...
# FED040 selecting middle as task ...
# FED041 selecting middle as task ...
# FED042 selecting middle as task ...
# FED043 selecting middle as task ...
# FED044 selecting middle as task ...
# FED045 selecting middle as task ...
# FED046 selecting middle as task ...
# FED047 selecting the only functional as task ...
# FED048 selecting middle as task ...
# FED049 selecting middle as task ...
# FED050 selecting second as task (last RS likely missing) ...
# FED051 selecting middle as task ...
#
#  FED052 has more than 3(4)  functional runs ... investigate
#
#
#  FED053 has more than 3(5)  functional runs ... investigate
#
# FED054 selecting middle as task ...
# FED055 selecting middle as task ...
# FED056 selecting middle as task ...
# FED057 selecting middle as task ...
# FED058 selecting middle as task ...
# FED059 selecting middle as task ...
# FED060 selecting middle as task ...
# FED061 selecting middle as task ...
# FED062 selecting middle as task ...
# FED063 selecting middle as task ...
# FED064 selecting middle as task ...
# FED065 selecting middle as task ...
# FED066 selecting middle as task ...
# FED067 selecting middle as task ...
# FED068 selecting middle as task ...

# %%
# manual correction for individual "problem subjects"
problem_sub = "FED053"
rep_string = "10"
for i in subdirs:
    dirs = []
    for j in FMRIdirs:
        # match FED number and collect sequence directories per subject
        if (re.match(fr'.*({problem_sub}).*', i)
            and re.match(fr'.*({problem_sub}).*', j)):
            # correct the sequence to the right parameters
            # by checking the last two digits of the sequence number
            if j[-2:] == rep_string:
                funcdirs.append(j)
            else:
                pass

# give the list a final sort
funcdirs = sorted(funcdirs)

# %%
# select the gradient fieldmaps
distcordirs = []
for i in subdirs:
    dirs = []
    for j in GREfielddirs:
        if i.rsplit('/', 1)[1] == j.rsplit('/', 2)[1]:
            dirs.append(j)
    # integrate dirs lists into one big list
    distcordirs.extend(sorted(dirs))

# %%
# distcordirs and subdirs have different lengths -> fix using re-matching
# (need more than one gradient fieldmaps per subject)
subdirs_corr = []
for i in subdirs:
    FEDnum = i.rsplit('/', 1)[1]
    for j in distcordirs:
        if re.match(fr'(.*{FEDnum}.*)', j):
            print(i, j)
            subdirs_corr.append(i)
# Out:
# /fMRI/FED006 /fMRI/FED006/GRE_FIELD_MAPPING_0006
# /fMRI/FED007 /fMRI/FED007/GRE_FIELD_MAPPING_0012
# /fMRI/FED007 /fMRI/FED007/GRE_FIELD_MAPPING_0013
# /fMRI/FED008 /fMRI/FED008/GRE_FIELD_MAPPING_0012
# /fMRI/FED008 /fMRI/FED008/GRE_FIELD_MAPPING_0020
# /fMRI/FED009 /fMRI/FED009/GRE_FIELD_MAPPING_0012
# /fMRI/FED009 /fMRI/FED009/GRE_FIELD_MAPPING_0020
# /fMRI/FED009 /fMRI/FED009/GRE_FIELD_MAPPING_0021
# /fMRI/FED010 /fMRI/FED010/GRE_FIELD_MAPPING_0010
# /fMRI/FED010 /fMRI/FED010/GRE_FIELD_MAPPING_0011
# /fMRI/FED011 /fMRI/FED011/GRE_FIELD_MAPPING_0016
# /fMRI/FED011 /fMRI/FED011/GRE_FIELD_MAPPING_0017
# /fMRI/FED012 /fMRI/FED012/GRE_FIELD_MAPPING_0006
# /fMRI/FED012 /fMRI/FED012/GRE_FIELD_MAPPING_0007
# /fMRI/FED013 /fMRI/FED013/GRE_FIELD_MAPPING_0006
# /fMRI/FED013 /fMRI/FED013/GRE_FIELD_MAPPING_0007
# /fMRI/FED014 /fMRI/FED014/GRE_FIELD_MAPPING_0010
# /fMRI/FED014 /fMRI/FED014/GRE_FIELD_MAPPING_0011
# /fMRI/FED015 /fMRI/FED015/GRE_FIELD_MAPPING_0006
# /fMRI/FED015 /fMRI/FED015/GRE_FIELD_MAPPING_0007
# /fMRI/FED016 /fMRI/FED016/GRE_FIELD_MAPPING_0006
# /fMRI/FED016 /fMRI/FED016/GRE_FIELD_MAPPING_0007
# /fMRI/FED017 /fMRI/FED017/GRE_FIELD_MAPPING_0012
# /fMRI/FED017 /fMRI/FED017/GRE_FIELD_MAPPING_0013
ED042', '/fMRI/FED042', '/fMRI/FED043', '/fMRI/FED043', '/fMRI/FED044', '/fMRI/FED044', '/fMRI/FED045', '/fMRI/FED045', '/fMRI/FED046', '/fMRI/FED046', '/fMRI/FED048', '/fMRI/FED048', '/fMRI/FED049', '/fMRI/FED049', '/fMRI/FED050', '/fMRI/FED050', '/fMRI/FED051', '/fMRI/FED051', '/fMRI/FED052', '/fMRI/FED052', '/fMRI/FED053', '/fMRI/FED053', '/fMRI/FED054', '/fMRI/FED054', '/fMRI/FED055', '/fMRI/FED055', '/fMRI/FED056', '/fMRI/FED056', '/fMRI/FED057', '/fMRI/FED057', '/fMRI/FED058', '/fMRI/FED058', '/fMRI/FED059', '/fMRI/FED059', '/fMRI/FED060', '/fMRI/FED060', '/fMRI/FED061', '/fMRI/FED061', '/fMRI/FED062', '/fMRI/FED062', '/fMRI/FED063', '/fMRI/FED063', '/fMRI/FED064', '/fMRI/FED064', '/fMRI/FED065', '/fMRI/FED065', '/fMRI/FED066', '/fMRI/FED066', '/fMRI/FED068', '/fMRI/FED068']
# 122

# %% [markdown]
# Convert .IMA files to NIFTI \
# Files need to have been softlinked to "/fMRI" from inside this container, otherwise Dcm2niix cannot read them!

# %%
# use sequence-list as source_dir and save output of converter in parent dir
# iterate over sequence and subject dirs, create nodes and run them to create NIFTI files
subjectdirs = [subdirs, subdirs, subdirs_corr]
sequencedirs = [funcdirs, T1dirs, distcordirs]

# adapt index in lists to specify which files to convert
for outdir, infile in zip(subjectdirs, sequencedirs):
    for d, f in zip(outdir, infile):
        print(d, f)
        # create DICOM-to-NIFTI converter node
        converter = Node(Dcm2niix(), name='converter')
        converter.inputs.compress = 'y'  # do compress -> saves space^^ GUNZIP for SPM options etc.
        converter.inputs.source_dir = f
        converter.inputs.output_dir = d
        converter.run()
# Out:
# /fMRI/FED006 /fMRI/FED006/WIP840_36SLICE_1800TR_FS_0009
# 210419-11:07:35,480 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpyu7q0cap/converter".
# 210419-11:07:35,485 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED006 -s n -v n /fMRI/FED006/WIP840_36SLICE_1800TR_FS_0009
# 210419-11:07:36,547 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:36.547736:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:07:36,549 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:36.547736:Found 280 DICOM file(s)
# 210419-11:07:36,549 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:36.547736:Convert 280 DICOM as /fMRI/FED006/WIP840_36SLICE_1800TR_FS_0009_WIP840_36slice_1800TR_fs_20141106153429_9 (72x68x36x280)
# 210419-11:07:45,156 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:45.156540:Conversion required 9.590433 seconds (9.196730 for core code).
# 210419-11:07:45,191 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED007 /fMRI/FED007/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:07:45,194 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp74mmxfhk/converter".
# 210419-11:07:45,198 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED007 -s n -v n /fMRI/FED007/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:07:46,172 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:46.172067:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:07:46,173 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:46.172067:Found 263 DICOM file(s)
# 210419-11:07:46,174 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:46.172067:Convert 263 DICOM as /fMRI/FED007/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141107104226_8 (72x68x36x263)
# 210419-11:07:53,370 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:53.370247:Conversion required 8.145402 seconds (7.731803 for core code).
# 210419-11:07:53,405 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED008 /fMRI/FED008/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:07:53,407 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp61zsg_uy/converter".
# 210419-11:07:53,412 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED008 -s n -v n /fMRI/FED008/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:07:54,374 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:54.374206:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:07:54,375 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:54.374206:Found 266 DICOM file(s)
# 210419-11:07:54,376 nipype.interface INFO:
# 	 stdout 2021-04-19T11:07:54.374206:Convert 266 DICOM as /fMRI/FED008/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141112155009_8 (72x68x36x266)
# 210419-11:08:01,527 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:01.527585:Conversion required 8.092726 seconds (7.697713 for core code).
# 210419-11:08:01,563 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED009 /fMRI/FED009/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:01,566 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4ytjtw1c/converter".
# 210419-11:08:01,571 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED009 -s n -v n /fMRI/FED009/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:02,576 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:02.576137:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:02,578 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:02.576137:Found 266 DICOM file(s)
# 210419-11:08:02,578 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:02.576137:Convert 266 DICOM as /fMRI/FED009/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141117154954_8 (72x68x36x266)
# 210419-11:08:10,404 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:10.404463:Conversion required 8.809887 seconds (8.410319 for core code).
# 210419-11:08:10,458 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED010 /fMRI/FED010/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:10,461 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmppdijxljt/converter".
# 210419-11:08:10,467 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED010 -s n -v n /fMRI/FED010/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:11,442 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:11.442474:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:11,444 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:11.442474:Found 269 DICOM file(s)
# 210419-11:08:11,444 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:11.442474:Convert 269 DICOM as /fMRI/FED010/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141119091904_8 (72x68x36x269)
# 210419-11:08:18,907 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:18.907556:Conversion required 8.411905 seconds (8.031894 for core code).
# 210419-11:08:18,944 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED011 /fMRI/FED011/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:18,946 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpvm3n1tyq/converter".
# 210419-11:08:18,951 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED011 -s n -v n /fMRI/FED011/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:08:19,934 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:19.934687:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:19,936 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:19.934687:Found 269 DICOM file(s)
# 210419-11:08:19,937 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:19.934687:Convert 269 DICOM as /fMRI/FED011/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141119161708_8 (72x68x36x269)
# 210419-11:08:27,546 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:27.546019:Conversion required 8.570228 seconds (8.162119 for core code).
# 210419-11:08:27,582 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED012 /fMRI/FED012/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:27,585 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp7h3hhfgj/converter".
# 210419-11:08:27,590 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED012 -s n -v n /fMRI/FED012/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:28,777 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:28.777470:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:28,779 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:28.777470:Found 264 DICOM file(s)
# 210419-11:08:28,779 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:28.777470:Convert 264 DICOM as /fMRI/FED012/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141124150148_10 (72x68x36x264)
# 210419-11:08:36,356 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:36.356647:Conversion required 8.739395 seconds (8.220689 for core code).
# 210419-11:08:36,394 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED013 /fMRI/FED013/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:36,397 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpyegbojjy/converter".
# 210419-11:08:36,402 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED013 -s n -v n /fMRI/FED013/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:37,384 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:37.384739:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:37,386 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:37.384739:Found 276 DICOM file(s)
# 210419-11:08:37,387 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:37.384739:Convert 276 DICOM as /fMRI/FED013/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141125093955_10 (72x68x36x276)
# 210419-11:08:45,72 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:45.072510:Conversion required 8.645553 seconds (8.251181 for core code).
# 210419-11:08:45,107 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED014 /fMRI/FED014/WIP840_36SLICE_1800TR_FS_0018
# 210419-11:08:45,110 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpw6079s4b/converter".
# 210419-11:08:45,114 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED014 -s n -v n /fMRI/FED014/WIP840_36SLICE_1800TR_FS_0018
# 210419-11:08:46,27 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:46.027534:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:46,29 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:46.027534:Found 272 DICOM file(s)
# 210419-11:08:46,30 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:46.027534:Convert 272 DICOM as /fMRI/FED014/WIP840_36SLICE_1800TR_FS_0018_WIP840_36slice_1800TR_fs_20141125153216_18 (72x68x36x272)
# 210419-11:08:53,571 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:53.571691:Conversion required 8.436586 seconds (8.054137 for core code).
# 210419-11:08:53,606 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED015 /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:53,608 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpbznx9k46/converter".
# 210419-11:08:53,613 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED015 -s n -v n /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:08:54,603 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:54.603313:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:08:54,604 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:54.603313:Found 273 DICOM file(s)
# 210419-11:08:54,606 nipype.interface INFO:
# 	 stdout 2021-04-19T11:08:54.603313:Convert 273 DICOM as /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141202145526_10 (72x68x36x273)
# 210419-11:09:02,595 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:02.595264:Conversion required 8.953134 seconds (8.564231 for core code).
# 210419-11:09:02,629 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED016 /fMRI/FED016/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:02,632 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4d9bysf6/converter".
# 210419-11:09:02,636 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED016 -s n -v n /fMRI/FED016/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:03,546 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:03.546611:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:03,548 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:03.546611:Found 264 DICOM file(s)
# 210419-11:09:03,549 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:03.546611:Convert 264 DICOM as /fMRI/FED016/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141202164821_10 (72x68x36x264)
# 210419-11:09:11,131 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:11.131833:Conversion required 8.476893 seconds (8.098670 for core code).
# 210419-11:09:11,166 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED017 /fMRI/FED017/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:09:11,168 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpswmbgw9v/converter".
# 210419-11:09:11,172 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED017 -s n -v n /fMRI/FED017/WIP840_36SLICE_1800TR_FS_0008
# 210419-11:09:12,338 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:12.338668:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:12,340 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:12.338668:Found 314 DICOM file(s)
# 210419-11:09:12,340 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:12.338668:Convert 314 DICOM as /fMRI/FED017/WIP840_36SLICE_1800TR_FS_0008_WIP840_36slice_1800TR_fs_20141204151043_8 (72x68x36x314)
# 210419-11:09:20,819 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:20.819213:Conversion required 9.629154 seconds (9.134782 for core code).
# 210419-11:09:20,853 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED018 /fMRI/FED018/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:20,855 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpqx1rzxwb/converter".
# 210419-11:09:20,859 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED018 -s n -v n /fMRI/FED018/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:21,820 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:21.820420:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:21,821 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:21.820420:Found 266 DICOM file(s)
# 210419-11:09:21,822 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:21.820420:Convert 266 DICOM as /fMRI/FED018/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141208163153_10 (68x72x36x266)
# 210419-11:09:28,818 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:28.818028:Conversion required 7.939746 seconds (7.539789 for core code).
# 210419-11:09:28,852 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED019 /fMRI/FED019/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:28,854 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmph04yc4k4/converter".
# 210419-11:09:28,859 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED019 -s n -v n /fMRI/FED019/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:29,823 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:29.823005:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:29,824 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:29.823005:Found 267 DICOM file(s)
# 210419-11:09:29,825 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:29.823005:Convert 267 DICOM as /fMRI/FED019/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141210090147_10 (72x68x36x267)
# 210419-11:09:36,930 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:36.930091:Conversion required 8.051043 seconds (7.671240 for core code).
# 210419-11:09:36,964 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED020 /fMRI/FED020/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:36,966 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpj18mezw_/converter".
# 210419-11:09:36,970 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED020 -s n -v n /fMRI/FED020/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:37,936 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:37.936378:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:37,938 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:37.936378:Found 278 DICOM file(s)
# 210419-11:09:37,938 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:37.936378:Convert 278 DICOM as /fMRI/FED020/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141210170232_10 (68x72x36x278)
# 210419-11:09:45,456 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:45.456925:Conversion required 8.469020 seconds (8.074833 for core code).
# 210419-11:09:45,490 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED021 /fMRI/FED021/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:45,493 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp3pitf1op/converter".
# 210419-11:09:45,497 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED021 -s n -v n /fMRI/FED021/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:46,480 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:46.480520:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:46,482 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:46.480520:Found 274 DICOM file(s)
# 210419-11:09:46,482 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:46.480520:Convert 274 DICOM as /fMRI/FED021/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141211095930_10 (68x72x36x274)
# 210419-11:09:54,627 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:54.627509:Conversion required 9.110617 seconds (8.704238 for core code).
# 210419-11:09:54,661 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED022 /fMRI/FED022/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:54,664 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmphx7t1ml5/converter".
# 210419-11:09:54,668 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED022 -s n -v n /fMRI/FED022/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:09:55,710 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:55.709859:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:09:55,711 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:55.709859:Found 269 DICOM file(s)
# 210419-11:09:55,712 nipype.interface INFO:
# 	 stdout 2021-04-19T11:09:55.709859:Convert 269 DICOM as /fMRI/FED022/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141211155503_10 (68x72x36x269)
# 210419-11:10:02,553 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:02.553195:Conversion required 7.862436 seconds (7.342988 for core code).
# 210419-11:10:02,587 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED023 /fMRI/FED023/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:02,590 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpytxyjfpd/converter".
# 210419-11:10:02,594 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED023 -s n -v n /fMRI/FED023/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:03,553 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:03.553766:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:03,555 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:03.553766:Found 269 DICOM file(s)
# 210419-11:10:03,556 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:03.553766:Convert 269 DICOM as /fMRI/FED023/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141216144604_10 (68x72x36x269)
# 210419-11:10:11,84 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:11.084393:Conversion required 8.468429 seconds (8.077924 for core code).
# 210419-11:10:11,118 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED024 /fMRI/FED024/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:11,120 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpealled7w/converter".
# 210419-11:10:11,125 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED024 -s n -v n /fMRI/FED024/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:12,58 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:12.058495:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:12,60 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:12.058495:Found 268 DICOM file(s)
# 210419-11:10:12,60 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:12.058495:Convert 268 DICOM as /fMRI/FED024/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150204145018_10 (68x72x36x268)
# 210419-11:10:19,63 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:19.063208:Conversion required 7.917742 seconds (7.548968 for core code).
# 210419-11:10:19,96 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED025 /fMRI/FED025/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:19,99 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp7gk6y22s/converter".
# 210419-11:10:19,104 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED025 -s n -v n /fMRI/FED025/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:20,32 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:20.032074:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:20,33 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:20.032074:Found 263 DICOM file(s)
# 210419-11:10:20,34 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:20.032074:Convert 263 DICOM as /fMRI/FED025/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150206123507_10 (68x72x36x263)
# 210419-11:10:27,423 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:27.423581:Conversion required 8.300080 seconds (7.918149 for core code).
# 210419-11:10:27,456 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED026 /fMRI/FED026/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:27,459 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp01wylyh2/converter".
# 210419-11:10:27,463 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED026 -s n -v n /fMRI/FED026/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:28,396 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:28.396517:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:28,398 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:28.396517:Found 273 DICOM file(s)
# 210419-11:10:28,398 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:28.396517:Convert 273 DICOM as /fMRI/FED026/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150211171144_10 (72x68x36x273)
# 210419-11:10:36,200 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:36.200075:Conversion required 8.717012 seconds (8.334235 for core code).
# 210419-11:10:36,233 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED027 /fMRI/FED027/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:10:36,236 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpwwclq1ak/converter".
# 210419-11:10:36,240 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED027 -s n -v n /fMRI/FED027/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:10:37,186 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:37.186684:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:37,188 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:37.186684:Found 271 DICOM file(s)
# 210419-11:10:37,189 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:37.186684:Convert 271 DICOM as /fMRI/FED027/WIP840_36SLICE_1800TR_FS_0014_WIP840_36slice_1800TR_fs_20150218162601_14 (72x68x36x271)
# 210419-11:10:44,874 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:44.874304:Conversion required 8.611537 seconds (8.231014 for core code).
# 210419-11:10:44,908 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED028 /fMRI/FED028/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:44,910 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpobtco_hd/converter".
# 210419-11:10:44,915 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED028 -s n -v n /fMRI/FED028/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:45,846 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:45.846683:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:45,848 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:45.846683:Found 273 DICOM file(s)
# 210419-11:10:45,849 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:45.846683:Convert 273 DICOM as /fMRI/FED028/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150219142148_10 (72x68x36x273)
# 210419-11:10:53,676 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:53.676290:Conversion required 8.739859 seconds (8.361768 for core code).
# 210419-11:10:53,710 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED029 /fMRI/FED029/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:53,712 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpmqploztr/converter".
# 210419-11:10:53,717 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED029 -s n -v n /fMRI/FED029/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:10:54,848 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:54.848041:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:10:54,849 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:54.848041:Found 302 DICOM file(s)
# 210419-11:10:54,850 nipype.interface INFO:
# 	 stdout 2021-04-19T11:10:54.848041:Convert 302 DICOM as /fMRI/FED029/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150226091949_10 (72x68x36x302)
# 210419-11:11:02,729 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:02.729454:Conversion required 8.985036 seconds (8.533016 for core code).
# 210419-11:11:02,763 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED030 /fMRI/FED030/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:11:02,765 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpnxd7x0qs/converter".
# 210419-11:11:02,770 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED030 -s n -v n /fMRI/FED030/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:11:05,157 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:05.157774:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:05,159 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:05.157774:Found 266 DICOM file(s)
# 210419-11:11:05,160 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:05.157774:Convert 266 DICOM as /fMRI/FED030/WIP840_36SLICE_1800TR_FS_0014_WIP840_36slice_1800TR_fs_20150226154844_14 (72x68x36x266)
# 210419-11:11:12,620 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:12.620823:Conversion required 9.828422 seconds (8.068478 for core code).
# 210419-11:11:12,654 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED031 /fMRI/FED031/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:12,657 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpeiu_egcq/converter".
# 210419-11:11:12,661 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED031 -s n -v n /fMRI/FED031/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:13,655 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:13.655527:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:13,657 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:13.655527:Found 274 DICOM file(s)
# 210419-11:11:13,657 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:13.655527:Convert 274 DICOM as /fMRI/FED031/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150310152650_10 (72x68x36x274)
# 210419-11:11:21,242 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:21.242738:Conversion required 8.562681 seconds (8.165003 for core code).
# 210419-11:11:21,276 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED032 /fMRI/FED032/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:21,279 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpyhwu3o14/converter".
# 210419-11:11:21,284 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED032 -s n -v n /fMRI/FED032/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:22,211 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:22.211549:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:22,213 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:22.211549:Found 265 DICOM file(s)
# 210419-11:11:22,216 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:22.211549:Convert 265 DICOM as /fMRI/FED032/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150313125246_10 (72x68x36x265)
# 210419-11:11:29,716 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:29.716674:Conversion required 8.408217 seconds (8.045830 for core code).
# 210419-11:11:29,751 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED033 /fMRI/FED033/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:29,752 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpepxv0bgz/converter".
# 210419-11:11:29,757 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED033 -s n -v n /fMRI/FED033/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:30,704 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:30.704444:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:30,706 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:30.704444:Found 268 DICOM file(s)
# 210419-11:11:30,706 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:30.704444:Convert 268 DICOM as /fMRI/FED033/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150326151309_10 (68x72x36x268)
# 210419-11:11:37,844 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:37.844481:Conversion required 8.066409 seconds (7.678919 for core code).
# 210419-11:11:37,877 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED034 /fMRI/FED034/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:37,879 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpskv420ww/converter".
# 210419-11:11:37,885 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED034 -s n -v n /fMRI/FED034/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:38,786 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:38.786545:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:38,788 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:38.786545:Found 271 DICOM file(s)
# 210419-11:11:38,789 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:38.786545:Convert 271 DICOM as /fMRI/FED034/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150909125805_10 (72x68x36x271)
# 210419-11:11:46,631 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:46.631372:Conversion required 8.727381 seconds (8.355245 for core code).
# 210419-11:11:46,664 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED035 /fMRI/FED035/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:46,667 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpst3ivgjm/converter".
# 210419-11:11:46,672 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED035 -s n -v n /fMRI/FED035/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:47,656 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:47.656166:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:47,657 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:47.656166:Found 263 DICOM file(s)
# 210419-11:11:47,658 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:47.656166:Convert 263 DICOM as /fMRI/FED035/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150917120306_10 (72x68x36x263)
# 210419-11:11:55,120 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:55.120611:Conversion required 8.427564 seconds (7.964828 for core code).
# 210419-11:11:55,147 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED036 /fMRI/FED036/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:55,150 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp5b7ujpvr/converter".
# 210419-11:11:55,153 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED036 -s n -v n /fMRI/FED036/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:11:56,67 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:56.067333:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:11:56,69 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:56.067333:Found 259 DICOM file(s)
# 210419-11:11:56,70 nipype.interface INFO:
# 	 stdout 2021-04-19T11:11:56.067333:Convert 259 DICOM as /fMRI/FED036/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150924172133_10 (72x68x36x259)
# 210419-11:12:03,266 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:03.266767:Conversion required 8.086871 seconds (7.716705 for core code).
# 210419-11:12:03,301 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED037 /fMRI/FED037/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:03,303 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp0hxs7m93/converter".
# 210419-11:12:03,308 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED037 -s n -v n /fMRI/FED037/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:06,715 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:06.715031:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:06,716 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:06.715031:Found 262 DICOM file(s)
# 210419-11:12:06,717 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:06.715031:Convert 262 DICOM as /fMRI/FED037/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20150929162030_10 (72x68x36x262)
# 210419-11:12:13,869 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:13.869137:Conversion required 10.540704 seconds (7.717056 for core code).
# 210419-11:12:13,903 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED038 /fMRI/FED038/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:13,905 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpewvmo033/converter".
# 210419-11:12:13,910 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED038 -s n -v n /fMRI/FED038/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:14,804 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:14.803915:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:14,805 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:14.803915:Found 263 DICOM file(s)
# 210419-11:12:14,806 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:14.803915:Convert 263 DICOM as /fMRI/FED038/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151001125857_10 (72x68x36x263)
# 210419-11:12:22,120 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:22.120808:Conversion required 8.188378 seconds (7.816028 for core code).
# 210419-11:12:22,155 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED039 /fMRI/FED039/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:22,157 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpzz4432zh/converter".
# 210419-11:12:22,162 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED039 -s n -v n /fMRI/FED039/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:23,60 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:23.060052:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:23,61 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:23.060052:Found 266 DICOM file(s)
# 210419-11:12:23,62 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:23.060052:Convert 266 DICOM as /fMRI/FED039/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151001173950_10 (72x68x36x266)
# 210419-11:12:30,708 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:30.707996:Conversion required 8.522965 seconds (8.158581 for core code).
# 210419-11:12:30,742 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED040 /fMRI/FED040/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:30,743 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpu8o73bze/converter".
# 210419-11:12:30,749 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED040 -s n -v n /fMRI/FED040/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:31,664 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:31.663874:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:31,665 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:31.663874:Found 266 DICOM file(s)
# 210419-11:12:31,666 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:31.663874:Convert 266 DICOM as /fMRI/FED040/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151009111760_10 (72x68x36x266)
# 210419-11:12:38,845 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:38.845268:Conversion required 8.076030 seconds (7.712275 for core code).
# 210419-11:12:38,879 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED041 /fMRI/FED041/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:38,881 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpdgvsfhcs/converter".
# 210419-11:12:38,886 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED041 -s n -v n /fMRI/FED041/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:39,811 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:39.811848:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:39,813 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:39.811848:Found 264 DICOM file(s)
# 210419-11:12:39,814 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:39.811848:Convert 264 DICOM as /fMRI/FED041/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151009164129_10 (72x68x36x264)
# 210419-11:12:47,14 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:47.014020:Conversion required 8.109007 seconds (7.721773 for core code).
# 210419-11:12:47,47 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED042 /fMRI/FED042/WIP840_36SLICE_1800TR_FS_0011
# 210419-11:12:47,49 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp5nxiyzuz/converter".
# 210419-11:12:47,55 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED042 -s n -v n /fMRI/FED042/WIP840_36SLICE_1800TR_FS_0011
# 210419-11:12:47,930 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:47.930730:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:47,932 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:47.930730:Found 255 DICOM file(s)
# 210419-11:12:47,933 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:47.930730:Convert 255 DICOM as /fMRI/FED042/WIP840_36SLICE_1800TR_FS_0011_WIP840_36slice_1800TR_fs_20151013110112_11 (72x68x36x255)
# 210419-11:12:54,762 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:54.762132:Conversion required 7.685813 seconds (7.330254 for core code).
# 210419-11:12:54,796 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED043 /fMRI/FED043/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:54,797 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpz2isbh8n/converter".
# 210419-11:12:54,802 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED043 -s n -v n /fMRI/FED043/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:12:55,694 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:55.694068:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:12:55,695 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:55.694068:Found 259 DICOM file(s)
# 210419-11:12:55,696 nipype.interface INFO:
# 	 stdout 2021-04-19T11:12:55.694068:Convert 259 DICOM as /fMRI/FED043/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151015122011_10 (72x68x36x259)
# 210419-11:13:02,768 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:02.768487:Conversion required 7.945240 seconds (7.588630 for core code).
# 210419-11:13:02,802 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED044 /fMRI/FED044/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:02,804 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmprv0vjwsn/converter".
# 210419-11:13:02,808 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED044 -s n -v n /fMRI/FED044/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:03,737 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:03.737335:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:13:03,739 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:03.737335:Found 271 DICOM file(s)
# 210419-11:13:03,740 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:03.737335:Convert 271 DICOM as /fMRI/FED044/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151029121235_10 (72x68x36x271)
# 210419-11:13:10,946 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:10.946082:Conversion required 8.115602 seconds (7.741516 for core code).
# 210419-11:13:10,979 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED045 /fMRI/FED045/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:10,982 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp8vdggj7l/converter".
# 210419-11:13:10,986 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED045 -s n -v n /fMRI/FED045/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:11,875 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:11.875340:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:13:11,877 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:11.875340:Found 268 DICOM file(s)
# 210419-11:13:11,877 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:11.875340:Convert 268 DICOM as /fMRI/FED045/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151105173027_10 (72x68x36x268)
# 210419-11:13:19,618 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:19.618694:Conversion required 8.610081 seconds (8.243024 for core code).
# 210419-11:13:19,651 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED046 /fMRI/FED046/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:19,654 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp3qi8spcx/converter".
# 210419-11:13:19,658 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED046 -s n -v n /fMRI/FED046/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:21,570 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:21.569914:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:13:21,571 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:21.569914:Found 550 DICOM file(s)
# 210419-11:13:21,572 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:21.569914:275 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 210419-11:13:21,573 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:21.569914:Convert 275 DICOM as /fMRI/FED046/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151106125904_10 (72x68x36x275)
# 210419-11:13:29,682 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:29.682924:Conversion required 10.002023 seconds (9.114653 for core code).
# 210419-11:13:29,715 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED047 /fMRI/FED047/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:13:29,717 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp9cikoidg/converter".
# 210419-11:13:29,720 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED047 -s n -v n /fMRI/FED047/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:13:30,653 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:30.653838:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:13:30,655 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:30.653838:Found 268 DICOM file(s)
# 210419-11:13:30,656 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:30.653838:Convert 268 DICOM as /fMRI/FED047/WIP840_36SLICE_1800TR_FS_0014_WIP840_36slice_1800TR_fs_20151116144126_14 (72x68x36x268)
# 210419-11:13:38,26 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:38.026734:Conversion required 8.284505 seconds (7.912567 for core code).
# 210419-11:13:38,60 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED048 /fMRI/FED048/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:38,61 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmplzxxawo9/converter".
# 210419-11:13:38,65 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED048 -s n -v n /fMRI/FED048/WIP840_36SLICE_1800TR_FS_0010
# 210419-11:13:39,361 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:39.361727:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:13:39,363 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:39.361727:Found 379 DICOM file(s)
# 210419-11:13:39,364 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:39.361727:Convert 379 DICOM as /fMRI/FED048/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20151118152060_10 (72x68x36x379)
# 210419-11:13:50,376 nipype.interface INFO:
# 	 stdout 2021-04-19T11:13:50.376016:Conversion required 12.290217 seconds (11.752182 for core code).
# 210419-11:13:50,409 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED049 /fMRI/FED049/WIP840_36SLICE_1800TR_FS_0014
# 210419-11:13:50,411 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp06uqomrk/converter".
# 210419-11:13:50,415 nipype.workflow INFO:
# ...
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED061 -s n -v n /fMRI/FED061/GRE_FIELD_MAPPING_0007
# 210419-11:20:56,993 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:56.993461:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:56,994 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:56.993461:Found 36 DICOM file(s)
# 210419-11:20:56,995 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:56.993461:Convert 36 DICOM as /fMRI/FED061/GRE_FIELD_MAPPING_0007_gre_field_mapping_20160301111011_7_e2_ph (64x64x36x1)
# 210419-11:20:57,13 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.013636:Conversion required 0.080799 seconds (0.051128 for core code).
# 210419-11:20:57,48 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED062 /fMRI/FED062/GRE_FIELD_MAPPING_0006
# 210419-11:20:57,50 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpvealf98c/converter".
# 210419-11:20:57,54 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED062 -s n -v n /fMRI/FED062/GRE_FIELD_MAPPING_0006
# 210419-11:20:57,187 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.187205:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:57,188 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.187205:Found 72 DICOM file(s)
# 210419-11:20:57,189 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.187205:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 210419-11:20:57,189 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.187205:Convert 36 DICOM as /fMRI/FED062/GRE_FIELD_MAPPING_0006_gre_field_mapping_20160301164049_6_e1 (64x64x36x1)
# 210419-11:20:57,218 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.218869:Convert 36 DICOM as /fMRI/FED062/GRE_FIELD_MAPPING_0006_gre_field_mapping_20160301164049_6_e2 (64x64x36x1)
# 210419-11:20:57,244 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.244859:Conversion required 0.171788 seconds (0.110471 for core code).
# 210419-11:20:57,280 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED062 /fMRI/FED062/GRE_FIELD_MAPPING_0007
# 210419-11:20:57,282 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpcs_auq0v/converter".
# 210419-11:20:57,286 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED062 -s n -v n /fMRI/FED062/GRE_FIELD_MAPPING_0007
# 210419-11:20:57,363 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.363588:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:57,364 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.363588:Found 36 DICOM file(s)
# 210419-11:20:57,365 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.363588:Convert 36 DICOM as /fMRI/FED062/GRE_FIELD_MAPPING_0007_gre_field_mapping_20160301164049_7_e2_ph (64x64x36x1)
# 210419-11:20:57,383 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.383394:Conversion required 0.081448 seconds (0.050898 for core code).
# 210419-11:20:57,416 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED063 /fMRI/FED063/GRE_FIELD_MAPPING_0009
# 210419-11:20:57,418 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpgsjkjs5x/converter".
# 210419-11:20:57,422 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED063 -s n -v n /fMRI/FED063/GRE_FIELD_MAPPING_0009
# 210419-11:20:57,554 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.554323:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:57,559 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.554323:Found 72 DICOM file(s)
# 210419-11:20:57,561 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.554323:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 210419-11:20:57,562 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.554323:Convert 36 DICOM as /fMRI/FED063/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160308162043_9_e1 (64x64x36x1)
# 210419-11:20:57,584 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.584332:Convert 36 DICOM as /fMRI/FED063/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160308162043_9_e2 (64x64x36x1)
# 210419-11:20:57,609 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.609935:Conversion required 0.169472 seconds (0.109971 for core code).
# 210419-11:20:57,646 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED063 /fMRI/FED063/GRE_FIELD_MAPPING_0010
# 210419-11:20:57,648 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp4u8u8haw/converter".
# 210419-11:20:57,651 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED063 -s n -v n /fMRI/FED063/GRE_FIELD_MAPPING_0010
# 210419-11:20:57,727 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.727226:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:57,728 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.727226:Found 36 DICOM file(s)
# 210419-11:20:57,729 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.727226:Convert 36 DICOM as /fMRI/FED063/GRE_FIELD_MAPPING_0010_gre_field_mapping_20160308162043_10_e2_ph (64x64x36x1)
# 210419-11:20:57,747 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.747447:Conversion required 0.080144 seconds (0.050619 for core code).
# 210419-11:20:57,782 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED064 /fMRI/FED064/GRE_FIELD_MAPPING_0009
# 210419-11:20:57,784 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpb98btj6x/converter".
# 210419-11:20:57,787 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED064 -s n -v n /fMRI/FED064/GRE_FIELD_MAPPING_0009
# 210419-11:20:57,921 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.921564:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:57,925 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.921564:Found 72 DICOM file(s)
# 210419-11:20:57,926 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.921564:Slices not stacked: echo varies (TE 7.38, 4.92; echo 2, 1). Use 'merge 2D slices' option to force stacking
# 210419-11:20:57,927 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.921564:Convert 36 DICOM as /fMRI/FED064/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160309173936_9_e2 (64x64x36x1)
# 210419-11:20:57,954 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.954000:Convert 36 DICOM as /fMRI/FED064/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160309173936_9_e1 (64x64x36x1)
# 210419-11:20:57,982 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:57.982085:Conversion required 0.178028 seconds (0.118647 for core code).
# 210419-11:20:58,17 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED064 /fMRI/FED064/GRE_FIELD_MAPPING_0010
# 210419-11:20:58,19 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp70606o5n/converter".
# 210419-11:20:58,23 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED064 -s n -v n /fMRI/FED064/GRE_FIELD_MAPPING_0010
# 210419-11:20:58,99 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.099020:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:58,100 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.099020:Found 36 DICOM file(s)
# 210419-11:20:58,101 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.099020:Convert 36 DICOM as /fMRI/FED064/GRE_FIELD_MAPPING_0010_gre_field_mapping_20160309173936_10_e2_ph (64x64x36x1)
# 210419-11:20:58,119 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.119150:Conversion required 0.079644 seconds (0.050446 for core code).
# 210419-11:20:58,152 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED065 /fMRI/FED065/GRE_FIELD_MAPPING_0016
# 210419-11:20:58,154 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpoo38syzy/converter".
# 210419-11:20:58,158 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED065 -s n -v n /fMRI/FED065/GRE_FIELD_MAPPING_0016
# 210419-11:20:58,289 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.289861:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:58,291 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.289861:Found 72 DICOM file(s)
# 210419-11:20:58,294 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.289861:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 210419-11:20:58,296 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.289861:Convert 36 DICOM as /fMRI/FED065/GRE_FIELD_MAPPING_0016_gre_field_mapping_20160310090712_16_e1 (64x64x36x1)
# 210419-11:20:58,321 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.321665:Convert 36 DICOM as /fMRI/FED065/GRE_FIELD_MAPPING_0016_gre_field_mapping_20160310090712_16_e2 (64x64x36x1)
# 210419-11:20:58,347 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.347948:Conversion required 0.171124 seconds (0.111680 for core code).
# 210419-11:20:58,383 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED065 /fMRI/FED065/GRE_FIELD_MAPPING_0017
# 210419-11:20:58,384 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpxqczxrw6/converter".
# 210419-11:20:58,388 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED065 -s n -v n /fMRI/FED065/GRE_FIELD_MAPPING_0017
# 210419-11:20:58,468 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.468100:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:58,469 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.468100:Found 36 DICOM file(s)
# 210419-11:20:58,469 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.468100:Convert 36 DICOM as /fMRI/FED065/GRE_FIELD_MAPPING_0017_gre_field_mapping_20160310090712_17_e2_ph (64x64x36x1)
# 210419-11:20:58,486 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.486641:Conversion required 0.081433 seconds (0.051998 for core code).
# 210419-11:20:58,520 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED066 /fMRI/FED066/GRE_FIELD_MAPPING_0010
# 210419-11:20:58,522 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpv5ssm014/converter".
# 210419-11:20:58,527 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED066 -s n -v n /fMRI/FED066/GRE_FIELD_MAPPING_0010
# 210419-11:20:58,659 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.659088:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:58,661 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.659088:Found 72 DICOM file(s)
# 210419-11:20:58,663 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.659088:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 210419-11:20:58,665 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.659088:Convert 36 DICOM as /fMRI/FED066/GRE_FIELD_MAPPING_0010_gre_field_mapping_20160310171152_10_e1 (64x64x36x1)
# 210419-11:20:58,687 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.687895:Convert 36 DICOM as /fMRI/FED066/GRE_FIELD_MAPPING_0010_gre_field_mapping_20160310171152_10_e2 (64x64x36x1)
# 210419-11:20:58,714 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.714567:Conversion required 0.170842 seconds (0.113634 for core code).
# 210419-11:20:58,745 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED066 /fMRI/FED066/GRE_FIELD_MAPPING_0011
# 210419-11:20:58,748 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmprgsdd7gg/converter".
# 210419-11:20:58,752 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED066 -s n -v n /fMRI/FED066/GRE_FIELD_MAPPING_0011
# 210419-11:20:58,826 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.826679:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:58,828 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.826679:Found 36 DICOM file(s)
# 210419-11:20:58,833 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.826679:Convert 36 DICOM as /fMRI/FED066/GRE_FIELD_MAPPING_0011_gre_field_mapping_20160310171152_11_e2_ph (64x64x36x1)
# 210419-11:20:58,848 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:58.848083:Conversion required 0.077184 seconds (0.046583 for core code).
# 210419-11:20:58,878 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED068 /fMRI/FED068/GRE_FIELD_MAPPING_0009
# 210419-11:20:58,880 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmpjlra_bnl/converter".
# 210419-11:20:58,884 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED068 -s n -v n /fMRI/FED068/GRE_FIELD_MAPPING_0009
# 210419-11:20:59,22 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.022100:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:59,23 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.022100:Found 72 DICOM file(s)
# 210419-11:20:59,26 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.022100:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 210419-11:20:59,27 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.022100:Convert 36 DICOM as /fMRI/FED068/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160331140317_9_e1 (64x64x36x1)
# 210419-11:20:59,51 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.051503:Convert 36 DICOM as /fMRI/FED068/GRE_FIELD_MAPPING_0009_gre_field_mapping_20160331140317_9_e2 (64x64x36x1)
# 210419-11:20:59,77 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.077872:Conversion required 0.175129 seconds (0.115587 for core code).
# 210419-11:20:59,106 nipype.workflow INFO:
# 	 [Node] Finished "converter".
# /fMRI/FED068 /fMRI/FED068/GRE_FIELD_MAPPING_0010
# 210419-11:20:59,107 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp91ujmnj0/converter".
# 210419-11:20:59,115 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED068 -s n -v n /fMRI/FED068/GRE_FIELD_MAPPING_0010
# 210419-11:20:59,189 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.189867:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-11:20:59,191 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.189867:Found 36 DICOM file(s)
# 210419-11:20:59,193 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.189867:Convert 36 DICOM as /fMRI/FED068/GRE_FIELD_MAPPING_0010_gre_field_mapping_20160331140317_10_e2_ph (64x64x36x1)
# 210419-11:20:59,215 nipype.interface INFO:
# 	 stdout 2021-04-19T11:20:59.215796:Conversion required 0.081835 seconds (0.046601 for core code).
# 210419-11:20:59,248 nipype.workflow INFO:
# 	 [Node] Finished "converter".

# %% [markdown]
# # QC

# %%
# for single subject post-correction/re-calculation
# adapt index in lists to specify which files to convert

for i, j in zip(subdirs, funcdirs):
    # insert subject ID into regex pattern
    if re.match(r'.*(FED015).*', i) and re.match(r'.*(FED015).*', j):
        print(i, j)
        # create DICOM-to-NIFTI converter node
        converter = Node(Dcm2niix(), name='converter')
        converter.inputs.compress = 'y'  # do compress -> saves space^^ GUNZIP for SPM options etc.
        converter.inputs.source_dir = j
        converter.inputs.output_dir = i
        converter.run()
# Out:
# /fMRI/FED015 /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010
# 210419-12:59:20,91 nipype.workflow INFO:
# 	 [Node] Setting-up "converter" in "/tmp/tmp3p6f_a_q/converter".
# 210419-12:59:20,97 nipype.workflow INFO:
# 	 [Node] Running "converter" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -o /fMRI/FED015 -s n -v n /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010
# 210419-12:59:21,126 nipype.interface INFO:
# 	 stdout 2021-04-19T12:59:21.125901:Chris Rorden's dcm2niiX version v1.0.20201102  (JP2:OpenJPEG) GCC6.3.0 x86-64 (64-bit Linux)
# 210419-12:59:21,127 nipype.interface INFO:
# 	 stdout 2021-04-19T12:59:21.125901:Found 273 DICOM file(s)
# 210419-12:59:21,128 nipype.interface INFO:
# 	 stdout 2021-04-19T12:59:21.125901:Convert 273 DICOM as /fMRI/FED015/WIP840_36SLICE_1800TR_FS_0010_WIP840_36slice_1800TR_fs_20141202145526_10 (72x68x36x273)
# 210419-12:59:29,379 nipype.interface INFO:
# 	 stdout 2021-04-19T12:59:29.379948:Conversion required 9.258614 seconds (8.843885 for core code).
# 210419-12:59:29,415 nipype.workflow INFO:
# 	 [Node] Finished "converter".

# %% [markdown]
# Script ends here
